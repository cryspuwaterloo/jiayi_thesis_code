# %% [markdown]
# ## Final-version of Accuracy Experiments

# %%
#@title Setup for COLAB Environment ONLY

## mount google drive
from google.colab import drive
drive.mount('/content/drive')

## load data to local
# from google.colab import files"
# dataset_files = files.upload()

## install and upgrate necessary packages
import sys
# !{sys.executable} -m pip install drive/MyDrive/pyds &> /dev/null
# !{sys.executable} -m pip install --upgrade imblearn &> /dev/null
# !{sys.executable} -m pip install --upgrade matplotlib &> /dev/null
# !{sys.executable} -m pip install --upgrade filterpy

## add mature code to PATH
sys.path.append('/content/drive/MyDrive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Collecting filterpy
#   Downloading filterpy-1.4.5.zip (177 kB)
#      |████████████████████████████████| 177 kB 10.0 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from filterpy) (1.21.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from filterpy) (1.4.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from filterpy) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (1.4.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (7.1.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (4.31.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (3.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib->filterpy) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib->filterpy) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib->filterpy) (1.15.0)
# Building wheels for collected packages: filterpy
#   Building wheel for filterpy (setup.py) ... done
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110474 sha256=bdef1d32573826350d5bbc86ef3148eaa487591c3e1dcd98a1fe7d73f28f4924
#   Stored in directory: /root/.cache/pip/wheels/ce/e0/ee/a2b3c5caab3418c1ccd8c4de573d4cbe13315d7e8b0a55fbc2
# Successfully built filterpy
# Installing collected packages: filterpy
# Successfully installed filterpy-1.4.5

# %%
## Import essential packages for IdAuth
# %matplotlib inline

import os
import json
from collections import Counter
import numpy as np
import pandas as pd
import imblearn.over_sampling

import tensorflow as tf

from idauth.datasets.hmog import HMOGProvider
from idauth.authenticators.touch import TouchAuth
from idauth.authenticators.gait import DeepGaitExtractionModel, DeepGaitAuthenticator, DeepGaitModel
from idauth.utils.sliding_window import SlidingWindow
from idauth.utils.helpers import balance_dataset, sparse_label_converter
from idauth.utils.metrics import eer
from idauth.simulator.imposter import ImposterProvider
from idauth.simulator.timeline import Timeline
from idauth.storage import BiometricStorage, SCHEME_TIME_SEQ_10

from sklearn.metrics import roc_curve, roc_auc_score, precision_score, recall_score, f1_score,auc,roc_curve, accuracy_score
import matplotlib.pyplot as plt

import logging

# %% [markdown]
# ## Notebook Global Configuration
#
# You might want to change some configurations for the notebook. Basically, you can determine the logging information to be displayed in the notebook.

# %%
## GLOBAL CONFIGURATION
LOG_OUTPUT_PATH = ""
LOG_FILENAME = 'c05.log'
logging.basicConfig(format='%(asctime)-15s %(message)s',
                    filename=os.path.join(LOG_OUTPUT_PATH, LOG_FILENAME),
                    level=logging.DEBUG)
logger = logging.getLogger('simulator')

SIMULATION_RESULT_DIR = "simulation"
GAME_DETAILS_ENABELD = False # to show training and testing sessions
VISUABLIZATION_ENABLED = False # show a timeline figure to visualize decisions

# %% [markdown]
# ## Helper Functions (For HMOG)
#
# ```simple_merge_acc_gyro```: merge accelerometer and gyroscope data in a non-temporal manner. ```step``` is the downsamplingr rate. E.g., step = 2, original frequency = 100Hz, then new frequency = 50Hz.

# %%
def simple_merge_acc_gyro(acc_df, gyro_df, step=2):
    size = min(acc_df.shape[0], gyro_df.shape[0])
    acc = acc_df.iloc[:size][['x', 'y', 'z']].to_numpy()
    gyro = gyro_df.iloc[:size][['x', 'y', 'z']].to_numpy()
    merged = np.concatenate((acc, gyro), axis=1)
    return merged[::step]

def touch_df_to_features(df):
    raw = df[['swipe_id', 'time', 'x', 'y', 'pressure', 'area', 'orientation',
              'activity']].values
    features = TouchAuth().extract_features(raw) # to be staticmethod
    return features

def get_touch_features_by_user_session(provider: HMOGProvider,
                                       user_session_settings):
    """
    Obtain a dictionary like:"
      result['<user_name>'][<session_id>]: feature list
    """
    result = {}
    for user, sessions in user_session_settings.items():
        result[user] = {}
        for sess in sessions:
            features = touch_df_to_features(provider.data[user][sess]['touch'])
            result[user][sess] = features
    return result

def get_gait_features_by_user_session(provider: HMOGProvider,
                                      user_session_settings):
    result = {}
    for user, sessions in user_session_settings.items():
        result[user] = {}
        for sess in sessions:
            tmp_data = simple_merge_acc_gyro(hmog.data[user][sess]['acc'],
                                         hmog.data[user][sess]['gyro'])
            features = DeepGaitAuthenticator().extract_features(tmp_data)
            result[user][sess] = features
    return result

def get_gait_features(provider, user, session):
    tmp_data = simple_merge_acc_gyro(provider.data[user][session]['acc'],
                                     provider.data[user][session]['gyro'])
    features = DeepGaitAuthenticator().extract_features(tmp_data)
    return features

def get_touch_features(provider, user, session):
    features = touch_df_to_features(provider.data[user][session]['touch'])
    return features

def get_features(provider, auth_type, user, session):
    if auth_type == 'gait':
        return get_gait_features(provider, user, session)
    elif auth_type == 'touch':
        return get_touch_features(provider, user, session)

###
## Timeline operations
###

def get_events_for_user_session(user, session, new_basetime):
    logger.info("generate events for: " + str(user) + ", " + str(session))
    base_time = int(min(hmog.data[user][session]['acc'].iloc[0]['time'],
                         hmog.data[user][session]['gyro'].iloc[0]['time']))
    # e.g. new_basetime starts from 0, base_time = 1000, t0 = 1003
    # offset = - base_time + new_basetime
    # offset = - 1000 + 0
    # new_timestamp = t0 + offset = 1003 - 1000 = 3
    offset = new_basetime - base_time
    acc_events = get_acc_events_for_user_session(user, session, offset)
    gyro_events = get_gyro_events_for_user_session(user, session, offset)
    touch_events = get_touch_events_for_user_session(user, session, offset)
    merged_events = sorted(acc_events + gyro_events + touch_events)
    return merged_events

def get_events_for_user_session_with_limit(user, session, new_basetime, limit):
    logger.info("generate events for: " + str(user) + ", " + str(session))
    base_time = int(min(hmog.data[user][session]['acc'].iloc[0]['time'],
                        hmog.data[user][session]['gyro'].iloc[0]['time']))
    end_time = base_time + limit
    # e.g. new_basetime starts from 0, base_time = 1000, t0 = 1003
    # offset = - base_time + new_basetime
    # offset = - 1000 + 0
    # new_timestamp = t0 + offset = 1003 - 1000 = 3
    offset = new_basetime - base_time
    acc_events = get_acc_events_for_user_session(user, session, offset, end_time)
    gyro_events = get_gyro_events_for_user_session(user, session, offset, end_time)
    touch_events = get_touch_events_for_user_session(user, session, offset, end_time)
    merged_events = sorted(acc_events + gyro_events + touch_events)
    return merged_events


def get_acc_events_for_user_session(user, session, offset, end_time=None, start_time=None):
    df = hmog.data[user][session]['acc'].iloc[::2]
    result = []
    for index, row in df.iterrows():
        if start_time is not None and int(row['time']) < start_time:
            continue
        if end_time is not None and int(row['time']) > end_time:
            break
        result.append((int(row['time']) + offset, 'acc',
                       (row['x'], row['y'], row['z'])))
    return result

def get_gyro_events_for_user_session(user, session, offset, end_time=None, start_time=None):
    df = hmog.data[user][session]['gyro'].iloc[::2]
    result = []
    for index, row in df.iterrows():
        if start_time is not None and int(row['time']) < start_time:
            continue
        if end_time is not None and int(row['time']) > end_time:
            break
        result.append((int(row['time']) + offset, 'gyro',
                       (row['x'], row['y'], row['z'])))
    return result

def get_touch_events_for_user_session(user, session, offset, end_time=None, start_time=None):
    df = hmog.data[user][session]['touch']
    result = []
    for index, row in df.iterrows():
        if start_time is not None and int(row['time']) < start_time:
            continue
        if end_time is not None and int(row['time']) > end_time:
            break
        result.append((int(row['time']) + offset, 'touch',
                       (row['swipe_id'], row['time'] + offset, row['x'], row['y'],
                        row['pressure'], row['area'], row['orientation'], row['activity'])))
    return result

# %% [markdown]
# ## Scoring functions

# %%
## Kalman Filter based fusion

from filterpy.kalman import KalmanFilter


class KFScorer:

    def add(self, z):
        self.kf.predict()
        # print(z)
        if len(z) == 0:
            self.kf.update(self.last_z)
        else:
            self.kf.update(z)

        self.last_z = z
        return self.kf.x

    def init(self, x0):
        self.kf.x = x0

    def setR(self, R):
        self.kf.R = R

    def __init__(self, n_classes, n_auth, discount, Q=0.25):
        self.kf = KalmanFilter(dim_x=n_classes, dim_z=n_auth)
        self.kf.Q = np.eye(n_classes) * Q
        self.kf.H = np.ones([n_auth, n_classes])
        self.kf.F = np.eye(n_classes) * discount
        self.last_z = np.zeros(n_auth)

# %%
## DS FUNC
import pyds as ds
import functools

TIME_INTERVAL = 100000

def ds_fusion_2(scores, uncertainties):
    mass_groups = [ds.MassFunction({'a': s * (1 - u), 'b': (1 - s) * (1 - u),
                                    'ab': u})
                   for s, u in zip(scores, uncertainties)]
    combined_mass = functools.reduce(lambda a, b: a & b, mass_groups)
    return combined_mass['a']


# =======================================
#  Scoring Strategy
# =======================================

def gait_scoring(buffer, t0):
    raw = [data for auth_type, data, t in buffer
           if t == t0 and auth_type == 'gait']
    return raw

def touch_scoring(buffer, t0):
    raw = [data for auth_type, data, t in buffer
           if t == t0 and auth_type == 'touch']
    return raw

def plain_average_scoring(buffer, t0, time_interval=TIME_INTERVAL):
    target_index = len(buffer) - 1
    for i in range(len(buffer) - 1, 0, -1):
        if np.abs(t0 - buffer[i][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    # print(sel_buffer)
    auth_types, results, times = zip(*sel_buffer)
    return [np.array(np.average(results, axis=0))]


def weighted_average_eer_scoring(buffer, t0, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer) - 1, 0, -1):
        if np.abs(t0 - buffer[i][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    # print(sel_buffer)

    weighted_scores = [[r * max(0, 1 - 2*strategy[auth_type]['eer'][i])
                        for i, r in enumerate(result)]
                        for auth_type, result, time in sel_buffer]

    return [np.array(np.average(weighted_scores, axis=0))]


def weighted_average_auc_scoring(buffer, t0, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer) - 1, 0, -1):
        if np.abs(t0 - buffer[i][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    weighted_scores = [[r * min(1,  strategy[auth_type]['auc'][i])
                        for i, r in enumerate(result)]
                        for auth_type, result, time in sel_buffer]

    return [np.array(np.average(weighted_scores, axis=0))]

def deer_ds_scoring(buffer, t0, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer), 0, -1):
        if np.abs(t0 - buffer[i - 1][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    if len(modalities.keys()) < 2:
        return [np.average(modalities[list(modalities.keys())[0]], axis=0)]

    result_gait = np.average(modalities['gait'], axis=0)
    result_touch = np.average(modalities['touch'], axis=0)

    final_result = []
    for i in range(result_gait.shape[0]):
        scores = [result_gait[i], result_touch[i]]
        uncertainty = [min(1, 2*strategy['gait']['eer'][i]),
                       min(1, 2*strategy['touch']['eer'][i])]

        result = ds_fusion_2(scores, uncertainty)
        # print(scores, uncertainty, result)
        final_result.append(result)

    return [np.array(final_result)]


def redeer_ds_scoring(buffer, t0, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer), 0, -1):
        if np.abs(t0 - buffer[i - 1][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    if len(modalities.keys()) < 2:
        return [np.average(modalities[list(modalities.keys())[0]], axis=0)]

    result_gait = np.average(modalities['gait'], axis=0)
    result_touch = np.average(modalities['touch'], axis=0)

    final_result = []
    for i in range(result_gait.shape[0]):
        scores = [result_gait[i], result_touch[i]]
        uncertainty = [max(0, 1 - 2 * strategy['gait']['eer'][i]),
                       max(0, 1 - 2 * strategy['touch']['eer'][i])]

        result = ds_fusion_2(scores, uncertainty)
        # print(scores, uncertainty, result)
        final_result.append(result)

    return [np.array(final_result)]

def auc_ds_scoring(buffer, t0, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer), 0, -1):
        if np.abs(t0 - buffer[i - 1][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    if len(modalities.keys()) < 2:
        return [np.average(modalities[list(modalities.keys())[0]], axis=0)]

    result_gait = np.average(modalities['gait'], axis=0)
    result_touch = np.average(modalities['touch'], axis=0)

    final_result = []
    for i in range(result_gait.shape[0]):
        scores = [result_gait[i], result_touch[i]]
        uncertainty = [max(0, 1 - strategy['gait']['auc'][i]),
                       max(0, 1 - strategy['touch']['auc'][i])]

        result = ds_fusion_2(scores, uncertainty)
        # print(scores, uncertainty, result)
        final_result.append(result)

    return [np.array(final_result)]


def kf_pu_scoring(buffer, t0, kmfs, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer), 0, -1):
        if np.abs(t0 - buffer[i - 1][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    result = []
    for u, kmf in enumerate(kmfs):
        # per user kalman filter
        raw_r = np.eye(2)
        obs = np.copy(kmf.last_z)
        for i, auth in enumerate(['touch', 'gait']):
            raw_r[i][i] = strategy[auth]['eer'][u]
            if auth in modalities:
                # print(obs[i], modalities[auth])
                obs[i] = np.average(modalities[auth], axis=0)[u]
        kmf.setR(raw_r)
        result.append(kmf.add(obs))

    return [np.array(result)]

def kalman_filter_scoring(buffer, t0, kmf, time_interval=TIME_INTERVAL, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer), 0, -1):
        if np.abs(t0 - buffer[i - 1][2]) > time_interval:
            break
        else:
            target_index = i - 1

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    if len(modalities.keys()) < 2:
        return [np.average(modalities[list(modalities.keys())[0]], axis=0)]

    # update R function
    raw_r = np.eye(len(modalities.keys()))
    for i, auth in enumerate(['touch', 'gait']):
        raw_r[i][i] = strategy[auth]['accuracy']

    kmf.setR(raw_r)

    result_gait = np.average(modalities['gait'], axis=0)
    result_touch = np.average(modalities['touch'], axis=0)

    result = kmf.add(np.array([result_touch, result_gait]))
    return [result]





SUPPORTED_SCORER = {
    'simple_average': plain_average_scoring,
    'weighted_average_eer': weighted_average_eer_scoring,
    'weighted_average_auc': weighted_average_auc_scoring,
    # 'dempster_shafer': dempster_shafer_score,
    # 'redeer_dempster_shafer': redeer_ds_scoring,
    'deer_dempster_shafer': deer_ds_scoring,
    'auc_dempster_shafer': auc_ds_scoring,
    'kalman_filter': kf_pu_scoring,
    # 'kalman_filter_0.1_0.9': kf_pu_scoring,
    # 'kalman_filter_0.01_0.9': kf_pu_scoring,
    # 'kalman_filter_0.001_0.9': kf_pu_scoring,
    # 'kalman_filter_0.25_1.0': kf_pu_scoring,
    # 'kalman_filter_0.25_0.8': kf_pu_scoring,
    # 'kalman_filter_0.25_0.7': kf_pu_scoring,
    # 'fixed_dempster_shafer': fixed_dempster_shafer_score
}


# =======================================
#  Different decision making strategies
# =======================================


def gait_only(buffer, t0):
    raw = [data for auth_type, data, t in buffer
           if t == t0 and auth_type == 'gait']

    if len(raw) < 3:
        return -1

    result = np.argmax(raw, axis=1)
    ctr = Counter(result)
    # print(ctr.most_common()[0])
    return ctr.most_common()[0][0]


def touch_only(buffer, t0):
    result = np.argmax([data for auth_type, data, t in buffer
                        if auth_type == 'touch'],
                        axis=1)
    to_check = result[-7:]
    final_result = -1
    sw = SlidingWindow(7, 4)
    for i in to_check:
        final_result = sw.add(i)
    return final_result


def direct_score(buffer, t0, time_interval=30000):
    target_index = len(buffer) - 1
    for i in range(len(buffer) - 1, 0, -1):
        if np.abs(t0 - buffer[i][2]) > time_interval:
            break
        else:
            target_index = i

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    result = np.argmax(np.average(results, axis=0))

    return result

def direct_decision(buffer, t0, time_interval=30000):
    result = [data for auth_type, data, t in buffer
              if np.abs(t - t0) < time_interval]
    ctr = Counter(result)
    item = ctr.most_common()
    if len(item) <= 0:
        return -1
    else:
        return ctr.most_common()[0][0]



def deer_dempster_shafer_score(buffer, t0, time_interval=30000, strategy=None):
    target_index = len(buffer) - 1
    for i in range(len(buffer) - 1, 0, -1):
        if np.abs(t0 - buffer[i][2]) > time_interval:
            break
        else:
            target_index = i

    sel_buffer = buffer[target_index:]
    auth_types, results, times = zip(*sel_buffer)

    modalities = dict()
    for auth_type, result, time in sel_buffer:
        if auth_type not in modalities:
            modalities[auth_type] = [result]
        else:
            modalities[auth_type].append(result)

    if len(modalities.keys()) < 2:
        return np.argmax(np.average(modalities[list(modalities.keys())[0]], axis=0))

    result_gait = np.average(modalities['gait'], axis=0)
    result_touch = np.average(modalities['touch'], axis=0)

    final_result = []
    for i in range(result_gait.shape[0]):
        scores = [result_gait[i], result_touch[i]]
#         uncertainty = [uncertainty_eer(strategy['gait']['eer'][i]),
#                        uncertainty_eer(strategy['touch']['eer'][i])]
        uncertainty = [min(1, 2*strategy['gait']['eer'][i]),
                       min(1, 2*strategy['touch']['eer'][i])]

        result = ds_fusion_2(scores, uncertainty)
        # print(scores, uncertainty, result)
        final_result.append(result)

    # result = np.argmax(np.average(results, axis=0))
    return np.argmax(final_result)



SUPPORTED_DECISION_MAKER = {
    'simple_average': direct_score,
    'simple_voting': direct_decision,
    # 'weight_average': weighted_score,
    # 'dempster_shafer': dempster_shafer_score,
    # 'wrong_dempster_shafer': wrong_dempster_shafer_score,
    'deer_dempster_shafer': deer_dempster_shafer_score,
    # 'fixed_dempster_shafer': fixed_dempster_shafer_score
}

# %% [markdown]
# ## Simulator Code

# %%
GAIT_NO_GAITS_DETECTED = -101
GAIT_GAITS_DETECTED = 101
GAIT_INSUFFICIENT_STEPS = -100

TOUCH_NO_SWIPE_DETECTED = -201
TOUCH_SWIPE_DETECTED = 201

DECISION_INSUFFICIENT_DATA = -1

EVENT_DEVICE_SHARING = "device sharing"

### comment types
COMMENT_FALSE_REJECTION = "false_rejection"
COMMENT_FALSE_ACCEPTANCE = "false_acceptance"
COMMENT_FALSE_MISCLASSIFICATION = "false_classification"
COMMENT_CONFIRM_USER_CHANGE = "confirm_user_change"

### special events
EVENT_SESSION_START = "session_start"
EVENT_SESSION_END = "session_end"
EVENT_ACCESS_GRANT = "access_grant"
EVENT_TRAIN_MODELS = "train_models"
EVENT_USER_CHANGE = "user_change" # user change signal is only for ground truth
EVENT_ADD_USER = "add_user"

SPECIAL_EVENTS = [
    EVENT_SESSION_START,
    EVENT_SESSION_END,
    EVENT_ACCESS_GRANT,
    EVENT_TRAIN_MODELS
]

### system states
STATE_ENROLLMENT = "state_enrollment"
STATE_NORMAL = "state_normal"
STATE_SHARING = "state_sharing"

SYSTEM_STATES = [
    STATE_ENROLLMENT,
    STATE_NORMAL,
    STATE_SHARING
]

### user states
USER_UNKNOWN = "Unknown"
USER_STRANGER = "Stranger"

### reaction types
REACTION_NONE = 0
REACTION_REJECT = -1
REACTION_USER_CHANGE = 9
REACTION_ACCEPT = 1



class TestPlayer:

    def train_auth(self, auth_type):
        auth = self.auth[auth_type]
        settings = self.gen_train_test_set(auth_type)
        # print('train', auth_type, settings['train_data'].shape, np.max(settings['train_label']))
        # print('test', auth_type, settings['test_data'].shape, np.max(settings['test_label'])
        reports = auth.train_model_with_eval((settings['train_label'],
                                              settings['train_data']),
                                             (settings['test_label'],
                                              settings['test_data']))

        # print(reports)
        return reports

    def train_all(self):
        for name, auth in self.auth.items():
            self.auth_report[name] = self.train_auth(name)
            print(name)
            print(self.auth_report[name]['report'])

        self.kalman = []
        for i in range(len(self.user_profile) + 1):
            kf = KFScorer(1,
                          len(self.auth), 0.9)
            kf.init(0.5)
            self.kalman.append(kf)

    def gen_train_test_set(self, auth_type):
        train_data_set = []
        train_label_set = []
        test_data_set = []
        test_label_set = []

        train_test_dict = self.storage.get_train_test_sets(auth_type, SCHEME_TIME_SEQ_10)
        for key, tt in train_test_dict['train'].items():
            label = self.get_user_label(key)
            train_data_set.append(tt)
            train_label_set.append(np.ones(tt.shape[0], dtype=int) * label)
        for key, tt in train_test_dict['test'].items():
            label = self.get_user_label(key)
            test_data_set.append(tt)
            test_label_set.append(np.ones(tt.shape[0], dtype=int) * label)

        # sample test dataset
        train_label, train_data = balance_dataset(np.concatenate(train_label_set),
                                                  np.concatenate(train_data_set),
                                                  1,
                                                  len(self.user_profile),
                                                  0)
        test_label, test_data = balance_dataset(np.concatenate(test_label_set),
                                                np.concatenate(test_data_set),
                                                1,
                                                len(self.user_profile),
                                                0)
        # print(test_label.shape, test_data.shape, train_data_set[0].shape,
        #       train_label_set[0].shape)
        # print(test_label)
        return {
            'train_data': train_data, # np.concatenate(train_data_set),
            'train_label': train_label, # np.concatenate(train_label_set),
            'test_data': test_data,
            'test_label': test_label
        }

    def feedback(self, comment):
        """
        feedback function receives user's feedback or other signal
        one representative example is: user correct misclassification
        comment format:
        (COMMENT_TYPE, DETAILS)
        """
        com_type, com = comment
        if com_type == COMMENT_FALSE_REJECTION:
            self.current_user = com
        elif com_type == COMMENT_FALSE_MISCLASSIFICATION:
            self.current_user = com
        elif com_type == COMMENT_CONFIRM_USER_CHANGE:
            # only after getting confirmation then update cached data to storage
            self.update_cache_to_storage(self.current_user)



    def __handle_special_events(self, event):
        if event == EVENT_SESSION_START:
            # handle a session start
            ## TODO: tasks that need to be done at session start
            pass

        elif event == EVENT_SESSION_END:
            # handle a session end
            if self.status == STATE_SHARING:
                self.status = STATE_NORMAL

            # assign allocation retrain
            # print("session end, train model")
            if self.flag_store_history:
                self.update_cache_to_storage(self.current_user)
            # self.train_all()

            # reset current user to unknown
            self.current_user = USER_UNKNOWN
            self.previous_user = USER_UNKNOWN

            # reset buffer and decisions
            self.buffer = {
                'acc': [],
                'gyro': [],
                'touch': []
            }
            self.decision_sw.reset()
            self.last_update = {
                'acc': -1,
                'gyro': -1,
                'touch': -1
            }

            self.detect_ctr = {
                'gait': 0
            }

            self.cur_swipe = -1
            self.decision_buffer = []
            self.another_buffer = []


        elif event == EVENT_ACCESS_GRANT:
            # handle a device sharing
            self.set_status(STATE_SHARING)

        elif event == EVENT_TRAIN_MODELS:
            self.train_all()


    def dispatch(self, event):
        time, sensor, data = event

        if sensor in SPECIAL_EVENTS:
            self.__handle_special_events(sensor)
            return REACTION_NONE

        self.buffer[sensor].append(data)

        reaction = REACTION_NONE # default reaction is nothing

        ## gait checker
        if sensor == 'acc':
            if len(self.buffer['acc']) >= 512 \
              and len(self.buffer['gyro']) >= 512 \
              and self.detect_ctr['gait'] >= 256:
                result = self.gait_detection()
                if result['code'] == GAIT_GAITS_DETECTED:
                    decision = self.aggregate("gait", result['result'], time)
                    if decision >= 0:
                        reaction = self.react_to_decision(decision)
                self.detect_ctr['gait'] = 0
            else:
                self.detect_ctr['gait'] += 1


        if sensor == 'touch':
            if self.cur_swipe == -1:
                self.cur_swipe = data[0]
            elif data[0] != self.cur_swipe:
                result = self.touch_detection()
                self.cur_swipe = data[0]
                if result['code'] == TOUCH_SWIPE_DETECTED:
                    decision = self.aggregate("touch", result['result'], time)
                    if decision >= 0:
                        reaction = self.react_to_decision(decision)
        return reaction


    def react_to_decision(self, decision):
        if decision < 0:
            # invalid decision
            return REACTION_NONE

        if decision == 0:
            self.current_user = USER_STRANGER
            if self.status == STATE_SHARING:
                return REACTION_NONE

            return REACTION_REJECT

        if self.current_user == USER_UNKNOWN:
            self.current_user = self.user_profile[decision - 1]
            return REACTION_ACCEPT
        else:
            if self.current_user != self.user_profile[decision - 1]:
                # TODO: react to user change

                self.previous_user = self.current_user
                self.current_user = self.user_profile[decision - 1]
                return REACTION_USER_CHANGE
            else:
                return REACTION_ACCEPT

    def cache_auth_data(self, auth_type, prediction, features):
        self.biometric_cache[auth_type].append((prediction, features))

    def update_cache_to_storage(self, true_user, crop=None):
        if true_user not in self.user_profile:
            print("current session does not belong to a valid user, discarded")
            self.clear_cache()
            return

        for auth_type, cached_data in self.biometric_cache.items():
            if len(cached_data) == 0:
                continue
            _, features = zip(*cached_data)
            self.storage.add_session_data(true_user,
                                          auth_type,
                                          np.array(features))
        self.clear_cache()

    def clear_cache(self):
        self.biometric_cache = {
            'gait': [],
            'touch': []
        }

    def gait_detection(self):
        dga = self.auth['gait']
        acc = np.array(self.buffer['acc'][-512:])
        gyro = np.array(self.buffer['gyro'][-512:])
        merged = np.concatenate([acc, gyro], axis=1)
        # processed = np.array([merged]).reshape(1, 1024, 6, 1)
        auth_result = None
        features = dga.extract_features(merged)
        if features is None:
            return {
                'code': GAIT_NO_GAITS_DETECTED,
                'result': None
            }
        else:
            r = dga.authenticate(features)
            for feature, result in zip(features, r):
                self.cache_auth_data('gait', result, feature)

            auth_result = r
        if auth_result is None or len(auth_result) == 0:
            return {
                'code': GAIT_NO_GAITS_DETECTED,
                'result': None
            }
        else:

            return {
                'code': GAIT_GAITS_DETECTED,
                'result': auth_result.tolist()
            }

    def gait_detection_full(self):
        dga = self.auth['gait']
        acc = np.array(self.buffer['acc'][-1024:])
        gyro = np.array(self.buffer['gyro'][-1024:])
        merged = np.concatenate([acc, gyro], axis=1)
        processed = np.array([merged]).reshape(1, 1024, 6, 1)
        result = dge.predict(processed.transpose(0, 2, 1, 3))[0]
        gaits = []
        st = 0
        flag = False
        tolerant_ctr = 0
        max_tolerance = 5
        for i in range(result.shape[0]):
            if result[i] > 0.5:
                if not flag:
                    st = i
                    flag = True
                tolerant_ctr = 0
            elif flag:
                if tolerant_ctr >= max_tolerance:
                    if i - st > 128:
                        gaits.append((st, i))
                        flag = False
                    else:
                        tolerant_ctr = 0
                        flag = False
                else:
                    tolerant_ctr += 1
        if flag and result.shape[0] - 1 - st > 128:
            gaits.append((st, result.shape[0] - 1))

        if len(gaits) == 0:
            return {
                'code': GAIT_NO_GAITS_DETECTED,
                'result': None
            }

        auth_result = None
        for gait in gaits:
            features = dga.extract_features(merged[gait[0]: gait[1] + 1])
            if features is None:
                continue
            else:
                r = dga.authenticate(features)
                for feature, result in zip(features, r):
                    self.cache_auth_data('gait', result, feature)

                auth_result = r if auth_result is None else np.concatenate((auth_result, r), axis=0)
        if auth_result is None or len(auth_result) == 0:
            return {
                'code': GAIT_NO_GAITS_DETECTED,
                'result': None
            }
        else:

            return {
                'code': GAIT_GAITS_DETECTED,
                'result': auth_result.tolist()
            }


    def touch_detection(self):
        toa = self.auth['touch']
        features = toa.extract_features(self.buffer['touch'])
        if len(features) == 0:
            return {
                'code': TOUCH_NO_SWIPE_DETECTED,
                'result': None
            }
        else:
            result = toa.authenticate([features[-1]])
            self.cache_auth_data('touch', result, features[-1])
            return {
                'code': TOUCH_SWIPE_DETECTED,
                'result': result
            }

    def aggregate(self, auth_type, raw_result, time):
        self.decision_buffer += [(auth_type, i, time) for i in raw_result]


        ### record all decision scores
        if auth_type == 'gait':
            result = gait_scoring(self.decision_buffer, time)
            # print(auth_type, result)
            # self.decision_scores[auth_type] += [(time, r) for r in result]
            self.decision_scores[auth_type].append((time, np.average(result, axis=0)))

        if auth_type == 'touch':
            result = touch_scoring(self.decision_buffer, time)
            self.decision_scores[auth_type] += [(time, r) for r in result]

        for dem_name, dem_maker in SUPPORTED_SCORER.items():
            if dem_name == 'simple_voting':
                result = dem_maker(self.another_buffer, time)
                self.decision_scores[dem_name] += [(time, r) for r in result]
            elif 'weighted_average' in dem_name:
                result = dem_maker(self.decision_buffer, time,
                                   strategy=self.auth_report)
                self.decision_scores[dem_name] += [(time, r) for r in result]
            elif 'dempster_shafer' in dem_name:
                result = dem_maker(self.decision_buffer, time,
                                   strategy=self.auth_report)
                self.decision_scores[dem_name] += [(time, r) for r in result]
            elif 'kalman_filter' in dem_name:
                result = dem_maker(self.decision_buffer, time,
                                   self.kalman, strategy=self.auth_report)
                self.decision_scores[dem_name] += [(time, r) for r in result]
            else:
                result = dem_maker(self.decision_buffer, time)
                self.decision_scores[dem_name] += [(time, r) for r in result]


        if auth_type == 'gait':
            result = gait_only(self.decision_buffer, time)
            if result >= 0:
                self.detection_events['gait'].append((time, result))
                self.another_buffer.append((auth_type, result, time))

        if auth_type == 'touch':
            result = touch_only(self.decision_buffer, time)
            if result >= 0:
                self.detection_events['touch'].append((time, result))
                self.another_buffer.append((auth_type, result, time))


        # GO THROUGH EACH DECISION MAKING FUNCTIONS
        # TODO: THE FOLLOWING CODE ONLY KEEPS FINAL RESULTS

        result = -1
        for dem_name, dem_maker in SUPPORTED_DECISION_MAKER.items():
            if dem_name == 'simple_voting':
                result = dem_maker(self.another_buffer, time)
            elif 'dempster_shafer' in dem_name:
                result = dem_maker(self.decision_buffer, time,
                                   strategy=self.auth_report)
            elif dem_name == 'weight_average':
                result = dem_maker(self.decision_buffer, time,
                                   weight_scheme = {
                                       'gait': self.auth_report['gait']['accuracy'],
                                       'touch': self.auth_report['touch']['accuracy'],
                                   })
            else:
                result = dem_maker(self.decision_buffer, time)
            if result >= 0:
                self.detection_events[dem_name].append((time, result))

        return self.decision_sw.add(self.detection_events['deer_dempster_shafer'][-1])

    # =====================================
    # System status management functions
    # =====================================
    def set_status(self, state):
        assert state in SYSTEM_STATES
        self.status = state

    def reset_authenticators(self):
        self.auth = {
            'touch': TouchAuth(),
            'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
        }


    # =====================================
    # User management functions
    # =====================================
    def add_user(self, user_id):
        if user_id in self.user_profile:
            print("User already registered.")
            return
        self.user_profile.append(user_id)
        self.storage.add_user(user_id)

    def get_user_label(self, user_id):
        # generate user label dict
        user_label_dict = {}
        for i, user in enumerate(self.user_profile):
            user_label_dict[user] = i + 1
        if user_id not in user_label_dict:
            return 0
        else:
            return user_label_dict[user_id]

    def enroll(self, user_id, details):
        self.add_user(user_id)
        for item in details:
            # print(item['user'], user_id)
            assert item['user'] == user_id
            self.storage.add_session_data(user_id, item['type'], item['feature'])
        self.reset_authenticators()
        self.train_all()


    # =====================================
    # Utility functions for experiments
    # =====================================

    def save_decision(self, dem_name, out_path):
        with open(os.path.join(out_path, dem_name + ".txt"), 'w') as fp:
            for time, result in self.detection_events[dem_name]:
                fp.write(str(time) + "," + str(result) + "\n")

    def save_all_decisions(self, out_path):
        for dem_name in SUPPORTED_DECISION_MAKER.keys():
            self.save_decision(dem_name, out_path)

    def set_flag_store_history(self, b):
        self.flag_store_history = b

    def __init__(self, authenticators, auth_report=None, imposter_set=None):
        self.auth = authenticators
        self.auth_report = {} if auth_report is None else auth_report
        self.status = STATE_NORMAL # default normal state
        self.flag_store_history = True
        self.current_user = USER_UNKNOWN
        self.previous_user = USER_UNKNOWN
        self.buffer = {
            'acc': [],
            'gyro': [],
            'touch': []
        }

        self.last_update = {
            'acc': -1,
            'gyro': -1,
            'touch': -1
        }

        self.detect_ctr = {
            'gait': 0
        }

        self.cur_swipe = -1

        self.decision_buffer = []
        self.another_buffer = []

        self.detection_events = {
            'touch': [],
            'gait': [],
        }

        for dem in SUPPORTED_DECISION_MAKER.keys():
            self.detection_events[dem] = []

        self.decision_scores = {
            'touch': [],
            'gait': [],
        }

        for dem in SUPPORTED_SCORER.keys():
            self.decision_scores[dem] = []

        ## dynamic system related variables
        self.biometric_cache = {
            'touch': [],
            'gait': []
        }

        self.storage = BiometricStorage(imposter_set=imposter_set)

        self.user_profile = []
        self.decision_sw = SlidingWindow(7, 4)

# %%
# scripter runner
# to handle exceptions during a simulation
# keep record of all progress
# calculate metrics of a simulation

## basic script workflow
## 1. obtain next event from timeline
## 2. feed it into the player
## 3. obtain detection result
## 4. update simulation status
## 5. capture exceptions
## 6. feedback

## whenever gets a valid result from player, first chech if it matches groundtruth

## some important definitions
## 1. false acceptance: false acceptance should be counted at session-level,

## when the user has changed (groundtruth) but the system
## is late to reject a stranger or identify the true user


## about metrics

EXCEPTION_FALSE_ACCEPTANCE = "FA"
EXCEPTION_FALSE_REJECTION = "FN"
EXCEPTION_MISCLASSIFICATION = "MC"


def generate_enrollment_data(provider, session_info):
    user = session_info[0]
    print("gen", user)
    d_sessions = session_info[1:]
    gait_sessions = [d_sessions[i + 1] for i in range(0, len(d_sessions), 2)
                     if d_sessions[i] == 'gait']
    touch_sessions = [d_sessions[i + 1] for i in range(0, len(d_sessions), 2)
                     if d_sessions[i] == 'touch']

    combined = []
    for sess in gait_sessions:
        feature = get_features(provider, 'gait', user, sess)
        combined.append({
            'user': user,
            'type': 'gait',
            'feature': feature
        })
    for sess in touch_sessions:
        feature = get_features(provider, 'touch', user, sess)
        combined.append({
            'user': user,
            'type': 'touch',
            'feature': feature
        })
    return combined

def script_runner(timeline: Timeline, player: TestPlayer):

    ## initialize the runner status
    cur_user = USER_UNKNOWN

    session_results = []
    tmp = None
    gt_start_time = 0

    for event in timeline:
        result = REACTION_NONE
        if event[1] not in [EVENT_USER_CHANGE, EVENT_ADD_USER]:
            # EVENT_USER_CHANGE IS NOT FOR PLAYER
            result = player.dispatch(event)

        true_user = timeline.get_groundtruth_result(event[0])


        if event[1] in [EVENT_SESSION_END, EVENT_USER_CHANGE]:
            logger.info("[groundtruth] detect session end")
            # print("tmp", tmp)
            processed = process_session_result(tmp)
            if processed is not None:
                session_results.append(processed)
            tmp = None
        if event[1] in [EVENT_SESSION_START, EVENT_USER_CHANGE]:
            logger.info("[groundtruth] detect session start")
            tmp = {
                'num_detection': 0,
                'num_accept': 0,
                'num_reject': 0,
                'num_fp': 0,
                'num_fn': 0,
                'num_mc': 0, # misclassification
                'delay': -1,
                'exceptions': []
            }
            gt_start_time = event[0]
        if event[1] == EVENT_ADD_USER:
            ## explicit enrollment format
            ## name, session
            logger.info("[new user enrolment] user: " + str(event[2][0]))
            enroll_data = generate_enrollment_data(hmog, event[2])
            player.enroll(event[2][0], enroll_data)

        ## possible results:
        ## reaction types
        ## REACTION_NONE = 0
        ## REACTION_REJECT = -1
        ## REACTION_USER_CHANGE = 9
        ## REACTION_ACCEPT = 1

        if result == REACTION_ACCEPT:

            ## compare to ground truth
            tmp['num_detection'] += 1
            tmp['num_accept'] += 1
            if player.current_user != true_user:
                # current user
                if true_user not in player.user_profile:
                    # false acceptance
                    tmp['num_fp'] += 1
                    tmp['exceptions'].append((event[0], EXCEPTION_FALSE_ACCEPTANCE))
                    player.feedback((COMMENT_FALSE_ACCEPTANCE, USER_STRANGER))
                else:
                    # misclassification
                    tmp['num_mc'] += 1
                    tmp['exceptions'].append((event[0], EXCEPTION_MISCLASSIFICATION))
                    player.feedback((COMMENT_FALSE_MISCLASSIFICATION, true_user))
            else:
                # true positive
                # check if it is the first detection
                if tmp['delay'] == -1:
                    tmp['delay'] = event[0] - gt_start_time

        elif result == REACTION_REJECT:
            tmp['num_detection'] += 1
            tmp['num_reject'] += 1
            if true_user in player.user_profile:
                # false rejection
                tmp['num_fn'] += 1
                tmp['exceptions'].append((event[0], EXCEPTION_FALSE_REJECTION))
                player.feedback((COMMENT_FALSE_REJECTION, true_user))
            else:
                # true rejection (check first detection)
                if tmp['delay'] == -1:
                    tmp['delay'] = event[0] - gt_start_time

        elif result == REACTION_USER_CHANGE:
            tmp['num_detection'] += 1
            # check if it is really a user change
            tmp['num_accept'] += 1
            if true_user == player.current_user:
                # yes!
                player.feedback((COMMENT_CONFIRM_USER_CHANGE, None))
                if tmp['delay'] == -1:
                    tmp['delay'] = event[0] - gt_start_time
                else:
                    print("there must be something going wrong")
            else:
                if true_user not in player.user_profile:
                    # false acceptance
                    tmp['num_fp'] += 1
                    tmp['exceptions'].append((event[0], EXCEPTION_FALSE_ACCEPTANCE))
                    player.feedback((COMMENT_FALSE_ACCEPTANCE, USER_STRANGER))
                else:
                    tmp['num_mc'] += 1
                    tmp['exceptions'].append((event[0], EXCEPTION_MISCLASSIFICATION))
                    player.feedback((COMMENT_FALSE_MISCLASSIFICATION, true_user))

    return session_results


def process_session_result(tmp):
    if tmp is None:
        return None
    return tmp

# %% [markdown]
# # Evaluation Code Snippets

# %%
def gen_groundtruth_for_decision_scores(tml: Timeline, player: TestPlayer):
    # generate groundtruth table for decision scores
    # return {<decison_maker>: {'pred': <scores>, 'true': <groundtruth labels>}}
    result_dict = {}
    for dec_name, dec_list in player.decision_scores.items():
        # process for a certain dec
        grt_list = []
        pred_list = []
        for time, result in dec_list:
            user = tml.get_groundtruth_result(time)
            grt = 0 if user not in player.user_profile else player.get_user_label(user)
            grt_list.append(grt)
            pred_list.append(result)
        result_dict[dec_name] = {
            'pred': pred_list,
            'true': grt_list
        }
    return result_dict


def one_vs_rest_binarize(decision_pair, pos_loc):
    score = np.array(decision_pair['pred'])[:, pos_loc]
    grt = (np.array(decision_pair['true']) == pos_loc).astype(int)
    full_score = np.array([[1 - s, s] for s in score])
    return {
        'score': score,
        'true': grt,
        'pred': full_score
    }

def one_vs_one_binarize(decision_pair, pos_loc, neg_loc):
    score = np.array(decision_pair['pred'])
    truth = np.array(decision_pair['true'])
    sel_score = score[(truth == pos_loc) | (truth == neg_loc)]
    sel_truth = truth[(truth == pos_loc) | (truth == neg_loc)]
    grt = (sel_truth == pos_loc).astype(int)
    single_score = np.array([s[pos_loc] for s in sel_score])
    full_score = np.array([[s[neg_loc], s[pos_loc]] for s in sel_score])
    return {
        'score': single_score,
        'true': grt,
        'pred': full_score
    }


def gen_per_segment_decision(tml: Timeline, player: TestPlayer):
    result_dict = {}
    for dec_name, dec_list in player.decision_scores.items():
        grt_list = []
        pred_list = []
        time_list = []
        segment_no = 0
        st, ed, user, _ = tml.user_groundtruth[segment_no]
        seg_grt = []
        seg_pred = []
        seg_time = []
        for time, result in dec_list:
            # user = tml.get_groundtruth_result(time)
            assert time >= st
            if time > ed:
                # move to the next segment
                grt_list.append(seg_grt)
                pred_list.append(seg_pred)
                time_list.append(seg_time)
                seg_grt = []
                seg_pred = []
                seg_time = []
                segment_no += 1
                assert segment_no <= len(tml.user_groundtruth)
                st, ed, user, _ = tml.user_groundtruth[segment_no]
            grt = 0 if user not in player.user_profile else player.get_user_label(user)
            seg_grt.append(grt)
            seg_pred.append(result)
            seg_time.append(time - st)
        grt_list.append(seg_grt)
        pred_list.append(seg_pred)
        time_list.append(seg_time)
        result_dict[dec_name] = {
            'pred': pred_list,
            'true': grt_list,
            'time': time_list
        }
    return result_dict



def get_metrics_per_segment(decision_pair, sliding_window=None):
    positives = 0
    negatives = 0
    false_rejections = 0
    true_rejections = 0
    false_identifications = 0
    latency_rejection = []
    result_dict = {
        'pos': 0,
        'neg': 0,
        'fr': 0,
        'tr': 0,
        'fi': 0,
        'latency': []
    }

    for i, j, t in zip(decision_pair['pred'], decision_pair['true'],
                      decision_pair['time']):
        # print(i)
        # print(j)
        score = np.array(i)
        truth = np.array(j)
        result = np.argmax(score, axis=1)
        if sum(truth) > 0:
            result_dict['pos'] += 1
            # positive case, focus on false rejection and false identification
            if sliding_window is not None:
                m, n = sliding_window
                sw = SlidingWindow(m, n)
                # stop at first rejection or misclassification
                flag = False
                for res in result:
                    decision = sw.add(res)
                    if decision == 0:
                        result_dict['fr'] += 1
                        flag = True
                        break
                    elif decision != truth[0] and decision > 0:
                        print(decision, truth[0])
                        result_dict['fi'] += 1
                        flag = True
                        break
            else:
                for res in result:
                    if res == 0:
                        result_dict['fr'] += 1
                        flag = True
                        break
                    elif res != truth[0]:
                        print(res, truth[0])
                        result_dict['fi'] += 1
                        flag = True
                        break
        else:
            result_dict['neg'] += 1
            if sliding_window is not None:
                m, n = sliding_window
                sw = SlidingWindow(m, n)
                # stop at first rejection or misclassification
                flag = False
                for res, time in zip(result, t):
                    decision = sw.add(res)
                    if decision == 0:
                        result_dict['tr'] += 1
                        result_dict['latency'].append(time)
                        flag = True
                        break
            else:
                for res, time in zip(result, t):
                    if res == 0:
                        result_dict['tr'] += 1
                        result_dict['latency'].append(time)
                        flag = True
                        break
    return result_dict


def gen_all_metrics_for_scheme(dcp, num_valid_users=2):
    final_result = dict()
    for user in range(num_valid_users):
        per_user_result = dict()
        result = one_vs_rest_binarize(dcp, user + 1)

        per_user_result['true'] = result['true']
        per_user_result['score'] = result['score']
        per_user_result['pred'] = result['pred']

        # obtain roc curve
        fpr, tpr, thres = roc_curve(result['true'], result['score'])

        per_user_result['fpr'] = fpr
        per_user_result['tpr'] = tpr
        per_user_result['thres'] = thres

        eer_score, _ = eer(result['true'], result['score'])
        per_user_result['eer'] = eer_score
        per_user_result['auc'] = roc_auc_score(result['true'], result['score'])
        final_result[user + 1] = per_user_result
    return final_result

def gen_all_metrics(score_dict, num_valid_users=2):
    return {
        name: gen_all_metrics_for_scheme(dcp, num_valid_users)
        for name, dcp in score_dict.items()
    }


# metrics_all = gen_all_metrics(score_dict, 2)


# fcs = FCS('simple_average')
# fcs.get_metric(result['true'], result['pred'],
#                (result['score'] > 0.3).astype(int))



import seaborn as sns

class FCS():

    def __init__(self, classifier_name):
        self.classifier_name = classifier_name
        self.true_labels = None
        self.pred_probs = None
        self.pred_labels = None
        self.plot = None
        self.axes = None

        return

    def get_metric(self, true_labels, predicted_probs, pred_labels, bins="auto",
                   ax=None, alpha=0.75):
        self.true_labels = true_labels
        self.pred_probs = predicted_probs
        self.pred_labels = pred_labels
        self.axes = ax
        df = pd.DataFrame(self.pred_probs)
        df.columns = ['prob_0', 'prob_1']
        df['pred_labels'] = pred_labels
        df['true_labels'] = true_labels
        df.loc[df['true_labels'] == 1, 'user_type'] = "positive_user"
        df.loc[df['true_labels'] == 0, 'user_type'] = "negative_user"

        bins = bins
        if self.axes is None:
            # sns.set_theme("whitegrid")
            self.plot = plt.figure(figsize=[12, 12])
            self.axes = self.plot.add_subplot(1, 1, 1)
            # sns.histplot(x="prob_1", data=df, hue="user_type", bins=bins, ax=self.axes, legend=True)

            self.axes.hist(df[df['true_labels'] == 1].prob_1.values, bins=bins,
                           label="Positive User",
                           edgecolor='black', linewidth=1.2, alpha=alpha)
            self.axes.hist(df[df['true_labels'] == 0].prob_1.values, bins=bins,
                           label="Negative User",
                           edgecolor='black', linewidth=1.2, alpha=alpha)

            self.axes.set_title('Frequency Count Score for ' + self.classifier_name)
            self.axes.set_xlabel('scores')
            self.axes.set_ylabel('Frequency Count')

            return self.plot
        else:
            pass
            # sns.histplot(x="prob_1", data=df, hue="user_type", bins=bins, ax=self.axes, legend=True)

            self.axes.hist(df[df['true_labels'] == 1].prob_1.values, bins=bins, label="Positive User",
                           edgecolor='black', linewidth=1.2, alpha=alpha)
            self.axes.hist(df[df['true_labels'] == 0].prob_1.values, bins=bins, label="Negative User",
                           edgecolor='black', linewidth=1.2, alpha=alpha)

            self.axes.set_title('Frequency Count Score for ' + self.classifier_name)
            self.axes.set_xlabel('scores')
            self.axes.set_ylabel('Frequency Count')

        return

# %%
### save experiment data

def save_experiment_data(player, tml, path):
    if os.path.exists(path) and os.path.isdir(path):
        print("Path exists, will overwrite the path")
    else:
        os.makedirs(path)

    # save timeline data
    tml.save("timeline", path)

    # save decisions
    # player.decision_scores, player.user_profiles
    # put everything into a big dictionary
    json_dict = {
        'user': player.user_profile,
        'decisions': []
    }
    for key, score in player.decision_scores.items():
        json_dict['decisions'].append(
            {
                'strategy': key,
                'result': [
                          {'time': time, 'score': s.tolist()}
                          for time, s in score
                ]
            }
        )

    # print(json_dict)

    with open(os.path.join(path, "result.json"), "w") as outfile:
        json.dump(json_dict, outfile)

    print("file saved.")

# %%
def segment_by_session_end(tml):
    st = 0
    segments = []
    for time, event, content in tml.events:
        if event == EVENT_SESSION_END:
            segments.append((st, time))
            st = time
    return segments

# print(segment_by_session_end(tml))

def gen_decisions_by_segment(tml, player, segments):
    result_dict = {}
    for dec_name, dec_list in player.decision_scores.items():
        grt_list = []
        pred_list = []
        time_list = []
        segment_no = 0
        st, ed = segments[segment_no]
        seg_grt = []
        seg_pred = []
        seg_time = []
        for time, result in dec_list:
            user = tml.get_groundtruth_result(time)
            assert time >= st
            if time > ed:
                grt_list.append(seg_grt)
                pred_list.append(seg_pred)
                time_list.append(seg_time)
                seg_grt = []
                seg_pred = []
                seg_time = []
                segment_no += 1
                st, ed = segments[segment_no]
            grt = 0 if user not in player.user_profile else player.get_user_label(user)
            seg_grt.append(grt)
            seg_pred.append(result)
            seg_time.append(time - st)
        grt_list.append(seg_grt)
        pred_list.append(seg_pred)
        time_list.append(seg_time)
        result_dict[dec_name] = {
            'pred': pred_list,
            'true': grt_list,
            'time': time_list
        }
    return result_dict


def get_metrics_for_experiment2(decision_pair, sliding_window=None):
    ## types of errors:
    ## early failures: early rejection and early misclassification
    ## identification failures: 1. false rejection 2. misclassification
    ## there is no negative case

    result_dict = {
        'case': 0,
        'er': 0,
        'em': 0,
        'fr': 0,
        'mi': 0,
        'latency': []
    }

    # owner = decision_pair['true'][0]
    # sharee = decision_pair['true'][-1]

    # moment = 0
    # for i, j in zip(decision_pair['true'], decision_pair['time']):
    #     if i == sharee:
    #         moment = j
    #         break


    for i, j, t in zip(decision_pair['pred'], decision_pair['true'],
                      decision_pair['time']):
        # print(i)
        # print(j)
        score = np.array(i)
        truth = np.array(j)
        # print(score, truth)
        result = np.argmax(score, axis=1)

        # obtain moment:
        owner = truth[0]
        sharee = truth[-1]
        moment = -1
        for i, j in zip(t, truth):
            if j == sharee:
                moment = i
                break
        assert moment != -1

        result_dict['case'] += 1

        if sliding_window is not None:
            m, n = sliding_window
            sw = SlidingWindow(m, n)
            early_rejection = False
            early_misclassification = False
            false_rejection = False
            misclassification = False
            flag = False
            for res, tru, tim in zip(result, truth, t):
                decision = sw.add(res)
                if tru == owner:
                    # pre sharing moment
                    if decision == 0: # false rejection
                        early_rejection = True
                        # print(tim, decision)
                    elif decision != owner and decision > 0:
                        early_misclassification = True
                elif tru == sharee:
                    if decision == 0:
                        false_rejection = True
                    # if decision == owner and :
                    #     misclassification = True
                    if decision != sharee and tim - moment > 60000 and decision > 0:
                        misclassification = True
                    if not flag and decision == sharee:
                        result_dict['latency'].append(tim - moment)
                        flag = True

            if early_rejection:
                result_dict['er'] += 1
            elif early_misclassification:
                result_dict['em'] += 1
            elif false_rejection:
                result_dict['fr'] += 1
            elif misclassification:
                result_dict['mi'] += 1


    return result_dict


def gen_per_segment_decision(tml: Timeline, player: TestPlayer):
    result_dict = {}
    for dec_name, dec_list in player.decision_scores.items():
        grt_list = []
        pred_list = []
        time_list = []
        segment_no = 0
        st, ed, user, _ = tml.user_groundtruth[segment_no]
        seg_grt = []
        seg_pred = []
        seg_time = []
        for time, result in dec_list:
            # user = tml.get_groundtruth_result(time)
            assert time >= st
            if time > ed:
                # move to the next segment
                grt_list.append(seg_grt)
                pred_list.append(seg_pred)
                time_list.append(seg_time)
                seg_grt = []
                seg_pred = []
                seg_time = []
                segment_no += 1
                assert segment_no <= len(tml.user_groundtruth)
                st, ed, user, _ = tml.user_groundtruth[segment_no]
            grt = 0 if user not in player.user_profile else player.get_user_label(user)
            seg_grt.append(grt)
            seg_pred.append(result)
            seg_time.append(time - st)
        grt_list.append(seg_grt)
        pred_list.append(seg_pred)
        time_list.append(seg_time)
        result_dict[dec_name] = {
            'pred': pred_list,
            'true': grt_list,
            'time': time_list
        }
    return result_dict



def get_metrics_per_segment(decision_pair, sliding_window=None):
    positives = 0
    negatives = 0
    false_rejections = 0
    true_rejections = 0
    false_identifications = 0
    latency_rejection = []
    result_dict = {
        'pos': 0,
        'neg': 0,
        'fr': 0,
        'tr': 0,
        'fi': 0,
        'latency': []
    }

    for i, j, t in zip(decision_pair['pred'], decision_pair['true'],
                      decision_pair['time']):
        # print(i)
        # print(j)
        score = np.array(i)
        truth = np.array(j)
        # print(score, truth)
        if len(score) == 0:
            continue

        result = np.argmax(score, axis=1)
        if sum(truth) > 0:
            result_dict['pos'] += 1
            # positive case, focus on false rejection and false identification
            if sliding_window is not None:
                m, n = sliding_window
                sw = SlidingWindow(m, n)
                # stop at first rejection or misclassification
                flag = False
                for res in result:
                    decision = sw.add(res)
                    if decision == 0:
                        result_dict['fr'] += 1
                        flag = True
                        break
                    elif decision != truth[0] and decision > 0:
                        print(decision, truth[0])
                        result_dict['fi'] += 1
                        flag = True
                        break
            else:
                for res in result:
                    if res == 0:
                        result_dict['fr'] += 1
                        flag = True
                        break
                    elif res != truth[0]:
                        print(res, truth[0])
                        result_dict['fi'] += 1
                        flag = True
                        break
        else:
            result_dict['neg'] += 1
            if sliding_window is not None:
                m, n = sliding_window
                sw = SlidingWindow(m, n)
                # stop at first rejection or misclassification
                flag = False
                for res, time in zip(result, t):
                    decision = sw.add(res)
                    if decision == 0:
                        result_dict['tr'] += 1
                        result_dict['latency'].append(time)
                        flag = True
                        break
            else:
                for res, time in zip(result, t):
                    if res == 0:
                        result_dict['tr'] += 1
                        result_dict['latency'].append(time)
                        flag = True
                        break
    return result_dict

# %%
## initialize hmog dataset provider
hmog = HMOGProvider("drive/MyDrive/dataset/HMOG")

# %% [markdown]
# # Negative Imposter Set
#
# This function only determines who are the imposter trainers. The amount of the negative data is not determined. It is the developers who determine how much data should be used for training.

# %%
## Negative Trainer (ImposterProvider)
trainer_seed = 100
num_trainers = 10

## Step 1: obtain trainers
trainers = hmog.gen_user_set(num_trainers, random_state=trainer_seed)

## Step 2: load data
hmog.load(trainers)

## Step 3: obtain session data for each authenticator

### Step 3.1: gait
gait_set = []
for user in trainers:
    ## gait sessions
    sel_sessions = hmog.get_sessions_for_unloaded_user(user,
                                [hmog.ACTIVITY_READING_WALKING,
                                 hmog.ACTIVITY_WRITING_WALKING])
    result = None
    for session in sel_sessions:
        tmp_data = simple_merge_acc_gyro(hmog.data[user][session]['acc'],
                                         hmog.data[user][session]['gyro'])
        features = DeepGaitAuthenticator().extract_features(tmp_data)
        if features is None:
            print(user, session, "contains no gait")
            continue
        result = features if result is None else np.concatenate(
            [result, features])
    gait_set.append(result)

### Step 3.2: touch
touch_set = []
for user in trainers:
    ## gait sessions
    sel_sessions = hmog.get_sessions_for_unloaded_user(user,
                                [hmog.ACTIVITY_READING_WALKING,
                                 hmog.ACTIVITY_READING_SITTING])
    result = None
    for session in sel_sessions:
        # print(user, session)
        features = touch_df_to_features(hmog.data[user][session]['touch'])
        # if user == '219303' and int(session) == 17:
        #     print(len(features))
        result = features if result is None else np.concatenate(
            [result, features])
    touch_set.append(result)

## Step4: generate imposter set
gait_imposters = ImposterProvider(gait_set)
gait_train, gait_test = gait_imposters.generate_train_test_sets(2)
touch_imposters = ImposterProvider(touch_set)
touch_train, touch_test = touch_imposters.generate_train_test_sets(2)
# print(gait_train.shape, gait_test.shape, touch_train.shape, touch_test.shape)
imposter_set = {
    'touch': {'train': touch_train, 'test': touch_test},
    'gait': {'train': gait_train, 'test': gait_test}
}

# %% [markdown]
# # Load Gait Extraction Model

# %%
dge = tf.keras.models.load_model("drive/MyDrive/deep_gait_extraction_21")
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %% [markdown]
# # Experiment 1: Standard Accuracy

# %%
def run_topic_accuracy_experiment_balance_limit(game_seed=0, n_balanced=3,
                                                n_train_session=2,limit=180000):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================

    num_testers = n_balanced
    num_valid_users = n_balanced

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                          str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    for user in valid_users:
        gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

        touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

        enrollment_script_type_1.append((user, 'gait', gait_sessions))
        enrollment_script_type_1.append((user, 'touch', touch_sessions))

    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================


    for user in valid_users:
        sel_session = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[-1]
        events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time,limit)
        tml.add_special_event(EVENT_SESSION_START, [])
        tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
        tml.add_special_event(EVENT_SESSION_END, [])
        # tml.add_special_event(EVENT_TRAIN_MODELS)

    for user in testers:
        sel_session = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[-1]
        events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time,limit)
        tml.add_special_event(EVENT_SESSION_START, [])
        tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
        tml.add_special_event(EVENT_SESSION_END, [])


    # ===============================================
    # 5. One line running script
    # ===============================================

    results = script_runner(tml, player)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    return tml, player

# %%
#@title Experiment 1.0: 1 + 1 training sessions

last_result = None

for seed in range(1000, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 3, 1)
    score_pairs = gen_per_segment_decision(tml, player)
    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/re_accuracy_3_1_limit", str(seed)))

# %%
#@title Experiment 1.1: 2 + 2 training sessions

last_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 3, 2)
    score_pairs = gen_per_segment_decision(tml, player)
    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022/re_accuracy_3_2_limit", str(seed)))
# Out:
# ========== SETUP ===========
# Game name:100_0_10_3_3
# Negative trainer seed:100
# Game seed:0
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:554303 (0), 663153 (1), 710707 (2)
# testers:171538, 277905, 771782
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.82      0.75      0.78        24
#            1       0.62      0.62      0.62         8
#            2       1.00      1.00      1.00         8
#            3       0.70      0.88      0.78         8
#
#     accuracy                           0.79        48
#    macro avg       0.79      0.81      0.80        48
# weighted avg       0.80      0.79      0.79        48
#
# Epoch 1/25
# 78/78 [==============================] - 5s 19ms/step - loss: 1.2471 - categorical_accuracy: 0.5710
# Epoch 2/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.8007 - categorical_accuracy: 0.6679
# Epoch 3/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.7034 - categorical_accuracy: 0.7109
# Epoch 4/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.6212 - categorical_accuracy: 0.7517
# Epoch 5/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.5346 - categorical_accuracy: 0.7883
# Epoch 6/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.4850 - categorical_accuracy: 0.8127
# Epoch 7/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.4201 - categorical_accuracy: 0.8371
# Epoch 8/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.3744 - categorical_accuracy: 0.8622
# Epoch 9/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.3335 - categorical_accuracy: 0.8764
# Epoch 10/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.2851 - categorical_accuracy: 0.8966
# Epoch 11/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.2591 - categorical_accuracy: 0.9023
# Epoch 12/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.2377 - categorical_accuracy: 0.9147
# Epoch 13/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.2070 - categorical_accuracy: 0.9235
# Epoch 14/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.1856 - categorical_accuracy: 0.9294
# Epoch 15/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.1537 - categorical_accuracy: 0.9443
# Epoch 16/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.1433 - categorical_accuracy: 0.9486
# Epoch 17/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.1166 - categorical_accuracy: 0.9576
# Epoch 18/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.0918 - categorical_accuracy: 0.9671
# Epoch 19/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.0919 - categorical_accuracy: 0.9672
# Epoch 20/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.0675 - categorical_accuracy: 0.9781
# Epoch 21/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.0708 - categorical_accuracy: 0.9759
# Epoch 22/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.0611 - categorical_accuracy: 0.9791
# Epoch 23/25
# 78/78 [==============================] - 2s 19ms/step - loss: 0.0502 - categorical_accuracy: 0.9843
# Epoch 24/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.0358 - categorical_accuracy: 0.9899
# Epoch 25/25
# 78/78 [==============================] - 1s 19ms/step - loss: 0.0316 - categorical_accuracy: 0.9904
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.73      0.78       552
#          1.0       0.96      0.99      0.98       184
#          2.0       0.70      0.99      0.82       184
#          3.0       0.61      0.57      0.59       184
#
#     accuracy                           0.79      1104
#    macro avg       0.78      0.82      0.79      1104
# weighted avg       0.80      0.79      0.79      1104
#
# training done
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41032 ms
# ==== Session #1 ====
# # of detection: 33, acceptance: 33, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 39178 ms
# ==== Session #2 ====
# # of detection: 36, acceptance: 36, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30747 ms
# ==== Session #3 ====
# # of detection: 50, acceptance: 32, rejection: 18
# # of FA: 32
# # of FR: 0
# # of MI: 0
# FAR: 0.64
# MIR: 0.0
# FRR: 0.0
# latency: 41220 ms
# ==== Session #4 ====
# # of detection: 22, acceptance: 17, rejection: 5
# # of FA: 17
# # of FR: 0
# # of MI: 0
# FAR: 0.7727272727272727
# MIR: 0.0
# FRR: 0.0
# latency: 46818 ms
# ==== Session #5 ====
# # of detection: 37, acceptance: 0, rejection: 37
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25563 ms
# simulation result: FAR: 0.21973094170403587
# MIR: 0.0
# FNR: 0.0
# latency: 37426.333333333336 ms
# 1 3
# [touch] pos: 3, neg: 3, fr: 0, tr: 2, fi: 1,
# [gait] pos: 3, neg: 3, fr: 1, tr: 1, fi: 0,
# [simple_average] pos: 3, neg: 3, fr: 1, tr: 2, fi: 0,
# [weighted_average_eer] pos: 3, neg: 3, fr: 1, tr: 1, fi: 0,
# [weighted_average_auc] pos: 3, neg: 3, fr: 1, tr: 2, fi: 0,
# [deer_dempster_shafer] pos: 3, neg: 3, fr: 1, tr: 2, fi: 0,
# [auc_dempster_shafer] pos: 3, neg: 3, fr: 1, tr: 2, fi: 0,
# [kalman_filter] pos: 3, neg: 3, fr: 1, tr: 2, fi: 0,
#
# Path exists, will overwrite the path
# file saved.
# ========== SETUP ===========
# Game name:100_100_10_3_3
# Negative trainer seed:100
# Game seed:100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:257279 (0), 771782 (1), 526319 (2)
# testers:431312, 777078, 693572
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.68      0.72      0.70        18
#            1       0.57      0.67      0.62         6
#            2       0.50      0.33      0.40         6
#            3       0.83      0.83      0.83         6
#
#     accuracy                           0.67        36
#    macro avg       0.65      0.64      0.64        36
# weighted avg       0.66      0.67      0.66        36
#
# Epoch 1/25
# 77/77 [==============================] - 5s 21ms/step - loss: 1.3233 - categorical_accuracy: 0.4956
# Epoch 2/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.8200 - categorical_accuracy: 0.6615
# Epoch 3/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.5218 - categorical_accuracy: 0.7876
# Epoch 4/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.4739 - categorical_accuracy: 0.8030
# Epoch 5/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3840 - categorical_accuracy: 0.8489
# Epoch 6/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3345 - categorical_accuracy: 0.8708
# Epoch 7/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2925 - categorical_accuracy: 0.8869
# Epoch 8/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2618 - categorical_accuracy: 0.9003
# Epoch 9/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2442 - categorical_accuracy: 0.9060
# Epoch 10/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2260 - categorical_accuracy: 0.9111
# Epoch 11/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1747 - categorical_accuracy: 0.9359
# Epoch 12/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1580 - categorical_accuracy: 0.9423
# Epoch 13/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1459 - categorical_accuracy: 0.9469
# Epoch 14/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2056 - categorical_accuracy: 0.9264
# Epoch 15/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1263 - categorical_accuracy: 0.9541
# Epoch 16/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1126 - categorical_accuracy: 0.9585
# Epoch 17/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1013 - categorical_accuracy: 0.9647
# Epoch 18/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0827 - categorical_accuracy: 0.9720
# Epoch 19/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0732 - categorical_accuracy: 0.9747
# Epoch 20/25
# 77/77 [==============================] - 2s 20ms/step - loss: 0.0939 - categorical_accuracy: 0.9709
# Epoch 21/25
# 77/77 [==============================] - 2s 19ms/step - loss: 0.1148 - categorical_accuracy: 0.9592
# Epoch 22/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0755 - categorical_accuracy: 0.9745
# Epoch 23/25
# 77/77 [==============================] - 2s 19ms/step - loss: 0.0468 - categorical_accuracy: 0.9863
# Epoch 24/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0365 - categorical_accuracy: 0.9905
# Epoch 25/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0432 - categorical_accuracy: 0.9880
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.48      0.57       546
#          1.0       0.92      0.44      0.59       182
#          2.0       0.41      0.98      0.58       182
#          3.0       0.87      0.93      0.90       182
#
#     accuracy                           0.63      1092
#    macro avg       0.72      0.71      0.66      1092
# weighted avg       0.72      0.63      0.63      1092
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 2
# FAR: 0.0
# MIR: 0.0625
# FRR: 0.0
# latency: 40237 ms
# ==== Session #1 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24929 ms
# ==== Session #2 ====
# # of detection: 28, acceptance: 28, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35797 ms
# ==== Session #3 ====
# # of detection: 65, acceptance: 12, rejection: 53
# # of FA: 12
# # of FR: 0
# # of MI: 0
# FAR: 0.18461538461538463
# MIR: 0.0
# FRR: 0.0
# latency: 42492 ms
# ==== Session #4 ====
# # of detection: 28, acceptance: 0, rejection: 28
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30724 ms
# ==== Session #5 ====
# # of detection: 33, acceptance: 3, rejection: 30
# # of FA: 3
# # of FR: 0
# # of MI: 0
# FAR: 0.09090909090909091
# MIR: 0.0
# FRR: 0.0
# latency: 36928 ms
# simulation result: FAR: 0.06696428571428571
# MIR: 0.008928571428571428
# FNR: 0.0
# latency: 35184.5 ms
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# [touch] pos: 6, neg: 6, fr: 1, tr: 4, fi: 1,
# [gait] pos: 6, neg: 6, fr: 1, tr: 3, fi: 1,
# [simple_average] pos: 6, neg: 6, fr: 1, tr: 5, fi: 1,
# [weighted_average_eer] pos: 6, neg: 6, fr: 1, tr: 4, fi: 1,
# [weighted_average_auc] pos: 6, neg: 6, fr: 1, tr: 5, fi: 1,
# [deer_dempster_shafer] pos: 6, neg: 6, fr: 1, tr: 5, fi: 1,
# [auc_dempster_shafer] pos: 6, neg: 6, fr: 1, tr: 5, fi: 0,
# [kalman_filter] pos: 6, neg: 6, fr: 1, tr: 5, fi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_200_10_3_3
# Negative trainer seed:100
# Game seed:200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:937904 (0), 751131 (1), 710707 (2)
# testers:923862, 538363, 808022
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.74      0.70      0.72        60
#            1       0.62      0.65      0.63        20
#            2       0.55      0.30      0.39        20
#            3       0.48      0.75      0.59        20
#
#     accuracy                           0.63       120
#    macro avg       0.60      0.60      0.58       120
# weighted avg       0.64      0.63      0.63       120
#
# Epoch 1/25
# 76/76 [==============================] - 5s 20ms/step - loss: 1.2623 - categorical_accuracy: 0.4831
# Epoch 2/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.9254 - categorical_accuracy: 0.5630
# Epoch 3/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.7887 - categorical_accuracy: 0.6491
# Epoch 4/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.6607 - categorical_accuracy: 0.7294
# Epoch 5/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.5590 - categorical_accuracy: 0.7776
# Epoch 6/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.4935 - categorical_accuracy: 0.8086
# Epoch 7/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.4294 - categorical_accuracy: 0.8340
# Epoch 8/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.3971 - categorical_accuracy: 0.8461
# Epoch 9/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.3396 - categorical_accuracy: 0.8684
# Epoch 10/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.2746 - categorical_accuracy: 0.8979
# Epoch 11/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.2516 - categorical_accuracy: 0.9047
# Epoch 12/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.2181 - categorical_accuracy: 0.9176
# Epoch 13/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.1944 - categorical_accuracy: 0.9271
# Epoch 14/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.1658 - categorical_accuracy: 0.9418
# Epoch 15/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.1446 - categorical_accuracy: 0.9470
# Epoch 16/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.1155 - categorical_accuracy: 0.9589
# Epoch 17/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.1044 - categorical_accuracy: 0.9628
# Epoch 18/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0887 - categorical_accuracy: 0.9707
# Epoch 19/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0618 - categorical_accuracy: 0.9830
# Epoch 20/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0468 - categorical_accuracy: 0.9874
# Epoch 21/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0417 - categorical_accuracy: 0.9888
# Epoch 22/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0336 - categorical_accuracy: 0.9911
# Epoch 23/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0427 - categorical_accuracy: 0.9878
# Epoch 24/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0753 - categorical_accuracy: 0.9724
# Epoch 25/25
# 76/76 [==============================] - 1s 19ms/step - loss: 0.0792 - categorical_accuracy: 0.9710
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.69      0.72       537
#          1.0       0.58      0.70      0.63       179
#          2.0       0.73      0.76      0.75       179
#          3.0       0.78      0.79      0.79       179
#
#     accuracy                           0.72      1074
#    macro avg       0.71      0.74      0.72      1074
# weighted avg       0.73      0.72      0.72      1074
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 24, acceptance: 24, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51631 ms
# ==== Session #1 ====
# # of detection: 50, acceptance: 29, rejection: 21
# # of FA: 0
# # of FR: 21
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.42
# latency: 38346 ms
# ==== Session #2 ====
# # of detection: 36, acceptance: 31, rejection: 5
# # of FA: 0
# # of FR: 5
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1388888888888889
# latency: 30747 ms
# ==== Session #3 ====
# # of detection: 43, acceptance: 0, rejection: 43
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20466 ms
# ==== Session #4 ====
# # of detection: 31, acceptance: 8, rejection: 23
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.25806451612903225
# MIR: 0.0
# FRR: 0.0
# latency: 53769 ms
# ==== Session #5 ====
# # of detection: 30, acceptance: 13, rejection: 17
# # of FA: 13
# # of FR: 0
# # of MI: 0
# FAR: 0.43333333333333335
# MIR: 0.0
# FRR: 0.0
# latency: 103460 ms
# simulation result: FAR: 0.09813084112149532
# MIR: 0.0
# FNR: 0.12149532710280374
# latency: 49736.5 ms
# 3 2
# 2 3
# [touch] pos: 9, neg: 9, fr: 1, tr: 7, fi: 3,
# [gait] pos: 9, neg: 9, fr: 3, tr: 6, fi: 1,
# [simple_average] pos: 9, neg: 9, fr: 3, tr: 8, fi: 1,
# [weighted_average_eer] pos: 9, neg: 9, fr: 2, tr: 7, fi: 1,
# [weighted_average_auc] pos: 9, neg: 9, fr: 3, tr: 8, fi: 1,
# [deer_dempster_shafer] pos: 9, neg: 9, fr: 3, tr: 8, fi: 1,
# [auc_dempster_shafer] pos: 9, neg: 9, fr: 3, tr: 8, fi: 0,
# [kalman_filter] pos: 9, neg: 9, fr: 3, tr: 8, fi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_300_10_3_3
# Negative trainer seed:100
# Game seed:300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:865881 (0), 396697 (1), 342329 (2)
# testers:966655, 368258, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75        24
#            1       0.70      0.88      0.78         8
#            2       1.00      1.00      1.00         8
#            3       0.50      0.38      0.43         8
#
#     accuracy                           0.75        48
#    macro avg       0.74      0.75      0.74        48
# weighted avg       0.74      0.75      0.74        48
#
# Epoch 1/25
# 59/59 [==============================] - 5s 21ms/step - loss: 1.4484 - categorical_accuracy: 0.4793
# Epoch 2/25
# 59/59 [==============================] - 1s 19ms/step - loss: 1.0140 - categorical_accuracy: 0.5841
# Epoch 3/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.8669 - categorical_accuracy: 0.6483
# Epoch 4/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.7554 - categorical_accuracy: 0.6899
# Epoch 5/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.6641 - categorical_accuracy: 0.7295
# Epoch 6/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.6060 - categorical_accuracy: 0.7512
# Epoch 7/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.6257 - categorical_accuracy: 0.7434
# Epoch 8/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.5652 - categorical_accuracy: 0.7792
# Epoch 9/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.5084 - categorical_accuracy: 0.7986
# Epoch 10/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.4901 - categorical_accuracy: 0.7989
# Epoch 11/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.4511 - categorical_accuracy: 0.8206
# Epoch 12/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.4301 - categorical_accuracy: 0.8356
# Epoch 13/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.4438 - categorical_accuracy: 0.8296
# Epoch 14/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.3847 - categorical_accuracy: 0.8509
# Epoch 15/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.3237 - categorical_accuracy: 0.8733
# Epoch 16/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.2844 - categorical_accuracy: 0.8941
# Epoch 17/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.2547 - categorical_accuracy: 0.9023
# Epoch 18/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.2216 - categorical_accuracy: 0.9213
# Epoch 19/25
# 59/59 [==============================] - 1s 20ms/step - loss: 0.1948 - categorical_accuracy: 0.9302
# Epoch 20/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1785 - categorical_accuracy: 0.9351
# Epoch 21/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1564 - categorical_accuracy: 0.9471
# Epoch 22/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1648 - categorical_accuracy: 0.9415
# Epoch 23/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1206 - categorical_accuracy: 0.9577
# Epoch 24/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.1068 - categorical_accuracy: 0.9632
# Epoch 25/25
# 59/59 [==============================] - 1s 19ms/step - loss: 0.0953 - categorical_accuracy: 0.9696
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.71      0.77       417
#          1.0       0.51      0.62      0.56       139
#          2.0       0.79      0.99      0.88       139
#          3.0       0.85      0.88      0.87       139
#
#     accuracy                           0.77       834
#    macro avg       0.75      0.80      0.77       834
# weighted avg       0.78      0.77      0.77       834
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41440 ms
# ==== Session #1 ====
# # of detection: 15, acceptance: 15, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51690 ms
# ==== Session #2 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36415 ms
# ==== Session #3 ====
# # of detection: 63, acceptance: 0, rejection: 63
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31558 ms
# ==== Session #4 ====
# # of detection: 19, acceptance: 19, rejection: 0
# # of FA: 19
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 83, acceptance: 0, rejection: 83
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 16173 ms
# simulation result: FAR: 0.07723577235772358
# MIR: 0.0
# FNR: 0.0
# latency: 29545.833333333332 ms
# 1 2
# [touch] pos: 12, neg: 12, fr: 1, tr: 9, fi: 3,
# [gait] pos: 12, neg: 12, fr: 3, tr: 9, fi: 1,
# [simple_average] pos: 12, neg: 12, fr: 3, tr: 11, fi: 1,
# [weighted_average_eer] pos: 12, neg: 12, fr: 2, tr: 10, fi: 1,
# [weighted_average_auc] pos: 12, neg: 12, fr: 3, tr: 11, fi: 1,
# [deer_dempster_shafer] pos: 12, neg: 12, fr: 3, tr: 11, fi: 1,
# [auc_dempster_shafer] pos: 12, neg: 12, fr: 3, tr: 11, fi: 0,
# [kalman_filter] pos: 12, neg: 12, fr: 3, tr: 10, fi: 2,
#
# file saved.
# ========== SETUP ===========
# Game name:100_400_10_3_3
# Negative trainer seed:100
# Game seed:400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:827212 (0), 277905 (1), 556357 (2)
# testers:720193, 966655, 554303
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.92        27
#            1       1.00      0.67      0.80         9
#            2       0.86      0.67      0.75         9
#            3       0.89      0.89      0.89         9
#
#     accuracy                           0.87        54
#    macro avg       0.90      0.81      0.84        54
# weighted avg       0.88      0.87      0.86        54
#
# Epoch 1/25
# 6/6 [==============================] - 4s 21ms/step - loss: 2.7055 - categorical_accuracy: 0.3399
# Epoch 2/25
# 6/6 [==============================] - 0s 19ms/step - loss: 1.2812 - categorical_accuracy: 0.4304
# Epoch 3/25
# 6/6 [==============================] - 0s 20ms/step - loss: 1.0883 - categorical_accuracy: 0.5630
# Epoch 4/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.9730 - categorical_accuracy: 0.5643
# Epoch 5/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.8581 - categorical_accuracy: 0.6286
# Epoch 6/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.7996 - categorical_accuracy: 0.6614
# Epoch 7/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.8066 - categorical_accuracy: 0.6654
# Epoch 8/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.7104 - categorical_accuracy: 0.6877
# Epoch 9/25
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6308 - categorical_accuracy: 0.7677
# Epoch 10/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.5513 - categorical_accuracy: 0.7874
# Epoch 11/25
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4054 - categorical_accuracy: 0.8635
# Epoch 12/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3548 - categorical_accuracy: 0.8793
# Epoch 13/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3277 - categorical_accuracy: 0.8990
# Epoch 14/25
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2635 - categorical_accuracy: 0.9199
# Epoch 15/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2466 - categorical_accuracy: 0.9147
# Epoch 16/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2058 - categorical_accuracy: 0.9357
# Epoch 17/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.2188 - categorical_accuracy: 0.9370
# Epoch 18/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1756 - categorical_accuracy: 0.9436
# Epoch 19/25
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2078 - categorical_accuracy: 0.9291
# Epoch 20/25
# 6/6 [==============================] - 0s 20ms/step - loss: 0.2125 - categorical_accuracy: 0.9304
# Epoch 21/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1605 - categorical_accuracy: 0.9554
# Epoch 22/25
# 6/6 [==============================] - 0s 20ms/step - loss: 0.1319 - categorical_accuracy: 0.9580
# Epoch 23/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.1172 - categorical_accuracy: 0.9619
# Epoch 24/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0978 - categorical_accuracy: 0.9751
# Epoch 25/25
# 6/6 [==============================] - 0s 19ms/step - loss: 0.0795 - categorical_accuracy: 0.9790
# gait
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.86      0.92        42
#          1.0       0.85      0.79      0.81        14
#          2.0       0.72      0.93      0.81        14
#          3.0       0.82      1.00      0.90        14
#
#     accuracy                           0.88        84
#    macro avg       0.85      0.89      0.86        84
# weighted avg       0.90      0.88      0.88        84
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 54, acceptance: 54, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.14814814814814814
# FRR: 0.0
# latency: 28037 ms
# ==== Session #1 ====
# # of detection: 22, acceptance: 22, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 46818 ms
# ==== Session #2 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 43537 ms
# ==== Session #3 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26168 ms
# ==== Session #4 ====
# # of detection: 63, acceptance: 0, rejection: 63
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31558 ms
# ==== Session #5 ====
# # of detection: 47, acceptance: 0, rejection: 47
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 37377 ms
# simulation result: FAR: 0.0
# MIR: 0.03305785123966942
# FNR: 0.0
# latency: 35582.5 ms
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# [touch] pos: 15, neg: 15, fr: 1, tr: 12, fi: 4,
# [gait] pos: 15, neg: 15, fr: 3, tr: 11, fi: 1,
# [simple_average] pos: 15, neg: 15, fr: 3, tr: 13, fi: 2,
# [weighted_average_eer] pos: 15, neg: 15, fr: 2, tr: 12, fi: 1,
# [weighted_average_auc] pos: 15, neg: 15, fr: 3, tr: 13, fi: 2,
# [deer_dempster_shafer] pos: 15, neg: 15, fr: 3, tr: 14, fi: 2,
# [auc_dempster_shafer] pos: 15, neg: 15, fr: 3, tr: 14, fi: 1,
# [kalman_filter] pos: 15, neg: 15, fr: 3, tr: 13, fi: 2,
#
# file saved.
# ========== SETUP ===========
# Game name:100_500_10_3_3
# Negative trainer seed:100
# Game seed:500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:990622 (0), 863985 (1), 698266 (2)
# testers:737973, 796581, 980953
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.84      0.69      0.76        39
#            1       0.56      0.69      0.62        13
#            2       0.67      0.92      0.77        13
#            3       0.67      0.62      0.64        13
#
#     accuracy                           0.72        78
#    macro avg       0.68      0.73      0.70        78
# weighted avg       0.74      0.72      0.72        78
#
# Epoch 1/25
# 72/72 [==============================] - 5s 21ms/step - loss: 1.2100 - categorical_accuracy: 0.5653
# Epoch 2/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.8441 - categorical_accuracy: 0.6469
# Epoch 3/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.7062 - categorical_accuracy: 0.7183
# Epoch 4/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.5640 - categorical_accuracy: 0.7710
# Epoch 5/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.4442 - categorical_accuracy: 0.8174
# Epoch 6/25
# 72/72 [==============================] - 1s 20ms/step - loss: 0.4136 - categorical_accuracy: 0.8258
# Epoch 7/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.3574 - categorical_accuracy: 0.8519
# Epoch 8/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.3234 - categorical_accuracy: 0.8667
# Epoch 9/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.3603 - categorical_accuracy: 0.8557
# Epoch 10/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2802 - categorical_accuracy: 0.8895
# Epoch 11/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2347 - categorical_accuracy: 0.9097
# Epoch 12/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2198 - categorical_accuracy: 0.9167
# Epoch 13/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1903 - categorical_accuracy: 0.9293
# Epoch 14/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.4133 - categorical_accuracy: 0.8467
# Epoch 15/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2039 - categorical_accuracy: 0.9286
# Epoch 16/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1332 - categorical_accuracy: 0.9528
# Epoch 17/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1326 - categorical_accuracy: 0.9543
# Epoch 18/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0960 - categorical_accuracy: 0.9656
# Epoch 19/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0956 - categorical_accuracy: 0.9676
# Epoch 20/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0674 - categorical_accuracy: 0.9786
# Epoch 21/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0718 - categorical_accuracy: 0.9769
# Epoch 22/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0544 - categorical_accuracy: 0.9823
# Epoch 23/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0332 - categorical_accuracy: 0.9920
# Epoch 24/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0275 - categorical_accuracy: 0.9941
# Epoch 25/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0305 - categorical_accuracy: 0.9926
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.75      0.79       507
#          1.0       0.61      0.81      0.70       169
#          2.0       0.58      0.70      0.63       169
#          3.0       0.98      0.76      0.85       169
#
#     accuracy                           0.75      1014
#    macro avg       0.75      0.75      0.74      1014
# weighted avg       0.78      0.75      0.76      1014
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 45, acceptance: 44, rejection: 1
# # of FA: 0
# # of FR: 1
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.022222222222222223
# latency: 41465 ms
# ==== Session #1 ====
# # of detection: 31, acceptance: 31, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 38361 ms
# ==== Session #2 ====
# # of detection: 54, acceptance: 54, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 16948 ms
# ==== Session #3 ====
# # of detection: 34, acceptance: 0, rejection: 34
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31139 ms
# ==== Session #4 ====
# # of detection: 22, acceptance: 0, rejection: 22
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 32410 ms
# ==== Session #5 ====
# # of detection: 6, acceptance: 0, rejection: 6
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41023 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.005208333333333333
# latency: 33557.666666666664 ms
# 2 3
# 2 3
# [touch] pos: 18, neg: 18, fr: 2, tr: 15, fi: 5,
# [gait] pos: 18, neg: 18, fr: 4, tr: 13, fi: 1,
# [simple_average] pos: 18, neg: 18, fr: 4, tr: 16, fi: 2,
# [weighted_average_eer] pos: 18, neg: 18, fr: 3, tr: 15, fi: 2,
# [weighted_average_auc] pos: 18, neg: 18, fr: 4, tr: 16, fi: 2,
# [deer_dempster_shafer] pos: 18, neg: 18, fr: 4, tr: 17, fi: 2,
# [auc_dempster_shafer] pos: 18, neg: 18, fr: 4, tr: 17, fi: 1,
# [kalman_filter] pos: 18, neg: 18, fr: 4, tr: 16, fi: 2,
#
# file saved.
# ========== SETUP ===========
# Game name:100_600_10_3_3
# Negative trainer seed:100
# Game seed:600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:657486 (0), 865881 (1), 220962 (2)
# testers:803262, 876011, 554303
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.92      0.67      0.77        36
#            1       0.92      1.00      0.96        12
#            2       0.58      0.92      0.71        12
#            3       0.50      0.58      0.54        12
#
#     accuracy                           0.75        72
#    macro avg       0.73      0.79      0.75        72
# weighted avg       0.80      0.75      0.76        72
#
# Epoch 1/25
# 61/61 [==============================] - 6s 20ms/step - loss: 1.1666 - categorical_accuracy: 0.5593
# Epoch 2/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.7108 - categorical_accuracy: 0.7031
# Epoch 3/25
# 61/61 [==============================] - 1s 20ms/step - loss: 0.6457 - categorical_accuracy: 0.7271
# Epoch 4/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.5841 - categorical_accuracy: 0.7564
# Epoch 5/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.5341 - categorical_accuracy: 0.7799
# Epoch 6/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.4795 - categorical_accuracy: 0.8042
# Epoch 7/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.3953 - categorical_accuracy: 0.8421
# Epoch 8/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.4271 - categorical_accuracy: 0.8257
# Epoch 9/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.3596 - categorical_accuracy: 0.8568
# Epoch 10/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.3285 - categorical_accuracy: 0.8726
# Epoch 11/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2690 - categorical_accuracy: 0.8956
# Epoch 12/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2706 - categorical_accuracy: 0.8914
# Epoch 13/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2119 - categorical_accuracy: 0.9156
# Epoch 14/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2791 - categorical_accuracy: 0.8900
# Epoch 15/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2830 - categorical_accuracy: 0.8860
# Epoch 16/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.2053 - categorical_accuracy: 0.9215
# Epoch 17/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.1707 - categorical_accuracy: 0.9345
# Epoch 18/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.1827 - categorical_accuracy: 0.9289
# Epoch 19/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.1343 - categorical_accuracy: 0.9493
# Epoch 20/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0966 - categorical_accuracy: 0.9672
# Epoch 21/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0960 - categorical_accuracy: 0.9668
# Epoch 22/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0791 - categorical_accuracy: 0.9744
# Epoch 23/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0661 - categorical_accuracy: 0.9801
# Epoch 24/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0458 - categorical_accuracy: 0.9877
# Epoch 25/25
# 61/61 [==============================] - 1s 19ms/step - loss: 0.0363 - categorical_accuracy: 0.9916
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.67      0.75       429
#          1.0       0.69      0.97      0.81       143
#          2.0       0.56      0.68      0.61       143
#          3.0       0.96      0.96      0.96       143
#
#     accuracy                           0.77       858
#    macro avg       0.77      0.82      0.78       858
# weighted avg       0.79      0.77      0.77       858
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 28, acceptance: 28, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 16
# FAR: 0.0
# MIR: 0.5714285714285714
# FRR: 0.0
# latency: 26899 ms
# ==== Session #1 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41440 ms
# ==== Session #2 ====
# # of detection: 15, acceptance: 9, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.4
# latency: 114214 ms
# ==== Session #3 ====
# # of detection: 29, acceptance: 8, rejection: 21
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.27586206896551724
# MIR: 0.0
# FRR: 0.0
# latency: 47838 ms
# ==== Session #4 ====
# # of detection: 11, acceptance: 11, rejection: 0
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 47, acceptance: 0, rejection: 47
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 37377 ms
# simulation result: FAR: 0.11728395061728394
# MIR: 0.09876543209876543
# FNR: 0.037037037037037035
# latency: 44627.833333333336 ms
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# 2 1
# [touch] pos: 21, neg: 21, fr: 2, tr: 17, fi: 5,
# [gait] pos: 21, neg: 21, fr: 5, tr: 15, fi: 2,
# [simple_average] pos: 21, neg: 21, fr: 5, tr: 18, fi: 3,
# [weighted_average_eer] pos: 21, neg: 21, fr: 3, tr: 17, fi: 3,
# [weighted_average_auc] pos: 21, neg: 21, fr: 5, tr: 18, fi: 3,
# [deer_dempster_shafer] pos: 21, neg: 21, fr: 5, tr: 19, fi: 3,
# [auc_dempster_shafer] pos: 21, neg: 21, fr: 5, tr: 19, fi: 2,
# [kalman_filter] pos: 21, neg: 21, fr: 4, tr: 18, fi: 3,
#
# file saved.
# ========== SETUP ===========
# Game name:100_700_10_3_3
# Negative trainer seed:100
# Game seed:700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:395129 (0), 151985 (1), 717868 (2)
# testers:937904, 100669, 720193
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        27
#            1       0.75      1.00      0.86         9
#            2       0.75      1.00      0.86         9
#            3       1.00      0.33      0.50         9
#
#     accuracy                           0.83        54
#    macro avg       0.85      0.81      0.78        54
# weighted avg       0.86      0.83      0.81        54
#
# Epoch 1/25
# 16/16 [==============================] - 5s 21ms/step - loss: 2.1813 - categorical_accuracy: 0.4203
# Epoch 2/25
# 16/16 [==============================] - 0s 19ms/step - loss: 1.1268 - categorical_accuracy: 0.5221
# Epoch 3/25
# 16/16 [==============================] - 0s 19ms/step - loss: 1.0033 - categorical_accuracy: 0.5998
# Epoch 4/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.9632 - categorical_accuracy: 0.6307
# Epoch 5/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.9177 - categorical_accuracy: 0.6260
# Epoch 6/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.9084 - categorical_accuracy: 0.6193
# Epoch 7/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.8358 - categorical_accuracy: 0.6451
# Epoch 8/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.7829 - categorical_accuracy: 0.6929
# Epoch 9/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.7548 - categorical_accuracy: 0.6878
# Epoch 10/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.7647 - categorical_accuracy: 0.6919
# Epoch 11/25
# 16/16 [==============================] - 0s 20ms/step - loss: 0.7552 - categorical_accuracy: 0.7099
# Epoch 12/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.7453 - categorical_accuracy: 0.7171
# Epoch 13/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.6991 - categorical_accuracy: 0.7274
# Epoch 14/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.6394 - categorical_accuracy: 0.7598
# Epoch 15/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.5812 - categorical_accuracy: 0.7809
# Epoch 16/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.5139 - categorical_accuracy: 0.8045
# Epoch 17/25
# 16/16 [==============================] - 0s 20ms/step - loss: 0.5805 - categorical_accuracy: 0.7824
# Epoch 18/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.5236 - categorical_accuracy: 0.8076
# Epoch 19/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4700 - categorical_accuracy: 0.8333
# Epoch 20/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4650 - categorical_accuracy: 0.8251
# Epoch 21/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.4268 - categorical_accuracy: 0.8395
# Epoch 22/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.3904 - categorical_accuracy: 0.8596
# Epoch 23/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.3025 - categorical_accuracy: 0.8951
# Epoch 24/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.2826 - categorical_accuracy: 0.9028
# Epoch 25/25
# 16/16 [==============================] - 0s 19ms/step - loss: 0.2614 - categorical_accuracy: 0.9131
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.39      0.55       105
#          1.0       0.75      0.94      0.84        35
#          2.0       0.50      1.00      0.67        35
#          3.0       0.58      0.89      0.70        35
#
#     accuracy                           0.67       210
#    macro avg       0.70      0.80      0.69       210
# weighted avg       0.78      0.67      0.64       210
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 18, acceptance: 18, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51307 ms
# ==== Session #1 ====
# # of detection: 33, acceptance: 33, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 42161 ms
# ==== Session #2 ====
# # of detection: 11, acceptance: 0, rejection: 11
# # of FA: 0
# # of FR: 11
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 1.0
# latency: -1 ms
# ==== Session #3 ====
# # of detection: 24, acceptance: 0, rejection: 24
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51631 ms
# ==== Session #4 ====
# # of detection: 49, acceptance: 11, rejection: 38
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.22448979591836735
# MIR: 0.0
# FRR: 0.0
# latency: 41992 ms
# ==== Session #5 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26168 ms
# simulation result: FAR: 0.06470588235294118
# MIR: 0.0
# FNR: 0.06470588235294118
# latency: 35543.0 ms
# [touch] pos: 24, neg: 24, fr: 2, tr: 20, fi: 5,
# [gait] pos: 24, neg: 24, fr: 6, tr: 17, fi: 2,
# [simple_average] pos: 24, neg: 24, fr: 6, tr: 20, fi: 3,
# [weighted_average_eer] pos: 24, neg: 24, fr: 4, tr: 19, fi: 3,
# [weighted_average_auc] pos: 24, neg: 24, fr: 6, tr: 20, fi: 3,
# [deer_dempster_shafer] pos: 24, neg: 24, fr: 6, tr: 22, fi: 3,
# [auc_dempster_shafer] pos: 24, neg: 24, fr: 6, tr: 22, fi: 2,
# [kalman_filter] pos: 24, neg: 24, fr: 4, tr: 21, fi: 3,
#
# file saved.
# ========== SETUP ===========
# Game name:100_800_10_3_3
# Negative trainer seed:100
# Game seed:800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:745224 (0), 472761 (1), 962159 (2)
# testers:733568, 588087, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78        21
#            1       0.75      0.86      0.80         7
#            2       1.00      0.71      0.83         7
#            3       0.67      0.86      0.75         7
#
#     accuracy                           0.79        42
#    macro avg       0.80      0.80      0.79        42
# weighted avg       0.80      0.79      0.79        42
#
# Epoch 1/25
# 67/67 [==============================] - 5s 21ms/step - loss: 1.0369 - categorical_accuracy: 0.6200
# Epoch 2/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.6256 - categorical_accuracy: 0.7272
# Epoch 3/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.5321 - categorical_accuracy: 0.7855
# Epoch 4/25
# 67/67 [==============================] - 1s 20ms/step - loss: 0.4675 - categorical_accuracy: 0.8192
# Epoch 5/25
# 67/67 [==============================] - 1s 20ms/step - loss: 0.4222 - categorical_accuracy: 0.8372
# Epoch 6/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.3780 - categorical_accuracy: 0.8576
# Epoch 7/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.3510 - categorical_accuracy: 0.8682
# Epoch 8/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.3073 - categorical_accuracy: 0.8831
# Epoch 9/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.2667 - categorical_accuracy: 0.8978
# Epoch 10/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.2667 - categorical_accuracy: 0.9022
# Epoch 11/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.2162 - categorical_accuracy: 0.9195
# Epoch 12/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.1937 - categorical_accuracy: 0.9285
# Epoch 13/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.1707 - categorical_accuracy: 0.9382
# Epoch 14/25
# 67/67 [==============================] - 1s 19ms/step - loss: 0.1769 - categorical_accuracy: 0.9341
# Epoch 15/25
# ...
# Epoch 5/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3656 - categorical_accuracy: 0.8550
# Epoch 6/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3360 - categorical_accuracy: 0.8704
# Epoch 7/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2917 - categorical_accuracy: 0.8854
# Epoch 8/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3323 - categorical_accuracy: 0.8658
# Epoch 9/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2438 - categorical_accuracy: 0.9065
# Epoch 10/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2202 - categorical_accuracy: 0.9154
# Epoch 11/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2911 - categorical_accuracy: 0.8903
# Epoch 12/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2176 - categorical_accuracy: 0.9163
# Epoch 13/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1648 - categorical_accuracy: 0.9403
# Epoch 14/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1748 - categorical_accuracy: 0.9345
# Epoch 15/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1261 - categorical_accuracy: 0.9539
# Epoch 16/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1494 - categorical_accuracy: 0.9424
# Epoch 17/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1575 - categorical_accuracy: 0.9382
# Epoch 18/25
# 77/77 [==============================] - 2s 19ms/step - loss: 0.1396 - categorical_accuracy: 0.9491
# Epoch 19/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0988 - categorical_accuracy: 0.9640
# Epoch 20/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1060 - categorical_accuracy: 0.9583
# Epoch 21/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0674 - categorical_accuracy: 0.9760
# Epoch 22/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0872 - categorical_accuracy: 0.9682
# Epoch 23/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0551 - categorical_accuracy: 0.9819
# Epoch 24/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.1232 - categorical_accuracy: 0.9526
# Epoch 25/25
# 77/77 [==============================] - 1s 19ms/step - loss: 0.0491 - categorical_accuracy: 0.9845
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.78      0.86       546
#          1.0       1.00      0.95      0.97       182
#          2.0       1.00      0.98      0.99       182
#          3.0       0.59      0.97      0.73       182
#
#     accuracy                           0.87      1092
#    macro avg       0.89      0.92      0.89      1092
# weighted avg       0.91      0.87      0.88      1092
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 42066 ms
# ==== Session #1 ====
# # of detection: 22, acceptance: 22, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 46114 ms
# ==== Session #2 ====
# # of detection: 28, acceptance: 28, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35797 ms
# ==== Session #3 ====
# # of detection: 57, acceptance: 6, rejection: 51
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.10526315789473684
# MIR: 0.0
# FRR: 0.0
# latency: 29812 ms
# ==== Session #4 ====
# # of detection: 32, acceptance: 0, rejection: 32
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41440 ms
# ==== Session #5 ====
# # of detection: 25, acceptance: 0, rejection: 25
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 46738 ms
# simulation result: FAR: 0.032432432432432434
# MIR: 0.0
# FNR: 0.0
# latency: 40327.833333333336 ms
# [touch] pos: 144, neg: 144, fr: 22, tr: 120, fi: 16,
# [gait] pos: 144, neg: 143, fr: 42, tr: 102, fi: 10,
# [simple_average] pos: 144, neg: 144, fr: 50, tr: 117, fi: 14,
# [weighted_average_eer] pos: 144, neg: 144, fr: 44, tr: 113, fi: 14,
# [weighted_average_auc] pos: 144, neg: 144, fr: 49, tr: 116, fi: 13,
# [deer_dempster_shafer] pos: 144, neg: 144, fr: 43, tr: 124, fi: 9,
# [auc_dempster_shafer] pos: 144, neg: 144, fr: 41, tr: 128, fi: 8,
# [kalman_filter] pos: 144, neg: 144, fr: 29, tr: 121, fi: 26,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4800_10_3_3
# Negative trainer seed:100
# Game seed:4800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:799296 (0), 863985 (1), 336172 (2)
# testers:763813, 856302, 277905
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.67      0.67      0.67        27
#            1       0.29      0.22      0.25         9
#            2       0.75      1.00      0.86         9
#            3       0.75      0.67      0.71         9
#
#     accuracy                           0.65        54
#    macro avg       0.61      0.64      0.62        54
# weighted avg       0.63      0.65      0.64        54
#
# Epoch 1/25
# 72/72 [==============================] - 5s 19ms/step - loss: 1.2035 - categorical_accuracy: 0.5387
# Epoch 2/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.8006 - categorical_accuracy: 0.6613
# Epoch 3/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.6504 - categorical_accuracy: 0.7232
# Epoch 4/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.5521 - categorical_accuracy: 0.7775
# Epoch 5/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.4230 - categorical_accuracy: 0.8318
# Epoch 6/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.4728 - categorical_accuracy: 0.8050
# Epoch 7/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.3656 - categorical_accuracy: 0.8598
# Epoch 8/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2912 - categorical_accuracy: 0.8878
# Epoch 9/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2528 - categorical_accuracy: 0.9062
# Epoch 10/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.2051 - categorical_accuracy: 0.9257
# Epoch 11/25
# 72/72 [==============================] - 1s 18ms/step - loss: 0.1819 - categorical_accuracy: 0.9361
# Epoch 12/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1519 - categorical_accuracy: 0.9458
# Epoch 13/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1335 - categorical_accuracy: 0.9514
# Epoch 14/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1032 - categorical_accuracy: 0.9628
# Epoch 15/25
# 72/72 [==============================] - 1s 18ms/step - loss: 0.1009 - categorical_accuracy: 0.9633
# Epoch 16/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0865 - categorical_accuracy: 0.9707
# Epoch 17/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.1342 - categorical_accuracy: 0.9570
# Epoch 18/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0756 - categorical_accuracy: 0.9756
# Epoch 19/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0356 - categorical_accuracy: 0.9926
# Epoch 20/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0284 - categorical_accuracy: 0.9942
# Epoch 21/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0175 - categorical_accuracy: 0.9978
# Epoch 22/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0132 - categorical_accuracy: 0.9981
# Epoch 23/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0102 - categorical_accuracy: 0.9986
# Epoch 24/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0122 - categorical_accuracy: 0.9977
# Epoch 25/25
# 72/72 [==============================] - 1s 19ms/step - loss: 0.0198 - categorical_accuracy: 0.9951
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.55      0.70       507
#          1.0       0.93      0.98      0.95       169
#          2.0       0.58      0.89      0.70       169
#          3.0       0.58      0.98      0.73       169
#
#     accuracy                           0.75      1014
#    macro avg       0.76      0.85      0.77      1014
# weighted avg       0.83      0.75      0.75      1014
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 25, acceptance: 25, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41039 ms
# ==== Session #1 ====
# # of detection: 31, acceptance: 31, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 38361 ms
# ==== Session #2 ====
# # of detection: 83, acceptance: 83, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 16173 ms
# ==== Session #3 ====
# # of detection: 19, acceptance: 0, rejection: 19
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51300 ms
# ==== Session #4 ====
# # of detection: 55, acceptance: 0, rejection: 55
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41325 ms
# ==== Session #5 ====
# # of detection: 22, acceptance: 5, rejection: 17
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.22727272727272727
# MIR: 0.0
# FRR: 0.0
# latency: 78433 ms
# simulation result: FAR: 0.02127659574468085
# MIR: 0.0
# FNR: 0.0
# latency: 44438.5 ms
# 1 3
# [touch] pos: 147, neg: 147, fr: 23, tr: 123, fi: 17,
# [gait] pos: 147, neg: 146, fr: 42, tr: 104, fi: 10,
# [simple_average] pos: 147, neg: 147, fr: 50, tr: 120, fi: 14,
# [weighted_average_eer] pos: 147, neg: 147, fr: 44, tr: 116, fi: 14,
# [weighted_average_auc] pos: 147, neg: 147, fr: 49, tr: 119, fi: 13,
# [deer_dempster_shafer] pos: 147, neg: 147, fr: 43, tr: 127, fi: 9,
# [auc_dempster_shafer] pos: 147, neg: 147, fr: 42, tr: 131, fi: 8,
# [kalman_filter] pos: 147, neg: 147, fr: 29, tr: 123, fi: 26,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4900_10_3_3
# Negative trainer seed:100
# Game seed:4900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:264325 (0), 342329 (1), 218719 (2)
# testers:396697, 556357, 220962
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.67      0.42      0.51        24
#            1       0.42      1.00      0.59         8
#            2       0.50      0.38      0.43         8
#            3       0.62      0.62      0.62         8
#
#     accuracy                           0.54        48
#    macro avg       0.55      0.60      0.54        48
# weighted avg       0.59      0.54      0.53        48
#
# Epoch 1/25
# 96/96 [==============================] - 6s 20ms/step - loss: 1.1578 - categorical_accuracy: 0.5759
# Epoch 2/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.7508 - categorical_accuracy: 0.7167
# Epoch 3/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.6518 - categorical_accuracy: 0.7566
# Epoch 4/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.5460 - categorical_accuracy: 0.7948
# Epoch 5/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.4605 - categorical_accuracy: 0.8236
# Epoch 6/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.3871 - categorical_accuracy: 0.8549
# Epoch 7/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.3772 - categorical_accuracy: 0.8582
# Epoch 8/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.3284 - categorical_accuracy: 0.8767
# Epoch 9/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.2659 - categorical_accuracy: 0.8994
# Epoch 10/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.2776 - categorical_accuracy: 0.8990
# Epoch 11/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.2414 - categorical_accuracy: 0.9098
# Epoch 12/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.2396 - categorical_accuracy: 0.9130
# Epoch 13/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1834 - categorical_accuracy: 0.9345
# Epoch 14/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1930 - categorical_accuracy: 0.9299
# Epoch 15/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1952 - categorical_accuracy: 0.9296
# Epoch 16/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1454 - categorical_accuracy: 0.9471
# Epoch 17/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1524 - categorical_accuracy: 0.9485
# Epoch 18/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1071 - categorical_accuracy: 0.9643
# Epoch 19/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0851 - categorical_accuracy: 0.9711
# Epoch 20/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0795 - categorical_accuracy: 0.9725
# Epoch 21/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0899 - categorical_accuracy: 0.9707
# Epoch 22/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.1190 - categorical_accuracy: 0.9583
# Epoch 23/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0716 - categorical_accuracy: 0.9766
# Epoch 24/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0775 - categorical_accuracy: 0.9726
# Epoch 25/25
# 96/96 [==============================] - 2s 19ms/step - loss: 0.0685 - categorical_accuracy: 0.9777
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.85      0.91       678
#          1.0       0.74      0.96      0.83       226
#          2.0       0.88      0.95      0.91       226
#          3.0       0.99      0.97      0.98       226
#
#     accuracy                           0.91      1356
#    macro avg       0.89      0.93      0.91      1356
# weighted avg       0.92      0.91      0.91      1356
#
# training done
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 27, acceptance: 27, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41635 ms
# ==== Session #1 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36415 ms
# ==== Session #2 ====
# # of detection: 48, acceptance: 39, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1875
# latency: 47764 ms
# ==== Session #3 ====
# # of detection: 13, acceptance: 13, rejection: 0
# # of FA: 13
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #4 ====
# # of detection: 21, acceptance: 17, rejection: 4
# # of FA: 17
# # of FR: 0
# # of MI: 0
# FAR: 0.8095238095238095
# MIR: 0.0
# FRR: 0.0
# latency: 92744 ms
# ==== Session #5 ====
# # of detection: 15, acceptance: 0, rejection: 15
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 51771 ms
# simulation result: FAR: 0.189873417721519
# MIR: 0.0
# FNR: 0.056962025316455694
# latency: 45054.666666666664 ms
# 1 3
# 1 3
# 1 3
# 1 3
# [touch] pos: 150, neg: 150, fr: 25, tr: 123, fi: 17,
# [gait] pos: 150, neg: 149, fr: 42, tr: 105, fi: 10,
# [simple_average] pos: 150, neg: 150, fr: 50, tr: 122, fi: 15,
# [weighted_average_eer] pos: 150, neg: 150, fr: 44, tr: 118, fi: 15,
# [weighted_average_auc] pos: 150, neg: 150, fr: 49, tr: 121, fi: 14,
# [deer_dempster_shafer] pos: 150, neg: 150, fr: 44, tr: 129, fi: 9,
# [auc_dempster_shafer] pos: 150, neg: 150, fr: 43, tr: 133, fi: 8,
# [kalman_filter] pos: 150, neg: 150, fr: 29, tr: 124, fi: 27,
#
# file saved.

# %%
#@title Experiment 1.2: 3 + 3 training sessions

last_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 3, 3)
    score_pairs = gen_per_segment_decision(tml, player)
    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022_3/re_accuracy_3_3", str(seed)))
# Out:
# ========== SETUP ===========
# Game name:100_0_10_3_3
# Negative trainer seed:100
# Game seed:0
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:554303 (0), 663153 (1), 710707 (2)
# testers:171538, 277905, 771782
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.97      0.85      0.90        39
#            1       0.68      1.00      0.81        13
#            2       1.00      0.92      0.96        13
#            3       0.69      0.69      0.69        13
#
#     accuracy                           0.86        78
#    macro avg       0.84      0.87      0.84        78
# weighted avg       0.88      0.86      0.86        78
#
# Epoch 1/25
# 115/115 [==============================] - 6s 19ms/step - loss: 1.0854 - categorical_accuracy: 0.6210
# Epoch 2/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.7383 - categorical_accuracy: 0.7022
# Epoch 3/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.6340 - categorical_accuracy: 0.7514
# Epoch 4/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.5159 - categorical_accuracy: 0.8055
# Epoch 5/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.4195 - categorical_accuracy: 0.8469
# Epoch 6/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3727 - categorical_accuracy: 0.8612
# Epoch 7/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.3220 - categorical_accuracy: 0.8811
# Epoch 8/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2777 - categorical_accuracy: 0.8957
# Epoch 9/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.2782 - categorical_accuracy: 0.9012
# Epoch 10/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.2111 - categorical_accuracy: 0.9244
# Epoch 11/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1877 - categorical_accuracy: 0.9317
# Epoch 12/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1656 - categorical_accuracy: 0.9395
# Epoch 13/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.1377 - categorical_accuracy: 0.9508
# Epoch 14/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.1206 - categorical_accuracy: 0.9582
# Epoch 15/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.0942 - categorical_accuracy: 0.9673
# Epoch 16/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.0996 - categorical_accuracy: 0.9656
# Epoch 17/25
# 115/115 [==============================] - 2s 18ms/step - loss: 0.0956 - categorical_accuracy: 0.9650
# Epoch 18/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0882 - categorical_accuracy: 0.9686
# Epoch 19/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0731 - categorical_accuracy: 0.9758
# Epoch 20/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0570 - categorical_accuracy: 0.9808
# Epoch 21/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0320 - categorical_accuracy: 0.9907
# Epoch 22/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0344 - categorical_accuracy: 0.9900
# Epoch 23/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0912 - categorical_accuracy: 0.9684
# Epoch 24/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0553 - categorical_accuracy: 0.9820
# Epoch 25/25
# 115/115 [==============================] - 2s 19ms/step - loss: 0.0384 - categorical_accuracy: 0.9876
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.65      0.76       813
#          1.0       0.94      0.89      0.91       271
#          2.0       0.62      0.94      0.75       271
#          3.0       0.67      0.96      0.79       271
#
#     accuracy                           0.79      1626
#    macro avg       0.79      0.86      0.80      1626
# weighted avg       0.83      0.79      0.79      1626
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 64, acceptance: 55, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.140625
# latency: 26004 ms
# ==== Session #1 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25650 ms
# ==== Session #2 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 21794 ms
# ==== Session #3 ====
# # of detection: 66, acceptance: 14, rejection: 52
# # of FA: 14
# # of FR: 0
# # of MI: 0
# FAR: 0.21212121212121213
# MIR: 0.0
# FRR: 0.0
# latency: 25864 ms
# ==== Session #4 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 21
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 54, acceptance: 0, rejection: 54
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 21771 ms
# simulation result: FAR: 0.11363636363636363
# MIR: 0.0
# FNR: 0.02922077922077922
# latency: 20180.333333333332 ms
# 1 3
# 1 2
# [touch] pos: 3, neg: 3, fr: 2, tr: 2, fi: 1,
# [gait] pos: 3, neg: 3, fr: 0, tr: 2, fi: 0,
# [simple_average] pos: 3, neg: 3, fr: 0, tr: 3, fi: 0,
# [weighted_average_eer] pos: 3, neg: 3, fr: 0, tr: 1, fi: 0,
# [weighted_average_auc] pos: 3, neg: 3, fr: 0, tr: 3, fi: 0,
# [deer_dempster_shafer] pos: 3, neg: 3, fr: 0, tr: 3, fi: 0,
# [auc_dempster_shafer] pos: 3, neg: 3, fr: 0, tr: 3, fi: 0,
# [kalman_filter] pos: 3, neg: 3, fr: 0, tr: 2, fi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_100_10_3_3
# Negative trainer seed:100
# Game seed:100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:257279 (0), 771782 (1), 526319 (2)
# testers:431312, 777078, 693572
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.88      0.77      0.82        30
#            1       0.60      0.90      0.72        10
#            2       1.00      0.80      0.89        10
#            3       0.91      1.00      0.95        10
#
#     accuracy                           0.83        60
#    macro avg       0.85      0.87      0.85        60
# weighted avg       0.86      0.83      0.84        60
#
# Epoch 1/25
# 108/108 [==============================] - 6s 20ms/step - loss: 1.1321 - categorical_accuracy: 0.5518
# Epoch 2/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.7710 - categorical_accuracy: 0.6717
# Epoch 3/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.6284 - categorical_accuracy: 0.7457
# Epoch 4/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.4634 - categorical_accuracy: 0.8172
# Epoch 5/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.3235 - categorical_accuracy: 0.8723
# Epoch 6/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.2648 - categorical_accuracy: 0.9008
# Epoch 7/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.2803 - categorical_accuracy: 0.8907
# Epoch 8/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.2394 - categorical_accuracy: 0.9079
# Epoch 9/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.2012 - categorical_accuracy: 0.9245
# Epoch 10/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.1713 - categorical_accuracy: 0.9365
# Epoch 11/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.1599 - categorical_accuracy: 0.9396
# Epoch 12/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1559 - categorical_accuracy: 0.9398
# Epoch 13/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.1251 - categorical_accuracy: 0.9546
# Epoch 14/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1019 - categorical_accuracy: 0.9615
# Epoch 15/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0887 - categorical_accuracy: 0.9688
# Epoch 16/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.1114 - categorical_accuracy: 0.9593
# Epoch 17/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0680 - categorical_accuracy: 0.9761
# Epoch 18/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0576 - categorical_accuracy: 0.9812
# Epoch 19/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0541 - categorical_accuracy: 0.9827
# Epoch 20/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0373 - categorical_accuracy: 0.9890
# Epoch 21/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0486 - categorical_accuracy: 0.9831
# Epoch 22/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0350 - categorical_accuracy: 0.9897
# Epoch 23/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0325 - categorical_accuracy: 0.9899
# Epoch 24/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0220 - categorical_accuracy: 0.9936
# Epoch 25/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.0235 - categorical_accuracy: 0.9927
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.54      0.67       765
#          1.0       0.96      0.85      0.90       255
#          2.0       0.42      0.93      0.58       255
#          3.0       0.88      0.91      0.90       255
#
#     accuracy                           0.72      1530
#    macro avg       0.78      0.81      0.76      1530
# weighted avg       0.81      0.72      0.73      1530
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25725 ms
# ==== Session #1 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25563 ms
# ==== Session #2 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24519 ms
# ==== Session #3 ====
# # of detection: 83, acceptance: 0, rejection: 83
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 16730 ms
# ==== Session #4 ====
# # of detection: 45, acceptance: 0, rejection: 45
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25640 ms
# ==== Session #5 ====
# # of detection: 50, acceptance: 0, rejection: 50
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 29738 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.0
# latency: 24652.5 ms
# 3 2
# 3 2
# [touch] pos: 6, neg: 6, fr: 3, tr: 4, fi: 1,
# [gait] pos: 6, neg: 6, fr: 1, tr: 5, fi: 0,
# [simple_average] pos: 6, neg: 6, fr: 1, tr: 6, fi: 0,
# [weighted_average_eer] pos: 6, neg: 6, fr: 0, tr: 4, fi: 1,
# [weighted_average_auc] pos: 6, neg: 6, fr: 1, tr: 6, fi: 1,
# [deer_dempster_shafer] pos: 6, neg: 6, fr: 0, tr: 6, fi: 0,
# [auc_dempster_shafer] pos: 6, neg: 6, fr: 0, tr: 6, fi: 0,
# [kalman_filter] pos: 6, neg: 6, fr: 0, tr: 5, fi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_200_10_3_3
# Negative trainer seed:100
# Game seed:200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:937904 (0), 751131 (1), 710707 (2)
# testers:923862, 538363, 808022
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72        87
#            1       0.45      0.34      0.39        29
#            2       0.78      0.72      0.75        29
#            3       0.62      0.86      0.72        29
#
#     accuracy                           0.68       174
#    macro avg       0.65      0.66      0.65       174
# weighted avg       0.67      0.68      0.67       174
#
# Epoch 1/25
# 110/110 [==============================] - 6s 20ms/step - loss: 1.1808 - categorical_accuracy: 0.4964
# Epoch 2/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.9252 - categorical_accuracy: 0.5766
# Epoch 3/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.7683 - categorical_accuracy: 0.6734
# Epoch 4/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.6612 - categorical_accuracy: 0.7331
# Epoch 5/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.5927 - categorical_accuracy: 0.7605
# Epoch 6/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.4841 - categorical_accuracy: 0.8132
# Epoch 7/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.4283 - categorical_accuracy: 0.8354
# Epoch 8/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3702 - categorical_accuracy: 0.8587
# Epoch 9/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.3228 - categorical_accuracy: 0.8778
# Epoch 10/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2765 - categorical_accuracy: 0.8958
# Epoch 11/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.2359 - categorical_accuracy: 0.9120
# Epoch 12/25
# 110/110 [==============================] - 2s 18ms/step - loss: 0.1935 - categorical_accuracy: 0.9314
# Epoch 13/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1661 - categorical_accuracy: 0.9397
# Epoch 14/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1476 - categorical_accuracy: 0.9460
# Epoch 15/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1160 - categorical_accuracy: 0.9605
# Epoch 16/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.1032 - categorical_accuracy: 0.9646
# Epoch 17/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0829 - categorical_accuracy: 0.9718
# Epoch 18/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0630 - categorical_accuracy: 0.9803
# Epoch 19/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0528 - categorical_accuracy: 0.9827
# Epoch 20/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0524 - categorical_accuracy: 0.9839
# Epoch 21/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0432 - categorical_accuracy: 0.9862
# Epoch 22/25
# 110/110 [==============================] - 2s 18ms/step - loss: 0.0588 - categorical_accuracy: 0.9795
# Epoch 23/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0447 - categorical_accuracy: 0.9856
# Epoch 24/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0395 - categorical_accuracy: 0.9861
# Epoch 25/25
# 110/110 [==============================] - 2s 19ms/step - loss: 0.0390 - categorical_accuracy: 0.9904
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.64      0.65       777
#          1.0       0.43      0.68      0.53       259
#          2.0       0.60      0.58      0.59       259
#          3.0       0.75      0.42      0.54       259
#
#     accuracy                           0.60      1554
#    macro avg       0.61      0.58      0.58      1554
# weighted avg       0.63      0.60      0.60      1554
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 41, acceptance: 41, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #1 ====
# # of detection: 69, acceptance: 69, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25980 ms
# ==== Session #2 ====
# # of detection: 51, acceptance: 43, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1568627450980392
# latency: 29324 ms
# ==== Session #3 ====
# # of detection: 58, acceptance: 0, rejection: 58
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15949 ms
# ==== Session #4 ====
# # of detection: 45, acceptance: 26, rejection: 19
# # of FA: 26
# # of FR: 0
# # of MI: 0
# FAR: 0.5777777777777777
# MIR: 0.0
# FRR: 0.0
# latency: 37094 ms
# ==== Session #5 ====
# # of detection: 39, acceptance: 16, rejection: 23
# # of FA: 16
# # of FR: 0
# # of MI: 0
# FAR: 0.41025641025641024
# MIR: 0.0
# FRR: 0.0
# latency: 31265 ms
# simulation result: FAR: 0.13861386138613863
# MIR: 0.0
# FNR: 0.026402640264026403
# latency: 27603.166666666668 ms
# 2 3
# 1 2
# [touch] pos: 9, neg: 9, fr: 3, tr: 7, fi: 2,
# [gait] pos: 9, neg: 9, fr: 4, tr: 8, fi: 0,
# [simple_average] pos: 9, neg: 9, fr: 1, tr: 9, fi: 0,
# [weighted_average_eer] pos: 9, neg: 9, fr: 0, tr: 6, fi: 1,
# [weighted_average_auc] pos: 9, neg: 9, fr: 1, tr: 9, fi: 1,
# [deer_dempster_shafer] pos: 9, neg: 9, fr: 0, tr: 9, fi: 0,
# [auc_dempster_shafer] pos: 9, neg: 9, fr: 0, tr: 9, fi: 0,
# [kalman_filter] pos: 9, neg: 9, fr: 0, tr: 8, fi: 2,
#
# file saved.
# ========== SETUP ===========
# Game name:100_300_10_3_3
# Negative trainer seed:100
# Game seed:300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:865881 (0), 396697 (1), 342329 (2)
# testers:966655, 368258, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.90      0.83      0.86        42
#            1       0.70      1.00      0.82        14
#            2       1.00      0.93      0.96        14
#            3       0.67      0.57      0.62        14
#
#     accuracy                           0.83        84
#    macro avg       0.82      0.83      0.82        84
# weighted avg       0.84      0.83      0.83        84
#
# Epoch 1/25
# 100/100 [==============================] - 6s 19ms/step - loss: 1.0346 - categorical_accuracy: 0.6144
# Epoch 2/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.7477 - categorical_accuracy: 0.7032
# Epoch 3/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.5453 - categorical_accuracy: 0.7847
# Epoch 4/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.4819 - categorical_accuracy: 0.8070
# Epoch 5/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.4169 - categorical_accuracy: 0.8334
# Epoch 6/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.3649 - categorical_accuracy: 0.8551
# Epoch 7/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.3405 - categorical_accuracy: 0.8694
# Epoch 8/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.3289 - categorical_accuracy: 0.8731
# Epoch 9/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.2588 - categorical_accuracy: 0.9037
# Epoch 10/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.2573 - categorical_accuracy: 0.9025
# Epoch 11/25
# 100/100 [==============================] - 2s 18ms/step - loss: 0.2073 - categorical_accuracy: 0.9220
# Epoch 12/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1833 - categorical_accuracy: 0.9331
# Epoch 13/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1570 - categorical_accuracy: 0.9421
# Epoch 14/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1328 - categorical_accuracy: 0.9531
# Epoch 15/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1397 - categorical_accuracy: 0.9521
# Epoch 16/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.1092 - categorical_accuracy: 0.9607
# Epoch 17/25
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0866 - categorical_accuracy: 0.9704
# Epoch 18/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0718 - categorical_accuracy: 0.9782
# Epoch 19/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0678 - categorical_accuracy: 0.9764
# Epoch 20/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0569 - categorical_accuracy: 0.9807
# Epoch 21/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0761 - categorical_accuracy: 0.9734
# Epoch 22/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0616 - categorical_accuracy: 0.9794
# Epoch 23/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0380 - categorical_accuracy: 0.9883
# Epoch 24/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0516 - categorical_accuracy: 0.9831
# Epoch 25/25
# 100/100 [==============================] - 2s 19ms/step - loss: 0.0364 - categorical_accuracy: 0.9891
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.83      0.74      0.78       708
#          1.0       0.57      0.96      0.72       236
#          2.0       0.95      0.95      0.95       236
#          3.0       0.90      0.58      0.71       236
#
#     accuracy                           0.78      1416
#    macro avg       0.81      0.81      0.79      1416
# weighted avg       0.82      0.78      0.79      1416
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 49, acceptance: 49, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# ==== Session #1 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25962 ms
# ==== Session #2 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25680 ms
# ==== Session #3 ====
# # of detection: 80, acceptance: 0, rejection: 80
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# ==== Session #4 ====
# # of detection: 33, acceptance: 11, rejection: 22
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.3333333333333333
# MIR: 0.0
# FRR: 0.0
# latency: 25924 ms
# ==== Session #5 ====
# # of detection: 100, acceptance: 0, rejection: 100
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# simulation result: FAR: 0.03188405797101449
# MIR: 0.0
# FNR: 0.0
# latency: 24166.833333333332 ms
# 1 2
# 2 3
# [touch] pos: 12, neg: 12, fr: 4, tr: 9, fi: 2,
# [gait] pos: 12, neg: 12, fr: 4, tr: 11, fi: 0,
# [simple_average] pos: 12, neg: 12, fr: 1, tr: 12, fi: 0,
# [weighted_average_eer] pos: 12, neg: 12, fr: 0, tr: 9, fi: 1,
# [weighted_average_auc] pos: 12, neg: 12, fr: 1, tr: 12, fi: 1,
# [deer_dempster_shafer] pos: 12, neg: 12, fr: 0, tr: 12, fi: 0,
# [auc_dempster_shafer] pos: 12, neg: 12, fr: 0, tr: 12, fi: 0,
# [kalman_filter] pos: 12, neg: 12, fr: 0, tr: 11, fi: 4,
#
# file saved.
# ========== SETUP ===========
# Game name:100_400_10_3_3
# Negative trainer seed:100
# Game seed:400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:827212 (0), 277905 (1), 556357 (2)
# testers:720193, 966655, 554303
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        36
#            1       1.00      0.67      0.80        12
#            2       1.00      1.00      1.00        12
#            3       0.73      0.92      0.81        12
#
#     accuracy                           0.93        72
#    macro avg       0.93      0.90      0.90        72
# weighted avg       0.94      0.93      0.93        72
#
# Epoch 1/25
# 9/9 [==============================] - 4s 28ms/step - loss: 2.4655 - categorical_accuracy: 0.4454
# Epoch 2/25
# 9/9 [==============================] - 0s 19ms/step - loss: 1.1391 - categorical_accuracy: 0.5019
# Epoch 3/25
# 9/9 [==============================] - 0s 19ms/step - loss: 1.0177 - categorical_accuracy: 0.5556
# Epoch 4/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.9148 - categorical_accuracy: 0.6157
# Epoch 5/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.8551 - categorical_accuracy: 0.6333
# Epoch 6/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7414 - categorical_accuracy: 0.6704
# Epoch 7/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7099 - categorical_accuracy: 0.7148
# Epoch 8/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6507 - categorical_accuracy: 0.7352
# Epoch 9/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.5355 - categorical_accuracy: 0.8111
# Epoch 10/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4331 - categorical_accuracy: 0.8500
# Epoch 11/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4702 - categorical_accuracy: 0.8269
# Epoch 12/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.5548 - categorical_accuracy: 0.7722
# Epoch 13/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3769 - categorical_accuracy: 0.8528
# Epoch 14/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3324 - categorical_accuracy: 0.8722
# Epoch 15/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2759 - categorical_accuracy: 0.9019
# Epoch 16/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2790 - categorical_accuracy: 0.8907
# Epoch 17/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2330 - categorical_accuracy: 0.9213
# Epoch 18/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2217 - categorical_accuracy: 0.9194
# Epoch 19/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2109 - categorical_accuracy: 0.9269
# Epoch 20/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1809 - categorical_accuracy: 0.9435
# Epoch 21/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1580 - categorical_accuracy: 0.9463
# Epoch 22/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.1463 - categorical_accuracy: 0.9574
# Epoch 23/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1919 - categorical_accuracy: 0.9269
# Epoch 24/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.1818 - categorical_accuracy: 0.9296
# Epoch 25/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.2134 - categorical_accuracy: 0.9130
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.84      0.88        57
#          1.0       1.00      0.89      0.94        19
#          2.0       0.59      0.84      0.70        19
#          3.0       0.78      0.74      0.76        19
#
#     accuracy                           0.83       114
#    macro avg       0.82      0.83      0.82       114
# weighted avg       0.86      0.83      0.84       114
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 55, acceptance: 55, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.14545454545454545
# FRR: 0.0
# latency: 28037 ms
# ==== Session #1 ====
# # of detection: 22, acceptance: 22, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 46818 ms
# ==== Session #2 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25734 ms
# ==== Session #3 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24905 ms
# ==== Session #4 ====
# # of detection: 80, acceptance: 0, rejection: 80
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# ==== Session #5 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# simulation result: FAR: 0.0
# MIR: 0.025806451612903226
# FNR: 0.0
# latency: 29583.833333333332 ms
# 2 1
# 2 3
# [touch] pos: 15, neg: 15, fr: 4, tr: 12, fi: 3,
# [gait] pos: 15, neg: 15, fr: 5, tr: 14, fi: 0,
# [simple_average] pos: 15, neg: 15, fr: 2, tr: 15, fi: 0,
# [weighted_average_eer] pos: 15, neg: 15, fr: 1, tr: 12, fi: 1,
# [weighted_average_auc] pos: 15, neg: 15, fr: 2, tr: 15, fi: 1,
# [deer_dempster_shafer] pos: 15, neg: 15, fr: 0, tr: 15, fi: 0,
# [auc_dempster_shafer] pos: 15, neg: 15, fr: 0, tr: 15, fi: 0,
# [kalman_filter] pos: 15, neg: 15, fr: 0, tr: 14, fi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_500_10_3_3
# Negative trainer seed:100
# Game seed:500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:990622 (0), 863985 (1), 698266 (2)
# testers:737973, 796581, 980953
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.93      0.72      0.81        57
#            1       0.79      0.79      0.79        19
#            2       0.64      0.95      0.77        19
#            3       0.78      0.95      0.86        19
#
#     accuracy                           0.81       114
#    macro avg       0.79      0.85      0.81       114
# weighted avg       0.84      0.81      0.81       114
#
# Epoch 1/25
# 104/104 [==============================] - 6s 19ms/step - loss: 1.1974 - categorical_accuracy: 0.5516
# Epoch 2/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.8646 - categorical_accuracy: 0.6472
# Epoch 3/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.7619 - categorical_accuracy: 0.6923
# Epoch 4/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.5240 - categorical_accuracy: 0.7882
# Epoch 5/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.5082 - categorical_accuracy: 0.7967
# Epoch 6/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.3981 - categorical_accuracy: 0.8417
# Epoch 7/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.3442 - categorical_accuracy: 0.8590
# Epoch 8/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.3261 - categorical_accuracy: 0.8682
# Epoch 9/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.2790 - categorical_accuracy: 0.8896
# Epoch 10/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.2398 - categorical_accuracy: 0.9092
# Epoch 11/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.2314 - categorical_accuracy: 0.9100
# Epoch 12/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.2101 - categorical_accuracy: 0.9202
# Epoch 13/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.2091 - categorical_accuracy: 0.9211
# Epoch 14/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1568 - categorical_accuracy: 0.9417
# Epoch 15/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1530 - categorical_accuracy: 0.9436
# Epoch 16/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1379 - categorical_accuracy: 0.9492
# Epoch 17/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1009 - categorical_accuracy: 0.9648
# Epoch 18/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1974 - categorical_accuracy: 0.9325
# Epoch 19/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1472 - categorical_accuracy: 0.9467
# Epoch 20/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0896 - categorical_accuracy: 0.9696
# Epoch 21/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0567 - categorical_accuracy: 0.9838
# Epoch 22/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0638 - categorical_accuracy: 0.9797
# Epoch 23/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0397 - categorical_accuracy: 0.9889
# Epoch 24/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.0324 - categorical_accuracy: 0.9916
# Epoch 25/25
# 104/104 [==============================] - 2s 19ms/step - loss: 0.1152 - categorical_accuracy: 0.9646
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.76      0.77       732
#          1.0       0.73      0.25      0.37       244
#          2.0       0.52      0.91      0.66       244
#          3.0       0.76      0.72      0.74       244
#
#     accuracy                           0.70      1464
#    macro avg       0.70      0.66      0.64      1464
# weighted avg       0.72      0.70      0.68      1464
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 61, acceptance: 61, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31203 ms
# ==== Session #1 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25986 ms
# ==== Session #2 ====
# # of detection: 76, acceptance: 76, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# ==== Session #3 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20927 ms
# ==== Session #4 ====
# # of detection: 34, acceptance: 0, rejection: 34
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #5 ====
# # of detection: 9, acceptance: 6, rejection: 3
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.6666666666666666
# MIR: 0.0
# FRR: 0.0
# latency: 77132 ms
# simulation result: FAR: 0.02197802197802198
# MIR: 0.0
# FNR: 0.0
# latency: 32486.666666666668 ms
# 2 3
# 1 2
# [touch] pos: 18, neg: 18, fr: 5, tr: 15, fi: 4,
# [gait] pos: 18, neg: 18, fr: 6, tr: 16, fi: 0,
# [simple_average] pos: 18, neg: 18, fr: 2, tr: 17, fi: 0,
# [weighted_average_eer] pos: 18, neg: 18, fr: 1, tr: 14, fi: 1,
# [weighted_average_auc] pos: 18, neg: 18, fr: 2, tr: 17, fi: 1,
# [deer_dempster_shafer] pos: 18, neg: 18, fr: 0, tr: 18, fi: 0,
# [auc_dempster_shafer] pos: 18, neg: 18, fr: 0, tr: 18, fi: 0,
# [kalman_filter] pos: 18, neg: 18, fr: 0, tr: 17, fi: 6,
#
# file saved.
# ========== SETUP ===========
# Game name:100_600_10_3_3
# Negative trainer seed:100
# Game seed:600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:657486 (0), 865881 (1), 220962 (2)
# testers:803262, 876011, 554303
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77        48
#            1       1.00      0.88      0.93        16
#            2       0.76      1.00      0.86        16
#            3       0.50      0.81      0.62        16
#
#     accuracy                           0.78        96
#    macro avg       0.79      0.84      0.80        96
# weighted avg       0.83      0.78      0.79        96
#
# Epoch 1/25
# 108/108 [==============================] - 6s 20ms/step - loss: 0.9713 - categorical_accuracy: 0.6173
# Epoch 2/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.6498 - categorical_accuracy: 0.7299
# Epoch 3/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.5806 - categorical_accuracy: 0.7616
# Epoch 4/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.5291 - categorical_accuracy: 0.7794
# Epoch 5/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.4709 - categorical_accuracy: 0.8112
# Epoch 6/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.4218 - categorical_accuracy: 0.8320
# Epoch 7/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.3752 - categorical_accuracy: 0.8519
# Epoch 8/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.3530 - categorical_accuracy: 0.8622
# Epoch 9/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.3189 - categorical_accuracy: 0.8753
# Epoch 10/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.2837 - categorical_accuracy: 0.8882
# Epoch 11/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.2493 - categorical_accuracy: 0.9020
# Epoch 12/25
# 108/108 [==============================] - 2s 18ms/step - loss: 0.2175 - categorical_accuracy: 0.9176
# Epoch 13/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.2096 - categorical_accuracy: 0.9209
# Epoch 14/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1793 - categorical_accuracy: 0.9313
# Epoch 15/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1507 - categorical_accuracy: 0.9456
# Epoch 16/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1452 - categorical_accuracy: 0.9461
# Epoch 17/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1310 - categorical_accuracy: 0.9505
# Epoch 18/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1073 - categorical_accuracy: 0.9608
# Epoch 19/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0928 - categorical_accuracy: 0.9664
# Epoch 20/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0944 - categorical_accuracy: 0.9660
# Epoch 21/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0633 - categorical_accuracy: 0.9794
# Epoch 22/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0579 - categorical_accuracy: 0.9813
# Epoch 23/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0711 - categorical_accuracy: 0.9739
# Epoch 24/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0551 - categorical_accuracy: 0.9817
# Epoch 25/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0581 - categorical_accuracy: 0.9803
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.62      0.73       765
#          1.0       0.65      0.84      0.74       255
#          2.0       0.58      0.95      0.72       255
#          3.0       0.96      0.94      0.95       255
#
#     accuracy                           0.76      1530
#    macro avg       0.77      0.84      0.78      1530
# weighted avg       0.81      0.76      0.76      1530
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 19, acceptance: 7, rejection: 12
# # of FA: 0
# # of FR: 12
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.631578947368421
# latency: 25934 ms
# ==== Session #1 ====
# # of detection: 49, acceptance: 49, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# ==== Session #2 ====
# # of detection: 32, acceptance: 23, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.28125
# latency: 72884 ms
# ==== Session #3 ====
# # of detection: 42, acceptance: 19, rejection: 23
# # of FA: 19
# # of FR: 0
# # of MI: 0
# FAR: 0.4523809523809524
# MIR: 0.0
# FRR: 0.0
# latency: 25669 ms
# ==== Session #4 ====
# # of detection: 19, acceptance: 19, rejection: 0
# # of FA: 19
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# simulation result: FAR: 0.1688888888888889
# MIR: 0.0
# FNR: 0.09333333333333334
# latency: 29396.5 ms
# 3 1
# 2 1
# 2 1
# 2 1
# [touch] pos: 21, neg: 21, fr: 6, tr: 17, fi: 5,
# [gait] pos: 21, neg: 21, fr: 7, tr: 18, fi: 0,
# [simple_average] pos: 21, neg: 21, fr: 3, tr: 19, fi: 1,
# [weighted_average_eer] pos: 21, neg: 21, fr: 2, tr: 16, fi: 2,
# [weighted_average_auc] pos: 21, neg: 21, fr: 3, tr: 19, fi: 2,
# [deer_dempster_shafer] pos: 21, neg: 21, fr: 1, tr: 20, fi: 0,
# [auc_dempster_shafer] pos: 21, neg: 21, fr: 1, tr: 20, fi: 0,
# [kalman_filter] pos: 21, neg: 21, fr: 1, tr: 19, fi: 6,
#
# file saved.
# ========== SETUP ===========
# Game name:100_700_10_3_3
# Negative trainer seed:100
# Game seed:700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:395129 (0), 151985 (1), 717868 (2)
# testers:937904, 100669, 720193
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.98      0.96      0.97        45
#            1       0.88      1.00      0.94        15
#            2       1.00      0.87      0.93        15
#            3       0.88      0.93      0.90        15
#
#     accuracy                           0.94        90
#    macro avg       0.93      0.94      0.93        90
# weighted avg       0.95      0.94      0.94        90
#
# Epoch 1/25
# 42/42 [==============================] - 5s 21ms/step - loss: 1.4563 - categorical_accuracy: 0.4904
# Epoch 2/25
# 42/42 [==============================] - 1s 19ms/step - loss: 1.0090 - categorical_accuracy: 0.5865
# Epoch 3/25
# 42/42 [==============================] - 1s 18ms/step - loss: 0.9288 - categorical_accuracy: 0.6096
# Epoch 4/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.8985 - categorical_accuracy: 0.6203
# Epoch 5/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.7820 - categorical_accuracy: 0.6916
# Epoch 6/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.8616 - categorical_accuracy: 0.6396
# Epoch 7/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.7990 - categorical_accuracy: 0.6753
# Epoch 8/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.7026 - categorical_accuracy: 0.7127
# Epoch 9/25
# 42/42 [==============================] - 1s 18ms/step - loss: 0.6643 - categorical_accuracy: 0.7247
# Epoch 10/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.6344 - categorical_accuracy: 0.7464
# Epoch 11/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.5462 - categorical_accuracy: 0.7881
# Epoch 12/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.4566 - categorical_accuracy: 0.8298
# Epoch 13/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.3953 - categorical_accuracy: 0.8498
# Epoch 14/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.3814 - categorical_accuracy: 0.8529
# Epoch 15/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.3088 - categorical_accuracy: 0.8842
# Epoch 16/25
# 42/42 [==============================] - 1s 18ms/step - loss: 0.2668 - categorical_accuracy: 0.9063
# Epoch 17/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.2378 - categorical_accuracy: 0.9172
# Epoch 18/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.2310 - categorical_accuracy: 0.9163
# Epoch 19/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.1774 - categorical_accuracy: 0.9405
# Epoch 20/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.1439 - categorical_accuracy: 0.9536
# Epoch 21/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.1404 - categorical_accuracy: 0.9538
# Epoch 22/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.1287 - categorical_accuracy: 0.9574
# Epoch 23/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.1266 - categorical_accuracy: 0.9561
# Epoch 24/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0946 - categorical_accuracy: 0.9700
# Epoch 25/25
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0626 - categorical_accuracy: 0.9863
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.36      0.49       294
#          1.0       0.71      0.97      0.82        98
#          2.0       0.41      0.95      0.57        98
#          3.0       0.66      0.62      0.64        98
#
#     accuracy                           0.60       588
#    macro avg       0.64      0.72      0.63       588
# weighted avg       0.69      0.60      0.58       588
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 35, acceptance: 35, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #1 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25692 ms
# ==== Session #2 ====
# # of detection: 25, acceptance: 14, rejection: 11
# # of FA: 0
# # of FR: 11
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.44
# latency: 31269 ms
# ==== Session #3 ====
# # of detection: 41, acceptance: 0, rejection: 41
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #4 ====
# # of detection: 66, acceptance: 0, rejection: 66
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26130 ms
# ==== Session #5 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24905 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.041044776119402986
# latency: 26611.833333333332 ms
# 1 2
# 2 3
# [touch] pos: 24, neg: 24, fr: 6, tr: 20, fi: 5,
# [gait] pos: 24, neg: 24, fr: 8, tr: 20, fi: 0,
# [simple_average] pos: 24, neg: 24, fr: 4, tr: 21, fi: 1,
# [weighted_average_eer] pos: 24, neg: 24, fr: 3, tr: 18, fi: 2,
# [weighted_average_auc] pos: 24, neg: 24, fr: 4, tr: 21, fi: 2,
# [deer_dempster_shafer] pos: 24, neg: 24, fr: 2, tr: 23, fi: 0,
# [auc_dempster_shafer] pos: 24, neg: 24, fr: 2, tr: 23, fi: 0,
# [kalman_filter] pos: 24, neg: 24, fr: 1, tr: 22, fi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_800_10_3_3
# Negative trainer seed:100
# Game seed:800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:745224 (0), 472761 (1), 962159 (2)
# testers:733568, 588087, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       1.00      0.70      0.82        33
#            1       0.85      1.00      0.92        11
#            2       0.73      1.00      0.85        11
#            3       0.73      1.00      0.85        11
#
#     accuracy                           0.85        66
#    macro avg       0.83      0.92      0.86        66
# weighted avg       0.89      0.85      0.85        66
#
# Epoch 1/25
# 103/103 [==============================] - 6s 20ms/step - loss: 0.9310 - categorical_accuracy: 0.6670
# Epoch 2/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.4982 - categorical_accuracy: 0.8047
# Epoch 3/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.4273 - categorical_accuracy: 0.8363
# Epoch 4/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.3742 - categorical_accuracy: 0.8616
# Epoch 5/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.3381 - categorical_accuracy: 0.8755
# Epoch 6/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.2981 - categorical_accuracy: 0.8911
# Epoch 7/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.2615 - categorical_accuracy: 0.9021
# Epoch 8/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.2256 - categorical_accuracy: 0.9171
# Epoch 9/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.1957 - categorical_accuracy: 0.9259
# Epoch 10/25
# 103/103 [==============================] - 2s 19ms/step - loss: 0.1676 - categorical_accuracy: 0.9377
# Epoch 11/25
# ...
# Epoch 5/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.2590 - categorical_accuracy: 0.8984
# Epoch 6/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.2028 - categorical_accuracy: 0.9206
# Epoch 7/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1530 - categorical_accuracy: 0.9446
# Epoch 8/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1963 - categorical_accuracy: 0.9257
# Epoch 9/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1056 - categorical_accuracy: 0.9616
# Epoch 10/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1183 - categorical_accuracy: 0.9562
# Epoch 11/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0751 - categorical_accuracy: 0.9723
# Epoch 12/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0727 - categorical_accuracy: 0.9746
# Epoch 13/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0669 - categorical_accuracy: 0.9756
# Epoch 14/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1110 - categorical_accuracy: 0.9585
# Epoch 15/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0660 - categorical_accuracy: 0.9754
# Epoch 16/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0392 - categorical_accuracy: 0.9882
# Epoch 17/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0418 - categorical_accuracy: 0.9857
# Epoch 18/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0744 - categorical_accuracy: 0.9750
# Epoch 19/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0256 - categorical_accuracy: 0.9930
# Epoch 20/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0593 - categorical_accuracy: 0.9793
# Epoch 21/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0383 - categorical_accuracy: 0.9867
# Epoch 22/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0146 - categorical_accuracy: 0.9968
# Epoch 23/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0184 - categorical_accuracy: 0.9945
# Epoch 24/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.1334 - categorical_accuracy: 0.9587
# Epoch 25/25
# 108/108 [==============================] - 2s 19ms/step - loss: 0.0569 - categorical_accuracy: 0.9790
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.93      0.87       765
#          1.0       0.99      0.93      0.96       255
#          2.0       0.99      0.50      0.67       255
#          3.0       0.82      0.90      0.86       255
#
#     accuracy                           0.85      1530
#    macro avg       0.90      0.82      0.84      1530
# weighted avg       0.87      0.85      0.85      1530
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 37, acceptance: 37, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36652 ms
# ==== Session #1 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31223 ms
# ==== Session #2 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24519 ms
# ==== Session #3 ====
# # of detection: 74, acceptance: 0, rejection: 74
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13889 ms
# ==== Session #4 ====
# # of detection: 49, acceptance: 0, rejection: 49
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# ==== Session #5 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25643 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.0
# latency: 26302.5 ms
# [touch] pos: 144, neg: 144, fr: 22, tr: 118, fi: 20,
# [gait] pos: 144, neg: 143, fr: 35, tr: 117, fi: 5,
# [simple_average] pos: 144, neg: 144, fr: 21, tr: 117, fi: 6,
# [weighted_average_eer] pos: 144, neg: 144, fr: 15, tr: 113, fi: 9,
# [weighted_average_auc] pos: 144, neg: 144, fr: 20, tr: 116, fi: 8,
# [deer_dempster_shafer] pos: 144, neg: 144, fr: 16, tr: 132, fi: 5,
# [auc_dempster_shafer] pos: 144, neg: 144, fr: 18, tr: 131, fi: 5,
# [kalman_filter] pos: 144, neg: 144, fr: 13, tr: 131, fi: 39,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4800_10_3_3
# Negative trainer seed:100
# Game seed:4800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:799296 (0), 863985 (1), 336172 (2)
# testers:763813, 856302, 277905
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.62      0.70        39
#            1       0.64      0.69      0.67        13
#            2       0.73      0.85      0.79        13
#            3       0.58      0.85      0.69        13
#
#     accuracy                           0.71        78
#    macro avg       0.69      0.75      0.71        78
# weighted avg       0.73      0.71      0.70        78
#
# Epoch 1/25
# 105/105 [==============================] - 7s 19ms/step - loss: 1.1189 - categorical_accuracy: 0.5757
# Epoch 2/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.7200 - categorical_accuracy: 0.6866
# Epoch 3/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.6356 - categorical_accuracy: 0.7321
# Epoch 4/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.5314 - categorical_accuracy: 0.7852
# Epoch 5/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.4547 - categorical_accuracy: 0.8231
# Epoch 6/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3829 - categorical_accuracy: 0.8545
# Epoch 7/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3272 - categorical_accuracy: 0.8767
# Epoch 8/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3198 - categorical_accuracy: 0.8793
# Epoch 9/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.3058 - categorical_accuracy: 0.8845
# Epoch 10/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.2514 - categorical_accuracy: 0.9038
# Epoch 11/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1887 - categorical_accuracy: 0.9297
# Epoch 12/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1746 - categorical_accuracy: 0.9341
# Epoch 13/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1525 - categorical_accuracy: 0.9456
# Epoch 14/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1254 - categorical_accuracy: 0.9549
# Epoch 15/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1680 - categorical_accuracy: 0.9370
# Epoch 16/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1733 - categorical_accuracy: 0.9372
# Epoch 17/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1097 - categorical_accuracy: 0.9603
# Epoch 18/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0690 - categorical_accuracy: 0.9778
# Epoch 19/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0709 - categorical_accuracy: 0.9759
# Epoch 20/25
# 105/105 [==============================] - 2s 18ms/step - loss: 0.0542 - categorical_accuracy: 0.9831
# Epoch 21/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0380 - categorical_accuracy: 0.9896
# Epoch 22/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.1459 - categorical_accuracy: 0.9478
# Epoch 23/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0352 - categorical_accuracy: 0.9896
# Epoch 24/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0616 - categorical_accuracy: 0.9804
# Epoch 25/25
# 105/105 [==============================] - 2s 19ms/step - loss: 0.0297 - categorical_accuracy: 0.9918
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.59      0.72       738
#          1.0       1.00      0.89      0.94       246
#          2.0       0.60      0.99      0.75       246
#          3.0       0.63      0.95      0.76       246
#
#     accuracy                           0.77      1476
#    macro avg       0.79      0.86      0.79      1476
# weighted avg       0.83      0.77      0.77      1476
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25695 ms
# ==== Session #1 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25986 ms
# ==== Session #2 ====
# # of detection: 100, acceptance: 100, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# ==== Session #3 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #4 ====
# # of detection: 73, acceptance: 0, rejection: 73
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #5 ====
# # of detection: 19, acceptance: 0, rejection: 19
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 62345 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.0
# latency: 30164.166666666668 ms
# [touch] pos: 147, neg: 147, fr: 24, tr: 121, fi: 20,
# [gait] pos: 147, neg: 146, fr: 35, tr: 119, fi: 5,
# [simple_average] pos: 147, neg: 147, fr: 21, tr: 120, fi: 6,
# [weighted_average_eer] pos: 147, neg: 147, fr: 15, tr: 116, fi: 9,
# [weighted_average_auc] pos: 147, neg: 147, fr: 20, tr: 119, fi: 8,
# [deer_dempster_shafer] pos: 147, neg: 147, fr: 16, tr: 135, fi: 5,
# [auc_dempster_shafer] pos: 147, neg: 147, fr: 18, tr: 134, fi: 5,
# [kalman_filter] pos: 147, neg: 147, fr: 13, tr: 134, fi: 39,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4900_10_3_3
# Negative trainer seed:100
# Game seed:4900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:264325 (0), 342329 (1), 218719 (2)
# testers:396697, 556357, 220962
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.81      0.62      0.70        42
#            1       0.35      0.43      0.39        14
#            2       0.50      0.64      0.56        14
#            3       0.59      0.71      0.65        14
#
#     accuracy                           0.61        84
#    macro avg       0.56      0.60      0.57        84
# weighted avg       0.65      0.61      0.62        84
#
# Epoch 1/25
# 143/143 [==============================] - 7s 19ms/step - loss: 1.0661 - categorical_accuracy: 0.5922
# Epoch 2/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.6638 - categorical_accuracy: 0.7417
# Epoch 3/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.5433 - categorical_accuracy: 0.7882
# Epoch 4/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.4625 - categorical_accuracy: 0.8218
# Epoch 5/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.3774 - categorical_accuracy: 0.8575
# Epoch 6/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.3180 - categorical_accuracy: 0.8788
# Epoch 7/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.2829 - categorical_accuracy: 0.8930
# Epoch 8/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.2636 - categorical_accuracy: 0.9019
# Epoch 9/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.2032 - categorical_accuracy: 0.9260
# Epoch 10/25
# 143/143 [==============================] - 3s 18ms/step - loss: 0.2016 - categorical_accuracy: 0.9266
# Epoch 11/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1647 - categorical_accuracy: 0.9416
# Epoch 12/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1388 - categorical_accuracy: 0.9509
# Epoch 13/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1423 - categorical_accuracy: 0.9487
# Epoch 14/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1113 - categorical_accuracy: 0.9616
# Epoch 15/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1016 - categorical_accuracy: 0.9655
# Epoch 16/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.1230 - categorical_accuracy: 0.9562
# Epoch 17/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0842 - categorical_accuracy: 0.9701
# Epoch 18/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0642 - categorical_accuracy: 0.9789
# Epoch 19/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0614 - categorical_accuracy: 0.9798
# Epoch 20/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0619 - categorical_accuracy: 0.9788
# Epoch 21/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0419 - categorical_accuracy: 0.9863
# Epoch 22/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0694 - categorical_accuracy: 0.9764
# Epoch 23/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0453 - categorical_accuracy: 0.9855
# Epoch 24/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0324 - categorical_accuracy: 0.9899
# Epoch 25/25
# 143/143 [==============================] - 3s 19ms/step - loss: 0.0290 - categorical_accuracy: 0.9912
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.74      0.78      1011
#          1.0       0.60      0.95      0.74       337
#          2.0       0.80      0.70      0.75       337
#          3.0       1.00      0.84      0.91       337
#
#     accuracy                           0.79      2022
#    macro avg       0.81      0.81      0.79      2022
# weighted avg       0.81      0.79      0.79      2022
#
# training done
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26280 ms
# ==== Session #1 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25680 ms
# ==== Session #2 ====
# # of detection: 66, acceptance: 66, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #3 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 32
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #4 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 38
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 32, acceptance: 0, rejection: 32
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26038 ms
# simulation result: FAR: 0.2661596958174905
# MIR: 0.0
# FNR: 0.0
# latency: 17280.5 ms
# [touch] pos: 150, neg: 150, fr: 26, tr: 121, fi: 20,
# [gait] pos: 150, neg: 149, fr: 35, tr: 120, fi: 5,
# [simple_average] pos: 150, neg: 150, fr: 21, tr: 121, fi: 6,
# [weighted_average_eer] pos: 150, neg: 150, fr: 15, tr: 117, fi: 9,
# [weighted_average_auc] pos: 150, neg: 150, fr: 20, tr: 120, fi: 8,
# [deer_dempster_shafer] pos: 150, neg: 150, fr: 16, tr: 136, fi: 5,
# [auc_dempster_shafer] pos: 150, neg: 150, fr: 18, tr: 135, fi: 5,
# [kalman_filter] pos: 150, neg: 150, fr: 13, tr: 135, fi: 39,
#
# file saved.

# %%
#@title Experiment 1.3: 5 users 3 + 3 training sessions

last_result = None

for seed in range(1600, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 5, 3)
    score_pairs = gen_per_segment_decision(tml, player)
    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022_3/re_accuracy_5_3_limit", str(seed)))
# Out:
# ========== SETUP ===========
# Game name:100_1600_10_5_5
# Negative trainer seed:100
# Game seed:1600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:785899 (0), 872895 (1), 277905 (2), 472761 (3), 396697 (4)
# testers:257279, 171538, 693572, 990622, 980953
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90        60
#            1       1.00      1.00      1.00        12
#            2       0.59      0.83      0.69        12
#            3       0.60      1.00      0.75        12
#            4       0.85      0.92      0.88        12
#            5       1.00      0.42      0.59        12
#
#     accuracy                           0.84       120
#    macro avg       0.83      0.84      0.80       120
# weighted avg       0.88      0.84      0.84       120
#
# Epoch 1/25
# 15/15 [==============================] - 3s 19ms/step - loss: 2.3386 - categorical_accuracy: 0.3728
# Epoch 2/25
# 15/15 [==============================] - 0s 17ms/step - loss: 1.2803 - categorical_accuracy: 0.4983
# Epoch 3/25
# 15/15 [==============================] - 0s 16ms/step - loss: 1.1218 - categorical_accuracy: 0.5656
# Epoch 4/25
# 15/15 [==============================] - 0s 17ms/step - loss: 1.0575 - categorical_accuracy: 0.5789
# Epoch 5/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.9086 - categorical_accuracy: 0.6667
# Epoch 6/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.7807 - categorical_accuracy: 0.7244
# Epoch 7/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6548 - categorical_accuracy: 0.7644
# Epoch 8/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.6520 - categorical_accuracy: 0.7472
# Epoch 9/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5072 - categorical_accuracy: 0.8117
# Epoch 10/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4126 - categorical_accuracy: 0.8483
# Epoch 11/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3722 - categorical_accuracy: 0.8667
# Epoch 12/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3869 - categorical_accuracy: 0.8611
# Epoch 13/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3772 - categorical_accuracy: 0.8628
# Epoch 14/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6996 - categorical_accuracy: 0.7211
# Epoch 15/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4952 - categorical_accuracy: 0.8222
# Epoch 16/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4051 - categorical_accuracy: 0.8556
# Epoch 17/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4000 - categorical_accuracy: 0.8483
# Epoch 18/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3246 - categorical_accuracy: 0.8756
# Epoch 19/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2696 - categorical_accuracy: 0.9000
# Epoch 20/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2466 - categorical_accuracy: 0.9128
# Epoch 21/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2453 - categorical_accuracy: 0.9067
# Epoch 22/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2962 - categorical_accuracy: 0.8878
# Epoch 23/25
# 15/15 [==============================] - 0s 17ms/step - loss: 0.3989 - categorical_accuracy: 0.8600
# Epoch 24/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3406 - categorical_accuracy: 0.8789
# Epoch 25/25
# 15/15 [==============================] - 0s 16ms/step - loss: 0.2495 - categorical_accuracy: 0.9150
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.55      0.67        95
#          1.0       0.70      1.00      0.83        19
#          2.0       0.63      1.00      0.78        19
#          3.0       0.52      0.79      0.62        19
#          4.0       0.41      0.47      0.44        19
#          5.0       0.48      0.53      0.50        19
#
#     accuracy                           0.65       190
#    macro avg       0.60      0.72      0.64       190
# weighted avg       0.70      0.65      0.65       190
#
# training done
# too short, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 44, acceptance: 28, rejection: 16
# # of FA: 0
# # of FR: 16
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.36363636363636365
# latency: 25687 ms
# ==== Session #1 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25638 ms
# ==== Session #2 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 47747 ms
# ==== Session #3 ====
# # of detection: 42, acceptance: 35, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.16666666666666666
# latency: 51527 ms
# ==== Session #4 ====
# # of detection: 31, acceptance: 31, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31108 ms
# ==== Session #5 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 51
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #6 ====
# # of detection: 61, acceptance: 0, rejection: 61
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 40301 ms
# ==== Session #7 ====
# # of detection: 50, acceptance: 40, rejection: 10
# # of FA: 40
# # of FR: 0
# # of MI: 0
# FAR: 0.8
# MIR: 0.0
# FRR: 0.0
# latency: 40068 ms
# ==== Session #8 ====
# # of detection: 59, acceptance: 0, rejection: 59
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41367 ms
# ==== Session #9 ====
# # of detection: 9, acceptance: 6, rejection: 3
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.6666666666666666
# MIR: 0.0
# FRR: 0.0
# latency: 77132 ms
# simulation result: FAR: 0.23891625615763548
# MIR: 0.0
# FNR: 0.05665024630541872
# latency: 38057.4 ms
# 5 3
# 5 3
# 3 4
# 4 5
# [touch] pos: 5, neg: 5, fr: 1, tr: 2, fi: 0,
# [gait] pos: 5, neg: 5, fr: 2, tr: 2, fi: 0,
# [simple_average] pos: 5, neg: 5, fr: 1, tr: 2, fi: 0,
# [weighted_average_eer] pos: 5, neg: 5, fr: 1, tr: 1, fi: 0,
# [weighted_average_auc] pos: 5, neg: 5, fr: 1, tr: 1, fi: 0,
# [deer_dempster_shafer] pos: 5, neg: 5, fr: 2, tr: 3, fi: 1,
# [auc_dempster_shafer] pos: 5, neg: 5, fr: 1, tr: 3, fi: 1,
# [kalman_filter] pos: 5, neg: 5, fr: 2, tr: 4, fi: 2,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1700_10_5_5
# Negative trainer seed:100
# Game seed:1700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:892687 (0), 527796 (1), 472761 (2), 431312 (3), 352716 (4)
# testers:698266, 962159, 863985, 100669, 621276
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.85        70
#            1       0.82      0.64      0.72        14
#            2       0.79      0.79      0.79        14
#            3       0.88      1.00      0.93        14
#            4       0.70      1.00      0.82        14
#            5       1.00      0.57      0.73        14
#
#     accuracy                           0.83       140
#    macro avg       0.84      0.81      0.81       140
# weighted avg       0.84      0.83      0.82       140
#
# Epoch 1/25
# 101/101 [==============================] - 4s 17ms/step - loss: 1.2318 - categorical_accuracy: 0.5527
# Epoch 2/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.8433 - categorical_accuracy: 0.6673
# Epoch 3/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.7462 - categorical_accuracy: 0.7108
# Epoch 4/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.6600 - categorical_accuracy: 0.7428
# Epoch 5/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.5690 - categorical_accuracy: 0.7820
# Epoch 6/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.5155 - categorical_accuracy: 0.8019
# Epoch 7/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.4513 - categorical_accuracy: 0.8314
# Epoch 8/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.3818 - categorical_accuracy: 0.8599
# Epoch 9/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.3585 - categorical_accuracy: 0.8665
# Epoch 10/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.2951 - categorical_accuracy: 0.8929
# Epoch 11/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.2576 - categorical_accuracy: 0.9069
# Epoch 12/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.2420 - categorical_accuracy: 0.9090
# Epoch 13/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.2042 - categorical_accuracy: 0.9275
# Epoch 14/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.2051 - categorical_accuracy: 0.9252
# Epoch 15/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.1693 - categorical_accuracy: 0.9377
# Epoch 16/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.1352 - categorical_accuracy: 0.9509
# Epoch 17/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.1140 - categorical_accuracy: 0.9619
# Epoch 18/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0895 - categorical_accuracy: 0.9727
# Epoch 19/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0926 - categorical_accuracy: 0.9687
# Epoch 20/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0780 - categorical_accuracy: 0.9741
# Epoch 21/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0802 - categorical_accuracy: 0.9747
# Epoch 22/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.1954 - categorical_accuracy: 0.9284
# Epoch 23/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.1266 - categorical_accuracy: 0.9545
# Epoch 24/25
# 101/101 [==============================] - 2s 17ms/step - loss: 0.0828 - categorical_accuracy: 0.9731
# Epoch 25/25
# 101/101 [==============================] - 2s 16ms/step - loss: 0.0683 - categorical_accuracy: 0.9782
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.64      0.70       715
#          1.0       0.58      0.63      0.61       143
#          2.0       0.90      0.76      0.83       143
#          3.0       0.49      0.69      0.57       143
#          4.0       0.56      0.62      0.59       143
#          5.0       0.69      0.94      0.79       143
#
#     accuracy                           0.68      1430
#    macro avg       0.66      0.71      0.68      1430
# weighted avg       0.70      0.68      0.69      1430
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 47, acceptance: 47, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36265 ms
# ==== Session #1 ====
# # of detection: 46, acceptance: 21, rejection: 25
# # of FA: 0
# # of FR: 25
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.5434782608695652
# latency: 25843 ms
# ==== Session #2 ====
# # of detection: 42, acceptance: 35, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.16666666666666666
# latency: 51527 ms
# ==== Session #3 ====
# # of detection: 82, acceptance: 82, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20624 ms
# ==== Session #4 ====
# # of detection: 29, acceptance: 29, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31137 ms
# ==== Session #5 ====
# # of detection: 76, acceptance: 0, rejection: 76
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# ==== Session #6 ====
# # of detection: 44, acceptance: 0, rejection: 44
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25631 ms
# ==== Session #7 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25986 ms
# ==== Session #8 ====
# # of detection: 63, acceptance: 0, rejection: 63
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41728 ms
# ==== Session #9 ====
# # of detection: 29, acceptance: 0, rejection: 29
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30839 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.064
# latency: 30536.5 ms
# 4 2
# 1 2
# 4 5
# [touch] pos: 10, neg: 9, fr: 2, tr: 6, fi: 1,
# [gait] pos: 10, neg: 10, fr: 5, tr: 7, fi: 0,
# [simple_average] pos: 10, neg: 10, fr: 4, tr: 7, fi: 0,
# [weighted_average_eer] pos: 10, neg: 10, fr: 4, tr: 6, fi: 0,
# [weighted_average_auc] pos: 10, neg: 10, fr: 4, tr: 6, fi: 0,
# [deer_dempster_shafer] pos: 10, neg: 10, fr: 4, tr: 8, fi: 1,
# [auc_dempster_shafer] pos: 10, neg: 10, fr: 3, tr: 8, fi: 1,
# [kalman_filter] pos: 10, neg: 10, fr: 3, tr: 9, fi: 4,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1800_10_5_5
# Negative trainer seed:100
# Game seed:1800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:862649 (0), 962159 (1), 220962 (2), 841866 (3), 366286 (4)
# testers:863985, 923862, 218719, 621276, 342329
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.81      0.62      0.70        55
#            1       1.00      0.64      0.78        11
#            2       0.83      0.91      0.87        11
#            3       0.45      0.82      0.58        11
#            4       0.60      0.82      0.69        11
#            5       0.64      0.82      0.72        11
#
#     accuracy                           0.71       110
#    macro avg       0.72      0.77      0.72       110
# weighted avg       0.76      0.71      0.71       110
#
# Epoch 1/25
# 183/183 [==============================] - 6s 17ms/step - loss: 1.0968 - categorical_accuracy: 0.5993
# Epoch 2/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.7152 - categorical_accuracy: 0.7303
# Epoch 3/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.5763 - categorical_accuracy: 0.7896
# Epoch 4/25
# 183/183 [==============================] - 3s 17ms/step - loss: 0.4632 - categorical_accuracy: 0.8329
# Epoch 5/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.4096 - categorical_accuracy: 0.8530
# Epoch 6/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.3564 - categorical_accuracy: 0.8716
# Epoch 7/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.3090 - categorical_accuracy: 0.8893
# Epoch 8/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.2751 - categorical_accuracy: 0.9011
# Epoch 9/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.2419 - categorical_accuracy: 0.9149
# Epoch 10/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.2089 - categorical_accuracy: 0.9258
# Epoch 11/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1820 - categorical_accuracy: 0.9363
# Epoch 12/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1600 - categorical_accuracy: 0.9431
# Epoch 13/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1360 - categorical_accuracy: 0.9549
# Epoch 14/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1211 - categorical_accuracy: 0.9588
# Epoch 15/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.1020 - categorical_accuracy: 0.9648
# Epoch 16/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0869 - categorical_accuracy: 0.9707
# Epoch 17/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0779 - categorical_accuracy: 0.9731
# Epoch 18/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0771 - categorical_accuracy: 0.9746
# Epoch 19/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0773 - categorical_accuracy: 0.9722
# Epoch 20/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0518 - categorical_accuracy: 0.9821
# Epoch 21/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0390 - categorical_accuracy: 0.9869
# Epoch 22/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0686 - categorical_accuracy: 0.9766
# Epoch 23/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0512 - categorical_accuracy: 0.9817
# Epoch 24/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0340 - categorical_accuracy: 0.9886
# Epoch 25/25
# 183/183 [==============================] - 3s 16ms/step - loss: 0.0190 - categorical_accuracy: 0.9940
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.81      0.85      1295
#          1.0       0.51      0.82      0.63       259
#          2.0       0.91      0.86      0.88       259
#          3.0       0.94      0.86      0.90       259
#          4.0       0.90      0.99      0.94       259
#          5.0       0.99      0.78      0.87       259
#
#     accuracy                           0.84      2590
#    macro avg       0.85      0.85      0.84      2590
# weighted avg       0.86      0.84      0.84      2590
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 36, acceptance: 27, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.25
# latency: 72096 ms
# ==== Session #1 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25631 ms
# ==== Session #2 ====
# # of detection: 32, acceptance: 19, rejection: 13
# # of FA: 0
# # of FR: 13
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.40625
# latency: 93464 ms
# ==== Session #3 ====
# # of detection: 74, acceptance: 74, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13889 ms
# ==== Session #4 ====
# # of detection: 48, acceptance: 48, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13980 ms
# ==== Session #5 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25986 ms
# ==== Session #6 ====
# # of detection: 58, acceptance: 0, rejection: 58
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15949 ms
# ==== Session #7 ====
# # of detection: 66, acceptance: 0, rejection: 66
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #8 ====
# # of detection: 30, acceptance: 0, rejection: 30
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25685 ms
# ==== Session #9 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25680 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.04573804573804574
# latency: 33804.7 ms
# 3 2
# 1 2
# [touch] pos: 15, neg: 14, fr: 3, tr: 10, fi: 2,
# [gait] pos: 15, neg: 15, fr: 7, tr: 12, fi: 0,
# [simple_average] pos: 15, neg: 15, fr: 6, tr: 12, fi: 0,
# [weighted_average_eer] pos: 15, neg: 15, fr: 6, tr: 11, fi: 0,
# [weighted_average_auc] pos: 15, neg: 15, fr: 6, tr: 11, fi: 0,
# [deer_dempster_shafer] pos: 15, neg: 15, fr: 6, tr: 13, fi: 1,
# [auc_dempster_shafer] pos: 15, neg: 15, fr: 5, tr: 13, fi: 1,
# [kalman_filter] pos: 15, neg: 15, fr: 5, tr: 14, fi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1900_10_5_5
# Negative trainer seed:100
# Game seed:1900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:796581 (0), 918136 (1), 913228 (2), 264325 (3), 893255 (4)
# testers:986737, 763813, 872895, 733568, 277905
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83        80
#            1       0.73      1.00      0.84        16
#            2       0.89      1.00      0.94        16
#            3       0.83      0.94      0.88        16
#            4       0.47      0.44      0.45        16
#            5       0.80      1.00      0.89        16
#
#     accuracy                           0.82       160
#    macro avg       0.77      0.86      0.81       160
# weighted avg       0.83      0.82      0.82       160
#
# Epoch 1/25
# 228/228 [==============================] - 7s 17ms/step - loss: 0.9610 - categorical_accuracy: 0.6476
# Epoch 2/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.5040 - categorical_accuracy: 0.8121
# Epoch 3/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.3396 - categorical_accuracy: 0.8771
# Epoch 4/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.2464 - categorical_accuracy: 0.9143
# Epoch 5/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.2096 - categorical_accuracy: 0.9278
# Epoch 6/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.1781 - categorical_accuracy: 0.9362
# Epoch 7/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.1374 - categorical_accuracy: 0.9517
# Epoch 8/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.1384 - categorical_accuracy: 0.9510
# Epoch 9/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.1008 - categorical_accuracy: 0.9649
# Epoch 10/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0947 - categorical_accuracy: 0.9658
# Epoch 11/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0930 - categorical_accuracy: 0.9674
# Epoch 12/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0662 - categorical_accuracy: 0.9760
# Epoch 13/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0588 - categorical_accuracy: 0.9787
# Epoch 14/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0492 - categorical_accuracy: 0.9833
# Epoch 15/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0550 - categorical_accuracy: 0.9810
# Epoch 16/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0462 - categorical_accuracy: 0.9844
# Epoch 17/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0337 - categorical_accuracy: 0.9890
# Epoch 18/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0283 - categorical_accuracy: 0.9902
# Epoch 19/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0280 - categorical_accuracy: 0.9911
# Epoch 20/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0640 - categorical_accuracy: 0.9785
# Epoch 21/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0411 - categorical_accuracy: 0.9862
# Epoch 22/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0184 - categorical_accuracy: 0.9937
# Epoch 23/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0199 - categorical_accuracy: 0.9929
# Epoch 24/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0152 - categorical_accuracy: 0.9956
# Epoch 25/25
# 228/228 [==============================] - 4s 16ms/step - loss: 0.0236 - categorical_accuracy: 0.9914
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.62      0.72      1620
#          1.0       0.72      0.98      0.83       324
#          2.0       0.92      0.98      0.95       324
#          3.0       0.57      0.72      0.64       324
#          4.0       0.50      0.90      0.64       324
#          5.0       0.84      0.82      0.83       324
#
#     accuracy                           0.75      3240
#    macro avg       0.74      0.84      0.77      3240
# weighted avg       0.79      0.75      0.75      3240
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# too short, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #1 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20697 ms
# ==== Session #2 ====
# # of detection: 29, acceptance: 29, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 57868 ms
# ==== Session #3 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26280 ms
# ==== Session #4 ====
# # of detection: 55, acceptance: 55, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #5 ====
# # of detection: 57, acceptance: 0, rejection: 57
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15420 ms
# ==== Session #6 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #7 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41075 ms
# ==== Session #8 ====
# # of detection: 57, acceptance: 0, rejection: 57
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26063 ms
# ==== Session #9 ====
# # of detection: 19, acceptance: 19, rejection: 0
# # of FA: 19
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# simulation result: FAR: 0.046341463414634146
# MIR: 0.0
# FNR: 0.0
# latency: 25499.5 ms
# 4 3
# 2 3
# 3 4
# [touch] pos: 20, neg: 19, fr: 4, tr: 14, fi: 2,
# [gait] pos: 20, neg: 20, fr: 7, tr: 16, fi: 1,
# [simple_average] pos: 20, neg: 20, fr: 6, tr: 16, fi: 0,
# [weighted_average_eer] pos: 20, neg: 20, fr: 6, tr: 15, fi: 0,
# [weighted_average_auc] pos: 20, neg: 20, fr: 6, tr: 15, fi: 0,
# [deer_dempster_shafer] pos: 20, neg: 20, fr: 6, tr: 17, fi: 1,
# [auc_dempster_shafer] pos: 20, neg: 20, fr: 5, tr: 17, fi: 1,
# [kalman_filter] pos: 20, neg: 20, fr: 5, tr: 18, fi: 7,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2000_10_5_5
# Negative trainer seed:100
# Game seed:2000
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:554303 (0), 553321 (1), 777078 (2), 720193 (3), 937904 (4)
# testers:803262, 962159, 395129, 539502, 556357
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.74      0.62      0.67        45
#            1       0.80      0.89      0.84         9
#            2       0.69      1.00      0.82         9
#            3       1.00      0.78      0.88         9
#            4       0.50      0.78      0.61         9
#            5       0.12      0.11      0.12         9
#
#     accuracy                           0.67        90
#    macro avg       0.64      0.70      0.66        90
# weighted avg       0.68      0.67      0.66        90
#
# Epoch 1/25
# 176/176 [==============================] - 6s 17ms/step - loss: 1.1146 - categorical_accuracy: 0.5893
# Epoch 2/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.7430 - categorical_accuracy: 0.7117
# Epoch 3/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.5834 - categorical_accuracy: 0.7760
# Epoch 4/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.4907 - categorical_accuracy: 0.8135
# Epoch 5/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.4200 - categorical_accuracy: 0.8448
# Epoch 6/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3637 - categorical_accuracy: 0.8623
# Epoch 7/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.3242 - categorical_accuracy: 0.8781
# Epoch 8/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.2877 - categorical_accuracy: 0.8907
# Epoch 9/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.2485 - categorical_accuracy: 0.9068
# Epoch 10/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.2069 - categorical_accuracy: 0.9238
# Epoch 11/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1909 - categorical_accuracy: 0.9294
# Epoch 12/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1686 - categorical_accuracy: 0.9374
# Epoch 13/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1483 - categorical_accuracy: 0.9466
# Epoch 14/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1317 - categorical_accuracy: 0.9522
# Epoch 15/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.1207 - categorical_accuracy: 0.9561
# Epoch 16/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0951 - categorical_accuracy: 0.9656
# Epoch 17/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0993 - categorical_accuracy: 0.9635
# Epoch 18/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0927 - categorical_accuracy: 0.9666
# Epoch 19/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0779 - categorical_accuracy: 0.9725
# Epoch 20/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0623 - categorical_accuracy: 0.9787
# Epoch 21/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0502 - categorical_accuracy: 0.9827
# Epoch 22/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0515 - categorical_accuracy: 0.9819
# Epoch 23/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0598 - categorical_accuracy: 0.9791
# Epoch 24/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0583 - categorical_accuracy: 0.9786
# Epoch 25/25
# 176/176 [==============================] - 3s 16ms/step - loss: 0.0728 - categorical_accuracy: 0.9733
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.67      0.73      1250
#          1.0       0.89      0.85      0.87       250
#          2.0       0.92      0.67      0.77       250
#          3.0       0.84      0.69      0.76       250
#          4.0       0.84      0.88      0.86       250
#          5.0       0.35      0.79      0.49       250
#
#     accuracy                           0.72      2500
#    macro avg       0.77      0.76      0.75      2500
# weighted avg       0.78      0.72      0.74      2500
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 64, acceptance: 64, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# ==== Session #1 ====
# # of detection: 5, acceptance: 5, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 80724 ms
# ==== Session #2 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25640 ms
# ==== Session #3 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #4 ====
# # of detection: 41, acceptance: 41, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #5 ====
# # of detection: 41, acceptance: 0, rejection: 41
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25669 ms
# ==== Session #6 ====
# # of detection: 44, acceptance: 0, rejection: 44
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25631 ms
# ==== Session #7 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #8 ====
# # of detection: 41, acceptance: 29, rejection: 12
# # of FA: 29
# # of FR: 0
# # of MI: 0
# FAR: 0.7073170731707317
# MIR: 0.0
# FRR: 0.0
# latency: 41675 ms
# ==== Session #9 ====
# # of detection: 37, acceptance: 6, rejection: 31
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.16216216216216217
# MIR: 0.0
# FRR: 0.0
# latency: 56815 ms
# simulation result: FAR: 0.08620689655172414
# MIR: 0.0
# FNR: 0.0
# latency: 35455.8 ms
# 5 1
# [touch] pos: 25, neg: 24, fr: 5, tr: 16, fi: 2,
# [gait] pos: 25, neg: 25, fr: 7, tr: 21, fi: 1,
# [simple_average] pos: 25, neg: 25, fr: 7, tr: 21, fi: 0,
# [weighted_average_eer] pos: 25, neg: 25, fr: 7, tr: 20, fi: 0,
# [weighted_average_auc] pos: 25, neg: 25, fr: 7, tr: 20, fi: 0,
# [deer_dempster_shafer] pos: 25, neg: 25, fr: 7, tr: 22, fi: 1,
# [auc_dempster_shafer] pos: 25, neg: 25, fr: 6, tr: 22, fi: 1,
# [kalman_filter] pos: 25, neg: 25, fr: 6, tr: 22, fi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2100_10_5_5
# Negative trainer seed:100
# Game seed:2100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:405035 (0), 538363 (1), 966655 (2), 856401 (3), 799296 (4)
# testers:893198, 785873, 553321, 785899, 720193
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.66      0.72        65
#            1       0.29      0.38      0.33        13
#            2       0.27      0.23      0.25        13
#            3       0.62      0.77      0.69        13
#            4       0.75      0.69      0.72        13
#            5       0.45      0.69      0.55        13
#
#     accuracy                           0.61       130
#    macro avg       0.53      0.57      0.54       130
# weighted avg       0.64      0.61      0.62       130
#
# Epoch 1/25
# 200/200 [==============================] - 6s 18ms/step - loss: 0.9194 - categorical_accuracy: 0.6606
# Epoch 2/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.5532 - categorical_accuracy: 0.7873
# Epoch 3/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.4452 - categorical_accuracy: 0.8355
# Epoch 4/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.3612 - categorical_accuracy: 0.8685
# Epoch 5/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.3093 - categorical_accuracy: 0.8907
# Epoch 6/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2660 - categorical_accuracy: 0.9045
# Epoch 7/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2390 - categorical_accuracy: 0.9133
# Epoch 8/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2051 - categorical_accuracy: 0.9280
# Epoch 9/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1873 - categorical_accuracy: 0.9324
# Epoch 10/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1671 - categorical_accuracy: 0.9405
# Epoch 11/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1490 - categorical_accuracy: 0.9466
# Epoch 12/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1227 - categorical_accuracy: 0.9564
# Epoch 13/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1056 - categorical_accuracy: 0.9629
# Epoch 14/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1013 - categorical_accuracy: 0.9641
# Epoch 15/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0863 - categorical_accuracy: 0.9700
# Epoch 16/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0779 - categorical_accuracy: 0.9725
# Epoch 17/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0826 - categorical_accuracy: 0.9708
# Epoch 18/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0745 - categorical_accuracy: 0.9741
# Epoch 19/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0545 - categorical_accuracy: 0.9809
# Epoch 20/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0517 - categorical_accuracy: 0.9824
# Epoch 21/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0523 - categorical_accuracy: 0.9818
# Epoch 22/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0558 - categorical_accuracy: 0.9806
# Epoch 23/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0460 - categorical_accuracy: 0.9844
# Epoch 24/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0493 - categorical_accuracy: 0.9836
# Epoch 25/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0438 - categorical_accuracy: 0.9850
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.94      0.92      1420
#          1.0       0.98      0.85      0.91       284
#          2.0       0.77      0.85      0.81       284
#          3.0       0.99      0.98      0.98       284
#          4.0       0.94      0.93      0.93       284
#          5.0       0.91      0.85      0.88       284
#
#     accuracy                           0.91      2840
#    macro avg       0.92      0.90      0.91      2840
# weighted avg       0.91      0.91      0.91      2840
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25376 ms
# ==== Session #1 ====
# # of detection: 46, acceptance: 46, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35974 ms
# ==== Session #2 ====
# # of detection: 79, acceptance: 79, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 29990 ms
# ==== Session #3 ====
# # of detection: 37, acceptance: 37, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35922 ms
# ==== Session #4 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25695 ms
# ==== Session #5 ====
# # of detection: 56, acceptance: 0, rejection: 56
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15552 ms
# ==== Session #6 ====
# # of detection: 41, acceptance: 0, rejection: 41
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25655 ms
# ==== Session #7 ====
# # of detection: 8, acceptance: 0, rejection: 8
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 56812 ms
# ==== Session #8 ====
# # of detection: 44, acceptance: 0, rejection: 44
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #9 ====
# # of detection: 53, acceptance: 10, rejection: 43
# # of FA: 10
# # of FR: 0
# # of MI: 0
# FAR: 0.18867924528301888
# MIR: 0.0
# FRR: 0.0
# latency: 38618 ms
# simulation result: FAR: 0.021929824561403508
# MIR: 0.0
# FNR: 0.0
# latency: 31528.1 ms
# [touch] pos: 30, neg: 29, fr: 6, tr: 19, fi: 2,
# [gait] pos: 30, neg: 30, fr: 7, tr: 26, fi: 1,
# [simple_average] pos: 30, neg: 30, fr: 7, tr: 26, fi: 0,
# [weighted_average_eer] pos: 30, neg: 30, fr: 7, tr: 25, fi: 0,
# [weighted_average_auc] pos: 30, neg: 30, fr: 7, tr: 25, fi: 0,
# [deer_dempster_shafer] pos: 30, neg: 30, fr: 7, tr: 27, fi: 1,
# [auc_dempster_shafer] pos: 30, neg: 30, fr: 6, tr: 27, fi: 1,
# [kalman_filter] pos: 30, neg: 30, fr: 6, tr: 27, fi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2200_10_5_5
# Negative trainer seed:100
# Game seed:2200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:248252 (0), 745224 (1), 171538 (2), 856401 (3), 785899 (4)
# testers:218719, 554303, 151985, 863985, 808022
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.95      0.86      0.90        65
#            1       0.87      1.00      0.93        13
#            2       0.80      0.92      0.86        13
#            3       0.77      0.77      0.77        13
#            4       0.67      0.77      0.71        13
#            5       0.92      0.92      0.92        13
#
#     accuracy                           0.87       130
#    macro avg       0.83      0.87      0.85       130
# weighted avg       0.88      0.87      0.87       130
#
# Epoch 1/25
# 134/134 [==============================] - 5s 17ms/step - loss: 0.9069 - categorical_accuracy: 0.6861
# Epoch 2/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.4247 - categorical_accuracy: 0.8452
# Epoch 3/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.2989 - categorical_accuracy: 0.8881
# Epoch 4/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.2444 - categorical_accuracy: 0.9118
# Epoch 5/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1997 - categorical_accuracy: 0.9282
# Epoch 6/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1673 - categorical_accuracy: 0.9412
# Epoch 7/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1514 - categorical_accuracy: 0.9448
# Epoch 8/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1328 - categorical_accuracy: 0.9547
# Epoch 9/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.1298 - categorical_accuracy: 0.9535
# Epoch 10/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1063 - categorical_accuracy: 0.9656
# Epoch 11/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0859 - categorical_accuracy: 0.9707
# Epoch 12/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0727 - categorical_accuracy: 0.9751
# Epoch 13/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0536 - categorical_accuracy: 0.9821
# Epoch 14/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0658 - categorical_accuracy: 0.9768
# Epoch 15/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0871 - categorical_accuracy: 0.9741
# Epoch 16/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0405 - categorical_accuracy: 0.9873
# Epoch 17/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0284 - categorical_accuracy: 0.9918
# Epoch 18/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0309 - categorical_accuracy: 0.9905
# Epoch 19/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0575 - categorical_accuracy: 0.9795
# Epoch 20/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0275 - categorical_accuracy: 0.9906
# Epoch 21/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0203 - categorical_accuracy: 0.9944
# Epoch 22/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0223 - categorical_accuracy: 0.9932
# Epoch 23/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0275 - categorical_accuracy: 0.9913
# Epoch 24/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0240 - categorical_accuracy: 0.9927
# Epoch 25/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0937 - categorical_accuracy: 0.9681
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.65      0.74       945
#          1.0       0.36      0.76      0.49       189
#          2.0       0.90      0.99      0.95       189
#          3.0       0.90      0.65      0.75       189
#          4.0       0.98      0.93      0.95       189
#          5.0       0.72      0.99      0.83       189
#
#     accuracy                           0.76      1890
#    macro avg       0.79      0.83      0.79      1890
# weighted avg       0.82      0.76      0.77      1890
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 62, acceptance: 62, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 4
# FAR: 0.0
# MIR: 0.06451612903225806
# FRR: 0.0
# latency: 41014 ms
# ==== Session #1 ====
# # of detection: 81, acceptance: 81, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23412 ms
# ==== Session #2 ====
# # of detection: 65, acceptance: 44, rejection: 21
# # of FA: 0
# # of FR: 21
# # of MI: 5
# FAR: 0.0
# MIR: 0.07692307692307693
# FRR: 0.3230769230769231
# latency: 61884 ms
# ==== Session #3 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 3
# FAR: 0.0
# MIR: 0.08823529411764706
# FRR: 0.0
# latency: 56498 ms
# ==== Session #4 ====
# # of detection: 41, acceptance: 0, rejection: 41
# # of FA: 0
# # of FR: 41
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 1.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 66, acceptance: 0, rejection: 66
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #6 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# ==== Session #7 ====
# # of detection: 50, acceptance: 24, rejection: 26
# # of FA: 24
# # of FR: 0
# # of MI: 0
# FAR: 0.48
# MIR: 0.0
# FRR: 0.0
# latency: 65932 ms
# ==== Session #8 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25986 ms
# ==== Session #9 ====
# # of detection: 40, acceptance: 27, rejection: 13
# # of FA: 27
# # of FR: 0
# # of MI: 0
# FAR: 0.675
# MIR: 0.0
# FRR: 0.0
# latency: 141843 ms
# simulation result: FAR: 0.09357798165137615
# MIR: 0.022018348623853212
# FNR: 0.11376146788990826
# latency: 46825.9 ms
# 1 2
# 5 3
# 2 4
# 5 1
# 5 3
# 2 4
# 5 1
# 5 3
# 2 4
# 5 1
# 5 3
# 2 4
# 5 1
# 5 3
# 2 4
# 5 1
# 5 3
# 2 4
# 5 1
# 2 4
# [touch] pos: 35, neg: 34, fr: 8, tr: 24, fi: 3,
# [gait] pos: 35, neg: 35, fr: 8, tr: 31, fi: 3,
# [simple_average] pos: 35, neg: 35, fr: 8, tr: 31, fi: 3,
# [weighted_average_eer] pos: 35, neg: 35, fr: 7, tr: 29, fi: 3,
# [weighted_average_auc] pos: 35, neg: 35, fr: 8, tr: 30, fi: 3,
# [deer_dempster_shafer] pos: 35, neg: 35, fr: 8, tr: 32, fi: 4,
# [auc_dempster_shafer] pos: 35, neg: 35, fr: 7, tr: 32, fi: 4,
# [kalman_filter] pos: 35, neg: 35, fr: 8, tr: 32, fi: 10,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2300_10_5_5
# Negative trainer seed:100
# Game seed:2300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:796581 (0), 710707 (1), 186676 (2), 277905 (3), 923862 (4)
# testers:893198, 657486, 180679, 257279, 396697
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
# ...
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 48, acceptance: 44, rejection: 4
# # of FA: 0
# # of FR: 4
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.08333333333333333
# latency: 46580 ms
# ==== Session #1 ====
# # of detection: 47, acceptance: 47, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20538 ms
# ==== Session #2 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25791 ms
# ==== Session #3 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31073 ms
# ==== Session #4 ====
# # of detection: 56, acceptance: 56, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20542 ms
# ==== Session #5 ====
# # of detection: 74, acceptance: 0, rejection: 74
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13889 ms
# ==== Session #6 ====
# # of detection: 49, acceptance: 0, rejection: 49
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# ==== Session #7 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25643 ms
# ==== Session #8 ====
# # of detection: 80, acceptance: 0, rejection: 80
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# ==== Session #9 ====
# # of detection: 40, acceptance: 0, rejection: 40
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15238 ms
# simulation result: FAR: 0.0
# MIR: 0.0
# FNR: 0.00784313725490196
# latency: 25118.8 ms
# 1 5
# 3 4
# [touch] pos: 159, neg: 157, fr: 34, tr: 118, fi: 11,
# [gait] pos: 160, neg: 160, fr: 42, tr: 129, fi: 9,
# [simple_average] pos: 160, neg: 160, fr: 42, tr: 131, fi: 7,
# [weighted_average_eer] pos: 160, neg: 160, fr: 26, tr: 117, fi: 15,
# [weighted_average_auc] pos: 160, neg: 160, fr: 37, tr: 128, fi: 9,
# [deer_dempster_shafer] pos: 160, neg: 160, fr: 38, tr: 141, fi: 8,
# [auc_dempster_shafer] pos: 160, neg: 160, fr: 38, tr: 146, fi: 8,
# [kalman_filter] pos: 160, neg: 160, fr: 36, tr: 140, fi: 40,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4800_10_5_5
# Negative trainer seed:100
# Game seed:4800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:799296 (0), 579284 (1), 556357 (2), 710707 (3), 336172 (4)
# testers:763813, 856302, 277905, 785899, 553321
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.86      0.63      0.73        60
#            1       0.53      0.75      0.62        12
#            2       0.37      0.58      0.45        12
#            3       1.00      1.00      1.00        12
#            4       0.50      0.67      0.57        12
#            5       0.42      0.42      0.42        12
#
#     accuracy                           0.66       120
#    macro avg       0.61      0.67      0.63       120
# weighted avg       0.71      0.66      0.67       120
#
# Epoch 1/25
# 200/200 [==============================] - 6s 17ms/step - loss: 1.0867 - categorical_accuracy: 0.5906
# Epoch 2/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.7428 - categorical_accuracy: 0.7027
# Epoch 3/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.5603 - categorical_accuracy: 0.7841
# Epoch 4/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.4386 - categorical_accuracy: 0.8341
# Epoch 5/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.3678 - categorical_accuracy: 0.8626
# Epoch 6/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.3228 - categorical_accuracy: 0.8788
# Epoch 7/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2789 - categorical_accuracy: 0.8968
# Epoch 8/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2559 - categorical_accuracy: 0.9052
# Epoch 9/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.2014 - categorical_accuracy: 0.9277
# Epoch 10/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1799 - categorical_accuracy: 0.9349
# Epoch 11/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1689 - categorical_accuracy: 0.9383
# Epoch 12/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1417 - categorical_accuracy: 0.9506
# Epoch 13/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1112 - categorical_accuracy: 0.9597
# Epoch 14/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1094 - categorical_accuracy: 0.9613
# Epoch 15/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.1079 - categorical_accuracy: 0.9608
# Epoch 16/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0846 - categorical_accuracy: 0.9700
# Epoch 17/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0703 - categorical_accuracy: 0.9761
# Epoch 18/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0623 - categorical_accuracy: 0.9780
# Epoch 19/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0636 - categorical_accuracy: 0.9776
# Epoch 20/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0607 - categorical_accuracy: 0.9780
# Epoch 21/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0556 - categorical_accuracy: 0.9808
# Epoch 22/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0466 - categorical_accuracy: 0.9836
# Epoch 23/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0563 - categorical_accuracy: 0.9802
# Epoch 24/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0657 - categorical_accuracy: 0.9764
# Epoch 25/25
# 200/200 [==============================] - 3s 17ms/step - loss: 0.0386 - categorical_accuracy: 0.9866
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.75      0.78      1420
#          1.0       0.95      0.85      0.89       284
#          2.0       0.68      0.63      0.65       284
#          3.0       0.78      1.00      0.88       284
#          4.0       0.74      0.68      0.71       284
#          5.0       0.60      0.81      0.69       284
#
#     accuracy                           0.77      2840
#    macro avg       0.76      0.78      0.77      2840
# weighted avg       0.78      0.77      0.77      2840
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25695 ms
# ==== Session #1 ====
# # of detection: 47, acceptance: 47, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20538 ms
# ==== Session #2 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25734 ms
# ==== Session #3 ====
# # of detection: 52, acceptance: 43, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.17307692307692307
# latency: 25663 ms
# ==== Session #4 ====
# # of detection: 100, acceptance: 100, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# ==== Session #5 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #6 ====
# # of detection: 73, acceptance: 0, rejection: 73
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #7 ====
# # of detection: 22, acceptance: 22, rejection: 0
# # of FA: 22
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #8 ====
# # of detection: 44, acceptance: 5, rejection: 39
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.11363636363636363
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #9 ====
# # of detection: 5, acceptance: 4, rejection: 1
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.8
# MIR: 0.0
# FRR: 0.0
# latency: 176767 ms
# simulation result: FAR: 0.06753812636165578
# MIR: 0.0
# FNR: 0.0196078431372549
# latency: 36704.2 ms
# 2 4
# 1 5
# 2 3
# [touch] pos: 164, neg: 162, fr: 34, tr: 121, fi: 13,
# [gait] pos: 165, neg: 165, fr: 43, tr: 132, fi: 9,
# [simple_average] pos: 165, neg: 165, fr: 42, tr: 135, fi: 7,
# [weighted_average_eer] pos: 165, neg: 165, fr: 26, tr: 120, fi: 15,
# [weighted_average_auc] pos: 165, neg: 165, fr: 37, tr: 131, fi: 9,
# [deer_dempster_shafer] pos: 165, neg: 165, fr: 38, tr: 145, fi: 8,
# [auc_dempster_shafer] pos: 165, neg: 165, fr: 38, tr: 150, fi: 8,
# [kalman_filter] pos: 165, neg: 165, fr: 36, tr: 144, fi: 41,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4900_10_5_5
# Negative trainer seed:100
# Game seed:4900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:973891 (0), 431312 (1), 248252 (2), 622852 (3), 218719 (4)
# testers:396697, 556357, 220962, 841866, 257279
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.95      0.76      0.84        50
#            1       0.67      1.00      0.80        10
#            2       0.80      0.80      0.80        10
#            3       0.71      1.00      0.83        10
#            4       0.77      1.00      0.87        10
#            5       0.88      0.70      0.78        10
#
#     accuracy                           0.83       100
#    macro avg       0.80      0.88      0.82       100
# weighted avg       0.86      0.83      0.83       100
#
# Epoch 1/25
# 134/134 [==============================] - 5s 17ms/step - loss: 1.2288 - categorical_accuracy: 0.5809
# Epoch 2/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.8595 - categorical_accuracy: 0.6860
# Epoch 3/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.7220 - categorical_accuracy: 0.7394
# Epoch 4/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.6206 - categorical_accuracy: 0.7716
# Epoch 5/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.4969 - categorical_accuracy: 0.8188
# Epoch 6/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.4164 - categorical_accuracy: 0.8443
# Epoch 7/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.3422 - categorical_accuracy: 0.8734
# Epoch 8/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.2958 - categorical_accuracy: 0.8926
# Epoch 9/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.2554 - categorical_accuracy: 0.9115
# Epoch 10/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.2362 - categorical_accuracy: 0.9156
# Epoch 11/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.2106 - categorical_accuracy: 0.9238
# Epoch 12/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1868 - categorical_accuracy: 0.9323
# Epoch 13/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1696 - categorical_accuracy: 0.9382
# Epoch 14/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1342 - categorical_accuracy: 0.9539
# Epoch 15/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1216 - categorical_accuracy: 0.9565
# Epoch 16/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1189 - categorical_accuracy: 0.9590
# Epoch 17/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.1053 - categorical_accuracy: 0.9635
# Epoch 18/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0805 - categorical_accuracy: 0.9744
# Epoch 19/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0733 - categorical_accuracy: 0.9754
# Epoch 20/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0644 - categorical_accuracy: 0.9791
# Epoch 21/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0554 - categorical_accuracy: 0.9816
# Epoch 22/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0616 - categorical_accuracy: 0.9784
# Epoch 23/25
# 134/134 [==============================] - 2s 16ms/step - loss: 0.0360 - categorical_accuracy: 0.9899
# Epoch 24/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0387 - categorical_accuracy: 0.9875
# Epoch 25/25
# 134/134 [==============================] - 2s 17ms/step - loss: 0.0599 - categorical_accuracy: 0.9786
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.68      0.72       945
#          1.0       0.58      0.83      0.68       189
#          2.0       0.62      0.60      0.61       189
#          3.0       0.43      0.68      0.52       189
#          4.0       0.84      0.69      0.76       189
#          5.0       1.00      0.67      0.80       189
#
#     accuracy                           0.69      1890
#    macro avg       0.70      0.69      0.68      1890
# weighted avg       0.72      0.69      0.70      1890
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 173, acceptance: 173, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 6660 ms
# ==== Session #1 ====
# # of detection: 83, acceptance: 83, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 4
# FAR: 0.0
# MIR: 0.04819277108433735
# FRR: 0.0
# latency: 16730 ms
# ==== Session #2 ====
# # of detection: 63, acceptance: 55, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.12698412698412698
# latency: 42974 ms
# ==== Session #3 ====
# # of detection: 36, acceptance: 36, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35971 ms
# ==== Session #4 ====
# # of detection: 66, acceptance: 66, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #5 ====
# # of detection: 32, acceptance: 20, rejection: 12
# # of FA: 20
# # of FR: 0
# # of MI: 0
# FAR: 0.625
# MIR: 0.0
# FRR: 0.0
# latency: 25962 ms
# ==== Session #6 ====
# # of detection: 36, acceptance: 9, rejection: 27
# # of FA: 9
# # of FR: 0
# # of MI: 0
# FAR: 0.25
# MIR: 0.0
# FRR: 0.0
# latency: 36071 ms
# ==== Session #7 ====
# # of detection: 32, acceptance: 0, rejection: 32
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26038 ms
# ==== Session #8 ====
# # of detection: 74, acceptance: 74, rejection: 0
# # of FA: 74
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #9 ====
# # of detection: 48, acceptance: 28, rejection: 20
# # of FA: 28
# # of FR: 0
# # of MI: 0
# FAR: 0.5833333333333334
# MIR: 0.0
# FRR: 0.0
# latency: 71535 ms
# simulation result: FAR: 0.20373250388802489
# MIR: 0.006220839813374806
# FNR: 0.012441679626749611
# latency: 28762.7 ms
# 3 2
# 3 4
# 3 4
# 3 4
# 2 3
# [touch] pos: 169, neg: 167, fr: 36, tr: 121, fi: 14,
# [gait] pos: 170, neg: 170, fr: 44, tr: 137, fi: 10,
# [simple_average] pos: 170, neg: 170, fr: 43, tr: 139, fi: 8,
# [weighted_average_eer] pos: 170, neg: 170, fr: 26, tr: 124, fi: 15,
# [weighted_average_auc] pos: 170, neg: 170, fr: 38, tr: 135, fi: 10,
# [deer_dempster_shafer] pos: 170, neg: 170, fr: 39, tr: 149, fi: 8,
# [auc_dempster_shafer] pos: 170, neg: 170, fr: 39, tr: 154, fi: 8,
# [kalman_filter] pos: 170, neg: 170, fr: 36, tr: 146, fi: 42,
#
# file saved.

# %%
#@title Experiment 1.3: 4 users 3 + 3 training sessions

last_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 5, 3)
    score_pairs = gen_per_segment_decision(tml, player)

    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/accuracy_balance_5_3_limit", str(seed)))

# %%
#@title Experiment 1.3: 10 users 3 + 3 training sessions

last_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 10, 3)
    score_pairs = gen_per_segment_decision(tml, player)

    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022_3/re_accuracy_10_3_limit", str(seed)))
# Out:
# Streaming output truncated to the last 5000 lines.
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 48, acceptance: 48, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20399 ms
# ==== Session #1 ====
# # of detection: 46, acceptance: 46, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35974 ms
# ==== Session #2 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #3 ====
# # of detection: 100, acceptance: 100, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# ==== Session #4 ====
# # of detection: 9, acceptance: 9, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25670 ms
# ==== Session #5 ====
# # of detection: 37, acceptance: 18, rejection: 19
# # of FA: 0
# # of FR: 19
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.5135135135135135
# latency: 44501 ms
# ==== Session #6 ====
# # of detection: 58, acceptance: 58, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 22518 ms
# ==== Session #7 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 22401 ms
# ==== Session #8 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 48867 ms
# ==== Session #9 ====
# # of detection: 52, acceptance: 18, rejection: 34
# # of FA: 0
# # of FR: 34
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.6538461538461539
# latency: 62260 ms
# ==== Session #10 ====
# # of detection: 36, acceptance: 23, rejection: 13
# # of FA: 23
# # of FR: 0
# # of MI: 0
# FAR: 0.6388888888888888
# MIR: 0.0
# FRR: 0.0
# latency: 25973 ms
# ==== Session #11 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25695 ms
# ==== Session #12 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #13 ====
# # of detection: 71, acceptance: 4, rejection: 67
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.056338028169014086
# MIR: 0.0
# FRR: 0.0
# latency: 42461 ms
# ==== Session #14 ====
# # of detection: 55, acceptance: 0, rejection: 55
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #15 ====
# # of detection: 47, acceptance: 0, rejection: 47
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15473 ms
# ==== Session #16 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 44
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #17 ====
# # of detection: 29, acceptance: 29, rejection: 0
# # of FA: 29
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #18 ====
# # of detection: 48, acceptance: 0, rejection: 48
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25847 ms
# ==== Session #19 ====
# # of detection: 76, acceptance: 0, rejection: 76
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# simulation result: FAR: 0.10638297872340426
# MIR: 0.0
# FNR: 0.05638297872340425
# latency: 25847.85 ms
# 5 7
# 8 9
# 9 10
# 8 9
# 4 5
# 5 6
# 8 9
# [touch] pos: 349, neg: 350, fr: 69, tr: 213, fi: 48,
# [gait] pos: 349, neg: 349, fr: 93, tr: 269, fi: 47,
# [simple_average] pos: 350, neg: 350, fr: 88, tr: 276, fi: 36,
# [weighted_average_eer] pos: 350, neg: 350, fr: 39, tr: 226, fi: 63,
# [weighted_average_auc] pos: 350, neg: 350, fr: 74, tr: 265, fi: 43,
# [deer_dempster_shafer] pos: 350, neg: 350, fr: 81, tr: 291, fi: 26,
# [auc_dempster_shafer] pos: 350, neg: 350, fr: 88, tr: 318, fi: 23,
# [kalman_filter] pos: 350, neg: 350, fr: 65, tr: 295, fi: 99,
#
# file saved.
# ========== SETUP ===========
# Game name:100_3500_10_10_10
# Negative trainer seed:100
# Game seed:3500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:937904 (0), 856302 (1), 698266 (2), 257279 (3), 892687 (4), 622852 (5), 893255 (6), 527796 (7), 986737 (8), 720193 (9)
# testers:171538, 248252, 663153, 710707, 841866, 973891, 277905, 431312, 862649, 865881
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.85      0.60      0.70       100
#            1       0.12      0.10      0.11        10
#            2       0.45      0.50      0.48        10
#            3       0.62      0.80      0.70        10
#            4       0.38      0.60      0.46        10
#            5       0.46      0.60      0.52        10
#            6       0.53      0.90      0.67        10
#            7       0.83      1.00      0.91        10
#            8       0.71      0.50      0.59        10
#            9       0.47      0.90      0.62        10
#           10       0.62      0.80      0.70        10
#
#     accuracy                           0.64       200
#    macro avg       0.55      0.66      0.59       200
# weighted avg       0.68      0.64      0.64       200
#
# Epoch 1/25
# 391/391 [==============================] - 9s 16ms/step - loss: 1.1233 - categorical_accuracy: 0.6218
# Epoch 2/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.6768 - categorical_accuracy: 0.7640
# Epoch 3/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.5462 - categorical_accuracy: 0.8102
# Epoch 4/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.4506 - categorical_accuracy: 0.8434
# Epoch 5/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3920 - categorical_accuracy: 0.8646
# Epoch 6/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.3376 - categorical_accuracy: 0.8814
# Epoch 7/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2952 - categorical_accuracy: 0.8963
# Epoch 8/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2727 - categorical_accuracy: 0.9029
# Epoch 9/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2297 - categorical_accuracy: 0.9192
# Epoch 10/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2137 - categorical_accuracy: 0.9239
# Epoch 11/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1868 - categorical_accuracy: 0.9328
# Epoch 12/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1634 - categorical_accuracy: 0.9415
# Epoch 13/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1429 - categorical_accuracy: 0.9500
# Epoch 14/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1380 - categorical_accuracy: 0.9507
# Epoch 15/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1243 - categorical_accuracy: 0.9551
# Epoch 16/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1306 - categorical_accuracy: 0.9534
# Epoch 17/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1002 - categorical_accuracy: 0.9635
# Epoch 18/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1017 - categorical_accuracy: 0.9638
# Epoch 19/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0962 - categorical_accuracy: 0.9650
# Epoch 20/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0846 - categorical_accuracy: 0.9699
# Epoch 21/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0787 - categorical_accuracy: 0.9713
# Epoch 22/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0762 - categorical_accuracy: 0.9724
# Epoch 23/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0837 - categorical_accuracy: 0.9704
# Epoch 24/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0850 - categorical_accuracy: 0.9705
# Epoch 25/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0833 - categorical_accuracy: 0.9701
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.37      0.49      2770
#          1.0       0.37      0.79      0.50       277
#          2.0       0.14      0.70      0.23       277
#          3.0       0.83      0.64      0.72       277
#          4.0       0.75      0.75      0.75       277
#          5.0       0.44      0.68      0.53       277
#          6.0       0.98      0.56      0.71       277
#          7.0       0.82      0.86      0.84       277
#          8.0       0.65      0.68      0.66       277
#          9.0       0.98      0.89      0.93       277
#         10.0       0.88      0.83      0.86       277
#
#     accuracy                           0.55      5540
#    macro avg       0.69      0.70      0.66      5540
# weighted avg       0.71      0.55      0.58      5540
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 41, acceptance: 41, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #1 ====
# # of detection: 73, acceptance: 73, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #2 ====
# # of detection: 76, acceptance: 76, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# ==== Session #3 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25725 ms
# ==== Session #4 ====
# # of detection: 48, acceptance: 48, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31195 ms
# ==== Session #5 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 22401 ms
# ==== Session #6 ====
# # of detection: 55, acceptance: 55, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #7 ====
# # of detection: 46, acceptance: 29, rejection: 17
# # of FA: 0
# # of FR: 17
# # of MI: 6
# FAR: 0.0
# MIR: 0.13043478260869565
# FRR: 0.3695652173913043
# latency: 100666 ms
# ==== Session #8 ====
# # of detection: 56, acceptance: 56, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20542 ms
# ==== Session #9 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #10 ====
# # of detection: 65, acceptance: 24, rejection: 41
# # of FA: 24
# # of FR: 0
# # of MI: 0
# FAR: 0.36923076923076925
# MIR: 0.0
# FRR: 0.0
# latency: 40301 ms
# ==== Session #11 ====
# # of detection: 63, acceptance: 45, rejection: 18
# # of FA: 45
# # of FR: 0
# # of MI: 0
# FAR: 0.7142857142857143
# MIR: 0.0
# FRR: 0.0
# latency: 25877 ms
# ==== Session #12 ====
# # of detection: 50, acceptance: 30, rejection: 20
# # of FA: 30
# # of FR: 0
# # of MI: 0
# FAR: 0.6
# MIR: 0.0
# FRR: 0.0
# latency: 25650 ms
# ==== Session #13 ====
# # of detection: 53, acceptance: 36, rejection: 17
# # of FA: 36
# # of FR: 0
# # of MI: 0
# FAR: 0.6792452830188679
# MIR: 0.0
# FRR: 0.0
# latency: 21794 ms
# ==== Session #14 ====
# # of detection: 74, acceptance: 45, rejection: 29
# # of FA: 45
# # of FR: 0
# # of MI: 0
# FAR: 0.6081081081081081
# MIR: 0.0
# FRR: 0.0
# latency: 13889 ms
# ==== Session #15 ====
# # of detection: 171, acceptance: 19, rejection: 152
# # of FA: 19
# # of FR: 0
# # of MI: 0
# FAR: 0.1111111111111111
# MIR: 0.0
# FRR: 0.0
# latency: 10350 ms
# ==== Session #16 ====
# # of detection: 17, acceptance: 0, rejection: 17
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 46818 ms
# ==== Session #17 ====
# # of detection: 83, acceptance: 45, rejection: 38
# # of FA: 45
# # of FR: 0
# # of MI: 0
# FAR: 0.5421686746987951
# MIR: 0.0
# FRR: 0.0
# latency: 16730 ms
# ==== Session #18 ====
# # of detection: 35, acceptance: 9, rejection: 26
# # of FA: 9
# # of FR: 0
# # of MI: 0
# FAR: 0.2571428571428571
# MIR: 0.0
# FRR: 0.0
# latency: 61192 ms
# ==== Session #19 ====
# # of detection: 49, acceptance: 0, rejection: 49
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# simulation result: FAR: 0.21118530884808012
# MIR: 0.005008347245409015
# FNR: 0.014190317195325543
# latency: 29766.3 ms
# 10 2
# 8 3
# 3 8
# 2 10
# 1 8
# 7 8
# [touch] pos: 359, neg: 360, fr: 70, tr: 217, fi: 52,
# [gait] pos: 359, neg: 359, fr: 97, tr: 276, fi: 47,
# [simple_average] pos: 360, neg: 360, fr: 90, tr: 285, fi: 36,
# [weighted_average_eer] pos: 360, neg: 360, fr: 39, tr: 231, fi: 64,
# [weighted_average_auc] pos: 360, neg: 360, fr: 75, tr: 274, fi: 43,
# [deer_dempster_shafer] pos: 360, neg: 360, fr: 82, tr: 301, fi: 26,
# [auc_dempster_shafer] pos: 360, neg: 360, fr: 89, tr: 328, fi: 23,
# [kalman_filter] pos: 360, neg: 360, fr: 65, tr: 304, fi: 100,
#
# file saved.
# ========== SETUP ===========
# Game name:100_3600_10_10_10
# Negative trainer seed:100
# Game seed:3600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:865501 (0), 352716 (1), 256487 (2), 663153 (3), 556357 (4), 527796 (5), 277905 (6), 763813 (7), 180679 (8), 553321 (9)
# testers:737973, 489146, 579284, 554303, 538363, 865881, 342329, 561993, 720193, 862649
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85       120
#            1       0.60      0.75      0.67        12
#            2       0.67      0.33      0.44        12
#            3       0.50      0.58      0.54        12
#            4       0.85      0.92      0.88        12
#            5       0.82      0.75      0.78        12
#            6       0.73      0.67      0.70        12
#            7       0.91      0.83      0.87        12
#            8       0.92      1.00      0.96        12
#            9       0.82      0.75      0.78        12
#           10       0.48      1.00      0.65        12
#
#     accuracy                           0.79       240
#    macro avg       0.74      0.76      0.74       240
# weighted avg       0.81      0.79      0.79       240
#
# Epoch 1/25
# 29/29 [==============================] - 3s 17ms/step - loss: 2.1817 - categorical_accuracy: 0.4617
# Epoch 2/25
# 29/29 [==============================] - 0s 16ms/step - loss: 1.5878 - categorical_accuracy: 0.5169
# Epoch 3/25
# 29/29 [==============================] - 0s 16ms/step - loss: 1.3863 - categorical_accuracy: 0.5481
# Epoch 4/25
# 29/29 [==============================] - 0s 16ms/step - loss: 1.3131 - categorical_accuracy: 0.5700
# Epoch 5/25
# 29/29 [==============================] - 0s 16ms/step - loss: 1.1517 - categorical_accuracy: 0.6067
# Epoch 6/25
# 29/29 [==============================] - 0s 16ms/step - loss: 1.0589 - categorical_accuracy: 0.6400
# Epoch 7/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.9255 - categorical_accuracy: 0.6856
# Epoch 8/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.8371 - categorical_accuracy: 0.7203
# Epoch 9/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.7530 - categorical_accuracy: 0.7458
# Epoch 10/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6618 - categorical_accuracy: 0.7806
# Epoch 11/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.6833 - categorical_accuracy: 0.7578
# Epoch 12/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.5654 - categorical_accuracy: 0.8000
# Epoch 13/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.5215 - categorical_accuracy: 0.8169
# Epoch 14/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.5361 - categorical_accuracy: 0.8064
# Epoch 15/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.4706 - categorical_accuracy: 0.8336
# Epoch 16/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.3721 - categorical_accuracy: 0.8756
# Epoch 17/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.4024 - categorical_accuracy: 0.8583
# Epoch 18/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.4064 - categorical_accuracy: 0.8567
# Epoch 19/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.3139 - categorical_accuracy: 0.9061
# Epoch 20/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.2348 - categorical_accuracy: 0.9261
# Epoch 21/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1867 - categorical_accuracy: 0.9453
# Epoch 22/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1672 - categorical_accuracy: 0.9525
# Epoch 23/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.1399 - categorical_accuracy: 0.9586
# Epoch 24/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.4253 - categorical_accuracy: 0.8525
# Epoch 25/25
# 29/29 [==============================] - 0s 16ms/step - loss: 0.4575 - categorical_accuracy: 0.8328
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.71      0.70       190
#          1.0       0.38      0.16      0.22        19
#          2.0       0.48      0.74      0.58        19
#          3.0       0.78      0.74      0.76        19
#          4.0       0.59      0.84      0.70        19
#          5.0       0.50      0.95      0.65        19
#          6.0       0.90      0.47      0.62        19
#          7.0       0.74      0.74      0.74        19
#          8.0       0.56      0.47      0.51        19
#          9.0       0.29      0.21      0.24        19
#         10.0       1.00      0.47      0.64        19
#
#     accuracy                           0.64       380
#    macro avg       0.63      0.59      0.58       380
# weighted avg       0.66      0.64      0.64       380
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 39, acceptance: 27, rejection: 12
# # of FA: 0
# # of FR: 12
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.3076923076923077
# latency: 55256 ms
# ==== Session #1 ====
# # of detection: 24, acceptance: 2, rejection: 22
# # of FA: 0
# # of FR: 22
# # of MI: 2
# FAR: 0.0
# MIR: 0.08333333333333333
# FRR: 0.9166666666666666
# latency: -1 ms
# ==== Session #2 ====
# # of detection: 36, acceptance: 36, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.25
# FRR: 0.0
# latency: 82658 ms
# ==== Session #3 ====
# # of detection: 48, acceptance: 39, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1875
# latency: 51378 ms
# ==== Session #4 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25734 ms
# ==== Session #5 ====
# # of detection: 47, acceptance: 18, rejection: 29
# # of FA: 0
# # of FR: 29
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.6170212765957447
# latency: 25843 ms
# ==== Session #6 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 47747 ms
# ==== Session #7 ====
# # of detection: 36, acceptance: 34, rejection: 2
# # of FA: 0
# # of FR: 2
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.05555555555555555
# latency: 25667 ms
# ==== Session #8 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 34787 ms
# ==== Session #9 ====
# # of detection: 8, acceptance: 1, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.875
# latency: 176767 ms
# ==== Session #10 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20927 ms
# ==== Session #11 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25643 ms
# ==== Session #12 ====
# # of detection: 46, acceptance: 0, rejection: 46
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24125 ms
# ==== Session #13 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# ==== Session #14 ====
# # of detection: 50, acceptance: 0, rejection: 50
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15372 ms
# ==== Session #15 ====
# # of detection: 49, acceptance: 15, rejection: 34
# # of FA: 15
# # of FR: 0
# # of MI: 0
# FAR: 0.30612244897959184
# MIR: 0.0
# FRR: 0.0
# latency: 25889 ms
# ==== Session #16 ====
# # of detection: 50, acceptance: 0, rejection: 50
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30829 ms
# ==== Session #17 ====
# # of detection: 34, acceptance: 26, rejection: 8
# # of FA: 26
# # of FR: 0
# # of MI: 0
# FAR: 0.7647058823529411
# MIR: 0.0
# FRR: 0.0
# latency: 25689 ms
# ==== Session #18 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24905 ms
# ==== Session #19 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30867 ms
# simulation result: FAR: 0.05036855036855037
# MIR: 0.013513513513513514
# FNR: 0.09950859950859951
# latency: 38804.3 ms
# 4 5
# 5 2
# 10 3
# 10 3
# 3 2
# 10 3
# 10 3
# 10 3
# 10 3
# 1 2
# 3 4
# 5 6
# 7 8
# 8 9
# 9 10
# [touch] pos: 369, neg: 370, fr: 71, tr: 226, fi: 53,
# [gait] pos: 369, neg: 369, fr: 102, tr: 285, fi: 49,
# [simple_average] pos: 370, neg: 370, fr: 95, tr: 294, fi: 37,
# [weighted_average_eer] pos: 370, neg: 370, fr: 42, tr: 239, fi: 66,
# [weighted_average_auc] pos: 370, neg: 370, fr: 80, tr: 283, fi: 44,
# [deer_dempster_shafer] pos: 370, neg: 370, fr: 87, tr: 311, fi: 27,
# [auc_dempster_shafer] pos: 370, neg: 370, fr: 94, tr: 338, fi: 24,
# [kalman_filter] pos: 370, neg: 370, fr: 67, tr: 314, fi: 106,
#
# file saved.
# ========== SETUP ===========
# Game name:100_3700_10_10_10
# Negative trainer seed:100
# Game seed:3700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:579284 (0), 862649 (1), 539502 (2), 937904 (3), 248252 (4), 990622 (5), 151985 (6), 171538 (7), 777078 (8), 720193 (9)
# testers:395129, 973891, 622852, 897652, 553321, 893255, 827212, 892687, 717868, 556357
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.78      0.59      0.67        90
#            1       0.42      0.56      0.48         9
#            2       0.64      0.78      0.70         9
#            3       0.69      1.00      0.82         9
#            4       0.08      0.11      0.09         9
#            5       0.50      0.89      0.64         9
#            6       0.67      0.44      0.53         9
#            7       1.00      1.00      1.00         9
#            8       0.43      0.33      0.38         9
#            9       0.70      0.78      0.74         9
#           10       0.27      0.44      0.33         9
#
#     accuracy                           0.61       180
#    macro avg       0.56      0.63      0.58       180
# weighted avg       0.66      0.61      0.62       180
#
# Epoch 1/25
# 237/237 [==============================] - 7s 16ms/step - loss: 1.5525 - categorical_accuracy: 0.5278
# Epoch 2/25
# 237/237 [==============================] - 4s 16ms/step - loss: 1.0765 - categorical_accuracy: 0.6395
# Epoch 3/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.7538 - categorical_accuracy: 0.7427
# Epoch 4/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.6139 - categorical_accuracy: 0.7903
# Epoch 5/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.5154 - categorical_accuracy: 0.8234
# Epoch 6/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.4236 - categorical_accuracy: 0.8530
# Epoch 7/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.3680 - categorical_accuracy: 0.8740
# Epoch 8/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.3185 - categorical_accuracy: 0.8898
# Epoch 9/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.2799 - categorical_accuracy: 0.9050
# Epoch 10/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.2451 - categorical_accuracy: 0.9142
# Epoch 11/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.2012 - categorical_accuracy: 0.9311
# Epoch 12/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.2013 - categorical_accuracy: 0.9304
# Epoch 13/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.1866 - categorical_accuracy: 0.9359
# Epoch 14/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.1263 - categorical_accuracy: 0.9566
# Epoch 15/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0995 - categorical_accuracy: 0.9669
# Epoch 16/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0916 - categorical_accuracy: 0.9691
# Epoch 17/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.1027 - categorical_accuracy: 0.9644
# Epoch 18/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.1032 - categorical_accuracy: 0.9641
# Epoch 19/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0639 - categorical_accuracy: 0.9782
# Epoch 20/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0734 - categorical_accuracy: 0.9753
# Epoch 21/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0963 - categorical_accuracy: 0.9659
# Epoch 22/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0706 - categorical_accuracy: 0.9755
# Epoch 23/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0537 - categorical_accuracy: 0.9822
# Epoch 24/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0992 - categorical_accuracy: 0.9672
# Epoch 25/25
# 237/237 [==============================] - 4s 16ms/step - loss: 0.0453 - categorical_accuracy: 0.9852
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.67      0.32      0.44      1680
#          1.0       0.54      0.62      0.58       168
#          2.0       0.45      0.57      0.50       168
#          3.0       0.85      0.62      0.71       168
#          4.0       0.21      0.57      0.30       168
#          5.0       0.28      0.57      0.38       168
#          6.0       0.69      0.80      0.74       168
#          7.0       0.21      0.85      0.33       168
#          8.0       0.80      0.44      0.57       168
#          9.0       0.93      0.49      0.64       168
#         10.0       0.76      0.77      0.76       168
#
#     accuracy                           0.48      3360
#    macro avg       0.58      0.60      0.54      3360
# weighted avg       0.62      0.48      0.50      3360
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 47, acceptance: 47, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20538 ms
# ==== Session #1 ====
# # of detection: 36, acceptance: 26, rejection: 10
# # of FA: 0
# # of FR: 10
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.2777777777777778
# latency: 77241 ms
# ==== Session #2 ====
# # of detection: 42, acceptance: 31, rejection: 11
# # of FA: 0
# # of FR: 11
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.2619047619047619
# latency: 12244 ms
# ==== Session #3 ====
# # of detection: 41, acceptance: 41, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #4 ====
# # of detection: 63, acceptance: 63, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.1111111111111111
# FRR: 0.0
# latency: 41845 ms
# ==== Session #5 ====
# # of detection: 62, acceptance: 62, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 4
# FAR: 0.0
# MIR: 0.06451612903225806
# FRR: 0.0
# latency: 26046 ms
# ==== Session #6 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25692 ms
# ==== Session #7 ====
# # of detection: 63, acceptance: 58, rejection: 5
# # of FA: 0
# # of FR: 5
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.07936507936507936
# latency: 25864 ms
# ==== Session #8 ====
# # of detection: 43, acceptance: 43, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 29725 ms
# ==== Session #9 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #10 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #11 ====
# # of detection: 172, acceptance: 11, rejection: 161
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.06395348837209303
# MIR: 0.0
# FRR: 0.0
# latency: 7408 ms
# ==== Session #12 ====
# # of detection: 38, acceptance: 4, rejection: 34
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.10526315789473684
# MIR: 0.0
# FRR: 0.0
# latency: 25722 ms
# ==== Session #13 ====
# # of detection: 39, acceptance: 4, rejection: 35
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.10256410256410256
# MIR: 0.0
# FRR: 0.0
# latency: 26363 ms
# ==== Session #14 ====
# # of detection: 4, acceptance: 4, rejection: 0
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #15 ====
# # of detection: 55, acceptance: 0, rejection: 55
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #16 ====
# # of detection: 57, acceptance: 57, rejection: 0
# # of FA: 57
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #17 ====
# # of detection: 45, acceptance: 10, rejection: 35
# # of FA: 10
# # of FR: 0
# # of MI: 0
# FAR: 0.2222222222222222
# MIR: 0.0
# FRR: 0.0
# latency: 37743 ms
# ==== Session #18 ====
# # of detection: 25, acceptance: 0, rejection: 25
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26210 ms
# ==== Session #19 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 38
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# simulation result: FAR: 0.12698412698412698
# MIR: 0.010912698412698412
# FNR: 0.025793650793650792
# latency: 23653.85 ms
# 8 6
# 7 5
# 10 8
# 4 5
# 4 5
# 4 5
# 4 5
# 4 5
# 4 5
# 4 7
# 7 8
# [touch] pos: 379, neg: 380, fr: 74, tr: 231, fi: 54,
# [gait] pos: 379, neg: 379, fr: 105, tr: 292, fi: 51,
# [simple_average] pos: 380, neg: 380, fr: 97, tr: 301, fi: 38,
# [weighted_average_eer] pos: 380, neg: 380, fr: 43, tr: 244, fi: 67,
# [weighted_average_auc] pos: 380, neg: 380, fr: 81, tr: 290, fi: 45,
# [deer_dempster_shafer] pos: 380, neg: 380, fr: 88, tr: 319, fi: 28,
# [auc_dempster_shafer] pos: 380, neg: 380, fr: 95, tr: 346, fi: 25,
# [kalman_filter] pos: 380, neg: 380, fr: 69, tr: 323, fi: 109,
#
# file saved.
# ========== SETUP ===========
# Game name:100_3800_10_10_10
# Negative trainer seed:100
# Game seed:3800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:526319 (0), 207696 (1), 923862 (2), 717868 (3), 856401 (4), 733568 (5), 398248 (6), 937904 (7), 698266 (8), 777078 (9)
# testers:893255, 342329, 785873, 998757, 803262, 913228, 621276, 186676, 737973, 693572
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.88      0.64      0.74        90
#            1       0.90      1.00      0.95         9
#            2       0.67      0.67      0.67         9
#            3       0.20      0.11      0.14         9
#            4       0.88      0.78      0.82         9
#            5       0.44      0.44      0.44         9
#            6       0.80      0.89      0.84         9
#            7       0.53      0.89      0.67         9
#            8       0.13      0.22      0.17         9
#            9       0.30      0.67      0.41         9
#           10       0.62      0.89      0.73         9
#
#     accuracy                           0.65       180
#    macro avg       0.58      0.65      0.60       180
# weighted avg       0.71      0.65      0.66       180
#
# Epoch 1/25
# 139/139 [==============================] - 5s 16ms/step - loss: 1.4595 - categorical_accuracy: 0.5527
# Epoch 2/25
# 139/139 [==============================] - 2s 16ms/step - loss: 1.0375 - categorical_accuracy: 0.6551
# Epoch 3/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.8038 - categorical_accuracy: 0.7267
# Epoch 4/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.7098 - categorical_accuracy: 0.7578
# Epoch 5/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.5815 - categorical_accuracy: 0.7969
# Epoch 6/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.5042 - categorical_accuracy: 0.8244
# Epoch 7/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.4701 - categorical_accuracy: 0.8338
# Epoch 8/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.4007 - categorical_accuracy: 0.8610
# Epoch 9/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.3459 - categorical_accuracy: 0.8820
# Epoch 10/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.3006 - categorical_accuracy: 0.8961
# Epoch 11/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.2515 - categorical_accuracy: 0.9137
# Epoch 12/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.2150 - categorical_accuracy: 0.9272
# Epoch 13/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.2030 - categorical_accuracy: 0.9288
# Epoch 14/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1711 - categorical_accuracy: 0.9450
# Epoch 15/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1336 - categorical_accuracy: 0.9564
# Epoch 16/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1424 - categorical_accuracy: 0.9505
# Epoch 17/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1538 - categorical_accuracy: 0.9465
# Epoch 18/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0892 - categorical_accuracy: 0.9722
# Epoch 19/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0743 - categorical_accuracy: 0.9761
# Epoch 20/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0905 - categorical_accuracy: 0.9698
# Epoch 21/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0636 - categorical_accuracy: 0.9800
# Epoch 22/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0838 - categorical_accuracy: 0.9727
# Epoch 23/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0685 - categorical_accuracy: 0.9761
# Epoch 24/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0437 - categorical_accuracy: 0.9864
# Epoch 25/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0502 - categorical_accuracy: 0.9833
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.55      0.64       980
#          1.0       0.77      0.89      0.82        98
#          2.0       0.39      0.83      0.53        98
#          3.0       0.38      0.79      0.51        98
#          4.0       0.51      0.74      0.61        98
#          5.0       0.95      0.92      0.93        98
#          6.0       0.64      0.71      0.67        98
#          7.0       0.88      0.89      0.88        98
#          8.0       0.28      0.49      0.36        98
#          9.0       0.74      0.44      0.55        98
#         10.0       0.69      0.37      0.48        98
#
#     accuracy                           0.63      1960
#    macro avg       0.64      0.69      0.64      1960
# weighted avg       0.69      0.63      0.64      1960
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24519 ms
# ==== Session #1 ====
# # of detection: 9, acceptance: 9, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.7777777777777778
# FRR: 0.0
# latency: 174361 ms
# ==== Session #2 ====
# # of detection: 57, acceptance: 57, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20039 ms
# ==== Session #3 ====
# # of detection: 25, acceptance: 14, rejection: 11
# # of FA: 0
# # of FR: 11
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.44
# latency: 31269 ms
# ==== Session #4 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 6
# FAR: 0.0
# MIR: 0.15384615384615385
# FRR: 0.0
# latency: 51351 ms
# ==== Session #5 ====
# # of detection: 57, acceptance: 33, rejection: 24
# # of FA: 0
# # of FR: 24
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.42105263157894735
# latency: 26063 ms
# ==== Session #6 ====
# # of detection: 46, acceptance: 46, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36285 ms
# ==== Session #7 ====
# # of detection: 41, acceptance: 34, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.17073170731707318
# latency: 26007 ms
# ==== Session #8 ====
# # of detection: 76, acceptance: 76, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# ==== Session #9 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26443 ms
# ==== Session #10 ====
# # of detection: 55, acceptance: 0, rejection: 55
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #11 ====
# # of detection: 51, acceptance: 0, rejection: 51
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25680 ms
# ==== Session #12 ====
# # of detection: 41, acceptance: 7, rejection: 34
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.17073170731707318
# MIR: 0.0
# FRR: 0.0
# latency: 25655 ms
# ==== Session #13 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25765 ms
# ==== Session #14 ====
# # of detection: 41, acceptance: 13, rejection: 28
# # of FA: 13
# # of FR: 0
# # of MI: 0
# FAR: 0.3170731707317073
# MIR: 0.0
# FRR: 0.0
# latency: 25669 ms
# ==== Session #15 ====
# # of detection: 30, acceptance: 23, rejection: 7
# # of FA: 23
# # of FR: 0
# # of MI: 0
# FAR: 0.7666666666666667
# MIR: 0.0
# FRR: 0.0
# latency: 149594 ms
# ==== Session #16 ====
# # of detection: 30, acceptance: 0, rejection: 30
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25685 ms
# ==== Session #17 ====
# # of detection: 40, acceptance: 20, rejection: 20
# # of FA: 20
# # of FR: 0
# # of MI: 0
# FAR: 0.5
# MIR: 0.0
# FRR: 0.0
# latency: 66984 ms
# ==== Session #18 ====
# # of detection: 49, acceptance: 0, rejection: 49
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26778 ms
# ==== Session #19 ====
# # of detection: 50, acceptance: 45, rejection: 5
# # of FA: 45
# # of FR: 0
# # of MI: 0
# FAR: 0.9
# MIR: 0.0
# FRR: 0.0
# latency: 55797 ms
# simulation result: FAR: 0.1254355400696864
# MIR: 0.015098722415795587
# FNR: 0.04878048780487805
# latency: 43888.4 ms
# 10 2
# 3 9
# 2 5
# 10 2
# 2 5
# 6 2
# 2 5
# 10 2
# 2 5
# 10 2
# 2 5
# 10 2
# 2 5
# 6 2
# 4 5
# [touch] pos: 389, neg: 390, fr: 76, tr: 236, fi: 56,
# [gait] pos: 389, neg: 389, fr: 107, tr: 299, fi: 52,
# [simple_average] pos: 390, neg: 390, fr: 98, tr: 308, fi: 40,
# [weighted_average_eer] pos: 390, neg: 390, fr: 44, tr: 250, fi: 69,
# [weighted_average_auc] pos: 390, neg: 390, fr: 82, tr: 297, fi: 47,
# [deer_dempster_shafer] pos: 390, neg: 390, fr: 90, tr: 328, fi: 30,
# [auc_dempster_shafer] pos: 390, neg: 390, fr: 98, tr: 356, fi: 27,
# [kalman_filter] pos: 390, neg: 390, fr: 72, tr: 333, fi: 111,
#
# file saved.
# ========== SETUP ===========
# Game name:100_3900_10_10_10
# Negative trainer seed:100
# Game seed:3900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:777078 (0), 220962 (1), 180679 (2), 710707 (3), 827212 (4), 796581 (5), 785873 (6), 990622 (7), 264325 (8), 594887 (9)
# testers:913228, 663153, 186676, 622852, 998757, 973891, 352716, 893198, 737973, 257279
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.71      0.58      0.64        90
#            1       0.88      0.78      0.82         9
#            2       0.18      0.22      0.20         9
#            3       1.00      0.89      0.94         9
#            4       0.46      0.67      0.55         9
#            5       0.88      0.78      0.82         9
#            6       0.46      0.67      0.55         9
#            7       0.25      0.33      0.29         9
#            8       0.67      0.67      0.67         9
#            9       0.33      0.33      0.33         9
#           10       0.25      0.44      0.32         9
#
#     accuracy                           0.58       180
#    macro avg       0.55      0.58      0.56       180
# weighted avg       0.62      0.58      0.59       180
#
# Epoch 1/25
# 87/87 [==============================] - 4s 17ms/step - loss: 1.6548 - categorical_accuracy: 0.5142
# Epoch 2/25
# 87/87 [==============================] - 1s 16ms/step - loss: 1.2002 - categorical_accuracy: 0.5951
# Epoch 3/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.8845 - categorical_accuracy: 0.6921
# Epoch 4/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.7113 - categorical_accuracy: 0.7564
# Epoch 5/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.6316 - categorical_accuracy: 0.7821
# Epoch 6/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.4967 - categorical_accuracy: 0.8274
# Epoch 7/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.4227 - categorical_accuracy: 0.8540
# Epoch 8/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.3625 - categorical_accuracy: 0.8765
# Epoch 9/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.3469 - categorical_accuracy: 0.8793
# Epoch 10/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.2811 - categorical_accuracy: 0.9021
# Epoch 11/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.2937 - categorical_accuracy: 0.8946
# Epoch 12/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.2191 - categorical_accuracy: 0.9262
# Epoch 13/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.2109 - categorical_accuracy: 0.9286
# Epoch 14/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.1681 - categorical_accuracy: 0.9428
# Epoch 15/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.1262 - categorical_accuracy: 0.9598
# Epoch 16/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.1001 - categorical_accuracy: 0.9712
# Epoch 17/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0811 - categorical_accuracy: 0.9755
# Epoch 18/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0671 - categorical_accuracy: 0.9809
# Epoch 19/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.1339 - categorical_accuracy: 0.9553
# Epoch 20/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0775 - categorical_accuracy: 0.9762
# Epoch 21/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0469 - categorical_accuracy: 0.9876
# Epoch 22/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0657 - categorical_accuracy: 0.9805
# Epoch 23/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0485 - categorical_accuracy: 0.9850
# Epoch 24/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0403 - categorical_accuracy: 0.9878
# Epoch 25/25
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0489 - categorical_accuracy: 0.9847
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.40      0.51       610
#          1.0       0.95      0.59      0.73        61
#          2.0       0.64      0.79      0.71        61
#          3.0       0.28      0.77      0.41        61
#          4.0       0.75      0.54      0.63        61
#          5.0       0.94      0.95      0.94        61
#          6.0       0.59      0.93      0.73        61
#          7.0       0.62      0.64      0.63        61
#          8.0       0.64      0.85      0.73        61
#          9.0       0.35      0.89      0.50        61
#         10.0       0.61      0.95      0.74        61
#
#     accuracy                           0.60      1220
#    macro avg       0.64      0.75      0.66      1220
# weighted avg       0.67      0.60      0.59      1220
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25640 ms
# ==== Session #1 ====
# # of detection: 32, acceptance: 23, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.28125
# latency: 72884 ms
# ==== Session #2 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 32145 ms
# ==== Session #3 ====
# # of detection: 51, acceptance: 43, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1568627450980392
# latency: 29324 ms
# ==== Session #4 ====
# # of detection: 58, acceptance: 58, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.13793103448275862
# FRR: 0.0
# latency: 22518 ms
# ==== Session #5 ====
# ...
# Epoch 9/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2473 - categorical_accuracy: 0.9136
# Epoch 10/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.2162 - categorical_accuracy: 0.9234
# Epoch 11/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1860 - categorical_accuracy: 0.9347
# Epoch 12/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1952 - categorical_accuracy: 0.9300
# Epoch 13/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1867 - categorical_accuracy: 0.9342
# Epoch 14/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1405 - categorical_accuracy: 0.9509
# Epoch 15/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1315 - categorical_accuracy: 0.9537
# Epoch 16/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1191 - categorical_accuracy: 0.9569
# Epoch 17/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0960 - categorical_accuracy: 0.9661
# Epoch 18/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.1003 - categorical_accuracy: 0.9637
# Epoch 19/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0855 - categorical_accuracy: 0.9705
# Epoch 20/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0783 - categorical_accuracy: 0.9718
# Epoch 21/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0695 - categorical_accuracy: 0.9761
# Epoch 22/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0870 - categorical_accuracy: 0.9699
# Epoch 23/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0672 - categorical_accuracy: 0.9756
# Epoch 24/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0426 - categorical_accuracy: 0.9849
# Epoch 25/25
# 391/391 [==============================] - 6s 16ms/step - loss: 0.0467 - categorical_accuracy: 0.9838
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.53      0.63      2770
#          1.0       0.40      0.95      0.56       277
#          2.0       0.45      0.62      0.52       277
#          3.0       0.97      0.81      0.88       277
#          4.0       0.88      0.89      0.89       277
#          5.0       0.95      0.99      0.97       277
#          6.0       0.44      0.55      0.49       277
#          7.0       0.56      0.58      0.57       277
#          8.0       0.33      0.79      0.46       277
#          9.0       0.78      0.52      0.62       277
#         10.0       0.71      0.74      0.72       277
#
#     accuracy                           0.64      5540
#    macro avg       0.66      0.72      0.67      5540
# weighted avg       0.71      0.64      0.65      5540
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 35, acceptance: 35, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #1 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26016 ms
# ==== Session #2 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25722 ms
# ==== Session #3 ====
# # of detection: 74, acceptance: 74, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13889 ms
# ==== Session #4 ====
# # of detection: 80, acceptance: 80, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# ==== Session #5 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.20588235294117646
# FRR: 0.0
# latency: 72096 ms
# ==== Session #6 ====
# # of detection: 82, acceptance: 82, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20624 ms
# ==== Session #7 ====
# # of detection: 75, acceptance: 75, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15371 ms
# ==== Session #8 ====
# # of detection: 40, acceptance: 40, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35940 ms
# ==== Session #9 ====
# # of detection: 47, acceptance: 47, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30806 ms
# ==== Session #10 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #11 ====
# # of detection: 72, acceptance: 50, rejection: 22
# # of FA: 50
# # of FR: 0
# # of MI: 0
# FAR: 0.6944444444444444
# MIR: 0.0
# FRR: 0.0
# latency: 99159 ms
# ==== Session #12 ====
# # of detection: 18, acceptance: 18, rejection: 0
# # of FA: 18
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #13 ====
# # of detection: 44, acceptance: 0, rejection: 44
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #14 ====
# # of detection: 4, acceptance: 4, rejection: 0
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #15 ====
# # of detection: 38, acceptance: 11, rejection: 27
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.2894736842105263
# MIR: 0.0
# FRR: 0.0
# latency: 20874 ms
# ==== Session #16 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 50
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #17 ====
# # of detection: 67, acceptance: 0, rejection: 67
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 34537 ms
# ==== Session #18 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25643 ms
# ==== Session #19 ====
# # of detection: 48, acceptance: 48, rejection: 0
# # of FA: 48
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# simulation result: FAR: 0.18583162217659138
# MIR: 0.007186858316221766
# FNR: 0.0
# latency: 26185.0 ms
# 7 4
# 4 6
# 4 6
# 4 6
# 4 6
# 4 6
# 1 2
# 4 6
# 8 9
# [touch] pos: 489, neg: 490, fr: 96, tr: 295, fi: 72,
# [gait] pos: 489, neg: 489, fr: 140, tr: 382, fi: 58,
# [simple_average] pos: 490, neg: 490, fr: 122, tr: 391, fi: 48,
# [weighted_average_eer] pos: 490, neg: 490, fr: 54, tr: 310, fi: 81,
# [weighted_average_auc] pos: 490, neg: 490, fr: 102, tr: 375, fi: 56,
# [deer_dempster_shafer] pos: 490, neg: 490, fr: 110, tr: 414, fi: 36,
# [auc_dempster_shafer] pos: 490, neg: 490, fr: 126, tr: 444, fi: 32,
# [kalman_filter] pos: 490, neg: 490, fr: 96, tr: 421, fi: 131,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4900_10_10_10
# Negative trainer seed:100
# Game seed:4900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:622852 (0), 588087 (1), 856302 (2), 693572 (3), 990622 (4), 872895 (5), 342329 (6), 796581 (7), 865501 (8), 207696 (9)
# testers:396697, 556357, 220962, 841866, 257279, 710707, 336172, 218719, 594887, 771782
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.65      0.72       100
#            1       0.60      0.90      0.72        10
#            2       0.50      0.60      0.55        10
#            3       0.47      0.80      0.59        10
#            4       1.00      0.70      0.82        10
#            5       0.70      0.70      0.70        10
#            6       0.67      0.80      0.73        10
#            7       0.17      0.20      0.18        10
#            8       0.69      0.90      0.78        10
#            9       0.25      0.40      0.31        10
#           10       0.80      0.40      0.53        10
#
#     accuracy                           0.65       200
#    macro avg       0.60      0.64      0.60       200
# weighted avg       0.69      0.65      0.65       200
#
# Epoch 1/25
# 190/190 [==============================] - 6s 16ms/step - loss: 1.5023 - categorical_accuracy: 0.5393
# Epoch 2/25
# 190/190 [==============================] - 3s 16ms/step - loss: 1.0592 - categorical_accuracy: 0.6443
# Epoch 3/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.7496 - categorical_accuracy: 0.7460
# Epoch 4/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.6002 - categorical_accuracy: 0.7951
# Epoch 5/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.4876 - categorical_accuracy: 0.8339
# Epoch 6/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.4086 - categorical_accuracy: 0.8642
# Epoch 7/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.3466 - categorical_accuracy: 0.8836
# Epoch 8/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.3310 - categorical_accuracy: 0.8862
# Epoch 9/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.2535 - categorical_accuracy: 0.9123
# Epoch 10/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.2425 - categorical_accuracy: 0.9162
# Epoch 11/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.2063 - categorical_accuracy: 0.9288
# Epoch 12/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.1598 - categorical_accuracy: 0.9452
# Epoch 13/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.1507 - categorical_accuracy: 0.9487
# Epoch 14/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.1229 - categorical_accuracy: 0.9584
# Epoch 15/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.1103 - categorical_accuracy: 0.9618
# Epoch 16/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0981 - categorical_accuracy: 0.9668
# Epoch 17/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0760 - categorical_accuracy: 0.9752
# Epoch 18/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0919 - categorical_accuracy: 0.9696
# Epoch 19/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0660 - categorical_accuracy: 0.9783
# Epoch 20/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0641 - categorical_accuracy: 0.9792
# Epoch 21/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.1239 - categorical_accuracy: 0.9564
# Epoch 22/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0651 - categorical_accuracy: 0.9773
# Epoch 23/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0380 - categorical_accuracy: 0.9886
# Epoch 24/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0408 - categorical_accuracy: 0.9871
# Epoch 25/25
# 190/190 [==============================] - 3s 16ms/step - loss: 0.0387 - categorical_accuracy: 0.9884
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.66      0.26      0.37      1350
#          1.0       0.91      0.64      0.75       135
#          2.0       0.19      0.36      0.25       135
#          3.0       0.13      0.59      0.21       135
#          4.0       0.70      0.87      0.78       135
#          5.0       0.64      0.87      0.74       135
#          6.0       0.53      0.90      0.67       135
#          7.0       0.57      0.39      0.46       135
#          8.0       0.73      0.90      0.81       135
#          9.0       0.98      0.79      0.88       135
#         10.0       0.45      0.88      0.60       135
#
#     accuracy                           0.49      2700
#    macro avg       0.59      0.68      0.59      2700
# weighted avg       0.62      0.49      0.49      2700
#
# training done
# too short, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 22401 ms
# ==== Session #1 ====
# # of detection: 28, acceptance: 28, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 35942 ms
# ==== Session #2 ====
# # of detection: 73, acceptance: 73, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #3 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 29738 ms
# ==== Session #4 ====
# # of detection: 59, acceptance: 32, rejection: 27
# # of FA: 0
# # of FR: 27
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.4576271186440678
# latency: 41367 ms
# ==== Session #5 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25638 ms
# ==== Session #6 ====
# # of detection: 51, acceptance: 51, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25680 ms
# ==== Session #7 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #8 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31223 ms
# ==== Session #9 ====
# # of detection: 9, acceptance: 9, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 52820 ms
# ==== Session #10 ====
# # of detection: 27, acceptance: 27, rejection: 0
# # of FA: 27
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #11 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 38
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #12 ====
# # of detection: 32, acceptance: 0, rejection: 32
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26038 ms
# ==== Session #13 ====
# # of detection: 71, acceptance: 66, rejection: 5
# # of FA: 66
# # of FR: 0
# # of MI: 0
# FAR: 0.9295774647887324
# MIR: 0.0
# FRR: 0.0
# latency: 108458 ms
# ==== Session #14 ====
# # of detection: 51, acceptance: 7, rejection: 44
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.13725490196078433
# MIR: 0.0
# FRR: 0.0
# latency: 25725 ms
# ==== Session #15 ====
# # of detection: 53, acceptance: 0, rejection: 53
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 21794 ms
# ==== Session #16 ====
# # of detection: 100, acceptance: 0, rejection: 100
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# ==== Session #17 ====
# # of detection: 63, acceptance: 48, rejection: 15
# # of FA: 48
# # of FR: 0
# # of MI: 0
# FAR: 0.7619047619047619
# MIR: 0.0
# FRR: 0.0
# latency: 133932 ms
# ==== Session #18 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20605 ms
# ==== Session #19 ====
# # of detection: 47, acceptance: 7, rejection: 40
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.14893617021276595
# MIR: 0.0
# FRR: 0.0
# latency: 51565 ms
# simulation result: FAR: 0.2
# MIR: 0.0
# FNR: 0.027979274611398965
# latency: 35905.15 ms
# 10 3
# 5 10
# 1 2
# 4 5
# 9 10
# [touch] pos: 499, neg: 500, fr: 98, tr: 299, fi: 73,
# [gait] pos: 499, neg: 499, fr: 141, tr: 389, fi: 58,
# [simple_average] pos: 500, neg: 500, fr: 123, tr: 398, fi: 48,
# [weighted_average_eer] pos: 500, neg: 500, fr: 54, tr: 315, fi: 81,
# [weighted_average_auc] pos: 500, neg: 500, fr: 103, tr: 381, fi: 57,
# [deer_dempster_shafer] pos: 500, neg: 500, fr: 110, tr: 421, fi: 36,
# [auc_dempster_shafer] pos: 500, neg: 500, fr: 127, tr: 452, fi: 32,
# [kalman_filter] pos: 500, neg: 500, fr: 96, tr: 428, fi: 134,
#
# file saved.

# %%
#@title Experiment 1.3: 7 users 3 + 3 training sessions

last_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_accuracy_experiment_balance_limit(seed, 7, 3)
    score_pairs = gen_per_segment_decision(tml, player)

    result_met = {i: get_metrics_per_segment(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if last_result is None:
        last_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                last_result[i][j] += sc
    to_display = ""
    for key, item in last_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022_3/re_accuracy_7_3_limit", str(seed)))
# Out:
# Streaming output truncated to the last 5000 lines.
# ==== Session #1 ====
# # of detection: 51, acceptance: 50, rejection: 1
# # of FA: 0
# # of FR: 1
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0196078431372549
# latency: 25563 ms
# ==== Session #2 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25962 ms
# ==== Session #3 ====
# # of detection: 35, acceptance: 35, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25668 ms
# ==== Session #4 ====
# # of detection: 40, acceptance: 40, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25812 ms
# ==== Session #5 ====
# # of detection: 36, acceptance: 36, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #6 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 31223 ms
# ==== Session #7 ====
# # of detection: 41, acceptance: 0, rejection: 41
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26007 ms
# ==== Session #8 ====
# # of detection: 31, acceptance: 24, rejection: 7
# # of FA: 24
# # of FR: 0
# # of MI: 0
# FAR: 0.7741935483870968
# MIR: 0.0
# FRR: 0.0
# latency: 106396 ms
# ==== Session #9 ====
# # of detection: 4, acceptance: 3, rejection: 1
# # of FA: 3
# # of FR: 0
# # of MI: 0
# FAR: 0.75
# MIR: 0.0
# FRR: 0.0
# latency: 38220 ms
# ==== Session #10 ====
# # of detection: 72, acceptance: 0, rejection: 72
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30911 ms
# ==== Session #11 ====
# # of detection: 7, acceptance: 7, rejection: 0
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #12 ====
# # of detection: 30, acceptance: 17, rejection: 13
# # of FA: 17
# # of FR: 0
# # of MI: 0
# FAR: 0.5666666666666667
# MIR: 0.0
# FRR: 0.0
# latency: 72411 ms
# ==== Session #13 ====
# # of detection: 43, acceptance: 0, rejection: 43
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25651 ms
# simulation result: FAR: 0.09902912621359224
# MIR: 0.0
# FNR: 0.001941747572815534
# latency: 34109.21428571428 ms
# 4 2
# 4 2
# 4 2
# 4 2
# 2 3
# 3 4
# [touch] pos: 84, neg: 83, fr: 14, tr: 57, fi: 6,
# [gait] pos: 84, neg: 84, fr: 24, tr: 71, fi: 12,
# [simple_average] pos: 84, neg: 84, fr: 11, tr: 68, fi: 6,
# [weighted_average_eer] pos: 84, neg: 84, fr: 4, tr: 52, fi: 7,
# [weighted_average_auc] pos: 84, neg: 84, fr: 9, tr: 65, fi: 6,
# [deer_dempster_shafer] pos: 84, neg: 84, fr: 10, tr: 69, fi: 3,
# [auc_dempster_shafer] pos: 84, neg: 84, fr: 11, tr: 75, fi: 3,
# [kalman_filter] pos: 84, neg: 84, fr: 13, tr: 77, fi: 17,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1200_10_7_7
# Negative trainer seed:100
# Game seed:1200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:663153 (0), 865881 (1), 561993 (2), 220962 (3), 876011 (4), 171538 (5), 856302 (6)
# testers:594887, 151985, 872895, 218719, 733568, 893255, 368258
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.85      0.68      0.75        84
#            1       0.77      0.83      0.80        12
#            2       0.48      0.92      0.63        12
#            3       0.75      1.00      0.86        12
#            4       0.33      0.50      0.40        12
#            5       0.80      0.67      0.73        12
#            6       1.00      0.33      0.50        12
#            7       0.41      0.58      0.48        12
#
#     accuracy                           0.68       168
#    macro avg       0.67      0.69      0.64       168
# weighted avg       0.75      0.68      0.69       168
#
# Epoch 1/25
# 117/117 [==============================] - 5s 17ms/step - loss: 1.4221 - categorical_accuracy: 0.5308
# Epoch 2/25
# 117/117 [==============================] - 2s 16ms/step - loss: 1.0064 - categorical_accuracy: 0.6309
# Epoch 3/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.8192 - categorical_accuracy: 0.7051
# Epoch 4/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.6447 - categorical_accuracy: 0.7707
# Epoch 5/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.5183 - categorical_accuracy: 0.8162
# Epoch 6/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.4371 - categorical_accuracy: 0.8428
# Epoch 7/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3848 - categorical_accuracy: 0.8608
# Epoch 8/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.3130 - categorical_accuracy: 0.8889
# Epoch 9/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.2916 - categorical_accuracy: 0.8970
# Epoch 10/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.2399 - categorical_accuracy: 0.9128
# Epoch 11/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.2175 - categorical_accuracy: 0.9225
# Epoch 12/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1742 - categorical_accuracy: 0.9405
# Epoch 13/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1704 - categorical_accuracy: 0.9406
# Epoch 14/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1416 - categorical_accuracy: 0.9503
# Epoch 15/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1218 - categorical_accuracy: 0.9586
# Epoch 16/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1026 - categorical_accuracy: 0.9654
# Epoch 17/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0931 - categorical_accuracy: 0.9690
# Epoch 18/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0689 - categorical_accuracy: 0.9768
# Epoch 19/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0603 - categorical_accuracy: 0.9808
# Epoch 20/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0430 - categorical_accuracy: 0.9877
# Epoch 21/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0523 - categorical_accuracy: 0.9841
# Epoch 22/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.1017 - categorical_accuracy: 0.9636
# Epoch 23/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0476 - categorical_accuracy: 0.9845
# Epoch 24/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0251 - categorical_accuracy: 0.9935
# Epoch 25/25
# 117/117 [==============================] - 2s 16ms/step - loss: 0.0216 - categorical_accuracy: 0.9946
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.51      0.14      0.22       826
#          1.0       0.80      0.99      0.89       118
#          2.0       0.81      0.69      0.74       118
#          3.0       0.81      0.81      0.81       118
#          4.0       0.84      0.86      0.85       118
#          5.0       0.70      0.99      0.82       118
#          6.0       0.99      0.59      0.74       118
#          7.0       0.14      0.86      0.25       118
#
#     accuracy                           0.48      1652
#    macro avg       0.70      0.74      0.66      1652
# weighted avg       0.62      0.48      0.47      1652
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# too short, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25650 ms
# ==== Session #1 ====
# # of detection: 49, acceptance: 40, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1836734693877551
# latency: 46667 ms
# ==== Session #2 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25689 ms
# ==== Session #3 ====
# # of detection: 32, acceptance: 23, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.28125
# latency: 72884 ms
# ==== Session #4 ====
# # of detection: 19, acceptance: 19, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30892 ms
# ==== Session #5 ====
# # of detection: 66, acceptance: 66, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25864 ms
# ==== Session #6 ====
# # of detection: 73, acceptance: 73, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #7 ====
# # of detection: 62, acceptance: 17, rejection: 45
# # of FA: 17
# # of FR: 0
# # of MI: 0
# FAR: 0.27419354838709675
# MIR: 0.0
# FRR: 0.0
# latency: 57970 ms
# ==== Session #8 ====
# # of detection: 50, acceptance: 44, rejection: 6
# # of FA: 44
# # of FR: 0
# # of MI: 0
# FAR: 0.88
# MIR: 0.0
# FRR: 0.0
# latency: 164701 ms
# ==== Session #9 ====
# # of detection: 38, acceptance: 0, rejection: 38
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25638 ms
# ==== Session #10 ====
# # of detection: 66, acceptance: 0, rejection: 66
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25687 ms
# ==== Session #11 ====
# # of detection: 57, acceptance: 0, rejection: 57
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26063 ms
# ==== Session #12 ====
# # of detection: 55, acceptance: 0, rejection: 55
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 18039 ms
# ==== Session #13 ====
# # of detection: 32, acceptance: 14, rejection: 18
# # of FA: 14
# # of FR: 0
# # of MI: 0
# FAR: 0.4375
# MIR: 0.0
# FRR: 0.0
# latency: 77890 ms
# simulation result: FAR: 0.10901162790697674
# MIR: 0.0
# FNR: 0.02616279069767442
# latency: 46384.642857142855 ms
# [touch] pos: 91, neg: 90, fr: 16, tr: 60, fi: 6,
# [gait] pos: 91, neg: 91, fr: 27, tr: 76, fi: 12,
# [simple_average] pos: 91, neg: 91, fr: 14, tr: 73, fi: 6,
# [weighted_average_eer] pos: 91, neg: 91, fr: 4, tr: 57, fi: 7,
# [weighted_average_auc] pos: 91, neg: 91, fr: 10, tr: 70, fi: 6,
# [deer_dempster_shafer] pos: 91, neg: 91, fr: 12, tr: 76, fi: 3,
# [auc_dempster_shafer] pos: 91, neg: 91, fr: 13, tr: 82, fi: 3,
# [kalman_filter] pos: 91, neg: 91, fr: 13, tr: 84, fi: 17,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1300_10_7_7
# Negative trainer seed:100
# Game seed:1300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:808022 (0), 663153 (1), 980953 (2), 865881 (3), 990622 (4), 256487 (5), 799296 (6)
# testers:737973, 841866, 693572, 588087, 248252, 698266, 998757
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.77        91
#            1       0.68      1.00      0.81        13
#            2       1.00      0.92      0.96        13
#            3       1.00      0.85      0.92        13
#            4       0.61      0.85      0.71        13
#            5       0.62      0.77      0.69        13
#            6       0.50      0.77      0.61        13
#            7       0.56      0.77      0.65        13
#
#     accuracy                           0.76       182
#    macro avg       0.73      0.82      0.76       182
# weighted avg       0.80      0.76      0.77       182
#
# Epoch 1/25
# 241/241 [==============================] - 7s 16ms/step - loss: 1.2214 - categorical_accuracy: 0.5854
# Epoch 2/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.8169 - categorical_accuracy: 0.7105
# Epoch 3/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.5834 - categorical_accuracy: 0.7923
# Epoch 4/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.4748 - categorical_accuracy: 0.8286
# Epoch 5/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.3978 - categorical_accuracy: 0.8550
# Epoch 6/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.3286 - categorical_accuracy: 0.8835
# Epoch 7/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.3095 - categorical_accuracy: 0.8866
# Epoch 8/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.2511 - categorical_accuracy: 0.9091
# Epoch 9/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.2123 - categorical_accuracy: 0.9237
# Epoch 10/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1862 - categorical_accuracy: 0.9331
# Epoch 11/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1499 - categorical_accuracy: 0.9466
# Epoch 12/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1587 - categorical_accuracy: 0.9417
# Epoch 13/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1079 - categorical_accuracy: 0.9627
# Epoch 14/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1149 - categorical_accuracy: 0.9599
# Epoch 15/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0860 - categorical_accuracy: 0.9700
# Epoch 16/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0861 - categorical_accuracy: 0.9700
# Epoch 17/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0902 - categorical_accuracy: 0.9683
# Epoch 18/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0660 - categorical_accuracy: 0.9763
# Epoch 19/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0640 - categorical_accuracy: 0.9782
# Epoch 20/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.1136 - categorical_accuracy: 0.9608
# Epoch 21/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0443 - categorical_accuracy: 0.9856
# Epoch 22/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0687 - categorical_accuracy: 0.9770
# Epoch 23/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0616 - categorical_accuracy: 0.9777
# Epoch 24/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0650 - categorical_accuracy: 0.9773
# Epoch 25/25
# 241/241 [==============================] - 4s 16ms/step - loss: 0.0446 - categorical_accuracy: 0.9843
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.67      0.77      1708
#          1.0       0.91      0.61      0.73       244
#          2.0       0.77      0.99      0.87       244
#          3.0       0.82      0.99      0.90       244
#          4.0       0.40      0.93      0.56       244
#          5.0       0.62      0.93      0.74       244
#          6.0       0.97      0.98      0.98       244
#          7.0       0.94      0.79      0.86       244
#
#     accuracy                           0.78      3416
#    macro avg       0.79      0.86      0.80      3416
# weighted avg       0.84      0.78      0.79      3416
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 38, acceptance: 28, rejection: 10
# # of FA: 0
# # of FR: 10
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.2631578947368421
# latency: 44501 ms
# ==== Session #1 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25650 ms
# ==== Session #2 ====
# # of detection: 9, acceptance: 9, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25670 ms
# ==== Session #3 ====
# # of detection: 47, acceptance: 43, rejection: 4
# # of FA: 0
# # of FR: 4
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0851063829787234
# latency: 46667 ms
# ==== Session #4 ====
# # of detection: 60, acceptance: 60, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36389 ms
# ==== Session #5 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26060 ms
# ==== Session #6 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25695 ms
# ==== Session #7 ====
# # of detection: 49, acceptance: 4, rejection: 45
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.08163265306122448
# MIR: 0.0
# FRR: 0.0
# latency: 26778 ms
# ==== Session #8 ====
# # of detection: 72, acceptance: 61, rejection: 11
# # of FA: 61
# # of FR: 0
# # of MI: 0
# FAR: 0.8472222222222222
# MIR: 0.0
# FRR: 0.0
# latency: 87660 ms
# ==== Session #9 ====
# # of detection: 50, acceptance: 7, rejection: 43
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.14
# MIR: 0.0
# FRR: 0.0
# latency: 29738 ms
# ==== Session #10 ====
# # of detection: 26, acceptance: 26, rejection: 0
# # of FA: 26
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #11 ====
# # of detection: 63, acceptance: 0, rejection: 63
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25877 ms
# ==== Session #12 ====
# # of detection: 76, acceptance: 0, rejection: 76
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15785 ms
# ==== Session #13 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25765 ms
# simulation result: FAR: 0.14961832061068703
# MIR: 0.0
# FNR: 0.021374045801526718
# latency: 31588.14285714286 ms
# 1 2
# 2 3
# [touch] pos: 98, neg: 97, fr: 17, tr: 63, fi: 6,
# [gait] pos: 98, neg: 98, fr: 29, tr: 82, fi: 12,
# [simple_average] pos: 98, neg: 98, fr: 16, tr: 78, fi: 6,
# [weighted_average_eer] pos: 98, neg: 98, fr: 6, tr: 60, fi: 7,
# [weighted_average_auc] pos: 98, neg: 98, fr: 12, tr: 75, fi: 6,
# [deer_dempster_shafer] pos: 98, neg: 98, fr: 14, tr: 82, fi: 3,
# [auc_dempster_shafer] pos: 98, neg: 98, fr: 15, tr: 88, fi: 3,
# [kalman_filter] pos: 98, neg: 98, fr: 15, tr: 88, fi: 19,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1400_10_7_7
# Negative trainer seed:100
# Game seed:1400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:264325 (0), 588087 (1), 710707 (2), 720193 (3), 207696 (4), 966655 (5), 594887 (6)
# testers:398248, 657486, 578526, 998757, 395129, 771782, 663153
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.78      0.58      0.66       119
#            1       0.45      0.59      0.51        17
#            2       0.48      0.76      0.59        17
#            3       0.64      0.82      0.72        17
#            4       0.65      0.76      0.70        17
#            5       0.91      0.59      0.71        17
#            6       0.63      0.71      0.67        17
#            7       0.39      0.65      0.49        17
#
#     accuracy                           0.64       238
#    macro avg       0.62      0.68      0.63       238
# weighted avg       0.68      0.64      0.65       238
#
# Epoch 1/25
# 133/133 [==============================] - 6s 17ms/step - loss: 1.4113 - categorical_accuracy: 0.5312
# Epoch 2/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.9443 - categorical_accuracy: 0.6620
# Epoch 3/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.7174 - categorical_accuracy: 0.7465
# Epoch 4/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.5894 - categorical_accuracy: 0.7951
# Epoch 5/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.4986 - categorical_accuracy: 0.8265
# Epoch 6/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.4175 - categorical_accuracy: 0.8581
# Epoch 7/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.3576 - categorical_accuracy: 0.8764
# Epoch 8/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.2918 - categorical_accuracy: 0.9008
# Epoch 9/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.2574 - categorical_accuracy: 0.9106
# Epoch 10/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.2311 - categorical_accuracy: 0.9193
# Epoch 11/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.1825 - categorical_accuracy: 0.9374
# Epoch 12/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.1614 - categorical_accuracy: 0.9433
# Epoch 13/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.1300 - categorical_accuracy: 0.9576
# Epoch 14/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.1183 - categorical_accuracy: 0.9611
# Epoch 15/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.1036 - categorical_accuracy: 0.9655
# Epoch 16/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0820 - categorical_accuracy: 0.9743
# Epoch 17/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0624 - categorical_accuracy: 0.9804
# Epoch 18/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0848 - categorical_accuracy: 0.9717
# Epoch 19/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0587 - categorical_accuracy: 0.9811
# Epoch 20/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0529 - categorical_accuracy: 0.9828
# Epoch 21/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0786 - categorical_accuracy: 0.9738
# Epoch 22/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0628 - categorical_accuracy: 0.9791
# Epoch 23/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0304 - categorical_accuracy: 0.9914
# Epoch 24/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0456 - categorical_accuracy: 0.9861
# Epoch 25/25
# 133/133 [==============================] - 2s 16ms/step - loss: 0.0546 - categorical_accuracy: 0.9819
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.48      0.62       945
#          1.0       0.46      0.88      0.60       135
#          2.0       0.22      0.32      0.26       135
#          3.0       0.63      0.84      0.72       135
#          4.0       0.94      0.83      0.88       135
#          5.0       0.46      0.92      0.61       135
#          6.0       0.85      0.97      0.91       135
#          7.0       0.65      0.98      0.78       135
#
#     accuracy                           0.65      1890
#    macro avg       0.64      0.78      0.67      1890
# weighted avg       0.74      0.65      0.65      1890
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26280 ms
# ==== Session #1 ====
# # of detection: 28, acceptance: 28, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 3
# FAR: 0.0
# MIR: 0.10714285714285714
# FRR: 0.0
# latency: 51379 ms
# ==== Session #2 ====
# # of detection: 51, acceptance: 43, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.1568627450980392
# latency: 29324 ms
# ==== Session #3 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #4 ====
# # of detection: 9, acceptance: 9, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 1.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 80, acceptance: 80, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# ==== Session #6 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 64
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 1.0
# latency: -1 ms
# ==== Session #7 ====
# # of detection: 48, acceptance: 0, rejection: 48
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25847 ms
# ==== Session #8 ====
# # of detection: 24, acceptance: 7, rejection: 17
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.2916666666666667
# MIR: 0.0
# FRR: 0.0
# latency: 59446 ms
# ==== Session #9 ====
# # of detection: 42, acceptance: 0, rejection: 42
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30245 ms
# ==== Session #10 ====
# # of detection: 34, acceptance: 4, rejection: 30
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.11764705882352941
# MIR: 0.0
# FRR: 0.0
# latency: 30906 ms
# ==== Session #11 ====
# # of detection: 32, acceptance: 12, rejection: 20
# # of FA: 12
# # of FR: 0
# # of MI: 0
# FAR: 0.375
# MIR: 0.0
# FRR: 0.0
# latency: 91071 ms
# ==== Session #12 ====
# # of detection: 53, acceptance: 0, rejection: 53
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 22562 ms
# ==== Session #13 ====
# # of detection: 50, acceptance: 0, rejection: 50
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25650 ms
# simulation result: FAR: 0.03758169934640523
# MIR: 0.0196078431372549
# FNR: 0.11764705882352941
# latency: 31388.428571428572 ms
# 1 3
# 6 4
# 3 5
# 7 6
# 3 5
# 1 2
# 3 5
# 1 2
# 3 5
# 3 5
# 3 5
# 1 2
# 4 5
# [touch] pos: 105, neg: 104, fr: 18, tr: 67, fi: 10,
# [gait] pos: 105, neg: 105, fr: 31, tr: 88, fi: 12,
# [simple_average] pos: 105, neg: 105, fr: 17, tr: 85, fi: 7,
# [weighted_average_eer] pos: 105, neg: 105, fr: 7, tr: 64, fi: 9,
# [weighted_average_auc] pos: 105, neg: 105, fr: 13, tr: 82, fi: 8,
# [deer_dempster_shafer] pos: 105, neg: 105, fr: 15, tr: 89, fi: 4,
# [auc_dempster_shafer] pos: 105, neg: 105, fr: 16, tr: 95, fi: 4,
# [kalman_filter] pos: 105, neg: 105, fr: 16, tr: 95, fi: 21,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1500_10_7_7
# Negative trainer seed:100
# Game seed:1500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:526319 (0), 856401 (1), 405035 (2), 663153 (3), 720193 (4), 745224 (5), 763813 (6)
# testers:990622, 540641, 693572, 398248, 539502, 554303, 973891
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.93      0.79      0.85        70
#            1       0.90      0.90      0.90        10
#            2       0.53      0.80      0.64        10
#            3       0.64      0.90      0.75        10
#            4       1.00      0.80      0.89        10
#            5       0.50      0.60      0.55        10
#            6       0.70      0.70      0.70        10
#            7       0.67      0.80      0.73        10
#
#     accuracy                           0.79       140
#    macro avg       0.73      0.79      0.75       140
# weighted avg       0.82      0.79      0.79       140
#
# Epoch 1/25
# 240/240 [==============================] - 7s 16ms/step - loss: 0.8801 - categorical_accuracy: 0.7040
# Epoch 2/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.4853 - categorical_accuracy: 0.8294
# Epoch 3/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.3393 - categorical_accuracy: 0.8823
# Epoch 4/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.2489 - categorical_accuracy: 0.9130
# Epoch 5/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.2111 - categorical_accuracy: 0.9256
# Epoch 6/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1778 - categorical_accuracy: 0.9387
# Epoch 7/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1604 - categorical_accuracy: 0.9419
# Epoch 8/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1364 - categorical_accuracy: 0.9526
# Epoch 9/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.1139 - categorical_accuracy: 0.9615
# Epoch 10/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0974 - categorical_accuracy: 0.9660
# Epoch 11/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0791 - categorical_accuracy: 0.9723
# Epoch 12/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0610 - categorical_accuracy: 0.9788
# Epoch 13/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0572 - categorical_accuracy: 0.9805
# Epoch 14/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0783 - categorical_accuracy: 0.9709
# Epoch 15/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0421 - categorical_accuracy: 0.9863
# Epoch 16/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0301 - categorical_accuracy: 0.9904
# Epoch 17/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0499 - categorical_accuracy: 0.9833
# Epoch 18/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0355 - categorical_accuracy: 0.9883
# Epoch 19/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0549 - categorical_accuracy: 0.9808
# Epoch 20/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0634 - categorical_accuracy: 0.9782
# Epoch 21/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0261 - categorical_accuracy: 0.9913
# Epoch 22/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0133 - categorical_accuracy: 0.9965
# Epoch 23/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0263 - categorical_accuracy: 0.9916
# Epoch 24/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0439 - categorical_accuracy: 0.9844
# Epoch 25/25
# 240/240 [==============================] - 4s 16ms/step - loss: 0.0372 - categorical_accuracy: 0.9878
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.89      0.83      1701
#          1.0       0.79      0.92      0.85       243
#          2.0       0.99      0.84      0.91       243
#          3.0       1.00      0.62      0.76       243
#          4.0       0.47      0.30      0.37       243
#          5.0       0.88      0.73      0.80       243
#          6.0       0.95      1.00      0.98       243
#          7.0       0.75      0.66      0.70       243
#
#     accuracy                           0.81      3402
#    macro avg       0.83      0.75      0.78      3402
# weighted avg       0.81      0.81      0.80      3402
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 45, acceptance: 45, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24519 ms
# ==== Session #1 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.20512820512820512
# FRR: 0.0
# latency: 56498 ms
# ==== Session #2 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25376 ms
# ==== Session #3 ====
# # of detection: 49, acceptance: 49, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30837 ms
# ==== Session #4 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #5 ====
# # of detection: 79, acceptance: 79, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26330 ms
# ==== Session #6 ====
# # of detection: 36, acceptance: 36, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #7 ====
# # of detection: 62, acceptance: 12, rejection: 50
# # of FA: 12
# # of FR: 0
# # of MI: 0
# FAR: 0.1935483870967742
# MIR: 0.0
# FRR: 0.0
# latency: 56001 ms
# ==== Session #8 ====
# # of detection: 34, acceptance: 12, rejection: 22
# # of FA: 12
# # of FR: 0
# # of MI: 0
# FAR: 0.35294117647058826
# MIR: 0.0
# FRR: 0.0
# latency: 41407 ms
# ==== Session #9 ====
# # of detection: 46, acceptance: 46, rejection: 0
# # of FA: 46
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #10 ====
# # of detection: 48, acceptance: 0, rejection: 48
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25847 ms
# ==== Session #11 ====
# # of detection: 42, acceptance: 6, rejection: 36
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.14285714285714285
# MIR: 0.0
# FRR: 0.0
# latency: 29398 ms
# ==== Session #12 ====
# # of detection: 64, acceptance: 0, rejection: 64
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26004 ms
# ==== Session #13 ====
# # of detection: 173, acceptance: 11, rejection: 162
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.06358381502890173
# MIR: 0.0
# FRR: 0.0
# latency: 6660 ms
# simulation result: FAR: 0.10609756097560975
# MIR: 0.00975609756097561
# FNR: 0.0
# latency: 28233.428571428572 ms
# 3 6
# 6 2
# 6 2
# 6 2
# 6 2
# 6 2
# 6 2
# 6 2
# [touch] pos: 112, neg: 111, fr: 20, tr: 70, fi: 11,
# [gait] pos: 112, neg: 112, fr: 31, tr: 95, fi: 13,
# [simple_average] pos: 112, neg: 112, fr: 17, tr: 92, fi: 8,
# [weighted_average_eer] pos: 112, neg: 112, fr: 7, tr: 71, fi: 10,
# [weighted_average_auc] pos: 112, neg: 112, fr: 13, tr: 89, fi: 9,
# [deer_dempster_shafer] pos: 112, neg: 112, fr: 15, tr: 95, fi: 5,
# [auc_dempster_shafer] pos: 112, neg: 112, fr: 16, tr: 102, fi: 5,
# [kalman_filter] pos: 112, neg: 112, fr: 17, tr: 101, fi: 22,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1600_10_7_7
# Negative trainer seed:100
# Game seed:1600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:865881 (0), 540641 (1), 277905 (2), 923862 (3), 745224 (4), 872895 (5), 396697 (6)
# testers:257279, 171538, 693572, 990622, 980953, 998757, 966655
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.81      0.68      0.74        84
#            1       0.55      0.92      0.69        12
#            2       0.56      0.83      0.67        12
#            3       0.61      0.92      0.73        12
#            4       0.40      0.17      0.24        12
#            5       0.73      0.92      0.81        12
#            6       0.56      0.75      0.64        12
#            7       0.83      0.42      0.56        12
#
#     accuracy                           0.69       168
#    macro avg       0.63      0.70      0.63       168
# weighted avg       0.71      0.69      0.68       168
#
# Epoch 1/25
# 20/20 [==============================] - 3s 21ms/step - loss: 2.3762 - categorical_accuracy: 0.3837
# Epoch 2/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4012 - categorical_accuracy: 0.5484
# Epoch 3/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2575 - categorical_accuracy: 0.5627
# Epoch 4/25
# 20/20 [==============================] - 0s 17ms/step - loss: 1.1456 - categorical_accuracy: 0.5996
# Epoch 5/25
# 20/20 [==============================] - 0s 15ms/step - loss: 1.0242 - categorical_accuracy: 0.6464
# Epoch 6/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9486 - categorical_accuracy: 0.6774
# Epoch 7/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8418 - categorical_accuracy: 0.7071
# Epoch 8/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.7837 - categorical_accuracy: 0.7262
# Epoch 9/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8777 - categorical_accuracy: 0.6905
# Epoch 10/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6862 - categorical_accuracy: 0.7651
# Epoch 11/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6076 - categorical_accuracy: 0.7877
# Epoch 12/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5610 - categorical_accuracy: 0.7929
# Epoch 13/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4626 - categorical_accuracy: 0.8298
# Epoch 14/25
# 20/20 [==============================] - 0s 17ms/step - loss: 0.4167 - categorical_accuracy: 0.8524
# Epoch 15/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3790 - categorical_accuracy: 0.8651
# Epoch 16/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4181 - categorical_accuracy: 0.8456
# Epoch 17/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4061 - categorical_accuracy: 0.8536
# Epoch 18/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3297 - categorical_accuracy: 0.8821
# Epoch 19/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2840 - categorical_accuracy: 0.8952
# Epoch 20/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2633 - categorical_accuracy: 0.9091
# Epoch 21/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2219 - categorical_accuracy: 0.9270
# Epoch 22/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1900 - categorical_accuracy: 0.9361
# Epoch 23/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1697 - categorical_accuracy: 0.9472
# Epoch 24/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1484 - categorical_accuracy: 0.9524
# Epoch 25/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.1499 - categorical_accuracy: 0.9607
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.57      0.67       133
#          1.0       0.56      0.53      0.54        19
#          2.0       0.76      0.68      0.72        19
#          3.0       0.62      0.79      0.70        19
#          4.0       0.38      0.79      0.52        19
#          5.0       0.80      0.84      0.82        19
#          6.0       0.38      0.79      0.51        19
#          7.0       0.73      0.58      0.65        19
#
#     accuracy                           0.64       266
#    macro avg       0.63      0.70      0.64       266
# weighted avg       0.71      0.64      0.65       266
#
# training done
# too short, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 49, acceptance: 22, rejection: 27
# # of FA: 0
# # of FR: 27
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.5510204081632653
# latency: 25889 ms
# ==== Session #1 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 41407 ms
# ==== Session #2 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 47747 ms
# ==== Session #3 ====
# # of detection: 58, acceptance: 58, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15949 ms
# ==== Session #4 ====
# # of detection: 79, acceptance: 61, rejection: 18
# # of FA: 0
# # of FR: 18
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.22784810126582278
# latency: 26330 ms
# ==== Session #5 ====
# # of detection: 38, acceptance: 31, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.18421052631578946
# latency: 25638 ms
# ==== Session #6 ====
# # of detection: 32, acceptance: 32, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25962 ms
# ==== Session #7 ====
# # of detection: 48, acceptance: 5, rejection: 43
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.10416666666666667
# MIR: 0.0
# FRR: 0.0
# latency: 41384 ms
# ==== Session #8 ====
# # of detection: 66, acceptance: 5, rejection: 61
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.07575757575757576
# MIR: 0.0
# FRR: 0.0
# latency: 40301 ms
# ==== Session #9 ====
# # of detection: 45, acceptance: 38, rejection: 7
# # of FA: 38
# # of FR: 0
# # of MI: 0
# FAR: 0.8444444444444444
# MIR: 0.0
# FRR: 0.0
# latency: 40068 ms
# ==== Session #10 ====
# # of detection: 60, acceptance: 0, rejection: 60
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 36389 ms
# ==== Session #11 ====
# # of detection: 8, acceptance: 0, rejection: 8
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 30816 ms
# ==== Session #12 ====
# # of detection: 35, acceptance: 0, rejection: 35
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25765 ms
# ==== Session #13 ====
# # of detection: 80, acceptance: 0, rejection: 80
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26005 ms
# simulation result: FAR: 0.07350689127105667
# MIR: 0.0
# FNR: 0.07963246554364471
# latency: 32117.85714285714 ms
# 2 5
# 5 4
# 5 3
# 5 3
# 6 7
# [touch] pos: 119, neg: 118, fr: 21, tr: 75, fi: 12,
# [gait] pos: 119, neg: 119, fr: 34, tr: 100, fi: 14,
# [simple_average] pos: 119, neg: 119, fr: 20, tr: 98, fi: 8,
# [weighted_average_eer] pos: 119, neg: 119, fr: 8, tr: 76, fi: 10,
# [weighted_average_auc] pos: 119, neg: 119, fr: 16, tr: 95, fi: 9,
# [deer_dempster_shafer] pos: 119, neg: 119, fr: 17, tr: 102, fi: 6,
# [auc_dempster_shafer] pos: 119, neg: 119, fr: 19, tr: 109, fi: 5,
# [kalman_filter] pos: 119, neg: 119, fr: 20, tr: 108, fi: 24,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1700_10_7_7
# Negative trainer seed:100
# Game seed:1700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:745224 (0), 796581 (1), 366286 (2), 556357 (3), 693572 (4), 201848 (5), 396697 (6)
# testers:698266, 962159, 863985, 100669, 621276, 799296, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80        84
#            1       0.73      0.92      0.81        12
#            2       0.63      1.00      0.77        12
#            3       0.69      0.75      0.72        12
#            4       0.77      0.83      0.80        12
#            5       0.89      0.67      0.76        12
#            6       0.27      0.33      0.30        12
#            7       1.00      0.92      0.96        12
#
#     accuracy                           0.76       168
#    macro avg       0.73      0.77      0.74       168
# weighted avg       0.79      0.76      0.77       168
#
# Epoch 1/25
# 234/234 [==============================] - 7s 16ms/step - loss: 0.9186 - categorical_accuracy: 0.6991
# Epoch 2/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.3947 - categorical_accuracy: 0.8653
# Epoch 3/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.2435 - categorical_accuracy: 0.9195
# Epoch 4/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.2000 - categorical_accuracy: 0.9325
# Epoch 5/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.1735 - categorical_accuracy: 0.9404
# Epoch 6/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.1381 - categorical_accuracy: 0.9524
# Epoch 7/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.1142 - categorical_accuracy: 0.9614
# Epoch 8/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0974 - categorical_accuracy: 0.9670
# Epoch 9/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0831 - categorical_accuracy: 0.9717
# Epoch 10/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0651 - categorical_accuracy: 0.9782
# Epoch 11/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0714 - categorical_accuracy: 0.9751
# Epoch 12/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0525 - categorical_accuracy: 0.9820
# Epoch 13/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0502 - categorical_accuracy: 0.9830
# Epoch 14/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0536 - categorical_accuracy: 0.9817
# Epoch 15/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0336 - categorical_accuracy: 0.9898
# Epoch 16/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0331 - categorical_accuracy: 0.9890
# Epoch 17/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0262 - categorical_accuracy: 0.9914
# Epoch 18/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0516 - categorical_accuracy: 0.9828
# Epoch 19/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0342 - categorical_accuracy: 0.9882
# Epoch 20/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0240 - categorical_accuracy: 0.9918
# Epoch 21/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0239 - categorical_accuracy: 0.9921
# Epoch 22/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0282 - categorical_accuracy: 0.9908
# Epoch 23/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0204 - categorical_accuracy: 0.9935
# Epoch 24/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0217 - categorical_accuracy: 0.9925
# Epoch 25/25
# 234/234 [==============================] - 4s 16ms/step - loss: 0.0172 - categorical_accuracy: 0.9944
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.47      0.62      1652
#          1.0       0.98      1.00      0.99       236
#          2.0       0.66      0.95      0.78       236
#          3.0       1.00      0.81      0.90       236
#          4.0       0.60      0.99      0.75       236
#          5.0       0.64      0.93      0.76       236
#          6.0       0.50      1.00      0.67       236
#          7.0       0.42      0.86      0.57       236
#
#     accuracy                           0.70      3304
#    macro avg       0.71      0.88      0.75      3304
# weighted avg       0.80      0.70      0.70      3304
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 80, acceptance: 80, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 24774 ms
# ==== Session #1 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #2 ====
# # of detection: 48, acceptance: 48, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 13980 ms
# ==== Session #3 ====
# # of detection: 38, acceptance: 38, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25734 ms
# ==== Session #4 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 29738 ms
# ==== Session #5 ====
# ...
# [simple_average] pos: 336, neg: 336, fr: 72, tr: 270, fi: 35,
# [weighted_average_eer] pos: 336, neg: 336, fr: 39, tr: 216, fi: 41,
# [weighted_average_auc] pos: 336, neg: 336, fr: 60, tr: 260, fi: 37,
# [deer_dempster_shafer] pos: 336, neg: 336, fr: 58, tr: 297, fi: 29,
# [auc_dempster_shafer] pos: 336, neg: 336, fr: 65, tr: 308, fi: 26,
# [kalman_filter] pos: 336, neg: 336, fr: 56, tr: 303, fi: 96,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4800_10_7_7
# Negative trainer seed:100
# Game seed:4800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:808022 (0), 588087 (1), 561993 (2), 720193 (3), 336172 (4), 796581 (5), 777078 (6)
# testers:763813, 856302, 277905, 785899, 553321, 539502, 693572
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.90      0.59      0.71        63
#            1       0.80      0.89      0.84         9
#            2       0.54      0.78      0.64         9
#            3       1.00      1.00      1.00         9
#            4       0.50      0.78      0.61         9
#            5       0.41      0.78      0.54         9
#            6       0.82      1.00      0.90         9
#            7       0.73      0.89      0.80         9
#
#     accuracy                           0.73       126
#    macro avg       0.71      0.84      0.75       126
# weighted avg       0.79      0.73      0.74       126
#
# Epoch 1/25
# 221/221 [==============================] - 6s 16ms/step - loss: 1.2249 - categorical_accuracy: 0.5855
# Epoch 2/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.7479 - categorical_accuracy: 0.7398
# Epoch 3/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.5515 - categorical_accuracy: 0.8079
# Epoch 4/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.4527 - categorical_accuracy: 0.8383
# Epoch 5/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.3765 - categorical_accuracy: 0.8660
# Epoch 6/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.3183 - categorical_accuracy: 0.8846
# Epoch 7/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.2758 - categorical_accuracy: 0.8995
# Epoch 8/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.2399 - categorical_accuracy: 0.9139
# Epoch 9/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.2079 - categorical_accuracy: 0.9243
# Epoch 10/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1718 - categorical_accuracy: 0.9372
# Epoch 11/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1589 - categorical_accuracy: 0.9414
# Epoch 12/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1319 - categorical_accuracy: 0.9519
# Epoch 13/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1108 - categorical_accuracy: 0.9602
# Epoch 14/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1118 - categorical_accuracy: 0.9583
# Epoch 15/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.1031 - categorical_accuracy: 0.9630
# Epoch 16/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0844 - categorical_accuracy: 0.9710
# Epoch 17/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0727 - categorical_accuracy: 0.9743
# Epoch 18/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0630 - categorical_accuracy: 0.9780
# Epoch 19/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0774 - categorical_accuracy: 0.9724
# Epoch 20/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0823 - categorical_accuracy: 0.9712
# Epoch 21/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0456 - categorical_accuracy: 0.9844
# Epoch 22/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0497 - categorical_accuracy: 0.9823
# Epoch 23/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0430 - categorical_accuracy: 0.9854
# Epoch 24/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0778 - categorical_accuracy: 0.9731
# Epoch 25/25
# 221/221 [==============================] - 4s 16ms/step - loss: 0.0634 - categorical_accuracy: 0.9767
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.68      0.74      1568
#          1.0       0.76      0.71      0.73       224
#          2.0       0.28      0.41      0.33       224
#          3.0       0.64      0.88      0.74       224
#          4.0       0.67      0.82      0.74       224
#          5.0       0.72      0.83      0.77       224
#          6.0       0.73      0.98      0.84       224
#          7.0       0.86      0.65      0.74       224
#
#     accuracy                           0.71      3136
#    macro avg       0.69      0.74      0.70      3136
# weighted avg       0.74      0.71      0.72      3136
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 35, acceptance: 29, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.17142857142857143
# latency: 44501 ms
# ==== Session #1 ====
# # of detection: 30, acceptance: 26, rejection: 4
# # of FA: 0
# # of FR: 4
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.13333333333333333
# latency: 46234 ms
# ==== Session #2 ====
# # of detection: 39, acceptance: 39, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25689 ms
# ==== Session #3 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 20725 ms
# ==== Session #4 ====
# # of detection: 100, acceptance: 100, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# ==== Session #5 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #6 ====
# # of detection: 44, acceptance: 44, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26443 ms
# ==== Session #7 ====
# # of detection: 36, acceptance: 0, rejection: 36
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25667 ms
# ==== Session #8 ====
# # of detection: 73, acceptance: 0, rejection: 73
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 25751 ms
# ==== Session #9 ====
# # of detection: 20, acceptance: 4, rejection: 16
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.2
# MIR: 0.0
# FRR: 0.0
# latency: 46818 ms
# ==== Session #10 ====
# # of detection: 41, acceptance: 29, rejection: 12
# # of FA: 29
# # of FR: 0
# # of MI: 0
# FAR: 0.7073170731707317
# MIR: 0.0
# FRR: 0.0
# latency: 98649 ms
# ==== Session #11 ====
# # of detection: 3, acceptance: 3, rejection: 0
# # of FA: 3
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# ==== Session #12 ====
# # of detection: 40, acceptance: 21, rejection: 19
# # of FA: 21
# # of FR: 0
# # of MI: 0
# FAR: 0.525
# MIR: 0.0
# FRR: 0.0
# latency: 72812 ms
# ==== Session #13 ====
# # of detection: 46, acceptance: 46, rejection: 0
# # of FA: 46
# # of FR: 0
# # of MI: 0
# FAR: 1.0
# MIR: 0.0
# FRR: 0.0
# latency: -1 ms
# simulation result: FAR: 0.1734006734006734
# MIR: 0.0
# FNR: 0.016835016835016835
# latency: 33765.357142857145 ms
# 4 5
# 6 5
# 1 2
# 1 3
# [touch] pos: 343, neg: 341, fr: 69, tr: 227, fi: 33,
# [gait] pos: 343, neg: 342, fr: 99, tr: 275, fi: 36,
# [simple_average] pos: 343, neg: 343, fr: 74, tr: 274, fi: 35,
# [weighted_average_eer] pos: 343, neg: 343, fr: 40, tr: 220, fi: 41,
# [weighted_average_auc] pos: 343, neg: 343, fr: 62, tr: 264, fi: 37,
# [deer_dempster_shafer] pos: 343, neg: 343, fr: 60, tr: 302, fi: 29,
# [auc_dempster_shafer] pos: 343, neg: 343, fr: 67, tr: 315, fi: 26,
# [kalman_filter] pos: 343, neg: 343, fr: 57, tr: 307, fi: 98,
#
# file saved.
# ========== SETUP ===========
# Game name:100_4900_10_7_7
# Negative trainer seed:100
# Game seed:4900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:897652 (0), 277905 (1), 751131 (2), 621276 (3), 218719 (4), 657486 (5), 796581 (6)
# testers:396697, 556357, 220962, 841866, 257279, 710707, 336172
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.86      0.66      0.75       112
#            1       0.61      0.69      0.65        16
#            2       1.00      1.00      1.00        16
#            3       0.82      0.88      0.85        16
#            4       0.47      0.88      0.61        16
#            5       0.39      0.56      0.46        16
#            6       1.00      0.94      0.97        16
#            7       0.68      0.81      0.74        16
#
#     accuracy                           0.74       224
#    macro avg       0.73      0.80      0.75       224
# weighted avg       0.79      0.74      0.75       224
#
# Epoch 1/25
# 20/20 [==============================] - 4s 18ms/step - loss: 2.0677 - categorical_accuracy: 0.4302
# Epoch 2/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.4498 - categorical_accuracy: 0.5052
# Epoch 3/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.2959 - categorical_accuracy: 0.5615
# Epoch 4/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.1733 - categorical_accuracy: 0.5996
# Epoch 5/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0900 - categorical_accuracy: 0.6083
# Epoch 6/25
# 20/20 [==============================] - 0s 16ms/step - loss: 1.0139 - categorical_accuracy: 0.6377
# Epoch 7/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9539 - categorical_accuracy: 0.6480
# Epoch 8/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.9023 - categorical_accuracy: 0.6754
# Epoch 9/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.8168 - categorical_accuracy: 0.7004
# Epoch 10/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.7778 - categorical_accuracy: 0.7163
# Epoch 11/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.7457 - categorical_accuracy: 0.7238
# Epoch 12/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6965 - categorical_accuracy: 0.7500
# Epoch 13/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6314 - categorical_accuracy: 0.7726
# Epoch 14/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6016 - categorical_accuracy: 0.7929
# Epoch 15/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.5554 - categorical_accuracy: 0.8000
# Epoch 16/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6657 - categorical_accuracy: 0.7492
# Epoch 17/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.6099 - categorical_accuracy: 0.7770
# Epoch 18/25
# 20/20 [==============================] - 0s 17ms/step - loss: 0.5333 - categorical_accuracy: 0.8127
# Epoch 19/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4592 - categorical_accuracy: 0.8528
# Epoch 20/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.4063 - categorical_accuracy: 0.8655
# Epoch 21/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3832 - categorical_accuracy: 0.8690
# Epoch 22/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3896 - categorical_accuracy: 0.8571
# Epoch 23/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.3432 - categorical_accuracy: 0.8794
# Epoch 24/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2925 - categorical_accuracy: 0.9004
# Epoch 25/25
# 20/20 [==============================] - 0s 16ms/step - loss: 0.2301 - categorical_accuracy: 0.9294
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.77      0.75       133
#          1.0       0.75      0.32      0.44        19
#          2.0       0.64      0.95      0.77        19
#          3.0       0.65      0.58      0.61        19
#          4.0       0.55      0.32      0.40        19
#          5.0       1.00      0.47      0.64        19
#          6.0       0.30      0.47      0.37        19
#          7.0       0.86      0.95      0.90        19
#
#     accuracy                           0.68       266
#    macro avg       0.68      0.60      0.61       266
# weighted avg       0.70      0.68      0.67       266
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 39, acceptance: 33, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.15384615384615385
# latency: 46960 ms
# ==== Session #1 ====
# # of detection: 21, acceptance: 21, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 47747 ms
# ==== Session #2 ====
# # of detection: 66, acceptance: 60, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.09090909090909091
# latency: 36281 ms
# ==== Session #3 ====
# # of detection: 28, acceptance: 2, rejection: 26
# # of FA: 0
# # of FR: 26
# # of MI: 2
# FAR: 0.0
# MIR: 0.07142857142857142
# FRR: 0.9285714285714286
# latency: -1 ms
# ==== Session #4 ====
# # of detection: 66, acceptance: 0, rejection: 66
# # of FA: 0
# # of FR: 66
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 1.0
# latency: -1 ms
# ==== Session #5 ====
# # of detection: 23, acceptance: 7, rejection: 16
# # of FA: 0
# # of FR: 16
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.6956521739130435
# latency: 25934 ms
# ==== Session #6 ====
# # of detection: 34, acceptance: 34, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 23887 ms
# ==== Session #7 ====
# # of detection: 30, acceptance: 26, rejection: 4
# # of FA: 26
# # of FR: 0
# # of MI: 0
# FAR: 0.8666666666666667
# MIR: 0.0
# FRR: 0.0
# latency: 36287 ms
# ==== Session #8 ====
# # of detection: 38, acceptance: 34, rejection: 4
# # of FA: 34
# # of FR: 0
# # of MI: 0
# FAR: 0.8947368421052632
# MIR: 0.0
# FRR: 0.0
# latency: 170367 ms
# ==== Session #9 ====
# # of detection: 32, acceptance: 0, rejection: 32
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 26038 ms
# ==== Session #10 ====
# # of detection: 68, acceptance: 57, rejection: 11
# # of FA: 57
# # of FR: 0
# # of MI: 0
# FAR: 0.8382352941176471
# MIR: 0.0
# FRR: 0.0
# latency: 49626 ms
# ==== Session #11 ====
# # of detection: 42, acceptance: 25, rejection: 17
# # of FA: 25
# # of FR: 0
# # of MI: 0
# FAR: 0.5952380952380952
# MIR: 0.0
# FRR: 0.0
# latency: 63191 ms
# ==== Session #12 ====
# # of detection: 53, acceptance: 0, rejection: 53
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 21794 ms
# ==== Session #13 ====
# # of detection: 100, acceptance: 0, rejection: 100
# # of FA: 0
# # of FR: 0
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.0
# latency: 15541 ms
# simulation result: FAR: 0.221875
# MIR: 0.003125
# FNR: 0.1875
# latency: 40260.78571428572 ms
# 7 6
# 7 6
# 7 6
# 7 2
# 7 2
# 2 3
# 3 4
# 3 5
# [touch] pos: 350, neg: 348, fr: 71, tr: 229, fi: 33,
# [gait] pos: 350, neg: 349, fr: 102, tr: 282, fi: 36,
# [simple_average] pos: 350, neg: 350, fr: 78, tr: 279, fi: 36,
# [weighted_average_eer] pos: 350, neg: 350, fr: 43, tr: 224, fi: 42,
# [weighted_average_auc] pos: 350, neg: 350, fr: 65, tr: 269, fi: 38,
# [deer_dempster_shafer] pos: 350, neg: 350, fr: 64, tr: 308, fi: 30,
# [auc_dempster_shafer] pos: 350, neg: 350, fr: 72, tr: 321, fi: 27,
# [kalman_filter] pos: 350, neg: 350, fr: 57, tr: 310, fi: 101,
#
# file saved.

# %% [markdown]
# # Experiment 2: User Switch
#
# ## Menu
#
# - 2.1 Basic setting: 2 + 2 for training (```userswitch_3_2```)

# %%
def run_topic_user_switch_experiment_limit(game_seed=0, n_balanced=3,
                                           n_train_session=2, limit=180000):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================

    num_testers = 0
    num_valid_users = n_balanced

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                          str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    for user in valid_users:
        gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

        touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

        enrollment_script_type_1.append((user, 'gait', gait_sessions))
        enrollment_script_type_1.append((user, 'touch', touch_sessions))

    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================

    for m in range(len(valid_users)):
        i = 1
        user_a = valid_users[m]
        for n in range(m + 1, len(valid_users)):
            user_b = valid_users[n]
            if user_a == user_b:
                continue
            sel_session = hmog.get_sessions_for_unloaded_user(
                user_a,[hmog.ACTIVITY_READING_WALKING])[-i]
            events = get_events_for_user_session_with_limit(user_a, sel_session, tml.end_time, limit)
            tml.add_special_event(EVENT_SESSION_START, [])
            tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

            sel_session = hmog.get_sessions_for_unloaded_user(
                user_b,[hmog.ACTIVITY_READING_WALKING])[-i]
            events = get_events_for_user_session_with_limit(user_b, sel_session, tml.end_time, limit)
            tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
            tml.add_special_event(EVENT_SESSION_END, [])
            i = i + 1


    # ===============================================
    # 5. One line running script
    # ===============================================

    results = script_runner(tml, player)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    return tml, player

# %%
#@title Experiment 2.1: 2 + 2 training sessions

experiment_result = None

for seed in range(0, 15000, 100):
    tml, player = run_topic_user_switch_experiment_limit(seed, 3, 2, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022_3/user_switch_3_2_limit", str(seed)))
# Out:
# Streaming output truncated to the last 5000 lines.
# # of MI: 9
# FAR: 0.0
# MIR: 0.0891089108910891
# FRR: 0.0
# latency: 29725 ms
# simulation result: FAR: 0.0
# MIR: 0.08146067415730338
# FNR: 0.0
# latency: 22362.666666666668 ms
# [touch] case: 6, er: 2, em: 0, fr: 1, mi: 0,
# [gait] case: 6, er: 0, em: 0, fr: 2, mi: 1,
# [simple_average] case: 6, er: 0, em: 0, fr: 2, mi: 3,
# [weighted_average_eer] case: 6, er: 0, em: 0, fr: 1, mi: 4,
# [weighted_average_auc] case: 6, er: 0, em: 0, fr: 1, mi: 4,
# [deer_dempster_shafer] case: 6, er: 0, em: 0, fr: 0, mi: 5,
# [auc_dempster_shafer] case: 6, er: 1, em: 0, fr: 0, mi: 5,
# [kalman_filter] case: 6, er: 0, em: 2, fr: 0, mi: 3,
#
# file saved.
# ========== SETUP ===========
# Game name:100_200_10_0_3
# Negative trainer seed:100
# Game seed:200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:923862 (0), 538363 (1), 808022 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.90      0.65      0.75        54
#            1       0.58      0.78      0.67        18
#            2       0.47      0.78      0.58        18
#            3       0.87      0.72      0.79        18
#
#     accuracy                           0.70       108
#    macro avg       0.70      0.73      0.70       108
# weighted avg       0.77      0.70      0.72       108
#
# Epoch 1/25
# 81/81 [==============================] - 4s 16ms/step - loss: 1.2801 - categorical_accuracy: 0.4978
# Epoch 2/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.9229 - categorical_accuracy: 0.5840
# Epoch 3/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.8340 - categorical_accuracy: 0.6345
# Epoch 4/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.8604 - categorical_accuracy: 0.6172
# Epoch 5/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.7642 - categorical_accuracy: 0.6620
# Epoch 6/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.6794 - categorical_accuracy: 0.7066
# Epoch 7/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.5750 - categorical_accuracy: 0.7583
# Epoch 8/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.4733 - categorical_accuracy: 0.8099
# Epoch 9/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.4308 - categorical_accuracy: 0.8238
# Epoch 10/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.3298 - categorical_accuracy: 0.8700
# Epoch 11/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.3051 - categorical_accuracy: 0.8795
# Epoch 12/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.2794 - categorical_accuracy: 0.8873
# Epoch 13/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.2525 - categorical_accuracy: 0.9017
# Epoch 14/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.2139 - categorical_accuracy: 0.9158
# Epoch 15/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1932 - categorical_accuracy: 0.9248
# Epoch 16/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1694 - categorical_accuracy: 0.9342
# Epoch 17/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1662 - categorical_accuracy: 0.9362
# Epoch 18/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1484 - categorical_accuracy: 0.9441
# Epoch 19/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1207 - categorical_accuracy: 0.9549
# Epoch 20/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1014 - categorical_accuracy: 0.9621
# Epoch 21/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0922 - categorical_accuracy: 0.9650
# Epoch 22/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0809 - categorical_accuracy: 0.9726
# Epoch 23/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0866 - categorical_accuracy: 0.9694
# Epoch 24/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.0742 - categorical_accuracy: 0.9727
# Epoch 25/25
# 81/81 [==============================] - 1s 16ms/step - loss: 0.1035 - categorical_accuracy: 0.9601
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.70      0.78       570
#          1.0       0.51      0.91      0.66       190
#          2.0       0.84      0.86      0.85       190
#          3.0       0.98      0.82      0.89       190
#
#     accuracy                           0.78      1140
#    macro avg       0.81      0.82      0.80      1140
# weighted avg       0.83      0.78      0.79      1140
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 114, acceptance: 114, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.07894736842105263
# FRR: 0.0
# latency: 15949 ms
# ==== Session #1 ====
# # of detection: 100, acceptance: 100, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 6
# FAR: 0.0
# MIR: 0.06
# FRR: 0.0
# latency: 25737 ms
# ==== Session #2 ====
# # of detection: 93, acceptance: 84, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 8
# FAR: 0.0
# MIR: 0.08602150537634409
# FRR: 0.0967741935483871
# latency: 25668 ms
# simulation result: FAR: 0.0
# MIR: 0.0749185667752443
# FNR: 0.029315960912052116
# latency: 22451.333333333332 ms
# [touch] case: 9, er: 3, em: 0, fr: 2, mi: 0,
# [gait] case: 9, er: 0, em: 0, fr: 2, mi: 1,
# [simple_average] case: 9, er: 0, em: 0, fr: 2, mi: 4,
# [weighted_average_eer] case: 9, er: 0, em: 0, fr: 1, mi: 5,
# [weighted_average_auc] case: 9, er: 0, em: 0, fr: 1, mi: 5,
# [deer_dempster_shafer] case: 9, er: 0, em: 0, fr: 0, mi: 6,
# [auc_dempster_shafer] case: 9, er: 1, em: 0, fr: 0, mi: 6,
# [kalman_filter] case: 9, er: 0, em: 2, fr: 0, mi: 4,
#
# file saved.
# ========== SETUP ===========
# Game name:100_300_10_0_3
# Negative trainer seed:100
# Game seed:300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:966655 (0), 368258 (1), 336172 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.84      0.77      0.80        48
#            1       0.75      0.75      0.75        16
#            2       0.94      0.94      0.94        16
#            3       0.55      0.69      0.61        16
#
#     accuracy                           0.78        96
#    macro avg       0.77      0.79      0.78        96
# weighted avg       0.79      0.78      0.79        96
#
# Epoch 1/25
# 49/49 [==============================] - 4s 17ms/step - loss: 1.1626 - categorical_accuracy: 0.5825
# Epoch 2/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.6482 - categorical_accuracy: 0.7387
# Epoch 3/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.5636 - categorical_accuracy: 0.7726
# Epoch 4/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.5025 - categorical_accuracy: 0.8042
# Epoch 5/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.4123 - categorical_accuracy: 0.8411
# Epoch 6/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3767 - categorical_accuracy: 0.8557
# Epoch 7/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.3055 - categorical_accuracy: 0.8915
# Epoch 8/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2801 - categorical_accuracy: 0.9018
# Epoch 9/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2953 - categorical_accuracy: 0.8939
# Epoch 10/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2913 - categorical_accuracy: 0.8894
# Epoch 11/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2452 - categorical_accuracy: 0.9091
# Epoch 12/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.2093 - categorical_accuracy: 0.9278
# Epoch 13/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1906 - categorical_accuracy: 0.9307
# Epoch 14/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1581 - categorical_accuracy: 0.9465
# Epoch 15/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1617 - categorical_accuracy: 0.9400
# Epoch 16/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1373 - categorical_accuracy: 0.9512
# Epoch 17/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1492 - categorical_accuracy: 0.9465
# Epoch 18/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1879 - categorical_accuracy: 0.9341
# Epoch 19/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1090 - categorical_accuracy: 0.9634
# Epoch 20/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.1103 - categorical_accuracy: 0.9626
# Epoch 21/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0874 - categorical_accuracy: 0.9718
# Epoch 22/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0740 - categorical_accuracy: 0.9774
# Epoch 23/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0824 - categorical_accuracy: 0.9700
# Epoch 24/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0766 - categorical_accuracy: 0.9716
# Epoch 25/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.0613 - categorical_accuracy: 0.9800
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.32      0.49       342
#          1.0       1.00      0.98      0.99       114
#          2.0       0.36      0.99      0.53       114
#          3.0       0.74      0.93      0.82       114
#
#     accuracy                           0.65       684
#    macro avg       0.77      0.81      0.71       684
# weighted avg       0.83      0.65      0.63       684
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 118, acceptance: 118, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 10
# FAR: 0.0
# MIR: 0.0847457627118644
# FRR: 0.0
# latency: 26005 ms
# ==== Session #1 ====
# # of detection: 158, acceptance: 158, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 12
# FAR: 0.0
# MIR: 0.0759493670886076
# FRR: 0.0
# latency: 26339 ms
# ==== Session #2 ====
# # of detection: 139, acceptance: 139, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 6
# FAR: 0.0
# MIR: 0.04316546762589928
# FRR: 0.0
# latency: 25924 ms
# simulation result: FAR: 0.0
# MIR: 0.06746987951807229
# FNR: 0.0
# latency: 26089.333333333332 ms
# [touch] case: 12, er: 3, em: 0, fr: 4, mi: 0,
# [gait] case: 12, er: 0, em: 0, fr: 3, mi: 1,
# [simple_average] case: 12, er: 0, em: 0, fr: 2, mi: 6,
# [weighted_average_eer] case: 12, er: 0, em: 0, fr: 1, mi: 7,
# [weighted_average_auc] case: 12, er: 0, em: 0, fr: 1, mi: 7,
# [deer_dempster_shafer] case: 12, er: 0, em: 0, fr: 0, mi: 8,
# [auc_dempster_shafer] case: 12, er: 1, em: 0, fr: 0, mi: 8,
# [kalman_filter] case: 12, er: 1, em: 2, fr: 0, mi: 6,
#
# file saved.
# ========== SETUP ===========
# Game name:100_400_10_0_3
# Negative trainer seed:100
# Game seed:400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:720193 (0), 966655 (1), 554303 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.76      0.74      0.75        69
#            1       0.50      0.35      0.41        23
#            2       0.83      0.83      0.83        23
#            3       0.56      0.78      0.65        23
#
#     accuracy                           0.70       138
#    macro avg       0.66      0.67      0.66       138
# weighted avg       0.70      0.70      0.69       138
#
# Epoch 1/25
# 79/79 [==============================] - 4s 17ms/step - loss: 0.8844 - categorical_accuracy: 0.6730
# Epoch 2/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.5045 - categorical_accuracy: 0.8029
# Epoch 3/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.3837 - categorical_accuracy: 0.8552
# Epoch 4/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2821 - categorical_accuracy: 0.8978
# Epoch 5/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2631 - categorical_accuracy: 0.9035
# Epoch 6/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1810 - categorical_accuracy: 0.9367
# Epoch 7/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1610 - categorical_accuracy: 0.9438
# Epoch 8/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1420 - categorical_accuracy: 0.9505
# Epoch 9/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1337 - categorical_accuracy: 0.9540
# Epoch 10/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1265 - categorical_accuracy: 0.9570
# Epoch 11/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1140 - categorical_accuracy: 0.9588
# Epoch 12/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1159 - categorical_accuracy: 0.9587
# Epoch 13/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0838 - categorical_accuracy: 0.9684
# Epoch 14/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0948 - categorical_accuracy: 0.9660
# Epoch 15/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0578 - categorical_accuracy: 0.9813
# Epoch 16/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0577 - categorical_accuracy: 0.9790
# Epoch 17/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0530 - categorical_accuracy: 0.9823
# Epoch 18/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0620 - categorical_accuracy: 0.9793
# Epoch 19/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0550 - categorical_accuracy: 0.9802
# Epoch 20/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0456 - categorical_accuracy: 0.9852
# Epoch 21/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0334 - categorical_accuracy: 0.9898
# Epoch 22/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0344 - categorical_accuracy: 0.9892
# Epoch 23/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0365 - categorical_accuracy: 0.9879
# Epoch 24/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0393 - categorical_accuracy: 0.9864
# Epoch 25/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0267 - categorical_accuracy: 0.9925
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.94       558
#          1.0       0.98      0.63      0.77       186
#          2.0       0.80      0.98      0.88       186
#          3.0       0.88      0.98      0.93       186
#
#     accuracy                           0.91      1116
#    macro avg       0.90      0.88      0.88      1116
# weighted avg       0.91      0.91      0.90      1116
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 140, acceptance: 140, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.05714285714285714
# FRR: 0.0
# latency: 20725 ms
# ==== Session #1 ====
# # of detection: 113, acceptance: 113, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 5
# FAR: 0.0
# MIR: 0.04424778761061947
# FRR: 0.0
# latency: 24651 ms
# ==== Session #2 ====
# # of detection: 151, acceptance: 146, rejection: 5
# # of FA: 0
# # of FR: 5
# # of MI: 10
# FAR: 0.0
# MIR: 0.06622516556291391
# FRR: 0.033112582781456956
# latency: 26005 ms
# simulation result: FAR: 0.0
# MIR: 0.05693069306930693
# FNR: 0.012376237623762377
# latency: 23793.666666666668 ms
# [touch] case: 15, er: 5, em: 0, fr: 4, mi: 0,
# [gait] case: 15, er: 0, em: 0, fr: 4, mi: 1,
# [simple_average] case: 15, er: 0, em: 0, fr: 2, mi: 7,
# [weighted_average_eer] case: 15, er: 0, em: 0, fr: 1, mi: 8,
# [weighted_average_auc] case: 15, er: 0, em: 0, fr: 1, mi: 8,
# [deer_dempster_shafer] case: 15, er: 0, em: 0, fr: 0, mi: 10,
# [auc_dempster_shafer] case: 15, er: 1, em: 0, fr: 0, mi: 10,
# [kalman_filter] case: 15, er: 1, em: 2, fr: 0, mi: 7,
#
# file saved.
# ========== SETUP ===========
# Game name:100_500_10_0_3
# Negative trainer seed:100
# Game seed:500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:737973 (0), 796581 (1), 980953 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        27
#            1       1.00      0.89      0.94         9
#            2       0.78      0.78      0.78         9
#            3       1.00      1.00      1.00         9
#
#     accuracy                           0.91        54
#    macro avg       0.92      0.90      0.91        54
# weighted avg       0.91      0.91      0.91        54
#
# Epoch 1/25
# 58/58 [==============================] - 4s 17ms/step - loss: 1.2066 - categorical_accuracy: 0.5820
# Epoch 2/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6875 - categorical_accuracy: 0.7293
# Epoch 3/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.4429 - categorical_accuracy: 0.8279
# Epoch 4/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.3654 - categorical_accuracy: 0.8608
# Epoch 5/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.2291 - categorical_accuracy: 0.9163
# Epoch 6/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1624 - categorical_accuracy: 0.9450
# Epoch 7/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.2443 - categorical_accuracy: 0.9090
# Epoch 8/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1990 - categorical_accuracy: 0.9283
# Epoch 9/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1567 - categorical_accuracy: 0.9415
# Epoch 10/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1333 - categorical_accuracy: 0.9525
# Epoch 11/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0904 - categorical_accuracy: 0.9697
# Epoch 12/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.1475 - categorical_accuracy: 0.9471
# Epoch 13/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0750 - categorical_accuracy: 0.9748
# Epoch 14/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0550 - categorical_accuracy: 0.9819
# Epoch 15/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0503 - categorical_accuracy: 0.9830
# Epoch 16/25
# 58/58 [==============================] - 1s 17ms/step - loss: 0.0575 - categorical_accuracy: 0.9807
# Epoch 17/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0446 - categorical_accuracy: 0.9845
# Epoch 18/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0285 - categorical_accuracy: 0.9922
# Epoch 19/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0216 - categorical_accuracy: 0.9948
# Epoch 20/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0194 - categorical_accuracy: 0.9944
# Epoch 21/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0153 - categorical_accuracy: 0.9969
# Epoch 22/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0132 - categorical_accuracy: 0.9965
# Epoch 23/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0097 - categorical_accuracy: 0.9984
# Epoch 24/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0125 - categorical_accuracy: 0.9961
# Epoch 25/25
# 58/58 [==============================] - 1s 16ms/step - loss: 0.0080 - categorical_accuracy: 0.9986
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.48      0.65       408
#          1.0       0.53      1.00      0.69       136
#          2.0       0.76      0.98      0.86       136
#          3.0       0.74      1.00      0.85       136
#
#     accuracy                           0.74       816
#    macro avg       0.75      0.87      0.76       816
# weighted avg       0.83      0.74      0.72       816
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 92, acceptance: 92, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.09782608695652174
# FRR: 0.0
# latency: 20927 ms
# ==== Session #1 ====
# # of detection: 94, acceptance: 50, rejection: 44
# # of FA: 0
# # of FR: 44
# # of MI: 22
# FAR: 0.0
# MIR: 0.23404255319148937
# FRR: 0.46808510638297873
# latency: 247891 ms
# ==== Session #2 ====
# # of detection: 50, acceptance: 50, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 11
# FAR: 0.0
# MIR: 0.22
# FRR: 0.0
# latency: 23887 ms
# simulation result: FAR: 0.0
# MIR: 0.17796610169491525
# FNR: 0.1864406779661017
# latency: 97568.33333333333 ms
# [touch] case: 18, er: 6, em: 0, fr: 4, mi: 0,
# [gait] case: 18, er: 1, em: 0, fr: 4, mi: 1,
# [simple_average] case: 18, er: 1, em: 0, fr: 2, mi: 8,
# [weighted_average_eer] case: 18, er: 1, em: 0, fr: 1, mi: 9,
# [weighted_average_auc] case: 18, er: 1, em: 0, fr: 1, mi: 9,
# [deer_dempster_shafer] case: 18, er: 1, em: 0, fr: 0, mi: 11,
# [auc_dempster_shafer] case: 18, er: 2, em: 0, fr: 0, mi: 11,
# [kalman_filter] case: 18, er: 2, em: 2, fr: 0, mi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_600_10_0_3
# Negative trainer seed:100
# Game seed:600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:803262 (0), 876011 (1), 554303 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.90      0.90      0.90        39
#            1       1.00      0.85      0.92        13
#            2       1.00      1.00      1.00        13
#            3       0.67      0.77      0.71        13
#
#     accuracy                           0.88        78
#    macro avg       0.89      0.88      0.88        78
# weighted avg       0.89      0.88      0.89        78
#
# Epoch 1/25
# 22/22 [==============================] - 4s 18ms/step - loss: 1.6067 - categorical_accuracy: 0.5004
# Epoch 2/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.9218 - categorical_accuracy: 0.6237
# Epoch 3/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.7898 - categorical_accuracy: 0.6918
# Epoch 4/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.7165 - categorical_accuracy: 0.7154
# Epoch 5/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.7056 - categorical_accuracy: 0.7082
# Epoch 6/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6657 - categorical_accuracy: 0.7197
# Epoch 7/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.6193 - categorical_accuracy: 0.7330
# Epoch 8/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.5443 - categorical_accuracy: 0.7703
# Epoch 9/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4969 - categorical_accuracy: 0.7792
# Epoch 10/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4798 - categorical_accuracy: 0.7935
# Epoch 11/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4682 - categorical_accuracy: 0.8000
# Epoch 12/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.4285 - categorical_accuracy: 0.8194
# Epoch 13/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3992 - categorical_accuracy: 0.8391
# Epoch 14/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3813 - categorical_accuracy: 0.8376
# Epoch 15/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3045 - categorical_accuracy: 0.8835
# Epoch 16/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3588 - categorical_accuracy: 0.8423
# Epoch 17/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3607 - categorical_accuracy: 0.8480
# Epoch 18/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.3082 - categorical_accuracy: 0.8713
# Epoch 19/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2612 - categorical_accuracy: 0.8971
# Epoch 20/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2645 - categorical_accuracy: 0.9004
# Epoch 21/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2299 - categorical_accuracy: 0.9125
# Epoch 22/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.1983 - categorical_accuracy: 0.9226
# Epoch 23/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2190 - categorical_accuracy: 0.9176
# Epoch 24/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2062 - categorical_accuracy: 0.9229
# Epoch 25/25
# 22/22 [==============================] - 0s 16ms/step - loss: 0.2189 - categorical_accuracy: 0.9190
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.66      0.76       153
#          1.0       0.07      0.04      0.05        51
#          2.0       0.44      0.75      0.55        51
#          3.0       0.65      1.00      0.79        51
#
#     accuracy                           0.63       306
#    macro avg       0.51      0.61      0.54       306
# weighted avg       0.64      0.63      0.61       306
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 70, acceptance: 63, rejection: 7
# # of FA: 0
# # of FR: 7
# # of MI: 34
# FAR: 0.0
# MIR: 0.4857142857142857
# FRR: 0.1
# latency: 102883 ms
# ==== Session #1 ====
# # of detection: 87, acceptance: 87, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 10
# FAR: 0.0
# MIR: 0.11494252873563218
# FRR: 0.0
# latency: 57458 ms
# ==== Session #2 ====
# # of detection: 85, acceptance: 76, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 23
# FAR: 0.0
# MIR: 0.27058823529411763
# FRR: 0.10588235294117647
# latency: 174906 ms
# simulation result: FAR: 0.0
# MIR: 0.2768595041322314
# FNR: 0.06611570247933884
# latency: 111749.0 ms
# [touch] case: 21, er: 6, em: 2, fr: 4, mi: 0,
# [gait] case: 21, er: 2, em: 1, fr: 4, mi: 1,
# [simple_average] case: 21, er: 2, em: 1, fr: 2, mi: 8,
# [weighted_average_eer] case: 21, er: 2, em: 2, fr: 1, mi: 9,
# [weighted_average_auc] case: 21, er: 2, em: 2, fr: 1, mi: 9,
# [deer_dempster_shafer] case: 21, er: 2, em: 2, fr: 0, mi: 11,
# [auc_dempster_shafer] case: 21, er: 3, em: 2, fr: 0, mi: 11,
# [kalman_filter] case: 21, er: 2, em: 5, fr: 0, mi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_700_10_0_3
# Negative trainer seed:100
# Game seed:700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:937904 (0), 100669 (1), 720193 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.66      0.60      0.63        63
#            1       0.53      0.48      0.50        21
#            2       0.64      0.76      0.70        21
#            3       0.62      0.71      0.67        21
#
#     accuracy                           0.63       126
#    macro avg       0.61      0.64      0.62       126
# weighted avg       0.63      0.63      0.62       126
#
# Epoch 1/25
# 79/79 [==============================] - 4s 16ms/step - loss: 1.2042 - categorical_accuracy: 0.5318
# Epoch 2/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.7212 - categorical_accuracy: 0.6852
# Epoch 3/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.5571 - categorical_accuracy: 0.7673
# Epoch 4/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.4300 - categorical_accuracy: 0.8252
# Epoch 5/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.3828 - categorical_accuracy: 0.8512
# Epoch 6/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.3103 - categorical_accuracy: 0.8821
# Epoch 7/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2798 - categorical_accuracy: 0.8873
# Epoch 8/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2523 - categorical_accuracy: 0.9010
# Epoch 9/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2150 - categorical_accuracy: 0.9170
# Epoch 10/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1885 - categorical_accuracy: 0.9280
# Epoch 11/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1859 - categorical_accuracy: 0.9289
# Epoch 12/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1558 - categorical_accuracy: 0.9419
# Epoch 13/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1311 - categorical_accuracy: 0.9473
# Epoch 14/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1165 - categorical_accuracy: 0.9567
# Epoch 15/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1044 - categorical_accuracy: 0.9611
# Epoch 16/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1382 - categorical_accuracy: 0.9459
# Epoch 17/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0785 - categorical_accuracy: 0.9734
# Epoch 18/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0841 - categorical_accuracy: 0.9694
# Epoch 19/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0630 - categorical_accuracy: 0.9797
# Epoch 20/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0502 - categorical_accuracy: 0.9827
# Epoch 21/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0447 - categorical_accuracy: 0.9853
# Epoch 22/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0448 - categorical_accuracy: 0.9850
# Epoch 23/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0348 - categorical_accuracy: 0.9885
# Epoch 24/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0323 - categorical_accuracy: 0.9908
# Epoch 25/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0356 - categorical_accuracy: 0.9888
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.37      0.49       558
#          1.0       0.44      0.66      0.53       186
#          2.0       0.47      0.97      0.63       186
#          3.0       0.89      0.80      0.84       186
#
#     accuracy                           0.59      1116
#    macro avg       0.63      0.70      0.62      1116
# weighted avg       0.66      0.59      0.58      1116
#
# training done
# there must be something going wrong
# Not found
# ==== Session #0 ====
# # of detection: 114, acceptance: 62, rejection: 52
# # of FA: 0
# # of FR: 52
# # of MI: 2
# FAR: 0.0
# MIR: 0.017543859649122806
# FRR: 0.45614035087719296
# latency: 26007 ms
# ==== Session #1 ====
# # of detection: 128, acceptance: 128, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 30
# FAR: 0.0
# MIR: 0.234375
# FRR: 0.0
# latency: 75090 ms
# ==== Session #2 ====
# # of detection: 126, acceptance: 71, rejection: 55
# # of FA: 0
# # of FR: 55
# # of MI: 2
# FAR: 0.0
# MIR: 0.015873015873015872
# FRR: 0.4365079365079365
# latency: 124054 ms
# simulation result: FAR: 0.0
# MIR: 0.09239130434782608
# FNR: 0.2907608695652174
# latency: 75050.33333333333 ms
# [touch] case: 24, er: 6, em: 2, fr: 5, mi: 0,
# [gait] case: 24, er: 4, em: 2, fr: 4, mi: 1,
# [simple_average] case: 24, er: 3, em: 2, fr: 3, mi: 8,
# [weighted_average_eer] case: 24, er: 3, em: 3, fr: 2, mi: 9,
# [weighted_average_auc] case: 24, er: 3, em: 3, fr: 2, mi: 9,
# [deer_dempster_shafer] case: 24, er: 3, em: 3, fr: 1, mi: 11,
# [auc_dempster_shafer] case: 24, er: 4, em: 3, fr: 1, mi: 11,
# [kalman_filter] case: 24, er: 3, em: 6, fr: 1, mi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_800_10_0_3
# Negative trainer seed:100
# Game seed:800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:733568 (0), 588087 (1), 336172 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.67      0.77        30
#            1       0.91      1.00      0.95        10
#            2       0.77      1.00      0.87        10
#            3       0.50      0.70      0.58        10
#
#     accuracy                           0.78        60
#    macro avg       0.77      0.84      0.79        60
# weighted avg       0.82      0.78      0.79        60
#
# Epoch 1/25
# 97/97 [==============================] - 5s 17ms/step - loss: 1.0040 - categorical_accuracy: 0.6450
# Epoch 2/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.6404 - categorical_accuracy: 0.7445
# Epoch 3/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.5533 - categorical_accuracy: 0.7726
# Epoch 4/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.4633 - categorical_accuracy: 0.8156
# Epoch 5/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.3808 - categorical_accuracy: 0.8481
# Epoch 6/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.3301 - categorical_accuracy: 0.8708
# Epoch 7/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.2935 - categorical_accuracy: 0.8900
# Epoch 8/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.2517 - categorical_accuracy: 0.9051
# Epoch 9/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.2279 - categorical_accuracy: 0.9149
# Epoch 10/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.2061 - categorical_accuracy: 0.9218
# Epoch 11/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.1672 - categorical_accuracy: 0.9361
# Epoch 12/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.1550 - categorical_accuracy: 0.9401
# Epoch 13/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.1366 - categorical_accuracy: 0.9484
# Epoch 14/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.1285 - categorical_accuracy: 0.9539
# Epoch 15/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.1071 - categorical_accuracy: 0.9622
# Epoch 16/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0941 - categorical_accuracy: 0.9663
# Epoch 17/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0854 - categorical_accuracy: 0.9693
# Epoch 18/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0768 - categorical_accuracy: 0.9704
# Epoch 19/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0592 - categorical_accuracy: 0.9807
# Epoch 20/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0492 - categorical_accuracy: 0.9841
# Epoch 21/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0432 - categorical_accuracy: 0.9875
# Epoch 22/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0378 - categorical_accuracy: 0.9895
# Epoch 23/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0391 - categorical_accuracy: 0.9875
# Epoch 24/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0336 - categorical_accuracy: 0.9883
# Epoch 25/25
# 97/97 [==============================] - 2s 16ms/step - loss: 0.0286 - categorical_accuracy: 0.9900
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.60      0.71       684
#          1.0       0.70      0.80      0.74       228
#          2.0       0.54      0.81      0.65       228
#          3.0       0.70      0.89      0.78       228
#
#     accuracy                           0.72      1368
#    macro avg       0.70      0.78      0.72      1368
# weighted avg       0.76      0.72      0.72      1368
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 90, acceptance: 51, rejection: 39
# # of FA: 0
# # of FR: 39
# # of MI: 15
# FAR: 0.0
# MIR: 0.16666666666666666
# FRR: 0.43333333333333335
# latency: 77760 ms
# ==== Session #1 ====
# # of detection: 122, acceptance: 99, rejection: 23
# # of FA: 0
# # of FR: 23
# # of MI: 17
# FAR: 0.0
# MIR: 0.13934426229508196
# FRR: 0.1885245901639344
# latency: 26060 ms
# ==== Session #2 ====
# # of detection: 136, acceptance: 136, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.058823529411764705
# FRR: 0.0
# latency: 30800 ms
# simulation result: FAR: 0.0
# MIR: 0.11494252873563218
# FNR: 0.1781609195402299
# latency: 44873.333333333336 ms
# [touch] case: 27, er: 7, em: 3, fr: 5, mi: 0,
# [gait] case: 27, er: 6, em: 2, fr: 4, mi: 1,
# [simple_average] case: 27, er: 4, em: 2, fr: 3, mi: 8,
# [weighted_average_eer] case: 27, er: 4, em: 3, fr: 2, mi: 9,
# [weighted_average_auc] case: 27, er: 4, em: 3, fr: 2, mi: 9,
# [deer_dempster_shafer] case: 27, er: 4, em: 3, fr: 1, mi: 11,
# [auc_dempster_shafer] case: 27, er: 5, em: 3, fr: 1, mi: 11,
# [kalman_filter] case: 27, er: 5, em: 7, fr: 1, mi: 8,
#
# file saved.
# ========== SETUP ===========
# Game name:100_900_10_0_3
# Negative trainer seed:100
# Game seed:900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:962159 (0), 777078 (1), 526319 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.86        18
#            1       0.71      0.83      0.77         6
#            2       0.67      0.67      0.67         6
#            3       0.83      0.83      0.83         6
#
#     accuracy                           0.81        36
#    macro avg       0.77      0.79      0.78        36
# weighted avg       0.81      0.81      0.81        36
#
# Epoch 1/25
# 74/74 [==============================] - 4s 18ms/step - loss: 1.2398 - categorical_accuracy: 0.5371
# Epoch 2/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.7761 - categorical_accuracy: 0.7092
# Epoch 3/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.6166 - categorical_accuracy: 0.7784
# Epoch 4/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.4929 - categorical_accuracy: 0.8253
# Epoch 5/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.4861 - categorical_accuracy: 0.8251
# Epoch 6/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.3644 - categorical_accuracy: 0.8664
# Epoch 7/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.2992 - categorical_accuracy: 0.8920
# Epoch 8/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.2478 - categorical_accuracy: 0.9101
# Epoch 9/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.2326 - categorical_accuracy: 0.9129
# Epoch 10/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1956 - categorical_accuracy: 0.9302
# Epoch 11/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1717 - categorical_accuracy: 0.9357
# Epoch 12/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1532 - categorical_accuracy: 0.9435
# Epoch 13/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1773 - categorical_accuracy: 0.9381
# Epoch 14/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1250 - categorical_accuracy: 0.9534
# Epoch 15/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.1002 - categorical_accuracy: 0.9651
# Epoch 16/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0813 - categorical_accuracy: 0.9708
# Epoch 17/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0721 - categorical_accuracy: 0.9750
# Epoch 18/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0721 - categorical_accuracy: 0.9753
# Epoch 19/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0485 - categorical_accuracy: 0.9837
# Epoch 20/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0384 - categorical_accuracy: 0.9881
# Epoch 21/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0392 - categorical_accuracy: 0.9863
# Epoch 22/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0328 - categorical_accuracy: 0.9909
# Epoch 23/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0225 - categorical_accuracy: 0.9941
# Epoch 24/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0295 - categorical_accuracy: 0.9908
# Epoch 25/25
# 74/74 [==============================] - 1s 16ms/step - loss: 0.0245 - categorical_accuracy: 0.9924
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.84      0.87       522
#          1.0       0.93      0.93      0.93       174
#          2.0       0.99      0.78      0.87       174
#          3.0       0.67      0.96      0.79       174
#
#     accuracy                           0.87      1044
#    macro avg       0.88      0.88      0.87      1044
# weighted avg       0.89      0.87      0.87      1044
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 94, acceptance: 88, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 4
# FAR: 0.0
# MIR: 0.0425531914893617
# FRR: 0.06382978723404255
# latency: 35914 ms
# ==== Session #1 ====
# # of detection: 87, acceptance: 87, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 10
# FAR: 0.0
# MIR: 0.11494252873563218
# FRR: 0.0
# latency: 25727 ms
# ==== Session #2 ====
# # of detection: 96, acceptance: 96, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.09375
# FRR: 0.0
# latency: 26443 ms
# simulation result: FAR: 0.0
# MIR: 0.08303249097472924
# FNR: 0.021660649819494584
# latency: 29361.333333333332 ms
# [touch] case: 30, er: 7, em: 3, fr: 7, mi: 0,
# [gait] case: 30, er: 6, em: 3, fr: 4, mi: 1,
# [simple_average] case: 30, er: 4, em: 3, fr: 3, mi: 10,
# [weighted_average_eer] case: 30, er: 4, em: 4, fr: 2, mi: 11,
# [weighted_average_auc] case: 30, er: 4, em: 4, fr: 2, mi: 11,
# [deer_dempster_shafer] case: 30, er: 4, em: 3, fr: 1, mi: 13,
# [auc_dempster_shafer] case: 30, er: 5, em: 3, fr: 1, mi: 13,
# [kalman_filter] case: 30, er: 5, em: 8, fr: 1, mi: 9,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1000_10_0_3
# Negative trainer seed:100
# Game seed:1000
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:796581 (0), 186676 (1), 893255 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.81      0.88      0.84        33
#            1       0.56      0.45      0.50        11
#            2       0.90      0.82      0.86        11
#            3       0.91      0.91      0.91        11
#
#     accuracy                           0.80        66
#    macro avg       0.79      0.77      0.78        66
# weighted avg       0.80      0.80      0.80        66
#
# Epoch 1/25
# 95/95 [==============================] - 4s 16ms/step - loss: 1.1374 - categorical_accuracy: 0.5547
# Epoch 2/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.7339 - categorical_accuracy: 0.6908
# Epoch 3/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.6360 - categorical_accuracy: 0.7328
# Epoch 4/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.4707 - categorical_accuracy: 0.8167
# Epoch 5/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.3605 - categorical_accuracy: 0.8632
# Epoch 6/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.3064 - categorical_accuracy: 0.8818
# Epoch 7/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.2624 - categorical_accuracy: 0.8993
# Epoch 8/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.2337 - categorical_accuracy: 0.9095
# Epoch 9/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1949 - categorical_accuracy: 0.9238
# Epoch 10/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1979 - categorical_accuracy: 0.9225
# Epoch 11/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1598 - categorical_accuracy: 0.9390
# Epoch 12/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1469 - categorical_accuracy: 0.9436
# Epoch 13/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1547 - categorical_accuracy: 0.9394
# Epoch 14/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1398 - categorical_accuracy: 0.9467
# Epoch 15/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0978 - categorical_accuracy: 0.9623
# Epoch 16/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.1124 - categorical_accuracy: 0.9593
# Epoch 17/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0953 - categorical_accuracy: 0.9648
# Epoch 18/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0963 - categorical_accuracy: 0.9643
# Epoch 19/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0655 - categorical_accuracy: 0.9772
# Epoch 20/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0555 - categorical_accuracy: 0.9813
# Epoch 21/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0432 - categorical_accuracy: 0.9859
# Epoch 22/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0606 - categorical_accuracy: 0.9785
# Epoch 23/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0708 - categorical_accuracy: 0.9727
# Epoch 24/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0435 - categorical_accuracy: 0.9852
# Epoch 25/25
# 95/95 [==============================] - 2s 16ms/step - loss: 0.0369 - categorical_accuracy: 0.9878
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.84      0.88       672
#          1.0       0.68      0.96      0.80       224
#          2.0       0.99      0.88      0.93       224
#          3.0       0.97      0.95      0.96       224
#
#     accuracy                           0.89      1344
#    macro avg       0.89      0.91      0.89      1344
# weighted avg       0.90      0.89      0.89      1344
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 81, acceptance: 76, rejection: 5
# # of FA: 0
# # of FR: 5
# # of MI: 13
# FAR: 0.0
# MIR: 0.16049382716049382
# FRR: 0.06172839506172839
# latency: 23887 ms
# ==== Session #1 ====
# # of detection: 134, acceptance: 134, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 13
# FAR: 0.0
# MIR: 0.09701492537313433
# FRR: 0.0
# latency: 25632 ms
# ==== Session #2 ====
# # of detection: 100, acceptance: 82, rejection: 18
# # of FA: 0
# # of FR: 18
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.18
# latency: 36113 ms
# simulation result: FAR: 0.0
# MIR: 0.08253968253968254
# FNR: 0.07301587301587302
# latency: 28544.0 ms
# [touch] case: 33, er: 7, em: 3, fr: 8, mi: 0,
# [gait] case: 33, er: 7, em: 3, fr: 5, mi: 1,
# [simple_average] case: 33, er: 4, em: 3, fr: 3, mi: 11,
# [weighted_average_eer] case: 33, er: 4, em: 4, fr: 2, mi: 12,
# [weighted_average_auc] case: 33, er: 4, em: 4, fr: 2, mi: 12,
# [deer_dempster_shafer] case: 33, er: 4, em: 3, fr: 2, mi: 14,
# [auc_dempster_shafer] case: 33, er: 5, em: 3, fr: 2, mi: 14,
# [kalman_filter] case: 33, er: 5, em: 8, fr: 2, mi: 10,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1100_10_0_3
# Negative trainer seed:100
# Game seed:1100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:937904 (0), 368258 (1), 980953 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.87      0.83      0.85        48
#            1       0.53      0.56      0.55        16
#            2       1.00      0.94      0.97        16
#            3       0.83      0.94      0.88        16
#
#     accuracy                           0.82        96
#    macro avg       0.81      0.82      0.81        96
# weighted avg       0.83      0.82      0.82        96
#
# Epoch 1/25
# 49/49 [==============================] - 4s 16ms/step - loss: 1.2409 - categorical_accuracy: 0.5479
# Epoch 2/25
# 49/49 [==============================] - 1s 16ms/step - loss: 0.7594 - categorical_accuracy: 0.6617
# Epoch 3/25
# ...
# [weighted_average_eer] case: 441, er: 97, em: 40, fr: 53, mi: 143,
# [weighted_average_auc] case: 441, er: 107, em: 36, fr: 55, mi: 139,
# [deer_dempster_shafer] case: 441, er: 102, em: 27, fr: 43, mi: 150,
# [auc_dempster_shafer] case: 441, er: 105, em: 26, fr: 52, mi: 141,
# [kalman_filter] case: 441, er: 111, em: 83, fr: 41, mi: 123,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14700_10_0_3
# Negative trainer seed:100
# Game seed:14700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:856401 (0), 220962 (1), 720193 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.67      0.44      0.53        27
#            1       0.54      0.78      0.64         9
#            2       0.38      0.33      0.35         9
#            3       0.27      0.44      0.33         9
#
#     accuracy                           0.48        54
#    macro avg       0.46      0.50      0.46        54
# weighted avg       0.53      0.48      0.49        54
#
# Epoch 1/25
# 79/79 [==============================] - 4s 16ms/step - loss: 0.8407 - categorical_accuracy: 0.6864
# Epoch 2/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.4227 - categorical_accuracy: 0.8355
# Epoch 3/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.3394 - categorical_accuracy: 0.8764
# Epoch 4/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2677 - categorical_accuracy: 0.9038
# Epoch 5/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2143 - categorical_accuracy: 0.9260
# Epoch 6/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.2167 - categorical_accuracy: 0.9231
# Epoch 7/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1699 - categorical_accuracy: 0.9420
# Epoch 8/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1578 - categorical_accuracy: 0.9461
# Epoch 9/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1420 - categorical_accuracy: 0.9512
# Epoch 10/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1363 - categorical_accuracy: 0.9511
# Epoch 11/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1186 - categorical_accuracy: 0.9592
# Epoch 12/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.1013 - categorical_accuracy: 0.9642
# Epoch 13/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0975 - categorical_accuracy: 0.9661
# Epoch 14/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0947 - categorical_accuracy: 0.9685
# Epoch 15/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0752 - categorical_accuracy: 0.9728
# Epoch 16/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0600 - categorical_accuracy: 0.9798
# Epoch 17/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0607 - categorical_accuracy: 0.9800
# Epoch 18/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0521 - categorical_accuracy: 0.9814
# Epoch 19/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0377 - categorical_accuracy: 0.9885
# Epoch 20/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0458 - categorical_accuracy: 0.9843
# Epoch 21/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0471 - categorical_accuracy: 0.9831
# Epoch 22/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0434 - categorical_accuracy: 0.9857
# Epoch 23/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0278 - categorical_accuracy: 0.9907
# Epoch 24/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0313 - categorical_accuracy: 0.9888
# Epoch 25/25
# 79/79 [==============================] - 1s 16ms/step - loss: 0.0268 - categorical_accuracy: 0.9917
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.93      0.84       558
#          1.0       0.81      0.46      0.59       186
#          2.0       0.92      0.99      0.95       186
#          3.0       0.88      0.65      0.75       186
#
#     accuracy                           0.81      1116
#    macro avg       0.84      0.76      0.78      1116
# weighted avg       0.82      0.81      0.80      1116
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 78, acceptance: 64, rejection: 14
# # of FA: 0
# # of FR: 14
# # of MI: 6
# FAR: 0.0
# MIR: 0.07692307692307693
# FRR: 0.1794871794871795
# latency: 48867 ms
# ==== Session #1 ====
# # of detection: 103, acceptance: 103, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.07766990291262135
# FRR: 0.0
# latency: 25654 ms
# ==== Session #2 ====
# # of detection: 90, acceptance: 82, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 10
# FAR: 0.0
# MIR: 0.1111111111111111
# FRR: 0.08888888888888889
# latency: 78031 ms
# simulation result: FAR: 0.0
# MIR: 0.08856088560885608
# FNR: 0.08118081180811808
# latency: 50850.666666666664 ms
# [touch] case: 444, er: 86, em: 22, fr: 88, mi: 32,
# [gait] case: 444, er: 142, em: 28, fr: 88, mi: 18,
# [simple_average] case: 444, er: 119, em: 32, fr: 56, mi: 134,
# [weighted_average_eer] case: 444, er: 98, em: 40, fr: 53, mi: 145,
# [weighted_average_auc] case: 444, er: 109, em: 36, fr: 55, mi: 140,
# [deer_dempster_shafer] case: 444, er: 104, em: 27, fr: 43, mi: 150,
# [auc_dempster_shafer] case: 444, er: 107, em: 26, fr: 52, mi: 141,
# [kalman_filter] case: 444, er: 113, em: 83, fr: 41, mi: 123,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14800_10_0_3
# Negative trainer seed:100
# Game seed:14800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:342329 (0), 539502 (1), 663153 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82        24
#            1       0.60      0.38      0.46         8
#            2       0.80      1.00      0.89         8
#            3       1.00      1.00      1.00         8
#
#     accuracy                           0.81        48
#    macro avg       0.80      0.80      0.79        48
# weighted avg       0.80      0.81      0.80        48
#
# Epoch 1/25
# 53/53 [==============================] - 4s 16ms/step - loss: 1.2823 - categorical_accuracy: 0.5346
# Epoch 2/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.8920 - categorical_accuracy: 0.6253
# Epoch 3/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.7605 - categorical_accuracy: 0.6955
# Epoch 4/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.6943 - categorical_accuracy: 0.7265
# Epoch 5/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.6022 - categorical_accuracy: 0.7596
# Epoch 6/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.5227 - categorical_accuracy: 0.8016
# Epoch 7/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.4910 - categorical_accuracy: 0.8126
# Epoch 8/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.4613 - categorical_accuracy: 0.8312
# Epoch 9/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.3655 - categorical_accuracy: 0.8653
# Epoch 10/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.3046 - categorical_accuracy: 0.8868
# Epoch 11/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.2600 - categorical_accuracy: 0.9044
# Epoch 12/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.2462 - categorical_accuracy: 0.9130
# Epoch 13/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.2228 - categorical_accuracy: 0.9249
# Epoch 14/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.1530 - categorical_accuracy: 0.9505
# Epoch 15/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.1578 - categorical_accuracy: 0.9460
# Epoch 16/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.1679 - categorical_accuracy: 0.9411
# Epoch 17/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.1532 - categorical_accuracy: 0.9451
# Epoch 18/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.1016 - categorical_accuracy: 0.9670
# Epoch 19/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0899 - categorical_accuracy: 0.9706
# Epoch 20/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0717 - categorical_accuracy: 0.9785
# Epoch 21/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0802 - categorical_accuracy: 0.9730
# Epoch 22/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0774 - categorical_accuracy: 0.9749
# Epoch 23/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0539 - categorical_accuracy: 0.9848
# Epoch 24/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0347 - categorical_accuracy: 0.9905
# Epoch 25/25
# 53/53 [==============================] - 1s 16ms/step - loss: 0.0238 - categorical_accuracy: 0.9952
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.82      0.89       372
#          1.0       0.91      0.94      0.92       124
#          2.0       0.78      0.97      0.86       124
#          3.0       0.84      1.00      0.91       124
#
#     accuracy                           0.90       744
#    macro avg       0.87      0.93      0.90       744
# weighted avg       0.91      0.90      0.90       744
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 100, acceptance: 65, rejection: 35
# # of FA: 0
# # of FR: 35
# # of MI: 14
# FAR: 0.0
# MIR: 0.14
# FRR: 0.35
# latency: 25680 ms
# ==== Session #1 ====
# # of detection: 96, acceptance: 96, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.09375
# FRR: 0.0
# latency: 25672 ms
# ==== Session #2 ====
# # of detection: 99, acceptance: 54, rejection: 45
# # of FA: 0
# # of FR: 45
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.45454545454545453
# latency: 12244 ms
# simulation result: FAR: 0.0
# MIR: 0.07796610169491526
# FNR: 0.2711864406779661
# latency: 21198.666666666668 ms
# [touch] case: 447, er: 88, em: 22, fr: 88, mi: 32,
# [gait] case: 447, er: 143, em: 28, fr: 90, mi: 18,
# [simple_average] case: 447, er: 120, em: 32, fr: 57, mi: 135,
# [weighted_average_eer] case: 447, er: 99, em: 40, fr: 54, mi: 146,
# [weighted_average_auc] case: 447, er: 110, em: 36, fr: 56, mi: 141,
# [deer_dempster_shafer] case: 447, er: 105, em: 27, fr: 44, mi: 151,
# [auc_dempster_shafer] case: 447, er: 108, em: 26, fr: 53, mi: 142,
# [kalman_filter] case: 447, er: 114, em: 83, fr: 42, mi: 124,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14900_10_0_3
# Negative trainer seed:100
# Game seed:14900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:594887 (0), 771782 (1), 862649 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85        66
#            1       0.65      0.77      0.71        22
#            2       0.88      0.64      0.74        22
#            3       0.95      0.95      0.95        22
#
#     accuracy                           0.83       132
#    macro avg       0.83      0.81      0.81       132
# weighted avg       0.83      0.83      0.83       132
#
# Epoch 1/25
# 109/109 [==============================] - 5s 16ms/step - loss: 1.2352 - categorical_accuracy: 0.5325
# Epoch 2/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.8833 - categorical_accuracy: 0.6075
# Epoch 3/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.7092 - categorical_accuracy: 0.6913
# Epoch 4/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.8496 - categorical_accuracy: 0.6228
# Epoch 5/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.6871 - categorical_accuracy: 0.7140
# Epoch 6/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.5124 - categorical_accuracy: 0.7978
# Epoch 7/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.3870 - categorical_accuracy: 0.8472
# Epoch 8/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.4110 - categorical_accuracy: 0.8382
# Epoch 9/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.4363 - categorical_accuracy: 0.8354
# Epoch 10/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.3481 - categorical_accuracy: 0.8715
# Epoch 11/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.2922 - categorical_accuracy: 0.8906
# Epoch 12/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.2120 - categorical_accuracy: 0.9205
# Epoch 13/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1900 - categorical_accuracy: 0.9281
# Epoch 14/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1487 - categorical_accuracy: 0.9486
# Epoch 15/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1407 - categorical_accuracy: 0.9493
# Epoch 16/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1244 - categorical_accuracy: 0.9546
# Epoch 17/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0843 - categorical_accuracy: 0.9718
# Epoch 18/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1098 - categorical_accuracy: 0.9593
# Epoch 19/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1383 - categorical_accuracy: 0.9487
# Epoch 20/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.1094 - categorical_accuracy: 0.9614
# Epoch 21/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0808 - categorical_accuracy: 0.9728
# Epoch 22/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0562 - categorical_accuracy: 0.9830
# Epoch 23/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0430 - categorical_accuracy: 0.9877
# Epoch 24/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0298 - categorical_accuracy: 0.9921
# Epoch 25/25
# 109/109 [==============================] - 2s 16ms/step - loss: 0.0212 - categorical_accuracy: 0.9950
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.66      0.77       768
#          1.0       0.77      0.99      0.87       256
#          2.0       0.74      0.89      0.81       256
#          3.0       0.65      0.92      0.76       256
#
#     accuracy                           0.80      1536
#    macro avg       0.78      0.87      0.80      1536
# weighted avg       0.83      0.80      0.79      1536
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 120, acceptance: 105, rejection: 15
# # of FA: 0
# # of FR: 15
# # of MI: 13
# FAR: 0.0
# MIR: 0.10833333333333334
# FRR: 0.125
# latency: 24027 ms
# ==== Session #1 ====
# # of detection: 151, acceptance: 137, rejection: 14
# # of FA: 0
# # of FR: 14
# # of MI: 13
# FAR: 0.0
# MIR: 0.08609271523178808
# FRR: 0.09271523178807947
# latency: 21111 ms
# ==== Session #2 ====
# # of detection: 96, acceptance: 73, rejection: 23
# # of FA: 0
# # of FR: 23
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.23958333333333334
# latency: 25563 ms
# simulation result: FAR: 0.0
# MIR: 0.07084468664850137
# FNR: 0.14168937329700274
# latency: 23567.0 ms
# [touch] case: 450, er: 89, em: 22, fr: 90, mi: 32,
# [gait] case: 450, er: 146, em: 28, fr: 90, mi: 18,
# [simple_average] case: 450, er: 123, em: 32, fr: 57, mi: 135,
# [weighted_average_eer] case: 450, er: 101, em: 40, fr: 54, mi: 146,
# [weighted_average_auc] case: 450, er: 112, em: 36, fr: 56, mi: 141,
# [deer_dempster_shafer] case: 450, er: 105, em: 27, fr: 46, mi: 151,
# [auc_dempster_shafer] case: 450, er: 108, em: 26, fr: 55, mi: 142,
# [kalman_filter] case: 450, er: 114, em: 83, fr: 44, mi: 124,
#
# file saved.

# %%
#@title Experiment 2.1: 2 + 2 + 30 training sessions

experiment_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_user_switch_experiment_limit(seed, 3, 2, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/user_switch_3_2_30_limit", str(seed)))

# %%
#@title Experiment 2.1: 3 + 3 training sessions

experiment_result = None

for seed in range(9200, 15000, 100):
    tml, player = run_topic_user_switch_experiment_limit(seed, 3, 3, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022/user_switch_3_3_limit", str(seed)))
# Out:
# ========== SETUP ===========
# Game name:100_9200_10_0_3
# Negative trainer seed:100
# Game seed:9200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:827212 (0), 472761 (1), 777078 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92        27
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00         9
#            3       0.73      0.89      0.80         9
#
#     accuracy                           0.93        54
#    macro avg       0.92      0.94      0.93        54
# weighted avg       0.93      0.93      0.93        54
#
# Epoch 1/25
# 26/26 [==============================] - 3s 18ms/step - loss: 1.8739 - categorical_accuracy: 0.4306
# Epoch 2/25
# 26/26 [==============================] - 0s 17ms/step - loss: 1.0222 - categorical_accuracy: 0.5402
# Epoch 3/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.8592 - categorical_accuracy: 0.6138
# Epoch 4/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.6585 - categorical_accuracy: 0.7415
# Epoch 5/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.6349 - categorical_accuracy: 0.7452
# Epoch 6/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.5301 - categorical_accuracy: 0.7902
# Epoch 7/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.5068 - categorical_accuracy: 0.7862
# Epoch 8/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.4521 - categorical_accuracy: 0.8207
# Epoch 9/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.4277 - categorical_accuracy: 0.8297
# Epoch 10/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.4290 - categorical_accuracy: 0.8309
# Epoch 11/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.4211 - categorical_accuracy: 0.8318
# Epoch 12/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3946 - categorical_accuracy: 0.8430
# Epoch 13/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3587 - categorical_accuracy: 0.8551
# Epoch 14/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.3467 - categorical_accuracy: 0.8638
# Epoch 15/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3072 - categorical_accuracy: 0.8874
# Epoch 16/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2907 - categorical_accuracy: 0.8895
# Epoch 17/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.3040 - categorical_accuracy: 0.8777
# Epoch 18/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2757 - categorical_accuracy: 0.8958
# Epoch 19/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2609 - categorical_accuracy: 0.8982
# Epoch 20/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2869 - categorical_accuracy: 0.8880
# Epoch 21/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2310 - categorical_accuracy: 0.9152
# Epoch 22/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2085 - categorical_accuracy: 0.9272
# Epoch 23/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1890 - categorical_accuracy: 0.9321
# Epoch 24/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1899 - categorical_accuracy: 0.9278
# Epoch 25/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1976 - categorical_accuracy: 0.9278
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.77      0.79       183
#          1.0       0.64      1.00      0.78        61
#          2.0       0.75      0.80      0.78        61
#          3.0       1.00      0.56      0.72        61
#
#     accuracy                           0.78       366
#    macro avg       0.80      0.78      0.77       366
# weighted avg       0.81      0.78      0.77       366
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 85, acceptance: 85, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.08235294117647059
# FRR: 0.0
# latency: 28037 ms
# ==== Session #1 ====
# # of detection: 54, acceptance: 54, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 4
# FAR: 0.0
# MIR: 0.07407407407407407
# FRR: 0.0
# latency: 37947 ms
# ==== Session #2 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 5
# FAR: 0.0
# MIR: 0.09433962264150944
# FRR: 0.0
# latency: 53486 ms
# simulation result: FAR: 0.0
# MIR: 0.08333333333333333
# FNR: 0.0
# latency: 39823.333333333336 ms
# [touch] case: 3, er: 0, em: 0, fr: 0, mi: 0,
# [gait] case: 3, er: 1, em: 0, fr: 1, mi: 0,
# [simple_average] case: 3, er: 1, em: 0, fr: 1, mi: 0,
# [weighted_average_eer] case: 3, er: 1, em: 0, fr: 1, mi: 0,
# [weighted_average_auc] case: 3, er: 1, em: 0, fr: 1, mi: 0,
# [deer_dempster_shafer] case: 3, er: 0, em: 0, fr: 0, mi: 0,
# [auc_dempster_shafer] case: 3, er: 0, em: 0, fr: 0, mi: 0,
# [kalman_filter] case: 3, er: 0, em: 0, fr: 1, mi: 0,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9300_10_0_3
# Negative trainer seed:100
# Game seed:9300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:352716 (0), 717868 (1), 368258 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91        45
#            1       0.73      0.73      0.73        15
#            2       0.79      0.73      0.76        15
#            3       0.75      0.80      0.77        15
#
#     accuracy                           0.83        90
#    macro avg       0.80      0.79      0.79        90
# weighted avg       0.83      0.83      0.83        90
#
# Epoch 1/25
# 42/42 [==============================] - 4s 17ms/step - loss: 1.4686 - categorical_accuracy: 0.5056
# Epoch 2/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.7944 - categorical_accuracy: 0.6723
# Epoch 3/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.7311 - categorical_accuracy: 0.7008
# Epoch 4/25
# 42/42 [==============================] - 1s 16ms/step - loss: 0.6555 - categorical_accuracy: 0.7357
# Epoch 5/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.6040 - categorical_accuracy: 0.7658
# Epoch 6/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.5788 - categorical_accuracy: 0.7620
# Epoch 7/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.4951 - categorical_accuracy: 0.8059
# Epoch 8/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.4155 - categorical_accuracy: 0.8427
# Epoch 9/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.3741 - categorical_accuracy: 0.8577
# Epoch 10/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.3777 - categorical_accuracy: 0.8560
# Epoch 11/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.2701 - categorical_accuracy: 0.8986
# Epoch 12/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.2430 - categorical_accuracy: 0.9125
# Epoch 13/25
# 42/42 [==============================] - 1s 16ms/step - loss: 0.2457 - categorical_accuracy: 0.9080
# Epoch 14/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.1948 - categorical_accuracy: 0.9298
# Epoch 15/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.1799 - categorical_accuracy: 0.9401
# Epoch 16/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.1622 - categorical_accuracy: 0.9424
# Epoch 17/25
# 42/42 [==============================] - 1s 16ms/step - loss: 0.1290 - categorical_accuracy: 0.9565
# Epoch 18/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.2319 - categorical_accuracy: 0.9176
# Epoch 19/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.2246 - categorical_accuracy: 0.9167
# Epoch 20/25
# 42/42 [==============================] - 1s 16ms/step - loss: 0.1199 - categorical_accuracy: 0.9587
# Epoch 21/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0807 - categorical_accuracy: 0.9760
# Epoch 22/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0755 - categorical_accuracy: 0.9752
# Epoch 23/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0610 - categorical_accuracy: 0.9822
# Epoch 24/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0423 - categorical_accuracy: 0.9891
# Epoch 25/25
# 42/42 [==============================] - 1s 17ms/step - loss: 0.0357 - categorical_accuracy: 0.9914
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.36      0.51       294
#          1.0       0.75      0.97      0.85        98
#          2.0       0.53      0.87      0.66        98
#          3.0       0.53      0.99      0.69        98
#
#     accuracy                           0.65       588
#    macro avg       0.68      0.80      0.68       588
# weighted avg       0.75      0.65      0.62       588
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 43, acceptance: 28, rejection: 15
# # of FA: 0
# # of FR: 15
# # of MI: 5
# FAR: 0.0
# MIR: 0.11627906976744186
# FRR: 0.3488372093023256
# latency: 53622 ms
# ==== Session #1 ====
# # of detection: 74, acceptance: 24, rejection: 50
# # of FA: 0
# # of FR: 50
# # of MI: 3
# FAR: 0.0
# MIR: 0.04054054054054054
# FRR: 0.6756756756756757
# latency: 43946 ms
# ==== Session #2 ====
# # of detection: 40, acceptance: 31, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.225
# latency: 31261 ms
# simulation result: FAR: 0.0
# MIR: 0.050955414012738856
# FNR: 0.4713375796178344
# latency: 42943.0 ms
# [touch] case: 6, er: 1, em: 0, fr: 1, mi: 0,
# [gait] case: 6, er: 2, em: 0, fr: 2, mi: 0,
# [simple_average] case: 6, er: 2, em: 0, fr: 3, mi: 0,
# [weighted_average_eer] case: 6, er: 2, em: 0, fr: 3, mi: 0,
# [weighted_average_auc] case: 6, er: 2, em: 0, fr: 3, mi: 0,
# [deer_dempster_shafer] case: 6, er: 1, em: 0, fr: 2, mi: 0,
# [auc_dempster_shafer] case: 6, er: 1, em: 0, fr: 2, mi: 0,
# [kalman_filter] case: 6, er: 0, em: 0, fr: 4, mi: 0,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9400_10_0_3
# Negative trainer seed:100
# Game seed:9400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:352716 (0), 827212 (1), 777078 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.96      0.85      0.90        27
#            1       0.89      0.89      0.89         9
#            2       1.00      1.00      1.00         9
#            3       0.75      1.00      0.86         9
#
#     accuracy                           0.91        54
#    macro avg       0.90      0.94      0.91        54
# weighted avg       0.92      0.91      0.91        54
#
# Epoch 1/25
# 26/26 [==============================] - 4s 18ms/step - loss: 1.8381 - categorical_accuracy: 0.4441
# Epoch 2/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.9675 - categorical_accuracy: 0.5836
# Epoch 3/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.7877 - categorical_accuracy: 0.6745
# Epoch 4/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.6603 - categorical_accuracy: 0.7361
# Epoch 5/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.6853 - categorical_accuracy: 0.7340
# Epoch 6/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.5267 - categorical_accuracy: 0.7959
# Epoch 7/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.4460 - categorical_accuracy: 0.8231
# Epoch 8/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3849 - categorical_accuracy: 0.8487
# Epoch 9/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3724 - categorical_accuracy: 0.8511
# Epoch 10/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3424 - categorical_accuracy: 0.8659
# Epoch 11/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.3081 - categorical_accuracy: 0.8765
# Epoch 12/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2593 - categorical_accuracy: 0.8958
# Epoch 13/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2697 - categorical_accuracy: 0.8907
# Epoch 14/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2637 - categorical_accuracy: 0.8995
# Epoch 15/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.2374 - categorical_accuracy: 0.9100
# Epoch 16/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2373 - categorical_accuracy: 0.9043
# Epoch 17/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.2280 - categorical_accuracy: 0.9161
# Epoch 18/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1937 - categorical_accuracy: 0.9242
# Epoch 19/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1905 - categorical_accuracy: 0.9263
# Epoch 20/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1862 - categorical_accuracy: 0.9275
# Epoch 21/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1453 - categorical_accuracy: 0.9478
# Epoch 22/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1352 - categorical_accuracy: 0.9529
# Epoch 23/25
# 26/26 [==============================] - 0s 16ms/step - loss: 0.1404 - categorical_accuracy: 0.9484
# Epoch 24/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1236 - categorical_accuracy: 0.9559
# Epoch 25/25
# 26/26 [==============================] - 0s 17ms/step - loss: 0.1880 - categorical_accuracy: 0.9318
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.78      0.80      0.79       183
#          1.0       0.60      0.93      0.73        61
#          2.0       0.95      0.95      0.95        61
#          3.0       0.96      0.38      0.54        61
#
#     accuracy                           0.78       366
#    macro avg       0.82      0.77      0.75       366
# weighted avg       0.81      0.78      0.77       366
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 80, acceptance: 80, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 5
# FAR: 0.0
# MIR: 0.0625
# FRR: 0.0
# latency: 56215 ms
# ==== Session #1 ====
# # of detection: 57, acceptance: 57, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 3
# FAR: 0.0
# MIR: 0.05263157894736842
# FRR: 0.0
# latency: 43946 ms
# ==== Session #2 ====
# # of detection: 87, acceptance: 87, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.08045977011494253
# FRR: 0.0
# latency: 30808 ms
# simulation result: FAR: 0.0
# MIR: 0.06696428571428571
# FNR: 0.0
# latency: 43656.333333333336 ms
# [touch] case: 9, er: 1, em: 0, fr: 1, mi: 0,
# [gait] case: 9, er: 3, em: 0, fr: 3, mi: 0,
# [simple_average] case: 9, er: 3, em: 0, fr: 4, mi: 0,
# [weighted_average_eer] case: 9, er: 2, em: 0, fr: 3, mi: 0,
# [weighted_average_auc] case: 9, er: 3, em: 0, fr: 4, mi: 0,
# [deer_dempster_shafer] case: 9, er: 1, em: 0, fr: 2, mi: 0,
# [auc_dempster_shafer] case: 9, er: 1, em: 0, fr: 2, mi: 0,
# [kalman_filter] case: 9, er: 1, em: 0, fr: 4, mi: 0,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9500_10_0_3
# Negative trainer seed:100
# Game seed:9500
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:856302 (0), 527796 (1), 151985 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.94        63
#            1       0.82      0.86      0.84        21
#            2       0.86      0.90      0.88        21
#            3       1.00      1.00      1.00        21
#
#     accuracy                           0.92       126
#    macro avg       0.91      0.92      0.91       126
# weighted avg       0.92      0.92      0.92       126
#
# Epoch 1/25
# 139/139 [==============================] - 5s 17ms/step - loss: 0.9624 - categorical_accuracy: 0.5926
# Epoch 2/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.5882 - categorical_accuracy: 0.7656
# Epoch 3/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.3941 - categorical_accuracy: 0.8478
# Epoch 4/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.3286 - categorical_accuracy: 0.8764
# Epoch 5/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.2864 - categorical_accuracy: 0.8925
# Epoch 6/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.2232 - categorical_accuracy: 0.9182
# Epoch 7/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1875 - categorical_accuracy: 0.9307
# Epoch 8/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.1591 - categorical_accuracy: 0.9416
# Epoch 9/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.1209 - categorical_accuracy: 0.9553
# Epoch 10/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.1067 - categorical_accuracy: 0.9620
# Epoch 11/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.1067 - categorical_accuracy: 0.9608
# Epoch 12/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0833 - categorical_accuracy: 0.9703
# Epoch 13/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0714 - categorical_accuracy: 0.9736
# Epoch 14/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0387 - categorical_accuracy: 0.9880
# Epoch 15/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0493 - categorical_accuracy: 0.9821
# Epoch 16/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0457 - categorical_accuracy: 0.9843
# Epoch 17/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0275 - categorical_accuracy: 0.9913
# Epoch 18/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0190 - categorical_accuracy: 0.9953
# Epoch 19/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0540 - categorical_accuracy: 0.9824
# Epoch 20/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0479 - categorical_accuracy: 0.9818
# Epoch 21/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0307 - categorical_accuracy: 0.9908
# Epoch 22/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0307 - categorical_accuracy: 0.9897
# Epoch 23/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0444 - categorical_accuracy: 0.9850
# Epoch 24/25
# 139/139 [==============================] - 2s 16ms/step - loss: 0.0134 - categorical_accuracy: 0.9957
# Epoch 25/25
# 139/139 [==============================] - 2s 17ms/step - loss: 0.0299 - categorical_accuracy: 0.9903
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.74      0.34      0.46       984
#          1.0       0.37      0.80      0.51       328
#          2.0       0.85      0.83      0.84       328
#          3.0       0.55      0.84      0.66       328
#
#     accuracy                           0.58      1968
#    macro avg       0.63      0.70      0.62      1968
# weighted avg       0.67      0.58      0.57      1968
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 91, acceptance: 72, rejection: 19
# # of FA: 0
# # of FR: 19
# # of MI: 6
# FAR: 0.0
# MIR: 0.06593406593406594
# FRR: 0.2087912087912088
# latency: 40266 ms
# ==== Session #1 ====
# # of detection: 71, acceptance: 71, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.11267605633802817
# FRR: 0.0
# latency: 29098 ms
# ==== Session #2 ====
# # of detection: 66, acceptance: 49, rejection: 17
# # of FA: 0
# # of FR: 17
# # of MI: 6
# FAR: 0.0
# MIR: 0.09090909090909091
# FRR: 0.25757575757575757
# latency: 140774 ms
# simulation result: FAR: 0.0
# MIR: 0.08771929824561403
# FNR: 0.15789473684210525
# latency: 70046.0 ms
# [touch] case: 12, er: 1, em: 0, fr: 1, mi: 0,
# [gait] case: 12, er: 4, em: 0, fr: 4, mi: 0,
# [simple_average] case: 12, er: 4, em: 0, fr: 5, mi: 0,
# [weighted_average_eer] case: 12, er: 3, em: 0, fr: 4, mi: 0,
# [weighted_average_auc] case: 12, er: 4, em: 0, fr: 5, mi: 0,
# [deer_dempster_shafer] case: 12, er: 2, em: 0, fr: 3, mi: 0,
# [auc_dempster_shafer] case: 12, er: 2, em: 0, fr: 3, mi: 0,
# [kalman_filter] case: 12, er: 1, em: 1, fr: 5, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9600_10_0_3
# Negative trainer seed:100
# Game seed:9600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:923862 (0), 872895 (1), 538363 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.76      0.69      0.72        36
#            1       0.54      0.58      0.56        12
#            2       0.73      0.67      0.70        12
#            3       0.47      0.58      0.52        12
#
#     accuracy                           0.65        72
#    macro avg       0.62      0.63      0.62        72
# weighted avg       0.67      0.65      0.66        72
#
# Epoch 1/25
# 105/105 [==============================] - 5s 17ms/step - loss: 1.0537 - categorical_accuracy: 0.6077
# Epoch 2/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.6227 - categorical_accuracy: 0.7553
# Epoch 3/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.4845 - categorical_accuracy: 0.8209
# Epoch 4/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.4059 - categorical_accuracy: 0.8462
# Epoch 5/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.3522 - categorical_accuracy: 0.8700
# Epoch 6/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.3215 - categorical_accuracy: 0.8833
# Epoch 7/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2793 - categorical_accuracy: 0.8975
# Epoch 8/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2766 - categorical_accuracy: 0.8989
# Epoch 9/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2452 - categorical_accuracy: 0.9110
# Epoch 10/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.2401 - categorical_accuracy: 0.9088
# Epoch 11/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.2260 - categorical_accuracy: 0.9173
# Epoch 12/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1837 - categorical_accuracy: 0.9314
# Epoch 13/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1706 - categorical_accuracy: 0.9366
# Epoch 14/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1355 - categorical_accuracy: 0.9489
# Epoch 15/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1181 - categorical_accuracy: 0.9567
# Epoch 16/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1178 - categorical_accuracy: 0.9550
# Epoch 17/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.1125 - categorical_accuracy: 0.9574
# Epoch 18/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.0790 - categorical_accuracy: 0.9729
# Epoch 19/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0611 - categorical_accuracy: 0.9791
# Epoch 20/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0599 - categorical_accuracy: 0.9787
# Epoch 21/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0729 - categorical_accuracy: 0.9737
# Epoch 22/25
# 105/105 [==============================] - 2s 16ms/step - loss: 0.1676 - categorical_accuracy: 0.9442
# Epoch 23/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0900 - categorical_accuracy: 0.9673
# Epoch 24/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0459 - categorical_accuracy: 0.9854
# Epoch 25/25
# 105/105 [==============================] - 2s 17ms/step - loss: 0.0301 - categorical_accuracy: 0.9910
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.49      0.63       738
#          1.0       0.53      0.94      0.68       246
#          2.0       0.64      0.96      0.76       246
#          3.0       0.81      0.85      0.83       246
#
#     accuracy                           0.70      1476
#    macro avg       0.71      0.81      0.72      1476
# weighted avg       0.77      0.70      0.69      1476
#
# training done
# too short, discarded
# Not found
# ==== Session #0 ====
# # of detection: 70, acceptance: 70, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 4
# FAR: 0.0
# MIR: 0.05714285714285714
# FRR: 0.0
# latency: 25971 ms
# ==== Session #1 ====
# # of detection: 77, acceptance: 77, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 12
# FAR: 0.0
# MIR: 0.15584415584415584
# FRR: 0.0
# latency: 30821 ms
# ==== Session #2 ====
# # of detection: 60, acceptance: 60, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 11
# FAR: 0.0
# MIR: 0.18333333333333332
# FRR: 0.0
# latency: 51272 ms
# simulation result: FAR: 0.0
# MIR: 0.13043478260869565
# FNR: 0.0
# latency: 36021.333333333336 ms
# [touch] case: 15, er: 2, em: 0, fr: 2, mi: 0,
# [gait] case: 15, er: 4, em: 0, fr: 4, mi: 0,
# [simple_average] case: 15, er: 4, em: 0, fr: 5, mi: 0,
# [weighted_average_eer] case: 15, er: 3, em: 0, fr: 4, mi: 0,
# [weighted_average_auc] case: 15, er: 4, em: 0, fr: 5, mi: 0,
# [deer_dempster_shafer] case: 15, er: 2, em: 0, fr: 3, mi: 0,
# [auc_dempster_shafer] case: 15, er: 2, em: 0, fr: 4, mi: 0,
# [kalman_filter] case: 15, er: 1, em: 1, fr: 5, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9700_10_0_3
# Negative trainer seed:100
# Game seed:9700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:579284 (0), 808022 (1), 663153 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87        39
#            1       0.65      0.85      0.73        13
#            2       0.92      0.92      0.92        13
#            3       1.00      0.85      0.92        13
#
#     accuracy                           0.86        78
#    macro avg       0.87      0.87      0.86        78
# weighted avg       0.87      0.86      0.86        78
#
# Epoch 1/25
# 115/115 [==============================] - 5s 17ms/step - loss: 1.1178 - categorical_accuracy: 0.5564
# Epoch 2/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.9078 - categorical_accuracy: 0.6011
# Epoch 3/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.8417 - categorical_accuracy: 0.6375
# Epoch 4/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.7072 - categorical_accuracy: 0.7114
# Epoch 5/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.5659 - categorical_accuracy: 0.7809
# Epoch 6/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.4718 - categorical_accuracy: 0.8178
# Epoch 7/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3761 - categorical_accuracy: 0.8577
# Epoch 8/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3442 - categorical_accuracy: 0.8745
# Epoch 9/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.3207 - categorical_accuracy: 0.8794
# Epoch 10/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.2524 - categorical_accuracy: 0.9064
# Epoch 11/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.2205 - categorical_accuracy: 0.9206
# Epoch 12/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.1857 - categorical_accuracy: 0.9353
# Epoch 13/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.1568 - categorical_accuracy: 0.9431
# Epoch 14/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.1269 - categorical_accuracy: 0.9545
# Epoch 15/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.1182 - categorical_accuracy: 0.9595
# Epoch 16/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.1018 - categorical_accuracy: 0.9648
# Epoch 17/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0723 - categorical_accuracy: 0.9754
# Epoch 18/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0677 - categorical_accuracy: 0.9781
# Epoch 19/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0853 - categorical_accuracy: 0.9704
# Epoch 20/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.0731 - categorical_accuracy: 0.9745
# Epoch 21/25
# 115/115 [==============================] - 2s 16ms/step - loss: 0.0433 - categorical_accuracy: 0.9859
# Epoch 22/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0468 - categorical_accuracy: 0.9844
# Epoch 23/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0262 - categorical_accuracy: 0.9920
# Epoch 24/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0185 - categorical_accuracy: 0.9948
# Epoch 25/25
# 115/115 [==============================] - 2s 17ms/step - loss: 0.0580 - categorical_accuracy: 0.9807
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.84      0.85       813
#          1.0       0.73      0.62      0.67       271
#          2.0       0.83      0.74      0.78       271
#          3.0       0.74      0.99      0.85       271
#
#     accuracy                           0.81      1626
#    macro avg       0.79      0.80      0.79      1626
# weighted avg       0.81      0.81      0.81      1626
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 69, acceptance: 69, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.13043478260869565
# FRR: 0.0
# latency: 24125 ms
# ==== Session #1 ====
# # of detection: 65, acceptance: 65, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 6
# FAR: 0.0
# MIR: 0.09230769230769231
# FRR: 0.0
# latency: 22462 ms
# ==== Session #2 ====
# # of detection: 69, acceptance: 69, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.10144927536231885
# FRR: 0.0
# latency: 42426 ms
# simulation result: FAR: 0.0
# MIR: 0.10837438423645321
# FNR: 0.0
# latency: 29671.0 ms
# [touch] case: 18, er: 2, em: 0, fr: 3, mi: 0,
# [gait] case: 18, er: 4, em: 0, fr: 4, mi: 0,
# [simple_average] case: 18, er: 5, em: 0, fr: 6, mi: 0,
# [weighted_average_eer] case: 18, er: 4, em: 0, fr: 5, mi: 0,
# [weighted_average_auc] case: 18, er: 5, em: 0, fr: 6, mi: 0,
# [deer_dempster_shafer] case: 18, er: 2, em: 0, fr: 3, mi: 0,
# [auc_dempster_shafer] case: 18, er: 2, em: 0, fr: 5, mi: 0,
# [kalman_filter] case: 18, er: 1, em: 1, fr: 5, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9800_10_0_3
# Negative trainer seed:100
# Game seed:9800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:990622 (0), 966655 (1), 841866 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.88      0.81      0.84        93
#            1       0.66      0.87      0.75        31
#            2       0.76      0.71      0.73        31
#            3       0.71      0.71      0.71        31
#
#     accuracy                           0.78       186
#    macro avg       0.75      0.77      0.76       186
# weighted avg       0.80      0.78      0.79       186
#
# Epoch 1/25
# 104/104 [==============================] - 6s 17ms/step - loss: 0.8968 - categorical_accuracy: 0.6600
# Epoch 2/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.5936 - categorical_accuracy: 0.7594
# Epoch 3/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.4842 - categorical_accuracy: 0.8080
# Epoch 4/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.3577 - categorical_accuracy: 0.8580
# Epoch 5/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.3098 - categorical_accuracy: 0.8776
# Epoch 6/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.2904 - categorical_accuracy: 0.8884
# Epoch 7/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.2546 - categorical_accuracy: 0.9046
# Epoch 8/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.3791 - categorical_accuracy: 0.8597
# Epoch 9/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.2381 - categorical_accuracy: 0.9111
# Epoch 10/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.1887 - categorical_accuracy: 0.9311
# Epoch 11/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.1625 - categorical_accuracy: 0.9448
# Epoch 12/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1414 - categorical_accuracy: 0.9488
# Epoch 13/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1281 - categorical_accuracy: 0.9532
# Epoch 14/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0944 - categorical_accuracy: 0.9673
# Epoch 15/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.1061 - categorical_accuracy: 0.9603
# Epoch 16/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.1471 - categorical_accuracy: 0.9461
# Epoch 17/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0964 - categorical_accuracy: 0.9664
# Epoch 18/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0605 - categorical_accuracy: 0.9790
# Epoch 19/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0522 - categorical_accuracy: 0.9824
# Epoch 20/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0452 - categorical_accuracy: 0.9861
# Epoch 21/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0589 - categorical_accuracy: 0.9794
# Epoch 22/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0843 - categorical_accuracy: 0.9698
# Epoch 23/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0493 - categorical_accuracy: 0.9828
# Epoch 24/25
# 104/104 [==============================] - 2s 16ms/step - loss: 0.0230 - categorical_accuracy: 0.9933
# Epoch 25/25
# 104/104 [==============================] - 2s 17ms/step - loss: 0.0179 - categorical_accuracy: 0.9955
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.80      0.86       732
#          1.0       0.62      0.94      0.75       244
#          2.0       1.00      1.00      1.00       244
#          3.0       0.97      0.93      0.95       244
#
#     accuracy                           0.88      1464
#    macro avg       0.88      0.92      0.89      1464
# weighted avg       0.90      0.88      0.88      1464
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 112, acceptance: 106, rejection: 6
# # of FA: 0
# # of FR: 6
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.05357142857142857
# latency: 41465 ms
# ==== Session #1 ====
# # of detection: 111, acceptance: 111, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 6
# FAR: 0.0
# MIR: 0.05405405405405406
# FRR: 0.0
# latency: 37141 ms
# ==== Session #2 ====
# # of detection: 126, acceptance: 126, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 14
# FAR: 0.0
# MIR: 0.1111111111111111
# FRR: 0.0
# latency: 31558 ms
# simulation result: FAR: 0.0
# MIR: 0.05730659025787966
# FNR: 0.017191977077363897
# latency: 36721.333333333336 ms
# [touch] case: 21, er: 2, em: 0, fr: 3, mi: 1,
# [gait] case: 21, er: 5, em: 0, fr: 4, mi: 0,
# [simple_average] case: 21, er: 6, em: 0, fr: 7, mi: 0,
# [weighted_average_eer] case: 21, er: 4, em: 0, fr: 6, mi: 0,
# [weighted_average_auc] case: 21, er: 5, em: 0, fr: 8, mi: 0,
# [deer_dempster_shafer] case: 21, er: 3, em: 0, fr: 3, mi: 0,
# [auc_dempster_shafer] case: 21, er: 3, em: 0, fr: 5, mi: 0,
# [kalman_filter] case: 21, er: 1, em: 1, fr: 5, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_9900_10_0_3
# Negative trainer seed:100
# Game seed:9900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:556357 (0), 578526 (1), 918136 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84        36
#            1       1.00      0.92      0.96        12
#            2       0.62      0.67      0.64        12
#            3       1.00      0.83      0.91        12
#
#     accuracy                           0.83        72
#    macro avg       0.86      0.82      0.84        72
# weighted avg       0.84      0.83      0.84        72
#
# Epoch 1/25
# 130/130 [==============================] - 5s 17ms/step - loss: 0.8698 - categorical_accuracy: 0.6924
# Epoch 2/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.3932 - categorical_accuracy: 0.8514
# Epoch 3/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.2845 - categorical_accuracy: 0.8944
# Epoch 4/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.2117 - categorical_accuracy: 0.9238
# Epoch 5/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.1672 - categorical_accuracy: 0.9388
# Epoch 6/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.1494 - categorical_accuracy: 0.9442
# Epoch 7/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.1441 - categorical_accuracy: 0.9480
# Epoch 8/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.1224 - categorical_accuracy: 0.9549
# Epoch 9/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0950 - categorical_accuracy: 0.9657
# Epoch 10/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0985 - categorical_accuracy: 0.9631
# Epoch 11/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0828 - categorical_accuracy: 0.9699
# Epoch 12/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0831 - categorical_accuracy: 0.9704
# Epoch 13/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0779 - categorical_accuracy: 0.9716
# Epoch 14/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0571 - categorical_accuracy: 0.9792
# Epoch 15/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0534 - categorical_accuracy: 0.9817
# Epoch 16/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0548 - categorical_accuracy: 0.9811
# Epoch 17/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0471 - categorical_accuracy: 0.9838
# Epoch 18/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0401 - categorical_accuracy: 0.9857
# Epoch 19/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0518 - categorical_accuracy: 0.9823
# Epoch 20/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0627 - categorical_accuracy: 0.9782
# Epoch 21/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0233 - categorical_accuracy: 0.9929
# Epoch 22/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0200 - categorical_accuracy: 0.9934
# Epoch 23/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0164 - categorical_accuracy: 0.9956
# Epoch 24/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0113 - categorical_accuracy: 0.9970
# Epoch 25/25
# 130/130 [==============================] - 2s 17ms/step - loss: 0.0411 - categorical_accuracy: 0.9855
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.89      0.90       918
#          1.0       0.79      1.00      0.88       306
#          2.0       0.90      0.72      0.80       306
#          3.0       0.98      0.99      0.99       306
#
#     accuracy                           0.89      1836
#    macro avg       0.89      0.90      0.89      1836
# weighted avg       0.90      0.89      0.89      1836
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 8
# FAR: 0.0
# MIR: 0.1509433962264151
# FRR: 0.0
# latency: 43537 ms
# ==== Session #1 ====
# # of detection: 56, acceptance: 56, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.125
# FRR: 0.0
# latency: 51376 ms
# ==== Session #2 ====
# # of detection: 59, acceptance: 59, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.11864406779661017
# FRR: 0.0
# latency: 43008 ms
# simulation result: FAR: 0.0
# MIR: 0.13095238095238096
# FNR: 0.0
# latency: 45973.666666666664 ms
# [touch] case: 24, er: 2, em: 0, fr: 4, mi: 1,
# [gait] case: 24, er: 6, em: 0, fr: 5, mi: 0,
# [simple_average] case: 24, er: 7, em: 0, fr: 8, mi: 0,
# [weighted_average_eer] case: 24, er: 5, em: 0, fr: 6, mi: 0,
# [weighted_average_auc] case: 24, er: 6, em: 0, fr: 9, mi: 0,
# [deer_dempster_shafer] case: 24, er: 3, em: 0, fr: 4, mi: 0,
# [auc_dempster_shafer] case: 24, er: 3, em: 0, fr: 5, mi: 0,
# [kalman_filter] case: 24, er: 1, em: 2, fr: 6, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_10000_10_0_3
# Negative trainer seed:100
# Game seed:10000
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:556357 (0), 710707 (1), 862649 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.84      0.89      0.86        36
#            1       1.00      1.00      1.00        12
#            2       0.69      0.75      0.72        12
#            3       1.00      0.75      0.86        12
#
#     accuracy                           0.86        72
#    macro avg       0.88      0.85      0.86        72
# weighted avg       0.87      0.86      0.86        72
#
# Epoch 1/25
# 142/142 [==============================] - 5s 17ms/step - loss: 1.0895 - categorical_accuracy: 0.5765
# Epoch 2/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.6846 - categorical_accuracy: 0.6989
# Epoch 3/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.5238 - categorical_accuracy: 0.7887
# Epoch 4/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.4325 - categorical_accuracy: 0.8355
# Epoch 5/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.3767 - categorical_accuracy: 0.8534
# Epoch 6/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.3123 - categorical_accuracy: 0.8820
# Epoch 7/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.2636 - categorical_accuracy: 0.9029
# Epoch 8/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.2447 - categorical_accuracy: 0.9103
# Epoch 9/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.2075 - categorical_accuracy: 0.9241
# Epoch 10/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.1711 - categorical_accuracy: 0.9371
# Epoch 11/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.1500 - categorical_accuracy: 0.9450
# Epoch 12/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.1448 - categorical_accuracy: 0.9468
# Epoch 13/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.1056 - categorical_accuracy: 0.9625
# Epoch 14/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0963 - categorical_accuracy: 0.9653
# Epoch 15/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0941 - categorical_accuracy: 0.9661
# Epoch 16/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0720 - categorical_accuracy: 0.9749
# Epoch 17/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0689 - categorical_accuracy: 0.9756
# Epoch 18/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0598 - categorical_accuracy: 0.9796
# Epoch 19/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0395 - categorical_accuracy: 0.9877
# Epoch 20/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0517 - categorical_accuracy: 0.9816
# Epoch 21/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0666 - categorical_accuracy: 0.9763
# Epoch 22/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0433 - categorical_accuracy: 0.9848
# Epoch 23/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0291 - categorical_accuracy: 0.9903
# Epoch 24/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0250 - categorical_accuracy: 0.9921
# Epoch 25/25
# 142/142 [==============================] - 2s 17ms/step - loss: 0.0209 - categorical_accuracy: 0.9934
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.71      0.77      1002
#          1.0       0.81      0.99      0.89       334
#          2.0       0.77      0.72      0.75       334
#          3.0       0.62      0.84      0.71       334
#
#     accuracy                           0.78      2004
#    macro avg       0.76      0.82      0.78      2004
# weighted avg       0.80      0.78      0.78      2004
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 63, acceptance: 63, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 9
# FAR: 0.0
# MIR: 0.14285714285714285
# FRR: 0.0
# latency: 43537 ms
# ==== Session #1 ====
# # of detection: 78, acceptance: 78, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 11
# FAR: 0.0
# MIR: 0.14102564102564102
# FRR: 0.0
# latency: 51376 ms
# ==== Session #2 ====
# # of detection: 63, acceptance: 59, rejection: 4
# # of FA: 0
# # of FR: 4
# # of MI: 8
# FAR: 0.0
# MIR: 0.12698412698412698
# FRR: 0.06349206349206349
# latency: 30747 ms
# simulation result: FAR: 0.0
# MIR: 0.13725490196078433
# FNR: 0.0196078431372549
# latency: 41886.666666666664 ms
# [touch] case: 27, er: 3, em: 0, fr: 6, mi: 1,
# [gait] case: 27, er: 6, em: 0, fr: 6, mi: 0,
# [simple_average] case: 27, er: 7, em: 0, fr: 9, mi: 0,
# [weighted_average_eer] case: 27, er: 5, em: 0, fr: 7, mi: 0,
# [weighted_average_auc] case: 27, er: 6, em: 0, fr: 10, mi: 0,
# [deer_dempster_shafer] case: 27, er: 3, em: 0, fr: 5, mi: 0,
# [auc_dempster_shafer] case: 27, er: 3, em: 0, fr: 6, mi: 0,
# [kalman_filter] case: 27, er: 2, em: 2, fr: 7, mi: 1,
#
# file saved.
# ========== SETUP ===========
# Game name:100_10100_10_0_3
# Negative trainer seed:100
# Game seed:10100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:693572 (0), 336172 (1), 777078 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.78      0.84        27
#            1       1.00      0.78      0.88         9
#            2       0.69      1.00      0.82         9
#            3       0.73      0.89      0.80         9
#
#     accuracy                           0.83        54
#    macro avg       0.83      0.86      0.83        54
# weighted avg       0.86      0.83      0.84        54
#
# Epoch 1/25
# 132/132 [==============================] - 6s 17ms/step - loss: 0.8889 - categorical_accuracy: 0.6808
# Epoch 2/25
# 132/132 [==============================] - 2s 17ms/step - loss: 0.5371 - categorical_accuracy: 0.7935
# Epoch 3/25
# 132/132 [==============================] - 2s 17ms/step - loss: 0.4099 - categorical_accuracy: 0.8418
# Epoch 4/25
# 132/132 [==============================] - 2s 17ms/step - loss: 0.3313 - categorical_accuracy: 0.8727
# Epoch 5/25
# 132/132 [==============================] - 2s 17ms/step - loss: 0.2822 - categorical_accuracy: 0.8951
# Epoch 6/25
# 132/132 [==============================] - 2s 16ms/step - loss: 0.2549 - categorical_accuracy: 0.9042
# Epoch 7/25
# 132/132 [==============================] - 2s 17ms/step - loss: 0.2078 - categorical_accuracy: 0.9240
# Epoch 8/25
# ...
# [simple_average] case: 165, er: 24, em: 4, fr: 30, mi: 5,
# [weighted_average_eer] case: 165, er: 16, em: 4, fr: 23, mi: 7,
# [weighted_average_auc] case: 165, er: 20, em: 4, fr: 30, mi: 5,
# [deer_dempster_shafer] case: 165, er: 17, em: 4, fr: 21, mi: 6,
# [auc_dempster_shafer] case: 165, er: 19, em: 4, fr: 21, mi: 5,
# [kalman_filter] case: 165, er: 16, em: 16, fr: 22, mi: 18,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14700_10_0_3
# Negative trainer seed:100
# Game seed:14700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:856401 (0), 220962 (1), 720193 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.87      0.51      0.65        39
#            1       0.67      0.77      0.71        13
#            2       0.45      0.77      0.57        13
#            3       0.61      0.85      0.71        13
#
#     accuracy                           0.65        78
#    macro avg       0.65      0.72      0.66        78
# weighted avg       0.72      0.65      0.66        78
#
# Epoch 1/25
# 123/123 [==============================] - 6s 17ms/step - loss: 0.6964 - categorical_accuracy: 0.7286
# Epoch 2/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.3958 - categorical_accuracy: 0.8499
# Epoch 3/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.2775 - categorical_accuracy: 0.8987
# Epoch 4/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.2327 - categorical_accuracy: 0.9153
# Epoch 5/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.2036 - categorical_accuracy: 0.9294
# Epoch 6/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1906 - categorical_accuracy: 0.9338
# Epoch 7/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1520 - categorical_accuracy: 0.9447
# Epoch 8/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1369 - categorical_accuracy: 0.9493
# Epoch 9/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1272 - categorical_accuracy: 0.9532
# Epoch 10/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1119 - categorical_accuracy: 0.9595
# Epoch 11/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.1010 - categorical_accuracy: 0.9640
# Epoch 12/25
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0785 - categorical_accuracy: 0.9728
# Epoch 13/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0693 - categorical_accuracy: 0.9756
# Epoch 14/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0662 - categorical_accuracy: 0.9763
# Epoch 15/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0633 - categorical_accuracy: 0.9781
# Epoch 16/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0483 - categorical_accuracy: 0.9826
# Epoch 17/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0396 - categorical_accuracy: 0.9868
# Epoch 18/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0397 - categorical_accuracy: 0.9853
# Epoch 19/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0393 - categorical_accuracy: 0.9868
# Epoch 20/25
# 123/123 [==============================] - 2s 16ms/step - loss: 0.0380 - categorical_accuracy: 0.9875
# Epoch 21/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0358 - categorical_accuracy: 0.9893
# Epoch 22/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0438 - categorical_accuracy: 0.9862
# Epoch 23/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0339 - categorical_accuracy: 0.9883
# Epoch 24/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0269 - categorical_accuracy: 0.9913
# Epoch 25/25
# 123/123 [==============================] - 2s 17ms/step - loss: 0.0147 - categorical_accuracy: 0.9966
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.81      0.87       870
#          1.0       0.88      0.96      0.92       290
#          2.0       0.92      0.93      0.93       290
#          3.0       0.71      0.91      0.80       290
#
#     accuracy                           0.87      1740
#    macro avg       0.86      0.90      0.88      1740
# weighted avg       0.88      0.87      0.87      1740
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 42, acceptance: 42, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 5
# FAR: 0.0
# MIR: 0.11904761904761904
# FRR: 0.0
# latency: 48867 ms
# ==== Session #1 ====
# # of detection: 68, acceptance: 68, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.10294117647058823
# FRR: 0.0
# latency: 51290 ms
# ==== Session #2 ====
# # of detection: 56, acceptance: 56, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 11
# FAR: 0.0
# MIR: 0.19642857142857142
# FRR: 0.0
# latency: 62475 ms
# simulation result: FAR: 0.0
# MIR: 0.13855421686746988
# FNR: 0.0
# latency: 54210.666666666664 ms
# [touch] case: 168, er: 25, em: 3, fr: 28, mi: 11,
# [gait] case: 168, er: 15, em: 4, fr: 17, mi: 5,
# [simple_average] case: 168, er: 24, em: 4, fr: 30, mi: 5,
# [weighted_average_eer] case: 168, er: 16, em: 4, fr: 23, mi: 7,
# [weighted_average_auc] case: 168, er: 20, em: 4, fr: 30, mi: 5,
# [deer_dempster_shafer] case: 168, er: 17, em: 4, fr: 21, mi: 6,
# [auc_dempster_shafer] case: 168, er: 19, em: 4, fr: 21, mi: 5,
# [kalman_filter] case: 168, er: 16, em: 16, fr: 22, mi: 18,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14800_10_0_3
# Negative trainer seed:100
# Game seed:14800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:342329 (0), 539502 (1), 663153 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.89      0.82      0.85        39
#            1       0.60      0.69      0.64        13
#            2       0.81      1.00      0.90        13
#            3       1.00      0.85      0.92        13
#
#     accuracy                           0.83        78
#    macro avg       0.83      0.84      0.83        78
# weighted avg       0.85      0.83      0.84        78
#
# Epoch 1/25
# 72/72 [==============================] - 4s 17ms/step - loss: 1.1823 - categorical_accuracy: 0.5546
# Epoch 2/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.8819 - categorical_accuracy: 0.6296
# Epoch 3/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.7626 - categorical_accuracy: 0.7054
# Epoch 4/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.7485 - categorical_accuracy: 0.7114
# Epoch 5/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.5882 - categorical_accuracy: 0.7770
# Epoch 6/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.5258 - categorical_accuracy: 0.7997
# Epoch 7/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.4367 - categorical_accuracy: 0.8350
# Epoch 8/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.3754 - categorical_accuracy: 0.8570
# Epoch 9/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.3342 - categorical_accuracy: 0.8762
# Epoch 10/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.3495 - categorical_accuracy: 0.8689
# Epoch 11/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.2646 - categorical_accuracy: 0.9029
# Epoch 12/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.2659 - categorical_accuracy: 0.9024
# Epoch 13/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.2413 - categorical_accuracy: 0.9106
# Epoch 14/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.1840 - categorical_accuracy: 0.9338
# Epoch 15/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.1434 - categorical_accuracy: 0.9507
# Epoch 16/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.1414 - categorical_accuracy: 0.9518
# Epoch 17/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.1021 - categorical_accuracy: 0.9655
# Epoch 18/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.1001 - categorical_accuracy: 0.9677
# Epoch 19/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0606 - categorical_accuracy: 0.9820
# Epoch 20/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0397 - categorical_accuracy: 0.9920
# Epoch 21/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0419 - categorical_accuracy: 0.9880
# Epoch 22/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0696 - categorical_accuracy: 0.9765
# Epoch 23/25
# 72/72 [==============================] - 1s 16ms/step - loss: 0.0535 - categorical_accuracy: 0.9842
# Epoch 24/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0234 - categorical_accuracy: 0.9953
# Epoch 25/25
# 72/72 [==============================] - 1s 17ms/step - loss: 0.0150 - categorical_accuracy: 0.9981
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.79      0.79       504
#          1.0       0.84      0.58      0.69       168
#          2.0       0.73      0.81      0.77       168
#          3.0       0.78      0.98      0.87       168
#
#     accuracy                           0.79      1008
#    macro avg       0.79      0.79      0.78      1008
# weighted avg       0.79      0.79      0.78      1008
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 73, acceptance: 64, rejection: 9
# # of FA: 0
# # of FR: 9
# # of MI: 11
# FAR: 0.0
# MIR: 0.1506849315068493
# FRR: 0.1232876712328767
# latency: 36415 ms
# ==== Session #1 ====
# # of detection: 61, acceptance: 61, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 7
# FAR: 0.0
# MIR: 0.11475409836065574
# FRR: 0.0
# latency: 42912 ms
# ==== Session #2 ====
# # of detection: 69, acceptance: 61, rejection: 8
# # of FA: 0
# # of FR: 8
# # of MI: 4
# FAR: 0.0
# MIR: 0.057971014492753624
# FRR: 0.11594202898550725
# latency: 14055 ms
# simulation result: FAR: 0.0
# MIR: 0.10837438423645321
# FNR: 0.08374384236453201
# latency: 31127.333333333332 ms
# [touch] case: 171, er: 27, em: 3, fr: 28, mi: 11,
# [gait] case: 171, er: 15, em: 4, fr: 17, mi: 5,
# [simple_average] case: 171, er: 25, em: 4, fr: 31, mi: 5,
# [weighted_average_eer] case: 171, er: 17, em: 4, fr: 24, mi: 7,
# [weighted_average_auc] case: 171, er: 21, em: 4, fr: 31, mi: 5,
# [deer_dempster_shafer] case: 171, er: 18, em: 4, fr: 22, mi: 6,
# [auc_dempster_shafer] case: 171, er: 20, em: 4, fr: 22, mi: 5,
# [kalman_filter] case: 171, er: 17, em: 16, fr: 23, mi: 18,
#
# file saved.
# ========== SETUP ===========
# Game name:100_14900_10_0_3
# Negative trainer seed:100
# Game seed:14900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:594887 (0), 771782 (1), 862649 (2)
# testers:
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.82      0.80      0.81        81
#            1       0.62      0.78      0.69        27
#            2       0.83      0.89      0.86        27
#            3       0.85      0.63      0.72        27
#
#     accuracy                           0.78       162
#    macro avg       0.78      0.77      0.77       162
# weighted avg       0.79      0.78      0.78       162
#
# Epoch 1/25
# 158/158 [==============================] - 6s 17ms/step - loss: 1.0542 - categorical_accuracy: 0.5581
# Epoch 2/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.6561 - categorical_accuracy: 0.7064
# Epoch 3/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.5498 - categorical_accuracy: 0.7707
# Epoch 4/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.4581 - categorical_accuracy: 0.8181
# Epoch 5/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.3813 - categorical_accuracy: 0.8513
# Epoch 6/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.3234 - categorical_accuracy: 0.8766
# Epoch 7/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2869 - categorical_accuracy: 0.8940
# Epoch 8/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2403 - categorical_accuracy: 0.9071
# Epoch 9/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.2035 - categorical_accuracy: 0.9239
# Epoch 10/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.1739 - categorical_accuracy: 0.9356
# Epoch 11/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.1526 - categorical_accuracy: 0.9449
# Epoch 12/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.1243 - categorical_accuracy: 0.9555
# Epoch 13/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.1079 - categorical_accuracy: 0.9609
# Epoch 14/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0880 - categorical_accuracy: 0.9689
# Epoch 15/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0668 - categorical_accuracy: 0.9764
# Epoch 16/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0997 - categorical_accuracy: 0.9630
# Epoch 17/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.1340 - categorical_accuracy: 0.9542
# Epoch 18/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0774 - categorical_accuracy: 0.9731
# Epoch 19/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0392 - categorical_accuracy: 0.9870
# Epoch 20/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0200 - categorical_accuracy: 0.9949
# Epoch 21/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0124 - categorical_accuracy: 0.9973
# Epoch 22/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0175 - categorical_accuracy: 0.9956
# Epoch 23/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0637 - categorical_accuracy: 0.9772
# Epoch 24/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0408 - categorical_accuracy: 0.9858
# Epoch 25/25
# 158/158 [==============================] - 3s 17ms/step - loss: 0.0589 - categorical_accuracy: 0.9791
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.45      0.60      1122
#          1.0       0.71      0.99      0.83       374
#          2.0       0.50      0.94      0.65       374
#          3.0       0.60      0.75      0.67       374
#
#     accuracy                           0.67      2244
#    macro avg       0.68      0.78      0.69      2244
# weighted avg       0.76      0.67      0.66      2244
#
# training done
# Not found
# ==== Session #0 ====
# # of detection: 89, acceptance: 40, rejection: 49
# # of FA: 0
# # of FR: 49
# # of MI: 0
# FAR: 0.0
# MIR: 0.0
# FRR: 0.550561797752809
# latency: 28105 ms
# ==== Session #1 ====
# # of detection: 117, acceptance: 117, rejection: 0
# # of FA: 0
# # of FR: 0
# # of MI: 15
# FAR: 0.0
# MIR: 0.1282051282051282
# FRR: 0.0
# latency: 21744 ms
# ==== Session #2 ====
# # of detection: 66, acceptance: 55, rejection: 11
# # of FA: 0
# # of FR: 11
# # of MI: 1
# FAR: 0.0
# MIR: 0.015151515151515152
# FRR: 0.16666666666666666
# latency: 24929 ms
# simulation result: FAR: 0.0
# MIR: 0.058823529411764705
# FNR: 0.22058823529411764
# latency: 24926.0 ms
# [touch] case: 174, er: 27, em: 3, fr: 30, mi: 11,
# [gait] case: 174, er: 16, em: 4, fr: 18, mi: 5,
# [simple_average] case: 174, er: 26, em: 4, fr: 32, mi: 5,
# [weighted_average_eer] case: 174, er: 18, em: 4, fr: 25, mi: 7,
# [weighted_average_auc] case: 174, er: 22, em: 4, fr: 32, mi: 5,
# [deer_dempster_shafer] case: 174, er: 19, em: 4, fr: 23, mi: 6,
# [auc_dempster_shafer] case: 174, er: 21, em: 4, fr: 23, mi: 5,
# [kalman_filter] case: 174, er: 18, em: 16, fr: 24, mi: 18,
#
# file saved.

# %%
#@title Experiment 2.1: 10 users 2 + 2 training sessions

experiment_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_user_switch_experiment_limit(seed, 10, 2, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/user_switch_10_2_limit", str(seed)))

# %%
#@title Experiment 2.1: 5 users 2 + 2 training sessions

experiment_result = None

for seed in range(0, 5000, 100):
    tml, player = run_topic_user_switch_experiment_limit(seed, 5, 2, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/user_switch_5_2_limit", str(seed)))

# %%
def run_topic_switch_attack_experiment_limit(game_seed=0, n_balanced=3,
                                           n_train_session=2, limit=180000):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================

    num_testers = n_balanced
    num_valid_users = n_balanced

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                          str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    for user in valid_users:
        gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

        touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

        enrollment_script_type_1.append((user, 'gait', gait_sessions))
        enrollment_script_type_1.append((user, 'touch', touch_sessions))

    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================

    for m in range(len(valid_users)):
        user_a = valid_users[m]
        user_b = testers[m]
        # for n in range(m + 1, len(valid_users)):
        #     user_b = valid_users[n]
        #     if user_a == user_b:
        #         continue
        #     sel_session = hmog.get_sessions_for_unloaded_user(
        #         user_a,[hmog.ACTIVITY_READING_WALKING])[-i]
        #     events = get_events_for_user_session_with_limit(user_a, sel_session, tml.end_time, limit)
        #     tml.add_special_event(EVENT_SESSION_START, [])
        #     tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

        #     sel_session = hmog.get_sessions_for_unloaded_user(
        #         user_b,[hmog.ACTIVITY_READING_WALKING])[-i]
        #     events = get_events_for_user_session_with_limit(user_b, sel_session, tml.end_time, limit)
        #     tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
        #     tml.add_special_event(EVENT_SESSION_END, [])
        #     i = i + 1
        sel_session = hmog.get_sessions_for_unloaded_user(
            user_a,[hmog.ACTIVITY_READING_WALKING])[-1]
        events = get_events_for_user_session_with_limit(user_a, sel_session, tml.end_time, limit)
        tml.add_special_event(EVENT_SESSION_START, [])
        tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

        sel_session = hmog.get_sessions_for_unloaded_user(
            user_b,[hmog.ACTIVITY_READING_WALKING])[-1]
        events = get_events_for_user_session_with_limit(user_b, sel_session, tml.end_time, limit)
        tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
        tml.add_special_event(EVENT_SESSION_END, [])


    # ===============================================
    # 5. One line running script
    # ===============================================

    results = script_runner(tml, player)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    return tml, player

# %%
#@title Experiment 2.2: 2 + 2 training sessions

experiment_result = None

for seed in range(0, 15000, 100):
    tml, player = run_topic_switch_attack_experiment_limit(seed, 3, 3, 180000)
    score_pairs = gen_decisions_by_segment(tml, player, segment_by_session_end(tml))
    result_met = {i: get_metrics_for_experiment2(score_pairs[i], (7, 4))
                  for i in score_pairs.keys()}
    if experiment_result is None:
        experiment_result = result_met
    else:
        for i, score in result_met.items():
            for j, sc in score.items():
                experiment_result[i][j] += sc
    to_display = ""
    for key, item in experiment_result.items():
        to_display += "[" + key + "] "
        for metr, value in item.items():
            if metr == 'latency':
                continue
            to_display += metr + ": " + str(value) + ", "
        to_display += "\r\n"
    print(to_display)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results2022/attack_switch_3_3_limit", str(seed)))
# Out:
# Streaming output truncated to the last 5000 lines.
# file saved.
# ========== SETUP ===========
# Game name:100_1600_10_3_3
# Negative trainer seed:100
# Game seed:1600
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:913228 (0), 986737 (1), 277905 (2)
# testers:257279, 171538, 693572
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.97      0.84      0.90        45
#            1       0.82      0.93      0.87        15
#            2       0.79      1.00      0.88        15
#            3       1.00      1.00      1.00        15
#
#     accuracy                           0.91        90
#    macro avg       0.90      0.94      0.92        90
# weighted avg       0.92      0.91      0.91        90
#
# Epoch 1/25
# 9/9 [==============================] - 4s 20ms/step - loss: 2.9455 - categorical_accuracy: 0.3722
# Epoch 2/25
# 9/9 [==============================] - 0s 18ms/step - loss: 1.1321 - categorical_accuracy: 0.5204
# Epoch 3/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.9097 - categorical_accuracy: 0.5907
# Epoch 4/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.7903 - categorical_accuracy: 0.6435
# Epoch 5/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.7273 - categorical_accuracy: 0.6694
# Epoch 6/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.6895 - categorical_accuracy: 0.7083
# Epoch 7/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6430 - categorical_accuracy: 0.7222
# Epoch 8/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.6407 - categorical_accuracy: 0.7361
# Epoch 9/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5713 - categorical_accuracy: 0.7620
# Epoch 10/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5588 - categorical_accuracy: 0.7750
# Epoch 11/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.5430 - categorical_accuracy: 0.7630
# Epoch 12/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4971 - categorical_accuracy: 0.7806
# Epoch 13/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.4600 - categorical_accuracy: 0.8120
# Epoch 14/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.4067 - categorical_accuracy: 0.8444
# Epoch 15/25
# 9/9 [==============================] - 0s 19ms/step - loss: 0.3922 - categorical_accuracy: 0.8324
# Epoch 16/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3944 - categorical_accuracy: 0.8519
# Epoch 17/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3721 - categorical_accuracy: 0.8546
# Epoch 18/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3790 - categorical_accuracy: 0.8500
# Epoch 19/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3285 - categorical_accuracy: 0.8759
# Epoch 20/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3500 - categorical_accuracy: 0.8722
# Epoch 21/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3362 - categorical_accuracy: 0.8750
# Epoch 22/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3103 - categorical_accuracy: 0.8815
# Epoch 23/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3029 - categorical_accuracy: 0.8722
# Epoch 24/25
# 9/9 [==============================] - 0s 18ms/step - loss: 0.3209 - categorical_accuracy: 0.8759
# Epoch 25/25
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3101 - categorical_accuracy: 0.8704
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.65      0.67        57
#          1.0       0.40      0.42      0.41        19
#          2.0       0.81      0.68      0.74        19
#          3.0       0.72      0.95      0.82        19
#
#     accuracy                           0.67       114
#    macro avg       0.66      0.68      0.66       114
# weighted avg       0.67      0.67      0.66       114
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 55, acceptance: 24, rejection: 31
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.14545454545454545
# MIR: 0.0
# FRR: 0.0
# latency: 77415 ms
# ==== Session #1 ====
# # of detection: 98, acceptance: 42, rejection: 56
# # of FA: 11
# # of FR: 9
# # of MI: 0
# FAR: 0.11224489795918367
# MIR: 0.0
# FRR: 0.09183673469387756
# latency: 22666 ms
# ==== Session #2 ====
# # of detection: 62, acceptance: 43, rejection: 19
# # of FA: 22
# # of FR: 0
# # of MI: 0
# FAR: 0.3548387096774194
# MIR: 0.0
# FRR: 0.0
# latency: 47747 ms
# simulation result: FAR: 0.19069767441860466
# MIR: 0.0
# FNR: 0.04186046511627907
# latency: 49276.0 ms
# [touch] case: 51, er: 12, em: 7, fr: 25, mi: 7,
# [gait] case: 51, er: 10, em: 2, fr: 25, mi: 13,
# [simple_average] case: 51, er: 12, em: 4, fr: 27, mi: 8,
# [weighted_average_eer] case: 51, er: 9, em: 4, fr: 27, mi: 11,
# [weighted_average_auc] case: 51, er: 10, em: 4, fr: 28, mi: 9,
# [deer_dempster_shafer] case: 51, er: 11, em: 3, fr: 31, mi: 6,
# [auc_dempster_shafer] case: 51, er: 11, em: 3, fr: 32, mi: 5,
# [kalman_filter] case: 51, er: 13, em: 3, fr: 31, mi: 4,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1700_10_3_3
# Negative trainer seed:100
# Game seed:1700
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:865501 (0), 553321 (1), 578526 (2)
# testers:698266, 962159, 863985
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.94      0.74      0.83        42
#            1       0.47      0.50      0.48        14
#            2       0.74      1.00      0.85        14
#            3       0.53      0.64      0.58        14
#
#     accuracy                           0.73        84
#    macro avg       0.67      0.72      0.68        84
# weighted avg       0.76      0.73      0.73        84
#
# Epoch 1/25
# 106/106 [==============================] - 6s 18ms/step - loss: 1.0200 - categorical_accuracy: 0.5870
# Epoch 2/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.7179 - categorical_accuracy: 0.6997
# Epoch 3/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.6445 - categorical_accuracy: 0.7345
# Epoch 4/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5778 - categorical_accuracy: 0.7684
# Epoch 5/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.5002 - categorical_accuracy: 0.8022
# Epoch 6/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.4310 - categorical_accuracy: 0.8313
# Epoch 7/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.3557 - categorical_accuracy: 0.8652
# Epoch 8/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.3020 - categorical_accuracy: 0.8847
# Epoch 9/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.3008 - categorical_accuracy: 0.8843
# Epoch 10/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.2089 - categorical_accuracy: 0.9230
# Epoch 11/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.2181 - categorical_accuracy: 0.9163
# Epoch 12/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1824 - categorical_accuracy: 0.9307
# Epoch 13/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1567 - categorical_accuracy: 0.9416
# Epoch 14/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1424 - categorical_accuracy: 0.9462
# Epoch 15/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1342 - categorical_accuracy: 0.9500
# Epoch 16/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1072 - categorical_accuracy: 0.9614
# Epoch 17/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0832 - categorical_accuracy: 0.9722
# Epoch 18/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0617 - categorical_accuracy: 0.9796
# Epoch 19/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0529 - categorical_accuracy: 0.9824
# Epoch 20/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0459 - categorical_accuracy: 0.9850
# Epoch 21/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0601 - categorical_accuracy: 0.9783
# Epoch 22/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.1007 - categorical_accuracy: 0.9636
# Epoch 23/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0581 - categorical_accuracy: 0.9799
# Epoch 24/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0250 - categorical_accuracy: 0.9925
# Epoch 25/25
# 106/106 [==============================] - 2s 18ms/step - loss: 0.0865 - categorical_accuracy: 0.9683
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.96      0.90       750
#          1.0       1.00      0.82      0.90       250
#          2.0       0.72      0.71      0.72       250
#          3.0       0.82      0.62      0.71       250
#
#     accuracy                           0.84      1500
#    macro avg       0.85      0.78      0.81      1500
# weighted avg       0.84      0.84      0.84      1500
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 90, acceptance: 74, rejection: 16
# # of FA: 52
# # of FR: 0
# # of MI: 0
# FAR: 0.5777777777777777
# MIR: 0.0
# FRR: 0.0
# latency: 46114 ms
# ==== Session #1 ====
# # of detection: 39, acceptance: 27, rejection: 12
# # of FA: 26
# # of FR: 6
# # of MI: 0
# FAR: 0.6666666666666666
# MIR: 0.0
# FRR: 0.15384615384615385
# latency: 176767 ms
# ==== Session #2 ====
# # of detection: 63, acceptance: 6, rejection: 57
# # of FA: 4
# # of FR: 24
# # of MI: 0
# FAR: 0.06349206349206349
# MIR: 0.0
# FRR: 0.38095238095238093
# latency: 171549 ms
# simulation result: FAR: 0.4270833333333333
# MIR: 0.0
# FNR: 0.15625
# latency: 131476.66666666666 ms
# [touch] case: 54, er: 12, em: 8, fr: 27, mi: 7,
# [gait] case: 54, er: 12, em: 2, fr: 25, mi: 13,
# [simple_average] case: 54, er: 14, em: 4, fr: 28, mi: 8,
# [weighted_average_eer] case: 54, er: 11, em: 4, fr: 28, mi: 11,
# [weighted_average_auc] case: 54, er: 12, em: 4, fr: 29, mi: 9,
# [deer_dempster_shafer] case: 54, er: 13, em: 3, fr: 32, mi: 6,
# [auc_dempster_shafer] case: 54, er: 13, em: 3, fr: 33, mi: 5,
# [kalman_filter] case: 54, er: 15, em: 3, fr: 31, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1800_10_3_3
# Negative trainer seed:100
# Game seed:1800
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:862649 (0), 986737 (1), 220962 (2)
# testers:863985, 923862, 218719
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.78      0.62      0.69        45
#            1       0.73      0.73      0.73        15
#            2       0.74      0.93      0.82        15
#            3       0.50      0.67      0.57        15
#
#     accuracy                           0.70        90
#    macro avg       0.69      0.74      0.70        90
# weighted avg       0.72      0.70      0.70        90
#
# Epoch 1/25
# 135/135 [==============================] - 7s 19ms/step - loss: 0.8830 - categorical_accuracy: 0.6533
# Epoch 2/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.6007 - categorical_accuracy: 0.7426
# Epoch 3/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.4602 - categorical_accuracy: 0.8140
# Epoch 4/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.3473 - categorical_accuracy: 0.8644
# Epoch 5/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.2857 - categorical_accuracy: 0.8938
# Epoch 6/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.2444 - categorical_accuracy: 0.9081
# Epoch 7/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.2023 - categorical_accuracy: 0.9241
# Epoch 8/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.1700 - categorical_accuracy: 0.9392
# Epoch 9/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.1352 - categorical_accuracy: 0.9521
# Epoch 10/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.1124 - categorical_accuracy: 0.9604
# Epoch 11/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0958 - categorical_accuracy: 0.9669
# Epoch 12/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0793 - categorical_accuracy: 0.9730
# Epoch 13/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0666 - categorical_accuracy: 0.9773
# Epoch 14/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0633 - categorical_accuracy: 0.9780
# Epoch 15/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0564 - categorical_accuracy: 0.9800
# Epoch 16/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0360 - categorical_accuracy: 0.9883
# Epoch 17/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0357 - categorical_accuracy: 0.9888
# Epoch 18/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0256 - categorical_accuracy: 0.9914
# Epoch 19/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0381 - categorical_accuracy: 0.9869
# Epoch 20/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0354 - categorical_accuracy: 0.9876
# Epoch 21/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0335 - categorical_accuracy: 0.9893
# Epoch 22/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0338 - categorical_accuracy: 0.9875
# Epoch 23/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0286 - categorical_accuracy: 0.9901
# Epoch 24/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0229 - categorical_accuracy: 0.9921
# Epoch 25/25
# 135/135 [==============================] - 2s 18ms/step - loss: 0.0172 - categorical_accuracy: 0.9944
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.87      0.81      0.84       957
#          1.0       0.67      0.76      0.71       319
#          2.0       0.90      0.96      0.93       319
#          3.0       0.85      0.88      0.87       319
#
#     accuracy                           0.84      1914
#    macro avg       0.82      0.85      0.84      1914
# weighted avg       0.84      0.84      0.84      1914
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 54, acceptance: 22, rejection: 32
# # of FA: 6
# # of FR: 1
# # of MI: 0
# FAR: 0.1111111111111111
# MIR: 0.0
# FRR: 0.018518518518518517
# latency: 71957 ms
# ==== Session #1 ====
# # of detection: 89, acceptance: 51, rejection: 38
# # of FA: 11
# # of FR: 0
# # of MI: 0
# FAR: 0.12359550561797752
# MIR: 0.0
# FRR: 0.0
# latency: 22666 ms
# ==== Session #2 ====
# # of detection: 69, acceptance: 23, rejection: 46
# # of FA: 9
# # of FR: 0
# # of MI: 0
# FAR: 0.13043478260869565
# MIR: 0.0
# FRR: 0.0
# latency: 62475 ms
# simulation result: FAR: 0.12264150943396226
# MIR: 0.0
# FNR: 0.0047169811320754715
# latency: 52366.0 ms
# [touch] case: 57, er: 12, em: 8, fr: 30, mi: 7,
# [gait] case: 57, er: 13, em: 2, fr: 27, mi: 13,
# [simple_average] case: 57, er: 16, em: 4, fr: 29, mi: 8,
# [weighted_average_eer] case: 57, er: 12, em: 4, fr: 30, mi: 11,
# [weighted_average_auc] case: 57, er: 14, em: 4, fr: 30, mi: 9,
# [deer_dempster_shafer] case: 57, er: 14, em: 3, fr: 34, mi: 6,
# [auc_dempster_shafer] case: 57, er: 14, em: 3, fr: 35, mi: 5,
# [kalman_filter] case: 57, er: 18, em: 3, fr: 31, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_1900_10_3_3
# Negative trainer seed:100
# Game seed:1900
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:796581 (0), 990622 (1), 777078 (2)
# testers:986737, 763813, 872895
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.91      0.74      0.82        27
#            1       0.60      1.00      0.75         9
#            2       0.88      0.78      0.82         9
#            3       0.78      0.78      0.78         9
#
#     accuracy                           0.80        54
#    macro avg       0.79      0.82      0.79        54
# weighted avg       0.83      0.80      0.80        54
#
# Epoch 1/25
# 104/104 [==============================] - 6s 18ms/step - loss: 1.1056 - categorical_accuracy: 0.5884
# Epoch 2/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.7284 - categorical_accuracy: 0.7111
# Epoch 3/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.5973 - categorical_accuracy: 0.7639
# Epoch 4/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.4657 - categorical_accuracy: 0.8223
# Epoch 5/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.3123 - categorical_accuracy: 0.8780
# Epoch 6/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.3010 - categorical_accuracy: 0.8808
# Epoch 7/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.2216 - categorical_accuracy: 0.9132
# Epoch 8/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1825 - categorical_accuracy: 0.9302
# Epoch 9/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1824 - categorical_accuracy: 0.9298
# Epoch 10/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1432 - categorical_accuracy: 0.9438
# Epoch 11/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.2488 - categorical_accuracy: 0.9056
# Epoch 12/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.2114 - categorical_accuracy: 0.9226
# Epoch 13/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.2160 - categorical_accuracy: 0.9221
# Epoch 14/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1356 - categorical_accuracy: 0.9500
# Epoch 15/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1223 - categorical_accuracy: 0.9566
# Epoch 16/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0961 - categorical_accuracy: 0.9661
# Epoch 17/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0713 - categorical_accuracy: 0.9767
# Epoch 18/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0603 - categorical_accuracy: 0.9816
# Epoch 19/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0616 - categorical_accuracy: 0.9788
# Epoch 20/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0641 - categorical_accuracy: 0.9771
# Epoch 21/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0402 - categorical_accuracy: 0.9867
# Epoch 22/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0650 - categorical_accuracy: 0.9766
# Epoch 23/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0436 - categorical_accuracy: 0.9850
# Epoch 24/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.1180 - categorical_accuracy: 0.9601
# Epoch 25/25
# 104/104 [==============================] - 2s 18ms/step - loss: 0.0220 - categorical_accuracy: 0.9943
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.91      0.76      0.83       732
#          1.0       0.72      0.98      0.83       244
#          2.0       0.71      0.91      0.80       244
#          3.0       0.98      0.84      0.90       244
#
#     accuracy                           0.83      1464
#    macro avg       0.83      0.87      0.84      1464
# weighted avg       0.86      0.83      0.84      1464
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 68, acceptance: 32, rejection: 36
# # of FA: 10
# # of FR: 0
# # of MI: 0
# FAR: 0.14705882352941177
# MIR: 0.0
# FRR: 0.0
# latency: 32410 ms
# ==== Session #1 ====
# # of detection: 71, acceptance: 46, rejection: 25
# # of FA: 1
# # of FR: 0
# # of MI: 0
# FAR: 0.014084507042253521
# MIR: 0.0
# FRR: 0.0
# latency: 41465 ms
# ==== Session #2 ====
# # of detection: 57, acceptance: 35, rejection: 22
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.12280701754385964
# MIR: 0.0
# FRR: 0.0
# latency: 30724 ms
# simulation result: FAR: 0.09183673469387756
# MIR: 0.0
# FNR: 0.0
# latency: 34866.333333333336 ms
# [touch] case: 60, er: 12, em: 8, fr: 32, mi: 8,
# [gait] case: 60, er: 14, em: 2, fr: 29, mi: 13,
# [simple_average] case: 60, er: 16, em: 4, fr: 32, mi: 8,
# [weighted_average_eer] case: 60, er: 12, em: 4, fr: 33, mi: 11,
# [weighted_average_auc] case: 60, er: 14, em: 4, fr: 33, mi: 9,
# [deer_dempster_shafer] case: 60, er: 14, em: 3, fr: 37, mi: 6,
# [auc_dempster_shafer] case: 60, er: 14, em: 3, fr: 38, mi: 5,
# [kalman_filter] case: 60, er: 18, em: 3, fr: 34, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2000_10_3_3
# Negative trainer seed:100
# Game seed:2000
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:540641 (0), 856401 (1), 796581 (2)
# testers:803262, 962159, 395129
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.94      0.81      0.87        36
#            1       0.73      0.92      0.81        12
#            2       0.83      0.83      0.83        12
#            3       0.86      1.00      0.92        12
#
#     accuracy                           0.86        72
#    macro avg       0.84      0.89      0.86        72
# weighted avg       0.87      0.86      0.86        72
#
# Epoch 1/25
# 137/137 [==============================] - 7s 19ms/step - loss: 0.8530 - categorical_accuracy: 0.6976
# Epoch 2/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.4107 - categorical_accuracy: 0.8506
# Epoch 3/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.2963 - categorical_accuracy: 0.8959
# Epoch 4/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.2735 - categorical_accuracy: 0.9030
# Epoch 5/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.1923 - categorical_accuracy: 0.9322
# Epoch 6/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.1626 - categorical_accuracy: 0.9420
# Epoch 7/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.1460 - categorical_accuracy: 0.9488
# Epoch 8/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.1155 - categorical_accuracy: 0.9593
# Epoch 9/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0846 - categorical_accuracy: 0.9724
# Epoch 10/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0801 - categorical_accuracy: 0.9719
# Epoch 11/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0602 - categorical_accuracy: 0.9781
# Epoch 12/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0507 - categorical_accuracy: 0.9821
# Epoch 13/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0487 - categorical_accuracy: 0.9837
# Epoch 14/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0481 - categorical_accuracy: 0.9857
# Epoch 15/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0422 - categorical_accuracy: 0.9861
# Epoch 16/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0299 - categorical_accuracy: 0.9913
# Epoch 17/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0248 - categorical_accuracy: 0.9921
# Epoch 18/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0333 - categorical_accuracy: 0.9884
# Epoch 19/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0202 - categorical_accuracy: 0.9935
# Epoch 20/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0174 - categorical_accuracy: 0.9947
# Epoch 21/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0155 - categorical_accuracy: 0.9948
# Epoch 22/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0308 - categorical_accuracy: 0.9907
# Epoch 23/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0384 - categorical_accuracy: 0.9873
# Epoch 24/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0261 - categorical_accuracy: 0.9919
# Epoch 25/25
# 137/137 [==============================] - 2s 18ms/step - loss: 0.0158 - categorical_accuracy: 0.9948
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.76      0.85       972
#          1.0       0.73      0.97      0.83       324
#          2.0       0.95      0.97      0.96       324
#          3.0       0.74      0.99      0.85       324
#
#     accuracy                           0.86      1944
#    macro avg       0.85      0.92      0.87      1944
# weighted avg       0.89      0.86      0.87      1944
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 56, acceptance: 28, rejection: 28
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.14285714285714285
# MIR: 0.0
# FRR: 0.0
# latency: 51603 ms
# ==== Session #1 ====
# # of detection: 55, acceptance: 28, rejection: 27
# # of FA: 6
# # of FR: 0
# # of MI: 0
# FAR: 0.10909090909090909
# MIR: 0.0
# FRR: 0.0
# latency: 48867 ms
# ==== Session #2 ====
# # of detection: 47, acceptance: 29, rejection: 18
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.14893617021276595
# MIR: 0.0
# FRR: 0.0
# latency: 32410 ms
# simulation result: FAR: 0.13291139240506328
# MIR: 0.0
# FNR: 0.0
# latency: 44293.333333333336 ms
# [touch] case: 63, er: 12, em: 8, fr: 34, mi: 8,
# [gait] case: 63, er: 14, em: 2, fr: 32, mi: 13,
# [simple_average] case: 63, er: 16, em: 4, fr: 35, mi: 8,
# [weighted_average_eer] case: 63, er: 12, em: 4, fr: 36, mi: 11,
# [weighted_average_auc] case: 63, er: 14, em: 4, fr: 36, mi: 9,
# [deer_dempster_shafer] case: 63, er: 14, em: 3, fr: 40, mi: 6,
# [auc_dempster_shafer] case: 63, er: 14, em: 3, fr: 41, mi: 5,
# [kalman_filter] case: 63, er: 18, em: 3, fr: 37, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2100_10_3_3
# Negative trainer seed:100
# Game seed:2100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:405035 (0), 538363 (1), 966655 (2)
# testers:893198, 785873, 553321
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.79      0.70      0.74        90
#            1       0.49      0.57      0.52        30
#            2       0.45      0.43      0.44        30
#            3       0.72      0.87      0.79        30
#
#     accuracy                           0.66       180
#    macro avg       0.61      0.64      0.62       180
# weighted avg       0.67      0.66      0.66       180
#
# Epoch 1/25
# 162/162 [==============================] - 7s 18ms/step - loss: 0.7620 - categorical_accuracy: 0.6870
# Epoch 2/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.4994 - categorical_accuracy: 0.8023
# Epoch 3/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.4039 - categorical_accuracy: 0.8455
# Epoch 4/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.3385 - categorical_accuracy: 0.8778
# Epoch 5/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.2914 - categorical_accuracy: 0.8957
# Epoch 6/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.2483 - categorical_accuracy: 0.9118
# Epoch 7/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.2196 - categorical_accuracy: 0.9230
# Epoch 8/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1980 - categorical_accuracy: 0.9279
# Epoch 9/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1731 - categorical_accuracy: 0.9391
# Epoch 10/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1728 - categorical_accuracy: 0.9389
# Epoch 11/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1403 - categorical_accuracy: 0.9520
# Epoch 12/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1420 - categorical_accuracy: 0.9511
# Epoch 13/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1251 - categorical_accuracy: 0.9553
# Epoch 14/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.1067 - categorical_accuracy: 0.9628
# Epoch 15/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0880 - categorical_accuracy: 0.9702
# Epoch 16/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0795 - categorical_accuracy: 0.9713
# Epoch 17/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0732 - categorical_accuracy: 0.9742
# Epoch 18/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0621 - categorical_accuracy: 0.9785
# Epoch 19/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0594 - categorical_accuracy: 0.9794
# Epoch 20/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0485 - categorical_accuracy: 0.9838
# Epoch 21/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0403 - categorical_accuracy: 0.9863
# Epoch 22/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0289 - categorical_accuracy: 0.9907
# Epoch 23/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0405 - categorical_accuracy: 0.9853
# Epoch 24/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0473 - categorical_accuracy: 0.9837
# Epoch 25/25
# 162/162 [==============================] - 3s 18ms/step - loss: 0.0326 - categorical_accuracy: 0.9889
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.93      0.93      1149
#          1.0       0.98      0.91      0.94       383
#          2.0       0.82      0.88      0.85       383
#          3.0       0.95      0.98      0.97       383
#
#     accuracy                           0.93      2298
#    macro avg       0.92      0.92      0.92      2298
# weighted avg       0.93      0.93      0.93      2298
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 78, acceptance: 45, rejection: 33
# # of FA: 12
# # of FR: 0
# # of MI: 0
# FAR: 0.15384615384615385
# MIR: 0.0
# FRR: 0.0
# latency: 41026 ms
# ==== Session #1 ====
# # of detection: 61, acceptance: 44, rejection: 17
# # of FA: 13
# # of FR: 0
# # of MI: 0
# FAR: 0.21311475409836064
# MIR: 0.0
# FRR: 0.0
# latency: 41029 ms
# ==== Session #2 ====
# # of detection: 75, acceptance: 70, rejection: 5
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.09333333333333334
# MIR: 0.0
# FRR: 0.0
# latency: 31558 ms
# simulation result: FAR: 0.14953271028037382
# MIR: 0.0
# FNR: 0.0
# latency: 37871.0 ms
# [touch] case: 66, er: 12, em: 10, fr: 35, mi: 8,
# [gait] case: 66, er: 14, em: 2, fr: 34, mi: 14,
# [simple_average] case: 66, er: 16, em: 4, fr: 38, mi: 8,
# [weighted_average_eer] case: 66, er: 12, em: 4, fr: 39, mi: 11,
# [weighted_average_auc] case: 66, er: 14, em: 4, fr: 39, mi: 9,
# [deer_dempster_shafer] case: 66, er: 14, em: 3, fr: 43, mi: 6,
# [auc_dempster_shafer] case: 66, er: 14, em: 3, fr: 44, mi: 5,
# [kalman_filter] case: 66, er: 18, em: 3, fr: 40, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2200_10_3_3
# Negative trainer seed:100
# Game seed:2200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:248252 (0), 763813 (1), 171538 (2)
# testers:218719, 554303, 151985
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96        81
#            1       0.76      0.81      0.79        27
#            2       0.81      0.96      0.88        27
#            3       1.00      0.78      0.88        27
#
#     accuracy                           0.90       162
#    macro avg       0.88      0.88      0.87       162
# weighted avg       0.91      0.90      0.90       162
#
# Epoch 1/25
# 81/81 [==============================] - 6s 18ms/step - loss: 1.2107 - categorical_accuracy: 0.5369
# Epoch 2/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.8147 - categorical_accuracy: 0.6673
# Epoch 3/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.6397 - categorical_accuracy: 0.7488
# Epoch 4/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.5189 - categorical_accuracy: 0.7952
# Epoch 5/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.4851 - categorical_accuracy: 0.8140
# Epoch 6/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.4291 - categorical_accuracy: 0.8342
# Epoch 7/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.4143 - categorical_accuracy: 0.8413
# Epoch 8/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.3252 - categorical_accuracy: 0.8757
# Epoch 9/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.2676 - categorical_accuracy: 0.9019
# Epoch 10/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.2268 - categorical_accuracy: 0.9147
# Epoch 11/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.1908 - categorical_accuracy: 0.9306
# Epoch 12/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.1827 - categorical_accuracy: 0.9344
# Epoch 13/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.1594 - categorical_accuracy: 0.9396
# Epoch 14/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.1353 - categorical_accuracy: 0.9496
# Epoch 15/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.1086 - categorical_accuracy: 0.9610
# Epoch 16/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0918 - categorical_accuracy: 0.9683
# Epoch 17/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0712 - categorical_accuracy: 0.9758
# Epoch 18/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0752 - categorical_accuracy: 0.9738
# Epoch 19/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0530 - categorical_accuracy: 0.9827
# Epoch 20/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0457 - categorical_accuracy: 0.9861
# Epoch 21/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0385 - categorical_accuracy: 0.9891
# Epoch 22/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0325 - categorical_accuracy: 0.9899
# Epoch 23/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0260 - categorical_accuracy: 0.9938
# Epoch 24/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0197 - categorical_accuracy: 0.9953
# Epoch 25/25
# 81/81 [==============================] - 1s 18ms/step - loss: 0.0216 - categorical_accuracy: 0.9948
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.67      0.71       567
#          1.0       0.49      0.89      0.64       189
#          2.0       0.88      0.64      0.74       189
#          3.0       0.79      0.63      0.70       189
#
#     accuracy                           0.69      1134
#    macro avg       0.73      0.71      0.70      1134
# weighted avg       0.74      0.69      0.70      1134
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 101, acceptance: 51, rejection: 50
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.04950495049504951
# MIR: 0.0
# FRR: 0.0
# latency: 39151 ms
# ==== Session #1 ====
# # of detection: 72, acceptance: 24, rejection: 48
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.06944444444444445
# MIR: 0.0
# FRR: 0.0
# latency: 51300 ms
# ==== Session #2 ====
# # of detection: 89, acceptance: 49, rejection: 40
# # of FA: 5
# # of FR: 6
# # of MI: 0
# FAR: 0.056179775280898875
# MIR: 0.0
# FRR: 0.06741573033707865
# latency: 53015 ms
# simulation result: FAR: 0.05725190839694656
# MIR: 0.0
# FNR: 0.022900763358778626
# latency: 47822.0 ms
# [touch] case: 69, er: 13, em: 10, fr: 37, mi: 8,
# [gait] case: 69, er: 14, em: 2, fr: 36, mi: 15,
# [simple_average] case: 69, er: 17, em: 4, fr: 40, mi: 8,
# [weighted_average_eer] case: 69, er: 13, em: 4, fr: 41, mi: 11,
# [weighted_average_auc] case: 69, er: 15, em: 4, fr: 41, mi: 9,
# [deer_dempster_shafer] case: 69, er: 15, em: 3, fr: 45, mi: 6,
# [auc_dempster_shafer] case: 69, er: 14, em: 3, fr: 47, mi: 5,
# [kalman_filter] case: 69, er: 20, em: 3, fr: 41, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2300_10_3_3
# Negative trainer seed:100
# Game seed:2300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:785873 (0), 693572 (1), 186676 (2)
# testers:893198, 657486, 180679
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.80      0.93      0.86        42
#            1       0.71      0.71      0.71        14
#            2       1.00      0.86      0.92        14
#            3       1.00      0.64      0.78        14
#
#     accuracy                           0.83        84
#    macro avg       0.88      0.79      0.82        84
# weighted avg       0.85      0.83      0.83        84
#
# Epoch 1/25
# 133/133 [==============================] - 6s 19ms/step - loss: 0.9031 - categorical_accuracy: 0.6551
# Epoch 2/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.5386 - categorical_accuracy: 0.7857
# Epoch 3/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.4407 - categorical_accuracy: 0.8263
# Epoch 4/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.3481 - categorical_accuracy: 0.8664
# Epoch 5/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.2860 - categorical_accuracy: 0.8904
# Epoch 6/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.2542 - categorical_accuracy: 0.9048
# Epoch 7/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.2165 - categorical_accuracy: 0.9173
# Epoch 8/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.1890 - categorical_accuracy: 0.9257
# Epoch 9/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.1653 - categorical_accuracy: 0.9378
# Epoch 10/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.1521 - categorical_accuracy: 0.9443
# Epoch 11/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.1432 - categorical_accuracy: 0.9463
# Epoch 12/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.1175 - categorical_accuracy: 0.9567
# Epoch 13/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0950 - categorical_accuracy: 0.9644
# Epoch 14/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0885 - categorical_accuracy: 0.9665
# Epoch 15/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0819 - categorical_accuracy: 0.9700
# Epoch 16/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0773 - categorical_accuracy: 0.9708
# Epoch 17/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0581 - categorical_accuracy: 0.9808
# Epoch 18/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0550 - categorical_accuracy: 0.9807
# Epoch 19/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0772 - categorical_accuracy: 0.9716
# Epoch 20/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0409 - categorical_accuracy: 0.9864
# Epoch 21/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0443 - categorical_accuracy: 0.9843
# Epoch 22/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0389 - categorical_accuracy: 0.9876
# Epoch 23/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0364 - categorical_accuracy: 0.9876
# Epoch 24/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0249 - categorical_accuracy: 0.9919
# Epoch 25/25
# 133/133 [==============================] - 2s 18ms/step - loss: 0.0330 - categorical_accuracy: 0.9885
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.78      0.84       942
#          1.0       0.68      0.84      0.75       314
#          2.0       0.80      0.93      0.86       314
#          3.0       0.96      0.95      0.96       314
#
#     accuracy                           0.84      1884
#    macro avg       0.83      0.88      0.85      1884
# weighted avg       0.86      0.84      0.84      1884
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 69, acceptance: 34, rejection: 35
# # of FA: 10
# # of FR: 0
# # of MI: 0
# FAR: 0.14492753623188406
# MIR: 0.0
# FRR: 0.0
# latency: 51288 ms
# ==== Session #1 ====
# # of detection: 68, acceptance: 43, rejection: 25
# # of FA: 10
# # of FR: 0
# # of MI: 0
# FAR: 0.14705882352941177
# MIR: 0.0
# FRR: 0.0
# latency: 36928 ms
# ==== Session #2 ====
# # of detection: 57, acceptance: 25, rejection: 32
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.07017543859649122
# MIR: 0.0
# FRR: 0.0
# latency: 41183 ms
# simulation result: FAR: 0.12371134020618557
# MIR: 0.0
# FNR: 0.0
# latency: 43133.0 ms
# [touch] case: 72, er: 13, em: 10, fr: 39, mi: 9,
# [gait] case: 72, er: 14, em: 2, fr: 39, mi: 15,
# [simple_average] case: 72, er: 17, em: 4, fr: 43, mi: 8,
# [weighted_average_eer] case: 72, er: 13, em: 4, fr: 44, mi: 11,
# [weighted_average_auc] case: 72, er: 15, em: 4, fr: 44, mi: 9,
# [deer_dempster_shafer] case: 72, er: 15, em: 3, fr: 48, mi: 6,
# [auc_dempster_shafer] case: 72, er: 14, em: 3, fr: 50, mi: 5,
# [kalman_filter] case: 72, er: 20, em: 3, fr: 44, mi: 5,
#
# file saved.
# ========== SETUP ===========
# Game name:100_2400_10_3_3
# Negative trainer seed:100
# Game seed:2400
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:856302 (0), 973891 (1), 980953 (2)
# testers:986737, 990622, 538363
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.96      0.83      0.89        60
#            1       0.75      0.90      0.82        20
#            2       0.79      0.95      0.86        20
#            3       0.95      0.95      0.95        20
#
#     accuracy                           0.88       120
#    macro avg       0.86      0.91      0.88       120
# weighted avg       0.90      0.88      0.89       120
#
# Epoch 1/25
# 125/125 [==============================] - 7s 18ms/step - loss: 1.0591 - categorical_accuracy: 0.6002
# Epoch 2/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.5548 - categorical_accuracy: 0.7857
# Epoch 3/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.3702 - categorical_accuracy: 0.8622
# Epoch 4/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2835 - categorical_accuracy: 0.8941
# Epoch 5/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2586 - categorical_accuracy: 0.9048
# Epoch 6/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.2199 - categorical_accuracy: 0.9179
# Epoch 7/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1845 - categorical_accuracy: 0.9311
# Epoch 8/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1656 - categorical_accuracy: 0.9397
# Epoch 9/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1776 - categorical_accuracy: 0.9348
# Epoch 10/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1485 - categorical_accuracy: 0.9462
# Epoch 11/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1405 - categorical_accuracy: 0.9464
# Epoch 12/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1274 - categorical_accuracy: 0.9528
# Epoch 13/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.1109 - categorical_accuracy: 0.9595
# Epoch 14/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0952 - categorical_accuracy: 0.9641
# Epoch 15/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0740 - categorical_accuracy: 0.9732
# Epoch 16/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0727 - categorical_accuracy: 0.9740
# Epoch 17/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0489 - categorical_accuracy: 0.9835
# Epoch 18/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0562 - categorical_accuracy: 0.9802
# Epoch 19/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0502 - categorical_accuracy: 0.9813
# Epoch 20/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0499 - categorical_accuracy: 0.9821
# Epoch 21/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0329 - categorical_accuracy: 0.9891
# Epoch 22/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0405 - categorical_accuracy: 0.9869
# Epoch 23/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0327 - categorical_accuracy: 0.9892
# Epoch 24/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0344 - categorical_accuracy: 0.9878
# Epoch 25/25
# 125/125 [==============================] - 2s 18ms/step - loss: 0.0138 - categorical_accuracy: 0.9963
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.13      0.23       888
#          1.0       0.27      0.89      0.42       296
#          2.0       0.75      0.86      0.80       296
#          3.0       0.92      1.00      0.96       296
#
#     accuracy                           0.53      1776
#    macro avg       0.69      0.72      0.60      1776
# weighted avg       0.73      0.53      0.48      1776
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 102, acceptance: 65, rejection: 37
# # of FA: 9
# # of FR: 0
# # of MI: 0
# FAR: 0.08823529411764706
# MIR: 0.0
# FRR: 0.0
# latency: 40266 ms
# ==== Session #1 ====
# # of detection: 205, acceptance: 160, rejection: 45
# # of FA: 4
# # of FR: 0
# # of MI: 0
# FAR: 0.01951219512195122
# MIR: 0.0
# FRR: 0.0
# latency: 6660 ms
# ==== Session #2 ====
# # of detection: 46, acceptance: 24, rejection: 22
# # of FA: 18
# # of FR: 0
# # of MI: 0
# FAR: 0.391304347826087
# MIR: 0.0
# FRR: 0.0
# latency: 41023 ms
# simulation result: FAR: 0.08781869688385269
# MIR: 0.0
# FNR: 0.0
# latency: 29316.333333333332 ms
# [touch] case: 75, er: 13, em: 11, fr: 41, mi: 9,
# [gait] case: 75, er: 14, em: 2, fr: 41, mi: 16,
# [simple_average] case: 75, er: 17, em: 4, fr: 45, mi: 9,
# ...
#
# file saved.
# ========== SETUP ===========
# Game name:100_5100_10_3_3
# Negative trainer seed:100
# Game seed:5100
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:621276 (0), 862649 (1), 897652 (2)
# testers:913228, 527796, 622852
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77        48
#            1       0.62      0.94      0.75        16
#            2       0.92      0.69      0.79        16
#            3       0.70      0.88      0.78        16
#
#     accuracy                           0.77        96
#    macro avg       0.77      0.80      0.77        96
# weighted avg       0.80      0.77      0.77        96
#
# Epoch 1/25
# 175/175 [==============================] - 8s 19ms/step - loss: 1.0841 - categorical_accuracy: 0.5450
# Epoch 2/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.7953 - categorical_accuracy: 0.6563
# Epoch 3/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.6159 - categorical_accuracy: 0.7546
# Epoch 4/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.5335 - categorical_accuracy: 0.7919
# Epoch 5/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.4547 - categorical_accuracy: 0.8259
# Epoch 6/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.4033 - categorical_accuracy: 0.8443
# Epoch 7/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3566 - categorical_accuracy: 0.8653
# Epoch 8/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.3018 - categorical_accuracy: 0.8849
# Epoch 9/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.2680 - categorical_accuracy: 0.8991
# Epoch 10/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.2212 - categorical_accuracy: 0.9182
# Epoch 11/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.1887 - categorical_accuracy: 0.9300
# Epoch 12/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.1629 - categorical_accuracy: 0.9397
# Epoch 13/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.1439 - categorical_accuracy: 0.9483
# Epoch 14/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.1209 - categorical_accuracy: 0.9563
# Epoch 15/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.1051 - categorical_accuracy: 0.9634
# Epoch 16/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0886 - categorical_accuracy: 0.9683
# Epoch 17/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0833 - categorical_accuracy: 0.9707
# Epoch 18/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0681 - categorical_accuracy: 0.9758
# Epoch 19/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0568 - categorical_accuracy: 0.9802
# Epoch 20/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0540 - categorical_accuracy: 0.9811
# Epoch 21/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0606 - categorical_accuracy: 0.9772
# Epoch 22/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0457 - categorical_accuracy: 0.9844
# Epoch 23/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0329 - categorical_accuracy: 0.9886
# Epoch 24/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0552 - categorical_accuracy: 0.9802
# Epoch 25/25
# 175/175 [==============================] - 3s 18ms/step - loss: 0.0579 - categorical_accuracy: 0.9781
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.63      0.74      1242
#          1.0       0.42      0.85      0.56       414
#          2.0       0.79      0.86      0.83       414
#          3.0       0.96      0.70      0.81       414
#
#     accuracy                           0.72      2484
#    macro avg       0.76      0.76      0.73      2484
# weighted avg       0.80      0.72      0.74      2484
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 40, acceptance: 25, rejection: 15
# # of FA: 16
# # of FR: 4
# # of MI: 0
# FAR: 0.4
# MIR: 0.0
# FRR: 0.1
# latency: 92425 ms
# ==== Session #1 ====
# # of detection: 57, acceptance: 28, rejection: 29
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.14035087719298245
# MIR: 0.0
# FRR: 0.0
# latency: 51407 ms
# ==== Session #2 ====
# # of detection: 49, acceptance: 36, rejection: 13
# # of FA: 15
# # of FR: 0
# # of MI: 0
# FAR: 0.30612244897959184
# MIR: 0.0
# FRR: 0.0
# latency: 42066 ms
# simulation result: FAR: 0.2671232876712329
# MIR: 0.0
# FNR: 0.0273972602739726
# latency: 61966.0 ms
# [touch] case: 156, er: 29, em: 18, fr: 89, mi: 17,
# [gait] case: 156, er: 24, em: 8, fr: 91, mi: 30,
# [simple_average] case: 156, er: 35, em: 6, fr: 96, mi: 19,
# [weighted_average_eer] case: 156, er: 24, em: 7, fr: 101, mi: 24,
# [weighted_average_auc] case: 156, er: 30, em: 6, fr: 100, mi: 20,
# [deer_dempster_shafer] case: 156, er: 21, em: 5, fr: 118, mi: 12,
# [auc_dempster_shafer] case: 156, er: 21, em: 5, fr: 119, mi: 11,
# [kalman_filter] case: 156, er: 33, em: 6, fr: 104, mi: 13,
#
# file saved.
# ========== SETUP ===========
# Game name:100_5200_10_3_3
# Negative trainer seed:100
# Game seed:5200
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:737973 (0), 923862 (1), 720193 (2)
# testers:913228, 336172, 876011
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.72      0.75      0.73        48
#            1       1.00      0.19      0.32        16
#            2       0.42      0.50      0.46        16
#            3       0.58      0.88      0.70        16
#
#     accuracy                           0.64        96
#    macro avg       0.68      0.58      0.55        96
# weighted avg       0.69      0.64      0.61        96
#
# Epoch 1/25
# 80/80 [==============================] - 5s 18ms/step - loss: 1.0359 - categorical_accuracy: 0.6035
# Epoch 2/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.5537 - categorical_accuracy: 0.7909
# Epoch 3/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3729 - categorical_accuracy: 0.8653
# Epoch 4/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.3038 - categorical_accuracy: 0.8891
# Epoch 5/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2578 - categorical_accuracy: 0.9078
# Epoch 6/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.2111 - categorical_accuracy: 0.9257
# Epoch 7/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1855 - categorical_accuracy: 0.9341
# Epoch 8/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1529 - categorical_accuracy: 0.9451
# Epoch 9/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1586 - categorical_accuracy: 0.9427
# Epoch 10/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1553 - categorical_accuracy: 0.9427
# Epoch 11/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.1010 - categorical_accuracy: 0.9634
# Epoch 12/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0944 - categorical_accuracy: 0.9656
# Epoch 13/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0839 - categorical_accuracy: 0.9694
# Epoch 14/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0977 - categorical_accuracy: 0.9650
# Epoch 15/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0683 - categorical_accuracy: 0.9767
# Epoch 16/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0696 - categorical_accuracy: 0.9775
# Epoch 17/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0932 - categorical_accuracy: 0.9677
# Epoch 18/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0338 - categorical_accuracy: 0.9885
# Epoch 19/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0204 - categorical_accuracy: 0.9953
# Epoch 20/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0157 - categorical_accuracy: 0.9968
# Epoch 21/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0435 - categorical_accuracy: 0.9839
# Epoch 22/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0249 - categorical_accuracy: 0.9923
# Epoch 23/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0528 - categorical_accuracy: 0.9811
# Epoch 24/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0304 - categorical_accuracy: 0.9899
# Epoch 25/25
# 80/80 [==============================] - 1s 18ms/step - loss: 0.0317 - categorical_accuracy: 0.9903
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.53      0.67       561
#          1.0       0.73      1.00      0.85       187
#          2.0       0.51      0.94      0.66       187
#          3.0       0.83      0.90      0.86       187
#
#     accuracy                           0.74      1122
#    macro avg       0.75      0.84      0.76      1122
# weighted avg       0.81      0.74      0.73      1122
#
# training done
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 60, acceptance: 60, rejection: 0
# # of FA: 27
# # of FR: 0
# # of MI: 0
# FAR: 0.45
# MIR: 0.0
# FRR: 0.0
# latency: 38439 ms
# ==== Session #1 ====
# # of detection: 130, acceptance: 49, rejection: 81
# # of FA: 8
# # of FR: 0
# # of MI: 0
# FAR: 0.06153846153846154
# MIR: 0.0
# FRR: 0.0
# latency: 25971 ms
# ==== Session #2 ====
# # of detection: 53, acceptance: 53, rejection: 0
# # of FA: 18
# # of FR: 0
# # of MI: 0
# FAR: 0.33962264150943394
# MIR: 0.0
# FRR: 0.0
# latency: 26168 ms
# simulation result: FAR: 0.21810699588477367
# MIR: 0.0
# FNR: 0.0
# latency: 30192.666666666668 ms
# [touch] case: 159, er: 30, em: 18, fr: 91, mi: 17,
# [gait] case: 159, er: 24, em: 8, fr: 92, mi: 32,
# [simple_average] case: 159, er: 35, em: 6, fr: 97, mi: 21,
# [weighted_average_eer] case: 159, er: 24, em: 7, fr: 102, mi: 26,
# [weighted_average_auc] case: 159, er: 30, em: 6, fr: 101, mi: 22,
# [deer_dempster_shafer] case: 159, er: 21, em: 5, fr: 119, mi: 14,
# [auc_dempster_shafer] case: 159, er: 21, em: 5, fr: 121, mi: 12,
# [kalman_filter] case: 159, er: 33, em: 6, fr: 105, mi: 15,
#
# file saved.
# ========== SETUP ===========
# Game name:100_5300_10_3_3
# Negative trainer seed:100
# Game seed:5300
# trainers:815316, 776328, 261313, 326223, 501973, 879155, 389015, 525584, 240168, 675397
# users:986737 (0), 720193 (1), 785873 (2)
# testers:248252, 220962, 733568
#
# Load data to memory. It may take up to 5 minutes...
# User already registered.
# User already registered.
# User already registered.
# touch
#               precision    recall  f1-score   support
#
#            0       0.86      0.71      0.78        45
#            1       0.72      0.87      0.79        15
#            2       0.53      0.67      0.59        15
#            3       0.62      0.67      0.65        15
#
#     accuracy                           0.72        90
#    macro avg       0.68      0.73      0.70        90
# weighted avg       0.74      0.72      0.73        90
#
# Epoch 1/25
# 123/123 [==============================] - 6s 18ms/step - loss: 0.9581 - categorical_accuracy: 0.6255
# Epoch 2/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.5200 - categorical_accuracy: 0.8041
# Epoch 3/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.3957 - categorical_accuracy: 0.8583
# Epoch 4/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.3089 - categorical_accuracy: 0.8903
# Epoch 5/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.2563 - categorical_accuracy: 0.9090
# Epoch 6/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.1959 - categorical_accuracy: 0.9312
# Epoch 7/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.1529 - categorical_accuracy: 0.9458
# Epoch 8/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.1219 - categorical_accuracy: 0.9584
# Epoch 9/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0985 - categorical_accuracy: 0.9659
# Epoch 10/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0825 - categorical_accuracy: 0.9719
# Epoch 11/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0713 - categorical_accuracy: 0.9749
# Epoch 12/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0483 - categorical_accuracy: 0.9846
# Epoch 13/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0370 - categorical_accuracy: 0.9886
# Epoch 14/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0599 - categorical_accuracy: 0.9800
# Epoch 15/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0392 - categorical_accuracy: 0.9874
# Epoch 16/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0299 - categorical_accuracy: 0.9917
# Epoch 17/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0172 - categorical_accuracy: 0.9953
# Epoch 18/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0197 - categorical_accuracy: 0.9942
# Epoch 19/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0099 - categorical_accuracy: 0.9976
# Epoch 20/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0046 - categorical_accuracy: 0.9993
# Epoch 21/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0033 - categorical_accuracy: 0.9994
# Epoch 22/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0026 - categorical_accuracy: 0.9996
# Epoch 23/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0023 - categorical_accuracy: 0.9997
# Epoch 24/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0014 - categorical_accuracy: 0.9999
# Epoch 25/25
# 123/123 [==============================] - 2s 18ms/step - loss: 0.0011 - categorical_accuracy: 0.9997
# gait
#               precision    recall  f1-score   support
#
#          0.0       0.93      0.84      0.88       870
#          1.0       0.97      0.96      0.96       290
#          2.0       0.80      0.88      0.84       290
#          3.0       0.70      0.85      0.77       290
#
#     accuracy                           0.87      1740
#    macro avg       0.85      0.88      0.86      1740
# weighted avg       0.88      0.87      0.87      1740
#
# training done
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# current session does not belong to a valid user, discarded
# Not found
# ==== Session #0 ====
# # of detection: 93, acceptance: 47, rejection: 46
# # of FA: 7
# # of FR: 0
# # of MI: 0
# FAR: 0.07526881720430108
# MIR: 0.0
# FRR: 0.0
# latency: 22666 ms
# ==== Session #1 ====
# # of detection: 56, acceptance: 40, rejection: 16
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.08928571428571429
# MIR: 0.0
# FRR: 0.0
# latency: 26168 ms
# ==== Session #2 ====
# # of detection: 70, acceptance: 29, rejection: 41
# # of FA: 5
# # of FR: 0
# # of MI: 0
# FAR: 0.07142857142857142
# MIR: 0.0
# FRR: 0.0
# latency: 51288 ms
# simulation result: FAR: 0.0776255707762557
# MIR: 0.0
# FNR: 0.0
# latency: 33374.0 ms
# [touch] case: 162, er: 31, em: 18, fr: 92, mi: 18,
# [gait] case: 162, er: 24, em: 8, fr: 95, mi: 32,
# [simple_average] case: 162, er: 35, em: 6, fr: 100, mi: 21,
# [weighted_average_eer] case: 162, er: 24, em: 7, fr: 105, mi: 26,
# [weighted_average_auc] case: 162, er: 30, em: 6, fr: 104, mi: 22,
# [deer_dempster_shafer] case: 162, er: 21, em: 5, fr: 122, mi: 14,
# [auc_dempster_shafer] case: 162, er: 21, em: 5, fr: 124, mi: 12,
# [kalman_filter] case: 162, er: 33, em: 6, fr: 108, mi: 15,
#
# file saved.

# %% [markdown]
# # Experiment 3: Robustness (Data and class incremental)

# %%
def run_topic_robustness_type_cmp(game_seed=0):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================


    num_testers = 0
    num_valid_users = 3

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "robust" + "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                                     str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)


    player2 = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)
    player2.set_flag_store_history(False) # player2 never learn

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    # for user in valid_users:
    #     gait_sessions = hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

    #     touch_sessions = hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

    #     enrollment_script_type_1.append((user, 'gait', gait_sessions))
    #     enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR OWNER
    user = valid_users[0]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:2]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:2] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR VALID USER 1
    user = valid_users[1]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))

    tf.random.set_seed(game_seed)
    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")

    tf.random.set_seed(game_seed)
    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player2.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player2.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player2.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================


    np.random.seed(0)
    lengths = np.random.randint(120000,300000, 20)


    # Part 1: owner - user 1

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[0])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[1])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    # Part 2: new user
    user = valid_users[2]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    user_info = [user]
    for session in gait_sessions:
        user_info += ['gait', session]
    for session in touch_sessions :
        user_info += ['touch', session]
    tml.add_special_event(EVENT_ADD_USER, user_info)

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[2])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[3])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[4])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    ## Part 3 New data
    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[5])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[6])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[7])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])


    # for user_a in valid_users:
    #     i = 1
    #     for user_b in valid_users:
    #         if user_a == user_b:
    #             continue
    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_a,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_a, sel_session, tml.end_time)
    #         tml.add_special_event(EVENT_SESSION_START, [])
    #         tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_b,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_b, sel_session, tml.end_time)
    #         tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
    #         # tml.add_special_event(EVENT_SESSION_END)
    #         # tml.add_special_event(EVENT_TRAIN_MODELS)
    #         tml.add_special_event(EVENT_SESSION_END, [])
    #         i = i + 1


    # ===============================================
    # 5. One line running script
    # ===============================================
    np.random.seed(game_seed)
    tf.random.set_seed(game_seed)
    results = script_runner(tml, player)
    np.random.seed(game_seed)
    tf.random.set_seed(game_seed)
    results2 = script_runner(tml, player2)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    print("===> simulator 1 <===")
    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    print("===> simulator 2 <===")

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results2):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)


    return tml, player, player2

# %%
def run_topic_robustness_type_1(game_seed=0):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================

    num_testers = 0
    num_valid_users = 3

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "robust" + "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                                     str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    # for user in valid_users:
    #     gait_sessions = hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

    #     touch_sessions = hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

    #     enrollment_script_type_1.append((user, 'gait', gait_sessions))
    #     enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR OWNER
    user = valid_users[0]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:2]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:2] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR VALID USER 1
    user = valid_users[1]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))



    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================


    # Part 1: owner - user 1

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    # Part 2: new user
    user = valid_users[2]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    user_info = [user]
    for session in gait_sessions:
        user_info += ['gait', session]
    for session in touch_sessions :
        user_info += ['touch', session]
    tml.add_special_event(EVENT_ADD_USER, user_info)

    np.random.seed(seed)
    lengths = np.random.randint(120000,300000, 10) # 2 to 5 minutes

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    ## Part 3 New data
    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session(user, sel_session, tml.end_time)
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])


    # for user_a in valid_users:
    #     i = 1
    #     for user_b in valid_users:
    #         if user_a == user_b:
    #             continue
    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_a,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_a, sel_session, tml.end_time)
    #         tml.add_special_event(EVENT_SESSION_START, [])
    #         tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_b,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_b, sel_session, tml.end_time)
    #         tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
    #         # tml.add_special_event(EVENT_SESSION_END)
    #         # tml.add_special_event(EVENT_TRAIN_MODELS)
    #         tml.add_special_event(EVENT_SESSION_END, [])
    #         i = i + 1


    # ===============================================
    # 5. One line running script
    # ===============================================

    results = script_runner(tml, player)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    return tml, player

# %%
for i in range(0, 5000, 100):
    tml, player = run_topic_robustness_type_1(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_new_1", str(i)))

# %%
for i in range(2000, 5000, 100):
    tml, player = run_topic_robustness_type_1(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_1", str(i)))

# %%
def run_topic_robustness_type_2(game_seed=0):
     # ================================================
    # 1. SETUP A GAME AND VIEW BASIC INFORMATION
    # ================================================

    num_testers = 0
    num_valid_users = 3

    testers = hmog.gen_user_set(num_testers, exclude=trainers,
                                random_state=game_seed)
    valid_users = hmog.gen_user_set(num_valid_users,
                                    exclude=trainers + testers,
                                    random_state=game_seed)

    all_users = trainers + testers + valid_users

    train_test_dict = hmog.gen_multiuser_train_test_sessions(all_users, 1,
                                                             random_state=game_seed)
    game_name = "robust" + "_".join([str(trainer_seed), str(game_seed), str(num_trainers),
                                     str(num_testers), str(num_valid_users)])


    summary = "========== SETUP ===========\n"
    summary += "Game name:" + game_name + "\n"
    summary += "Negative trainer seed:" + str(trainer_seed) + "\n"
    summary += "Game seed:" + str(game_seed) + "\n"
    summary += "trainers:" + ", ".join(trainers) + "\n"
    summary += "users:" + ", ".join([u + " (" + str(i) + ")"
                                     for i, u in enumerate(valid_users)]) + "\n"
    summary += "testers:" + ", ".join(testers) + "\n"

    # ================================================
    # 1.5 SHOW GAME DETAILS (SESSION DISTRIBUTION)
    # ================================================

    if GAME_DETAILS_ENABELD:
        summary += "\n========== DETAILS ===========\n"
        for user, train_test in train_test_dict.items():
            summary += user + "\n"
            summary += "  Training sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['train'][no]]) + "\n"
            summary += "  Testing sessions: \n"
            for no, activity in ACTIVITIES:
                summary += "    " + activity + ": " + ", ".join(
                    [str(session) for session in
                     train_test['test'][no]]) + "\n"

    print(summary)

    # ===============================================
    # 2. LOAD DATA AND PRETRAINED MODELS
    # ===============================================

    print("Load data to memory. It may take up to 5 minutes...")
    hmog.load(all_users)

    player = TestPlayer(authenticators={
        'touch': TouchAuth(),
        'gait': DeepGaitAuthenticator(profile={'batch_size': 128, 'epochs': 25})
    }, imposter_set=imposter_set)

    # ===============================================
    # 3. SCRIPT INIT
    # ===============================================
    enrollment_script_type_1 = []

    # for user in valid_users:
    #     gait_sessions = hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_READING_WALKING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user,[hmog.ACTIVITY_WRITING_WALKING])[:n_train_session]

    #     touch_sessions = hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_SITTING])[:n_train_session] \
    #         + hmog.get_sessions_for_unloaded_user(
    #         user, [hmog.ACTIVITY_READING_WALKING])[:n_train_session]

    #     enrollment_script_type_1.append((user, 'gait', gait_sessions))
    #     enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR OWNER
    user = valid_users[0]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:2]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:2] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))

    ## FOR VALID USER 1
    user = valid_users[1]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    enrollment_script_type_1.append((user, 'gait', gait_sessions))
    enrollment_script_type_1.append((user, 'touch', touch_sessions))



    for user, auth_type, sessions in enrollment_script_type_1:
        # print("try to add", user)
        player.add_user(user)
        for sess in sessions:
            feature = get_features(hmog, auth_type, user, sess)
            # print(player.storage.data.keys())
            player.storage.add_session_data(user, auth_type, feature)
    # print(player.user_profile)
    player.train_all()
    print("training done")


    tml = Timeline()
    # ===============================================
    # 4. STORY
    # ===============================================

    np.random.seed(seed)
    lengths = np.random.randint(120000,300000, 20)


    # Part 1: owner - user 1

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[0])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[1])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    # Part 2: new user
    user = valid_users[2]
    gait_sessions = hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_READING_WALKING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user,[hmog.ACTIVITY_WRITING_WALKING])[:1]

    touch_sessions = hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_SITTING])[:1] \
            + hmog.get_sessions_for_unloaded_user(
            user, [hmog.ACTIVITY_READING_WALKING])[:1]

    user_info = [user]
    for session in gait_sessions:
        user_info += ['gait', session]
    for session in touch_sessions :
        user_info += ['touch', session]
    tml.add_special_event(EVENT_ADD_USER, user_info)

    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[2])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[3])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[1]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[4])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])
    tml.add_special_event(EVENT_TRAIN_MODELS, [])

    ## Part 3 New data
    user = valid_users[0]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[5])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[1]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user, [hmog.ACTIVITY_READING_WALKING])[3]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[6])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])

    user = valid_users[2]
    sel_session = hmog.get_sessions_for_unloaded_user(
                user,[hmog.ACTIVITY_READING_WALKING])[2]
    events = get_events_for_user_session_with_limit(user, sel_session, tml.end_time, lengths[7])
    tml.add_special_event(EVENT_SESSION_START, [])
    tml.add_user_session(user, hmog.ACTIVITY_READING_WALKING, events)
    tml.add_special_event(EVENT_SESSION_END, [])


    # for user_a in valid_users:
    #     i = 1
    #     for user_b in valid_users:
    #         if user_a == user_b:
    #             continue
    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_a,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_a, sel_session, tml.end_time)
    #         tml.add_special_event(EVENT_SESSION_START, [])
    #         tml.add_user_session(user_a, hmog.ACTIVITY_READING_WALKING, events)

    #         sel_session = hmog.get_sessions_for_unloaded_user(
    #             user_b,[hmog.ACTIVITY_READING_WALKING])[-i]
    #         events = get_events_for_user_session(user_b, sel_session, tml.end_time)
    #         tml.add_user_session(user_b, hmog.ACTIVITY_READING_WALKING, events)
    #         # tml.add_special_event(EVENT_SESSION_END)
    #         # tml.add_special_event(EVENT_TRAIN_MODELS)
    #         tml.add_special_event(EVENT_SESSION_END, [])
    #         i = i + 1


    # ===============================================
    # 5. One line running script
    # ===============================================

    results = script_runner(tml, player)

    # ===============================================
    # 6. Metrics and Report Saving
    # ===============================================

    total_result = {
        'num_detection': 0,
        'num_accept': 0,
        'num_reject': 0,
        'num_fn': 0,
        'num_fp': 0,
        'num_mc': 0,
        'delay': []
    }

    for i, result in enumerate(results):
        to_show = "==== Session #" + str(i) + " ====\n"
        to_show += "# of detection: " + str(result['num_detection']) + ", "
        to_show += "acceptance: " + str(result['num_accept']) + ", "
        to_show += "rejection: " + str(result['num_reject']) + "\n"
        to_show += "# of FA: " + str(result['num_fp']) + "\n"
        to_show += "# of FR: " + str(result['num_fn']) + "\n"
        to_show += "# of MI: " + str(result['num_mc']) + "\n"
        if result['num_detection'] > 0:
            to_show += "FAR: " + str(result['num_fp'] / result['num_detection']) + "\n"
            to_show += "MIR: " + str(result['num_mc'] / result['num_detection']) + "\n"
            to_show += "FRR: " + str(result['num_fn'] / result['num_detection']) + "\n"

        to_show += "latency: " + str(result['delay']) + " ms"
        print(to_show)

        total_result['num_detection'] += result['num_detection']
        total_result['num_accept'] += result['num_accept']
        total_result['num_reject'] += result['num_reject']
        total_result['num_fp'] += result['num_fp']
        total_result['num_fn'] += result['num_fn']
        total_result['num_mc'] += result['num_mc']
        total_result['delay'].append(result['delay'])

    to_show = "simulation result: "
    if total_result['num_detection'] > 0:
        to_show += "FAR: " + str(total_result['num_fp'] / total_result['num_detection']) + "\n"
        to_show += "MIR: " + str(total_result['num_mc'] / total_result['num_detection']) + "\n"
        to_show += "FNR: " + str(total_result['num_fn'] / total_result['num_detection']) + "\n"
    to_show += "latency: " + str(np.average(total_result['delay'])) + " ms"
    print(to_show)

    return tml, player

# %%
for i in range(10000, 15000, 100):
    tml, player = run_topic_robustness_type_2(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_new_2", str(i)))

# %%
for i in range(0, 10000, 100):
    tml, player = run_topic_robustness_type_2(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_new_2", str(i)))

# %%
for i in range(9400, 10000, 100):
    tml, player, player2 = run_topic_robustness_type_cmp(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_new_cmp_1", str(i)))
    save_experiment_data(player2, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_new_cmp_2", str(i)))

# %%
for i in range(8000, 10000, 100):
    tml, player, player2 = run_topic_robustness_type_cmp(i)
    save_experiment_data(player, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_cmp_2_1", str(i)))
    save_experiment_data(player2, tml, os.path.join("/content/drive/MyDrive/muia_experiment_results/robustness_cmp_2_2", str(i)))
